# %% [markdown]
# # **Use the stopwords file from after section 8 to proceed with model building**

# %% [markdown]
# # Importing the relevant libraries

# %%
import tensorflow
import os
import pandas as pd
import numpy as np
# %tensorflow_version
# Out:
# Currently selected TF version: 2.x
# Available versions:
# * 1.x
# * 2.x

# %% [markdown]
# ### Define file path & prepare the Drive and current working directory

# %%
file_input = '1_input_data.xlsx'
file_input_translated = "input_data_translated.xlsx"
from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/My Drive/'
os.chdir( file_path )
os.getcwd()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/My Drive'

# %% [markdown]
# ### Read the input excel

# %%
df= pd.read_excel(file_input)

# %%
df.shape
# Out:
# (8500, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8500 entries, 0 to 8499
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Short description  8492 non-null   object
#  1   Description        8499 non-null   object
#  2   Caller             8500 non-null   object
#  3   Assignment group   8500 non-null   object
# dtypes: object(4)
# memory usage: 265.8+ KB

# %% [markdown]
# # 1. Missing Values
# ### 1. Handle the missing values in the "Short Description" and "Description" field,
#
# ### 2. Process the short description and description columns separately
#
# ### 3. Missing values in short Description can be removed if we consider only the short description as our independent variable
#
# ### 4. Missing values in Description, one way would be to fill it with the text available in the short description if available or drop the row if not

# %%
df.isna().sum()
# Out:
# Short description    8
# Description          1
# Caller               0
# Assignment group     0
# dtype: int64

# %% [markdown]
# 1a.  Dropping the 8 null values in Short description

# %%
short_desc_idx = df[df['Short description'].isnull() == True].index.tolist()

# %%
short_desc_idx
# Out:
# [2604, 3383, 3906, 3910, 3915, 3921, 3924, 4341]

# %%
df = df.drop(short_desc_idx,axis=0)

# %%
df.isna().sum()
# Out:
# Short description    0
# Description          1
# Caller               0
# Assignment group     0
# dtype: int64

# %%
print(df[df['Description'].isnull() == True].index)
# Out:
# Int64Index([4395], dtype='int64')

# %% [markdown]
# 1b.  Replacing the null Description with the Short description

# %%
df.iloc[4395]['Description'] = df.iloc[4395]['Short description']
print(df.iloc[4395])
# Out:
# Short description    erp SID_39 password reset
# Description          erp SID_39 password reset
# Caller                       rqtmpjdb ohitelsg
# Assignment group                         GRP_0
# Name: 4403, dtype: object

# %%
df[df['Description'] == 0].index
# Out:
# Int64Index([], dtype='int64')

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#                Short description  ... Assignment group
# 0                    login issue  ...            GRP_0
# 1                        outlook  ...            GRP_0
# 2             cant log in to vpn  ...            GRP_0
# 3  unable to access hr_tool page  ...            GRP_0
# 4                   skype error   ...            GRP_0
#
# [5 rows x 4 columns]

# %%
df.to_excel("testingInd.xlsx",index=True)

# %% [markdown]
# ### 2. Duplicate values in Short description & Description
# Find indices that have the Short description and Description fields the same, we will ignore these indices while concatenating

# %%
duplicate_list = []
for l in range(len(df)):
  if df.iloc[l]['Description'] == df.iloc[l]['Short description']:
    # print(df.iloc[l]['Description'])
    # print(df.iloc[l]['Short description'])
    duplicate_list.append(l)

# %%
duplicate_df = pd.DataFrame(duplicate_list)

# %%
duplicate_df.to_pickle("duplicates.pkl")

# %%
len(duplicate_list)
# Out:
# 2862

# %% [markdown]
# We will use duplicate_list for the indices that should not be concatented (Short description + Description)

# %% [markdown]
# # 3. Standardize the encoding to utf-8
#
# ## Unable to encode to ANSI in Colab but possible in windows machine

# %%
# !pip install chardet    #library for detecting the encoding
# Out:
# Requirement already satisfied: chardet in /usr/local/lib/python3.6/dist-packages (3.0.4)

# %%
import chardet

# %%
idx_list_enc = [(x,chardet.detect(str(df.iloc[x]['Description']).encode())['encoding']) for x in range(len(df))]

# %%
df_enc = pd.DataFrame(idx_list_enc,columns = ['index','encoding'])

# %%
df_enc['encoding'].unique()
# Out:
# array(['ascii', 'utf-8', 'Windows-1254'], dtype=object)

# %%
df_enc['encoding'].value_counts()
# Out:
# ascii           7674
# utf-8            817
# Windows-1254       1
# Name: encoding, dtype: int64

# %%
df_enc[df_enc['encoding'] == 'Windows-1254'].index
# Out:
# Int64Index([1344], dtype='int64')

# %%
print(df.iloc[1344]['Description'])
print(df.iloc[1344]['Description'].encode('Windows-1254').decode('utf8'))
# Out:
# einlasten bei it-germany, da hierfÃ¼r bereits ein ersatz-pc verbaut ist und ein neuer bestellt wurde.
# einlasten bei it-germany, da hierfür bereits ein ersatz-pc verbaut ist und ein neuer bestellt wurde.

# %%
df['Description'][1344] = df['Description'][1344].encode('Windows-1254').decode('utf8')
df['Short description'][1344] = df['Short description'][1344].encode('Windows-1254').decode('utf8')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.iloc[1344]
# Out:
# index                                                             1344
# Short description    pc an r241 in halle c nähe büro nesner fährt n...
# Description          einlasten bei it-germany, da hierfür bereits e...
# Caller                                               dtrvxiuq bwuqdtfo
# Assignment group                                                GRP_33
# Name: 1344, dtype: object

# %%
df.shape
# Out:
# (8492, 5)

# %% [markdown]
# **Run** **the below code on Windows machine**
#
# *Problem 1 : Need to figure out a way to handle encoding from ANSI to decoding to utf-8*

# %%
# for idx in range(len(df)):
#   df['Description'][idx] = df.iloc[idx]['Description'].encode('ANSI').decode('utf8')
#   df['Short description'][idx] = df.iloc[idx]['Short description'].encode('ANSI').decode('utf8')

# %% [markdown]
# **Importing the ansi encoded/utf decoded text from local machine**

# %%
df = pd.read_excel("ansi_encoded_utf8_decoded.xlsx",index_col=0)

# %%
df_inbetween = pd.read_excel("ansi_encoded_utf8_decoded_v1.xlsx",index_col=0)

# %%
utf = [1554,3643,3645,3674,4876,5456,5819,5827]

# %%
for c in utf:
  df['Short description'][c] = df_inbetween['Short description'][c]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for c in utf:
 print(df['Short description'][c])
# Out:
# 答复: ticket_no1559458 : wireless guest access- hr_tool trainer
# 答复: 答复: order products online problem
# 答复: 答复: order products online problem
# erro programdntya docad
# 答复: shipments iak
# 答复: 35969737/2032252
# 答复: ticket_no1538811::company center authorization
# 答复: ticket_no1538811::company center authorization

# %%
df.to_excel("ansi_encoded_utf8_decoded_v2.xlsx")

# %%
df = pd.read_excel("ansi_encoded_utf8_decoded_v3.xlsx",index_col=0)

# %%
df = pd.read_excel("ansi_encoded_utf8_decoded_v4.xlsx",index_col=0)

# %%
df.shape
# Out:
# (8492, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8492 entries, 0 to 8491
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Short description  8492 non-null   object
#  1   Description        8492 non-null   object
#  2   Caller             8492 non-null   object
#  3   Assignment group   8492 non-null   object
# dtypes: object(4)
# memory usage: 331.7+ KB

# %% [markdown]
# # 4. Translating the other languages to English using Googletrans

# %%
import time

# %%
# !pip install googletrans
# Out:
# Requirement already satisfied: googletrans in /usr/local/lib/python3.6/dist-packages (3.0.0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.6/dist-packages (from googletrans) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from httpx==0.13.3->googletrans) (2020.6.20)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.6/dist-packages (from httpx==0.13.3->googletrans) (1.4.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.6/dist-packages (from httpx==0.13.3->googletrans) (0.9.1)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.6/dist-packages (from httpx==0.13.3->googletrans) (2.10)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.6/dist-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.6/dist-packages (from httpx==0.13.3->googletrans) (2020.8.25)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.6/dist-packages (from httpx==0.13.3->googletrans) (1.1.0)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.6/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.6/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (3.2.0)
# Requirement already satisfied: contextvars>=2.1; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from sniffio->httpx==0.13.3->googletrans) (2.4)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.6/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.6/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (3.0.0)
# Requirement already satisfied: immutables>=0.9 in /usr/local/lib/python3.6/dist-packages (from contextvars>=2.1; python_version < "3.7"->sniffio->httpx==0.13.3->googletrans) (0.14)

# %%
from googletrans import Translator
translator = Translator()

# %% [markdown]
# **This code will run for almost 5-6 hours due to data size**

# %%
# count=0
# non_English = []
# for t in range(len(df)):
#   raw_text_desc = df['Description'][t]
#   flag_desc = translator.detect(raw_text_desc)
#   time.sleep(7)
#   if flag_desc.lang != 'en':
#     translation = translator.translate(raw_text_desc,dest='en')
#     non_English.append(t)
#     count+=1
#     df['Description'][t] = translation.text
#     print("language is : {} , confidence level is  : {}, index is : {} , text is : {}".format(flag_desc.lang,flag_desc.confidence,t,translation.text))
#   else:
#     print("language is : {} , confidence level is  : {}, index is : {}".format(flag_desc.lang,flag_desc.confidence,t))
# print("count : {}".format(count))

# %%
# non_English_df = pd.DataFrame(non_English)

# %%
# non_English_df

# %%
# non_English_df.to_pickle("Non_English_Indices.pkl")

# %% [markdown]
# **This wasn't run**

# %%
count=0
non_English_sd = []
for t in range(7960,len(df)):
  raw_text_sd = df['Short description'][t]
  #print(raw_text)
  flag_sd_desc = translator.detect(raw_text_sd)
  time.sleep(7)
  if flag_sd_desc.lang != 'en':
    translation = translator.translate(raw_text_sd,dest='en')
    count+=1
    df['Short description'][t] = translation.text
    non_English_sd.append(t)
    print("language is : {} , confidence level is  : {}, index is : {} , text is : {}".format(flag_sd_desc.lang,flag_sd_desc.confidence,t,translation.text))
  else:
    print("language is : {} , confidence level is  : {}, index is : {}".format(flag_sd_desc.lang,flag_sd_desc.confidence,t))
print("count : {}".format(count))
# Out:
# language is : en , confidence level is  : 1.0, index is : 7960
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# language is : zh-CN , confidence level is  : 1.0, index is : 7961 , text is : The online system provided by the customer cannot be opened
# language is : de , confidence level is  : 0.686801, index is : 7962 , text is : evening job in job scheduler: Job 1320
# language is : en , confidence level is  : 1.0, index is : 7963
# language is : en , confidence level is  : 0.98703134, index is : 7964
# language is : en , confidence level is  : 1.0, index is : 7965
# language is : en , confidence level is  : 1.0, index is : 7966
# language is : en , confidence level is  : 1.0, index is : 7967
# language is : en , confidence level is  : 1.0, index is : 7968
# language is : en , confidence level is  : 1.0, index is : 7969
# language is : en , confidence level is  : 0.98204625, index is : 7970
# language is : en , confidence level is  : 1.0, index is : 7971
# language is : en , confidence level is  : 1.0, index is : 7972
# language is : en , confidence level is  : 1.0, index is : 7973
# language is : en , confidence level is  : 1.0, index is : 7974
# language is : en , confidence level is  : 1.0, index is : 7975
# language is : en , confidence level is  : 1.0, index is : 7976
# language is : en , confidence level is  : 1.0, index is : 7977
# language is : en , confidence level is  : 1.0, index is : 7978
# language is : en , confidence level is  : 1.0, index is : 7979
# language is : en , confidence level is  : 1.0, index is : 7980
# language is : en , confidence level is  : 1.0, index is : 7981
# language is : en , confidence level is  : 1.0, index is : 7982
# language is : en , confidence level is  : 1.0, index is : 7983
# language is : en , confidence level is  : 1.0, index is : 7984
# language is : en , confidence level is  : 1.0, index is : 7985
# language is : en , confidence level is  : 1.0, index is : 7986
# language is : en , confidence level is  : 1.0, index is : 7987
# language is : en , confidence level is  : 1.0, index is : 7988
# language is : en , confidence level is  : 1.0, index is : 7989
# language is : en , confidence level is  : 1.0, index is : 7990
# language is : en , confidence level is  : 1.0, index is : 7991
# language is : en , confidence level is  : 0.91337967, index is : 7992
# language is : en , confidence level is  : 1.0, index is : 7993
# language is : en , confidence level is  : 1.0, index is : 7994
# language is : en , confidence level is  : 0.98815846, index is : 7995
# language is : en , confidence level is  : 0.94495505, index is : 7996
# language is : en , confidence level is  : 1.0, index is : 7997
# language is : en , confidence level is  : 1.0, index is : 7998
# language is : en , confidence level is  : 1.0, index is : 7999
# language is : en , confidence level is  : 1.0, index is : 8000
# language is : en , confidence level is  : 1.0, index is : 8001
# language is : en , confidence level is  : 1.0, index is : 8002
# language is : en , confidence level is  : 1.0, index is : 8003
# language is : en , confidence level is  : 1.0, index is : 8004
# language is : en , confidence level is  : 1.0, index is : 8005
# language is : en , confidence level is  : 1.0, index is : 8006
# language is : en , confidence level is  : 1.0, index is : 8007
# language is : en , confidence level is  : 1.0, index is : 8008
# language is : en , confidence level is  : 1.0, index is : 8009
# language is : en , confidence level is  : 1.0, index is : 8010
# language is : en , confidence level is  : 1.0, index is : 8011
# language is : en , confidence level is  : 1.0, index is : 8012
# language is : en , confidence level is  : 1.0, index is : 8013
# language is : en , confidence level is  : 0.98251754, index is : 8014
# language is : en , confidence level is  : 1.0, index is : 8015
# language is : en , confidence level is  : 1.0, index is : 8016
# language is : en , confidence level is  : 1.0, index is : 8017
# language is : en , confidence level is  : 1.0, index is : 8018
# language is : en , confidence level is  : 1.0, index is : 8019
# language is : en , confidence level is  : 0.98251754, index is : 8020
# language is : en , confidence level is  : 1.0, index is : 8021
# language is : en , confidence level is  : 1.0, index is : 8022
# language is : en , confidence level is  : 1.0, index is : 8023
# language is : en , confidence level is  : 1.0, index is : 8024
# language is : en , confidence level is  : 1.0, index is : 8025
# language is : pt , confidence level is  : 1.0, index is : 8026 , text is : outlook is not working.
# language is : en , confidence level is  : 1.0, index is : 8027
# language is : en , confidence level is  : 1.0, index is : 8028
# language is : en , confidence level is  : 1.0, index is : 8029
# language is : en , confidence level is  : 1.0, index is : 8030
# language is : en , confidence level is  : 1.0, index is : 8031
# language is : en , confidence level is  : 0.9879023, index is : 8032
# language is : en , confidence level is  : 1.0, index is : 8033
# language is : en , confidence level is  : 1.0, index is : 8034
# language is : en , confidence level is  : 0.7206448, index is : 8035
# language is : en , confidence level is  : 1.0, index is : 8036
# language is : en , confidence level is  : 1.0, index is : 8037
# language is : en , confidence level is  : 1.0, index is : 8038
# language is : en , confidence level is  : 1.0, index is : 8039
# language is : en , confidence level is  : 0.9253992, index is : 8040
# language is : es , confidence level is  : 0.8800081, index is : 8041 , text is : review pc lpaw8515845 (g0rfv12) usadtto dfsdby ffthhiago frsilva
# language is : en , confidence level is  : 1.0, index is : 8042
# language is : en , confidence level is  : 1.0, index is : 8043
# language is : en , confidence level is  : 1.0, index is : 8044
# language is : en , confidence level is  : 1.0, index is : 8045
# language is : en , confidence level is  : 0.98251754, index is : 8046
# language is : en , confidence level is  : 1.0, index is : 8047
# language is : en , confidence level is  : 1.0, index is : 8048
# language is : en , confidence level is  : 1.0, index is : 8049
# language is : en , confidence level is  : 1.0, index is : 8050
# language is : en , confidence level is  : 1.0, index is : 8051
# language is : en , confidence level is  : 1.0, index is : 8052
# language is : en , confidence level is  : 1.0, index is : 8053
# language is : en , confidence level is  : 1.0, index is : 8054
# language is : en , confidence level is  : 1.0, index is : 8055
# language is : en , confidence level is  : 1.0, index is : 8056
# language is : en , confidence level is  : 1.0, index is : 8057
# language is : en , confidence level is  : 1.0, index is : 8058
# language is : en , confidence level is  : 1.0, index is : 8059
# language is : en , confidence level is  : 1.0, index is : 8060
# language is : en , confidence level is  : 1.0, index is : 8061
# language is : de , confidence level is  : 1.0, index is : 8062 , text is : Screen at the kyocera workplace defective
# language is : en , confidence level is  : 0.98242426, index is : 8063
# language is : en , confidence level is  : 0.73353744, index is : 8064
# language is : en , confidence level is  : 1.0, index is : 8065
# language is : en , confidence level is  : 1.0, index is : 8066
# language is : en , confidence level is  : 1.0, index is : 8067
# language is : en , confidence level is  : 1.0, index is : 8068
# language is : en , confidence level is  : 1.0, index is : 8069
# language is : en , confidence level is  : 1.0, index is : 8070
# language is : en , confidence level is  : 1.0, index is : 8071
# language is : en , confidence level is  : 1.0, index is : 8072
# language is : en , confidence level is  : 1.0, index is : 8073
# language is : en , confidence level is  : 1.0, index is : 8074
# language is : en , confidence level is  : 1.0, index is : 8075
# language is : en , confidence level is  : 1.0, index is : 8076
# language is : en , confidence level is  : 1.0, index is : 8077
# language is : en , confidence level is  : 1.0, index is : 8078
# language is : en , confidence level is  : 1.0, index is : 8079
# language is : en , confidence level is  : 1.0, index is : 8080
# language is : en , confidence level is  : 1.0, index is : 8081
# language is : en , confidence level is  : 1.0, index is : 8082
# language is : en , confidence level is  : 1.0, index is : 8083
# language is : en , confidence level is  : 1.0, index is : 8084
# language is : en , confidence level is  : 1.0, index is : 8085
# language is : en , confidence level is  : 1.0, index is : 8086
# language is : en , confidence level is  : 1.0, index is : 8087
# language is : en , confidence level is  : 1.0, index is : 8088
# language is : plhmn , confidence level is  : 0.5425523, index is : 8089 , text is : aw: [ticket # 2016080878000153] according to: after # 4505612440
# language is : en , confidence level is  : 1.0, index is : 8090
# language is : en , confidence level is  : 1.0, index is : 8091
# language is : en , confidence level is  : 1.0, index is : 8092
# language is : en , confidence level is  : 1.0, index is : 8093
# language is : en , confidence level is  : 1.0, index is : 8094
# language is : pl , confidence level is  : 1.0, index is : 8095 , text is : according to: [ticket # 2016080878000153] according to: after # 4505612440
# language is : en , confidence level is  : 1.0, index is : 8096
# language is : de , confidence level is  : 1.0, index is : 8097 , text is : bios setting
# language is : en , confidence level is  : 1.0, index is : 8098
# language is : en , confidence level is  : 1.0, index is : 8099
# language is : en , confidence level is  : 1.0, index is : 8100
# language is : en , confidence level is  : 1.0, index is : 8101
# language is : de , confidence level is  : 0.686801, index is : 8102 , text is : evening job in job scheduler: Job 1142
# language is : en , confidence level is  : 0.64779377, index is : 8103
# language is : en , confidence level is  : 1.0, index is : 8104
# language is : de , confidence level is  : 0.686801, index is : 8105 , text is : evening job in job scheduler: Job 549
# language is : en , confidence level is  : 0.9146564, index is : 8106
# language is : ende , confidence level is  : 0.61948645, index is : 8107 , text is : abended job in job_scheduler: SID_50filesys
# language is : de , confidence level is  : 0.686801, index is : 8108 , text is : evening job in job scheduler: Job 1305
# language is : en , confidence level is  : 1.0, index is : 8109
# language is : en , confidence level is  : 1.0, index is : 8110
# language is : en , confidence level is  : 1.0, index is : 8111
# language is : en , confidence level is  : 1.0, index is : 8112
# language is : el , confidence level is  : 0.94282573, index is : 8113 , text is : ceremony at 5018072616 & 5018966647
# language is : en , confidence level is  : 1.0, index is : 8114
# language is : en , confidence level is  : 1.0, index is : 8115
# language is : en , confidence level is  : 1.0, index is : 8116
# language is : en , confidence level is  : 1.0, index is : 8117
# language is : de , confidence level is  : 0.686801, index is : 8118 , text is : evening job in job scheduler: Job 1320
# language is : en , confidence level is  : 0.73564893, index is : 8119
# language is : en , confidence level is  : 1.0, index is : 8120
# language is : en , confidence level is  : 1.0, index is : 8121
# language is : en , confidence level is  : 1.0, index is : 8122
# language is : en , confidence level is  : 1.0, index is : 8123
# language is : en , confidence level is  : 1.0, index is : 8124
# language is : en , confidence level is  : 1.0, index is : 8125
# language is : en , confidence level is  : 1.0, index is : 8126
# language is : en , confidence level is  : 1.0, index is : 8127
# language is : en , confidence level is  : 1.0, index is : 8128
# language is : en , confidence level is  : 1.0, index is : 8129
# language is : en , confidence level is  : 1.0, index is : 8130
# language is : en , confidence level is  : 1.0, index is : 8131
# language is : en , confidence level is  : 1.0, index is : 8132
# language is : en , confidence level is  : 1.0, index is : 8133
# language is : en , confidence level is  : 1.0, index is : 8134
# language is : en , confidence level is  : 1.0, index is : 8135
# language is : en , confidence level is  : 0.6922084, index is : 8136
# language is : en , confidence level is  : 1.0, index is : 8137
# language is : en , confidence level is  : 1.0, index is : 8138
# language is : en , confidence level is  : 1.0, index is : 8139
# language is : en , confidence level is  : 0.98003364, index is : 8140
# language is : en , confidence level is  : 1.0, index is : 8141
# language is : en , confidence level is  : 1.0, index is : 8142
# language is : en , confidence level is  : 1.0, index is : 8143
# language is : en , confidence level is  : 1.0, index is : 8144
# language is : en , confidence level is  : 0.9179779, index is : 8145
# language is : en , confidence level is  : 1.0, index is : 8146
# language is : en , confidence level is  : 0.98270255, index is : 8147
# language is : en , confidence level is  : 1.0, index is : 8148
# language is : en , confidence level is  : 1.0, index is : 8149
# language is : en , confidence level is  : 1.0, index is : 8150
# language is : en , confidence level is  : 1.0, index is : 8151
# language is : en , confidence level is  : 1.0, index is : 8152
# language is : en , confidence level is  : 1.0, index is : 8153
# language is : en , confidence level is  : 1.0, index is : 8154
# language is : en , confidence level is  : 1.0, index is : 8155
# language is : en , confidence level is  : 1.0, index is : 8156
# language is : en , confidence level is  : 1.0, index is : 8157
# language is : en , confidence level is  : 1.0, index is : 8158
# language is : en , confidence level is  : 1.0, index is : 8159
# language is : en , confidence level is  : 0.9471654, index is : 8160
# language is : en , confidence level is  : 1.0, index is : 8161
# language is : en , confidence level is  : 0.69833, index is : 8162
# language is : en , confidence level is  : 1.0, index is : 8163
# language is : en , confidence level is  : 1.0, index is : 8164
# language is : en , confidence level is  : 1.0, index is : 8165
# language is : en , confidence level is  : 1.0, index is : 8166
# language is : en , confidence level is  : 1.0, index is : 8167
# language is : en , confidence level is  : 1.0, index is : 8168
# language is : en , confidence level is  : 0.59891576, index is : 8169
# language is : en , confidence level is  : 1.0, index is : 8170
# language is : en , confidence level is  : 1.0, index is : 8171
# language is : en , confidence level is  : 1.0, index is : 8172
# language is : en , confidence level is  : 1.0, index is : 8173
# language is : en , confidence level is  : 1.0, index is : 8174
# language is : en , confidence level is  : 1.0, index is : 8175
# language is : en , confidence level is  : 0.98251754, index is : 8176
# language is : en , confidence level is  : 1.0, index is : 8177
# language is : en , confidence level is  : 1.0, index is : 8178
# language is : en , confidence level is  : 1.0, index is : 8179
# language is : en , confidence level is  : 1.0, index is : 8180
# language is : en , confidence level is  : 1.0, index is : 8181
# language is : es , confidence level is  : 0.49731994, index is : 8182 , text is : login to business_client
# language is : en , confidence level is  : 1.0, index is : 8183
# language is : en , confidence level is  : 1.0, index is : 8184
# language is : en , confidence level is  : 1.0, index is : 8185
# language is : en , confidence level is  : 1.0, index is : 8186
# language is : en , confidence level is  : 1.0, index is : 8187
# language is : en , confidence level is  : 1.0, index is : 8188
# language is : en , confidence level is  : 0.8917014, index is : 8189
# language is : en , confidence level is  : 1.0, index is : 8190
# language is : en , confidence level is  : 1.0, index is : 8191
# language is : en , confidence level is  : 1.0, index is : 8192
# language is : en , confidence level is  : 1.0, index is : 8193
# language is : en , confidence level is  : 1.0, index is : 8194
# language is : de , confidence level is  : 0.970327, index is : 8195 , text is : problems with computer ewew8323531 \ defective fp sectors \ xosdfhbu gtbfkisl
# language is : en , confidence level is  : 1.0, index is : 8196
# language is : en , confidence level is  : 1.0, index is : 8197
# language is : en , confidence level is  : 1.0, index is : 8198
# language is : en , confidence level is  : 1.0, index is : 8199
# language is : en , confidence level is  : 1.0, index is : 8200
# language is : en , confidence level is  : 1.0, index is : 8201
# language is : en , confidence level is  : 1.0, index is : 8202
# language is : en , confidence level is  : 1.0, index is : 8203
# language is : en , confidence level is  : 1.0, index is : 8204
# language is : en , confidence level is  : 1.0, index is : 8205
# language is : en , confidence level is  : 1.0, index is : 8206
# language is : en , confidence level is  : 1.0, index is : 8207
# language is : en , confidence level is  : 1.0, index is : 8208
# language is : en , confidence level is  : 1.0, index is : 8209
# language is : en , confidence level is  : 0.9328799, index is : 8210
# language is : en , confidence level is  : 1.0, index is : 8211
# language is : en , confidence level is  : 1.0, index is : 8212
# language is : en , confidence level is  : 1.0, index is : 8213
# language is : en , confidence level is  : 1.0, index is : 8214
# language is : en , confidence level is  : 1.0, index is : 8215
# language is : en , confidence level is  : 1.0, index is : 8216
# language is : en , confidence level is  : 1.0, index is : 8217
# language is : en , confidence level is  : 1.0, index is : 8218
# language is : en , confidence level is  : 0.58327645, index is : 8219
# language is : en , confidence level is  : 1.0, index is : 8220
# language is : en , confidence level is  : 1.0, index is : 8221
# language is : ende , confidence level is  : 0.5126263, index is : 8222 , text is : investment antrag mnakehrf mvunqihf - new laptop request - mnakehrf mvunqihf
# language is : de , confidence level is  : 0.686801, index is : 8223 , text is : evening job in job scheduler: Job 3181
# language is : en , confidence level is  : 1.0, index is : 8224
# language is : en , confidence level is  : 1.0, index is : 8225
# language is : de , confidence level is  : 0.64660734, index is : 8226 , text is : data backup and restore \ ahlqgjwx wbsfavhg
# language is : en , confidence level is  : 1.0, index is : 8227
# language is : en , confidence level is  : 1.0, index is : 8228
# language is : en , confidence level is  : 1.0, index is : 8229
# language is : de , confidence level is  : 1.0, index is : 8230 , text is : problems with printer in Löwe uacyltoe hxgayczeraum \ reinhard kröger
# language is : de , confidence level is  : 0.686801, index is : 8231 , text is : evening job in job scheduler: Job 501
# language is : en , confidence level is  : 1.0, index is : 8232
# language is : de , confidence level is  : 0.686801, index is : 8233 , text is : evening job in job scheduler: Job 489
# language is : de , confidence level is  : 1.0, index is : 8234 , text is : telephone receiver on the device production hall c defective
# language is : en , confidence level is  : 1.0, index is : 8235
# language is : en , confidence level is  : 1.0, index is : 8236
# language is : en , confidence level is  : 1.0, index is : 8237
# language is : en , confidence level is  : 1.0, index is : 8238
# language is : en , confidence level is  : 1.0, index is : 8239
# language is : en , confidence level is  : 1.0, index is : 8240
# language is : en , confidence level is  : 1.0, index is : 8241
# language is : en , confidence level is  : 1.0, index is : 8242
# language is : en , confidence level is  : 1.0, index is : 8243
# language is : de , confidence level is  : 0.686801, index is : 8244 , text is : abended job in job_scheduler: Job_2584
# language is : en , confidence level is  : 1.0, index is : 8245
# language is : en , confidence level is  : 1.0, index is : 8246
# language is : de , confidence level is  : 0.686801, index is : 8247 , text is : evening job in job scheduler: Job 481
# language is : en , confidence level is  : 1.0, index is : 8248
# language is : en , confidence level is  : 1.0, index is : 8249
# language is : en , confidence level is  : 1.0, index is : 8250
# language is : en , confidence level is  : 1.0, index is : 8251
# language is : en , confidence level is  : 1.0, index is : 8252
# language is : en , confidence level is  : 1.0, index is : 8253
# language is : en , confidence level is  : 1.0, index is : 8254
# language is : en , confidence level is  : 1.0, index is : 8255
# language is : en , confidence level is  : 1.0, index is : 8256
# language is : en , confidence level is  : 1.0, index is : 8257
# language is : zh-CN , confidence level is  : 1.0, index is : 8258 , text is : erp cannot purchase (transferred to He Zhengping)
# language is : en , confidence level is  : 1.0, index is : 8259
# language is : en , confidence level is  : 1.0, index is : 8260
# language is : en , confidence level is  : 1.0, index is : 8261
# language is : zh-CN , confidence level is  : 1.0, index is : 8262 , text is : After the password is changed, Outlook cannot log in
# language is : en , confidence level is  : 1.0, index is : 8263
# language is : en , confidence level is  : 1.0, index is : 8264
# language is : en , confidence level is  : 1.0, index is : 8265
# language is : de , confidence level is  : 0.686801, index is : 8266 , text is : abended job in job_scheduler: Job_2114
# language is : en , confidence level is  : 1.0, index is : 8267
# language is : de , confidence level is  : 0.686801, index is : 8268 , text is : evening job in job scheduler: Job 1640
# language is : de , confidence level is  : 0.9321986, index is : 8269 , text is : Abended job in job_scheduler: snp_heu_5_regen
# language is : en , confidence level is  : 0.7854852, index is : 8270
# language is : en , confidence level is  : 1.0, index is : 8271
# language is : deen , confidence level is  : 0.58315617, index is : 8272 , text is : abended job in job_scheduler: bwhrattr
# language is : en , confidence level is  : 1.0, index is : 8273
# language is : en , confidence level is  : 0.8864109, index is : 8274
# language is : en , confidence level is  : 1.0, index is : 8275
# language is : de , confidence level is  : 0.9321986, index is : 8276 , text is : Abended job in job_scheduler: snp_heu_1_regen
# language is : en , confidence level is  : 1.0, index is : 8277
# language is : en , confidence level is  : 0.9819505, index is : 8278
# language is : en , confidence level is  : 1.0, index is : 8279
# language is : de , confidence level is  : 0.686801, index is : 8280 , text is : evening job in job scheduler: Job 1305
# language is : en , confidence level is  : 1.0, index is : 8281
# language is : de , confidence level is  : 0.686801, index is : 8282 , text is : abended job in job_scheduler: Job_1315
# language is : en , confidence level is  : 0.7854852, index is : 8283
# language is : de , confidence level is  : 0.686801, index is : 8284 , text is : abended job in job_scheduler: Job_1383
# language is : de , confidence level is  : 0.686801, index is : 8285 , text is : evening job in job scheduler: Job 1142
# language is : en , confidence level is  : 0.8778434, index is : 8286
# language is : deen , confidence level is  : 0.5310973, index is : 8287 , text is : Abended job in job_scheduler: SID_51_start_hana_slt
# language is : en , confidence level is  : 0.8270691, index is : 8288
# language is : en , confidence level is  : 1.0, index is : 8289
# language is : ende , confidence level is  : 0.66062284, index is : 8290 , text is : abended job in job_scheduler: SID_51start
# language is : en , confidence level is  : 0.81019485, index is : 8291
# language is : en , confidence level is  : 1.0, index is : 8292
# language is : ende , confidence level is  : 0.6409357, index is : 8293 , text is : abended job in job_scheduler: SID_47cold
# language is : en , confidence level is  : 0.6797699, index is : 8294
# language is : en , confidence level is  : 0.8624461, index is : 8295
# language is : en , confidence level is  : 0.741919, index is : 8296
# language is : en , confidence level is  : 0.78302884, index is : 8297
# language is : de , confidence level is  : 0.686801, index is : 8298 , text is : evening job in job scheduler: Job 3032
# language is : ende , confidence level is  : 0.65697116, index is : 8299 , text is : abended job in job_scheduler: SID_51stop
# language is : de , confidence level is  : 0.686801, index is : 8300 , text is : evening job in job scheduler: Job 1665
# language is : ende , confidence level is  : 0.505415, index is : 8301 , text is : abended job in job_scheduler: SID_51_stop_hana_slt
# language is : de , confidence level is  : 0.686801, index is : 8302 , text is : evening job in job scheduler: Job 1428
# language is : de , confidence level is  : 0.686801, index is : 8303 , text is : abended job in job_scheduler: Job_2078
# language is : en , confidence level is  : 1.0, index is : 8304
# language is : en , confidence level is  : 1.0, index is : 8305
# language is : en , confidence level is  : 1.0, index is : 8306
# language is : en , confidence level is  : 0.73564893, index is : 8307
# language is : en , confidence level is  : 0.98941785, index is : 8308
# language is : en , confidence level is  : 0.68446666, index is : 8309
# language is : deen , confidence level is  : 0.55185974, index is : 8310 , text is : Abended job in job_scheduler: apo_cif_pds5_eu
# language is : de , confidence level is  : 0.686801, index is : 8311 , text is : abended job in job_scheduler: Job_1319
# language is : en , confidence level is  : 1.0, index is : 8312
# language is : de , confidence level is  : 0.686801, index is : 8313 , text is : evening job in job scheduler: Job 1141
# language is : en , confidence level is  : 1.0, index is : 8314
# language is : en , confidence level is  : 1.0, index is : 8315
# language is : en , confidence level is  : 0.66906905, index is : 8316
# language is : en , confidence level is  : 1.0, index is : 8317
# language is : en , confidence level is  : 1.0, index is : 8318
# language is : en , confidence level is  : 1.0, index is : 8319
# language is : en , confidence level is  : 1.0, index is : 8320
# language is : en , confidence level is  : 1.0, index is : 8321
# language is : en , confidence level is  : 1.0, index is : 8322
# language is : en , confidence level is  : 0.9402409, index is : 8323
# language is : en , confidence level is  : 1.0, index is : 8324
# language is : en , confidence level is  : 1.0, index is : 8325
# language is : en , confidence level is  : 1.0, index is : 8326
# language is : en , confidence level is  : 1.0, index is : 8327
# language is : en , confidence level is  : 1.0, index is : 8328
# language is : en , confidence level is  : 1.0, index is : 8329
# language is : en , confidence level is  : 1.0, index is : 8330
# language is : en , confidence level is  : 1.0, index is : 8331
# language is : en , confidence level is  : 1.0, index is : 8332
# language is : en , confidence level is  : 1.0, index is : 8333
# language is : en , confidence level is  : 0.96002597, index is : 8334
# language is : en , confidence level is  : 1.0, index is : 8335
# language is : en , confidence level is  : 0.964497, index is : 8336
# language is : en , confidence level is  : 1.0, index is : 8337
# language is : en , confidence level is  : 1.0, index is : 8338
# language is : en , confidence level is  : 1.0, index is : 8339
# language is : en , confidence level is  : 1.0, index is : 8340
# language is : en , confidence level is  : 0.988031, index is : 8341
# language is : en , confidence level is  : 1.0, index is : 8342
# language is : en , confidence level is  : 1.0, index is : 8343
# language is : en , confidence level is  : 1.0, index is : 8344
# language is : en , confidence level is  : 1.0, index is : 8345
# language is : en , confidence level is  : 1.0, index is : 8346
# language is : en , confidence level is  : 1.0, index is : 8347
# language is : de , confidence level is  : 0.686801, index is : 8348 , text is : evening job in job scheduler: Job 3194
# language is : en , confidence level is  : 1.0, index is : 8349
# language is : de , confidence level is  : 0.686801, index is : 8350 , text is : evening job in job scheduler: Job 1390
# language is : en , confidence level is  : 1.0, index is : 8351
# language is : en , confidence level is  : 1.0, index is : 8352
# language is : en , confidence level is  : 1.0, index is : 8353
# language is : en , confidence level is  : 1.0, index is : 8354
# language is : en , confidence level is  : 1.0, index is : 8355
# language is : en , confidence level is  : 1.0, index is : 8356
# language is : en , confidence level is  : 1.0, index is : 8357
# language is : en , confidence level is  : 1.0, index is : 8358
# language is : en , confidence level is  : 1.0, index is : 8359
# language is : en , confidence level is  : 0.77384526, index is : 8360
# language is : en , confidence level is  : 0.77384526, index is : 8361
# language is : en , confidence level is  : 0.77384526, index is : 8362
# language is : en , confidence level is  : 1.0, index is : 8363
# language is : en , confidence level is  : 1.0, index is : 8364
# language is : en , confidence level is  : 1.0, index is : 8365
# language is : en , confidence level is  : 1.0, index is : 8366
# language is : en , confidence level is  : 1.0, index is : 8367
# language is : en , confidence level is  : 1.0, index is : 8368
# language is : en , confidence level is  : 1.0, index is : 8369
# language is : en , confidence level is  : 0.77682006, index is : 8370
# language is : en , confidence level is  : 1.0, index is : 8371
# language is : en , confidence level is  : 0.7292822, index is : 8372
# language is : en , confidence level is  : 1.0, index is : 8373
# language is : en , confidence level is  : 1.0, index is : 8374
# language is : en , confidence level is  : 1.0, index is : 8375
# language is : en , confidence level is  : 1.0, index is : 8376
# language is : en , confidence level is  : 1.0, index is : 8377
# language is : en , confidence level is  : 1.0, index is : 8378
# language is : en , confidence level is  : 1.0, index is : 8379
# language is : en , confidence level is  : 1.0, index is : 8380
# language is : en , confidence level is  : 1.0, index is : 8381
# language is : en , confidence level is  : 1.0, index is : 8382
# language is : en , confidence level is  : 1.0, index is : 8383
# language is : en , confidence level is  : 1.0, index is : 8384
# language is : en , confidence level is  : 1.0, index is : 8385
# language is : en , confidence level is  : 1.0, index is : 8386
# language is : en , confidence level is  : 1.0, index is : 8387
# language is : pt , confidence level is  : 1.0, index is : 8388 , text is : format micro
# language is : de , confidence level is  : 0.8956893, index is : 8389 , text is : security error in travel expense accounting programdnty
# language is : en , confidence level is  : 1.0, index is : 8390
# language is : en , confidence level is  : 1.0, index is : 8391
# language is : en , confidence level is  : 1.0, index is : 8392
# language is : en , confidence level is  : 1.0, index is : 8393
# language is : en , confidence level is  : 1.0, index is : 8394
# language is : en , confidence level is  : 1.0, index is : 8395
# language is : en , confidence level is  : 0.78851163, index is : 8396
# language is : en , confidence level is  : 1.0, index is : 8397
# language is : en , confidence level is  : 1.0, index is : 8398
# language is : en , confidence level is  : 1.0, index is : 8399
# language is : en , confidence level is  : 1.0, index is : 8400
# language is : en , confidence level is  : 1.0, index is : 8401
# language is : en , confidence level is  : 1.0, index is : 8402
# language is : en , confidence level is  : 1.0, index is : 8403
# language is : en , confidence level is  : 1.0, index is : 8404
# language is : de , confidence level is  : 0.46011084, index is : 8405 , text is : problems with we_combi \ jumps kpz cmv
# language is : de , confidence level is  : 1.0, index is : 8406 , text is : slow computer \ checking \ niptbwdq csenjruz
# language is : en , confidence level is  : 1.0, index is : 8407
# language is : en , confidence level is  : 0.9693771, index is : 8408
# language is : ku , confidence level is  : 0.75379324, index is : 8409 , text is : bluetooth keybankrd defect \ dardabthyr
# language is : en , confidence level is  : 0.4835, index is : 8410
# language is : de , confidence level is  : 1.0, index is : 8411 , text is : problems with screen saver \ we91 \ jionmpsf wnkpzcmv
# language is : svno , confidence level is  : 0.41511607, index is : 8412 , text is : mobile phone defective
# language is : en , confidence level is  : 0.9478144, index is : 8413
# language is : en , confidence level is  : 1.0, index is : 8414
# language is : en , confidence level is  : 1.0, index is : 8415
# language is : en , confidence level is  : 1.0, index is : 8416
# language is : de , confidence level is  : 1.0, index is : 8417 , text is : i cannot reset my erp password.
# language is : en , confidence level is  : 1.0, index is : 8418
# language is : en , confidence level is  : 1.0, index is : 8419
# language is : en , confidence level is  : 1.0, index is : 8420
# language is : en , confidence level is  : 1.0, index is : 8421
# language is : en , confidence level is  : 1.0, index is : 8422
# language is : en , confidence level is  : 1.0, index is : 8423
# language is : de , confidence level is  : 0.686801, index is : 8424 , text is : abended job in job_scheduler: Job_593
# language is : en , confidence level is  : 1.0, index is : 8425
# language is : en , confidence level is  : 0.91779286, index is : 8426
# language is : de , confidence level is  : 0.686801, index is : 8427 , text is : evening job in job scheduler: Job 467
# language is : en , confidence level is  : 0.817076, index is : 8428
# language is : en , confidence level is  : 1.0, index is : 8429
# language is : en , confidence level is  : 1.0, index is : 8430
# language is : de , confidence level is  : 1.0, index is : 8431 , text is : the printer for the ups-lapels does not print correctly.
# language is : en , confidence level is  : 0.8667959, index is : 8432
# language is : en , confidence level is  : 1.0, index is : 8433
# language is : de , confidence level is  : 0.686801, index is : 8434 , text is : evening job in job scheduler: Job 481
# language is : en , confidence level is  : 1.0, index is : 8435
# language is : en , confidence level is  : 1.0, index is : 8436
# language is : en , confidence level is  : 1.0, index is : 8437
# language is : en , confidence level is  : 1.0, index is : 8438
# language is : en , confidence level is  : 1.0, index is : 8439
# language is : de , confidence level is  : 0.686801, index is : 8440 , text is : evening job in job scheduler: Job 483
# language is : en , confidence level is  : 1.0, index is : 8441
# language is : en , confidence level is  : 1.0, index is : 8442
# language is : en , confidence level is  : 0.98251754, index is : 8443
# language is : en , confidence level is  : 1.0, index is : 8444
# language is : ar , confidence level is  : 0.90012443, index is : 8445 , text is : Or: SID_1 erp
# language is : en , confidence level is  : 1.0, index is : 8446
# language is : en , confidence level is  : 1.0, index is : 8447
# language is : en , confidence level is  : 1.0, index is : 8448
# language is : zh-CN , confidence level is  : 1.0, index is : 8449 , text is : Unable to log in hr_tool attendance system
# language is : en , confidence level is  : 1.0, index is : 8450
# language is : en , confidence level is  : 1.0, index is : 8451
# language is : de , confidence level is  : 0.686801, index is : 8452 , text is : evening job in job scheduler: Job 1148
# language is : en , confidence level is  : 0.98368657, index is : 8453
# language is : de , confidence level is  : 0.686801, index is : 8454 , text is : evening job in job scheduler: Job 1141
# language is : en , confidence level is  : 1.0, index is : 8455
# language is : en , confidence level is  : 1.0, index is : 8456
# language is : zh-CN , confidence level is  : 1.0, index is : 8457 , text is : vpn can't connect
# language is : en , confidence level is  : 0.73564893, index is : 8458
# language is : en , confidence level is  : 1.0, index is : 8459
# language is : en , confidence level is  : 1.0, index is : 8460
# language is : en , confidence level is  : 1.0, index is : 8461
# language is : en , confidence level is  : 1.0, index is : 8462
# language is : zh-CN , confidence level is  : 1.0, index is : 8463 , text is : The computer cannot be turned on
# language is : en , confidence level is  : 1.0, index is : 8464
# language is : en , confidence level is  : 1.0, index is : 8465
# language is : en , confidence level is  : 1.0, index is : 8466
# language is : en , confidence level is  : 1.0, index is : 8467
# language is : en , confidence level is  : 1.0, index is : 8468
# language is : en , confidence level is  : 1.0, index is : 8469
# language is : en , confidence level is  : 0.8768117, index is : 8470
# language is : en , confidence level is  : 1.0, index is : 8471
# language is : en , confidence level is  : 1.0, index is : 8472
# language is : de , confidence level is  : 0.7788659, index is : 8473 , text is : ess portal
# language is : en , confidence level is  : 1.0, index is : 8474
# language is : en , confidence level is  : 1.0, index is : 8475
# language is : en , confidence level is  : 1.0, index is : 8476
# language is : en , confidence level is  : 1.0, index is : 8477
# language is : en , confidence level is  : 1.0, index is : 8478
# language is : en , confidence level is  : 1.0, index is : 8479
# language is : en , confidence level is  : 0.93715584, index is : 8480
# language is : en , confidence level is  : 1.0, index is : 8481
# language is : en , confidence level is  : 1.0, index is : 8482
# language is : en , confidence level is  : 1.0, index is : 8483
# language is : en , confidence level is  : 1.0, index is : 8484
# language is : en , confidence level is  : 1.0, index is : 8485
# language is : en , confidence level is  : 1.0, index is : 8486
# language is : en , confidence level is  : 1.0, index is : 8487
# language is : en , confidence level is  : 1.0, index is : 8488
# language is : en , confidence level is  : 1.0, index is : 8489
# language is : pt , confidence level is  : 0.9868218, index is : 8490 , text is : machine is not working
# language is : de , confidence level is  : 1.0, index is : 8491 , text is : Different programs cannot be opened on several pc's.
# count : 72

# %%
# non_English_sd = [164,186,222,223,255,265,,270,276,302,304,306,335,339,357,363,365,368,370,441,446,450,453,454,455,456,463,466,469,481,487,488,555,558,
# 559,565,570,572,574,578,582,586,589,595,608,610,618,3009]

# %%
non_English_sd_df = pd.DataFrame(non_English_sd)

# %%
non_English_sd_df.head(20)
# Out:
#        0
# 0   2260
# 1   2282
# 2   2285
# 3   2286
# 4   2301
# 5   2307
# 6   2354
# 7   2359
# 8   2382
# 9   2389
# 10  2405
# 11  2406
# 12  2407
# 13  2420
# 14  2438
# 15  2445
# 16  2578
# 17  2610
# 18  2696
# 19  2708

# %%
non_English_sd_df.to_pickle("Non_English_sd_Indices_setTwelve.pkl")

# %%
non_English_df = pd.DataFrame(non_English)

# %%
# df = pd.read_excel("ansi_encoded_utf8_decoded.xlsx",index_col=0)

# %%
df.shape
# Out:
# (8492, 5)

# %%
print(df.iloc[1344]['Description'])
print(df.iloc[1344]['Description'].encode('Windows-1254').decode('utf8'))
# Out:
# einlasten bei it-germany, da hierfÃ¼r bereits ein ersatz-pc verbaut ist und ein neuer bestellt wurde.
# einlasten bei it-germany, da hierfür bereits ein ersatz-pc verbaut ist und ein neuer bestellt wurde.

# %%
df[df['Description'] == 0].index.tolist()
# Out:
# []

# %%
df['Description'][3954] = df['Short description'][3954]
df['Description'][6726] = df['Short description'][6726]
df['Description'][6880] = df['Short description'][6880]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['Short description'][1554] = translator.translate(df['Short description'][1554],dest='en').text
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Short description'][1554]
# Out:
# '答复: ticket_no1559458 : wireless guest access- hr_tool trainer'

# %%
joint_indices = pd.read_pickle("1_joint_indices.pkl")
short_desc_indices = pd.read_pickle("2_short_desc_indices.pkl")
desc_indices = pd.read_pickle("3_desc_indices.pkl")

# %%
print(joint_indices.shape)
print(short_desc_indices.shape)
print(desc_indices.shape)
# Out:
# (640, 1)
# (182, 1)
# (101, 1)

# %%
joint_indices = joint_indices[0].values.tolist()
short_desc_indices = short_desc_indices[0].values.tolist()
desc_indices = desc_indices[0].values.tolist()

# %%
joint_indices.append(1344)

# %%
print(len(joint_indices))
print(len(short_desc_indices))
print(len(desc_indices))
# Out:
# 641
# 182
# 101

# %%
for x in short_desc_indices:
  text = df.loc[x]['Short description']
  time.sleep(6)
  translation = translator.translate(text,dest='en')
  translated_text = translation.text
  df['Short description'][x] = translated_text
  print("index : {} , original text : {} , translated text : {}".format(x,text,translated_text))
# Out:
# index : 266 , original text : a kündigung for fgxprnub hlanwgqj, 11161827, effective 31.05.2017 has been approved.  , translated text : a kündigung for fgxprnub hlanwgqj, 11161827, effective 31.05.2017 has been approved.
# index : 456 , original text : primary telephone flow down - company EU  - EU plant , translated text : primary telephone flow down - company EU - EU plant
# index : 524 , original text : a kündigung for eluvxqhw gpbfkqeu, 11166428, effective 28.02.2017 has been approved.  , translated text : a kündigung for eluvxqhw gpbfkqeu, 11166428, effective 28.02.2017 has been approved.
# index : 558 , original text : usa ou deletion , translated text : usa or deletion
# index : 559 , original text : uacyltoe hxgaycze , translated text : uacyltoe hxgaycze
# index : 565 , original text : new iphone activation /  die synchronisierung mit exchange activesync ist auf ihrem gerät vorübergehend blockiert, bis d , translated text : new iphone activation / the synchronization with exchange activesync is temporarily blocked on your device until d
# index : 995 , original text : bei herrn potthryzler (benutzerkennung: potsffwzlo) geht EU_tool am rechner: empw8111201a nicht. , translated text : with mr potthryzler (user ID: potsffwzlo) EU_tool does not work on the computer: empw8111201a.
# index : 1094 , original text : envoyé à partir de l’outil capture d’écran , translated text : sent from the screenshot tool
# index : 1299 , original text : dn 9169508476,t/o 642392 , translated text : dn 9169508476, t / o 642392
# index : 1312 , original text : bobj , translated text : Bob
# index : 1403 , original text : bobj , translated text : Bob
# index : 1411 , original text : a kündigung for dxnzkcuh eqdgoxap, 11161751, effective 13.10.2016 has been approved.  , translated text : a kündigung for dxnzkcuh eqdgoxap, 11161751, effective 13.10.2016 has been approved.
# index : 1554 , original text : 答复: ticket_no1559458 : wireless guest access- hr_tool trainer , translated text : 答复: ticket_no1559458 : wireless guest access- hr_tool trainer
# index : 1566 , original text : ess portal , translated text : ess portal
# index : 1627 , original text : tmunkaiv ockthiyj  , translated text : tmunkaiv ockthiyj
# index : 1773 , original text : s&op password , translated text : s & op password
# index : 1801 , original text : kis_zebra print , translated text : little zebra print
# index : 2179 , original text : no bobj acces , translated text : no bobj acces
# index : 2445 , original text : vh 27 - werk germany - fehlende druckaufträge  - eilt monatswechsel!!! , translated text : vh 27 - factory germany - missing print jobs - change of month rushes !!!
# index : 2578 , original text : zifujpvr vxfkwaqh , translated text : zifujpvr vxfkwaqh
# index : 2720 , original text : drucker em26 druckt mit bis zu 2 std. verzögerung (printer can not be pinged. see attachment) , translated text : printer em26 prints with up to 2 hours. delay (printer can not be pinged. see attachment)
# index : 2832 , original text : hsh , translated text : Hush
# index : 2953 , original text : drucker vh77 und vh79 funktionieren nicht. ticket bitte an edv germany hr. wurdack/ steinich , translated text : printer vh77 and vh79 do not work. Please send your ticket to edv germany hr. wurdack / steinich
# index : 2958 , original text : hsh , translated text : Hush
# index : 2990 , original text : erp access issue p 11, passwort zurück setzen , translated text : erp access issue p 11, reset password
# index : 3087 , original text : probleme bei der projekt eingabe im collaboration_platform / infopath , translated text : problems with the project entry in collaboration_platform / infopath
# index : 3296 , original text : outlook  -  keine rückmeldung , translated text : outlook - no feedback
# index : 3452 , original text : password reset -hsh , translated text : Password reset - hash
# index : 3527 , original text : PR , translated text : PR
# index : 3557 , original text : bitte konto erzeugen. ewew7212768 , translated text : please create an account. ewew7212768
# index : 3591 , original text : awb 0276036761 / sin - jnb  , translated text : awb 0276036761 / sin - jnb
# index : 3643 , original text : 答复: 答复: order products online problem , translated text : Reply: Reply: order products online problem
# index : 3645 , original text : 答复: 答复: order products online problem , translated text : Reply: Reply: order products online problem
# index : 3674 , original text : erro programdntya docad , translated text : docd programdntya error
# index : 3832 , original text : awb 0276036761 / sin - jnb , translated text : awb 0276036761 / sin - jnb
# index : 4038 , original text : vvdgtyachac , translated text : vvjtihak
# index : 4064 , original text : abend batch job:Job_1391 , translated text : evening batch job: Job_1391
# index : 4351 , original text :  bobj error  , translated text : bobj error
# index : 4691 , original text : bobj  , translated text : Bob
# index : 4715 , original text : 转发: 以色列修磨/rma6001502596 , translated text : Forward: Israel grinding/rma6001502596
# index : 4876 , original text : 答复: shipments iak , translated text : Answer: shipments iak
# index : 4877 , original text : job bk_bia_bobje failed in job_scheduler at: 09/09/2016 04:34:00   , translated text : job bk_bia_bobje failed in job_scheduler at: 09/09/2016 04:34:00
# index : 4903 , original text : 转发: finished: start of s&op process , translated text : Forward: finished: start of s&op process
# index : 4962 , original text : drucker ng15 funktioniert nicht mehr (hardware problem), dringend benötigt für auftragspapiere und bestellungen , translated text : printer ng15 no longer works (hardware problem), urgently needed for order papers and orders
# index : 5004 , original text : hsh , translated text : Hush
# index : 5136 , original text : babiluntr , translated text : Babylon suddenly
# index : 5322 , original text : mm# 5260903 ( kr230 ) , translated text : mm # 5260903 (kr230)
# index : 5386 , original text : hana  , translated text : Here
# index : 5456 , original text : 答复: 35969737/2032252 , translated text : Reply: 35969737/2032252
# index : 5498 , original text : dsw in22457494 , translated text : dsw in22457494
# index : 5523 , original text : av system usa , translated text : of system usa
# index : 5534 , original text : po - a4 4505633620 , translated text : by - a4 4505633620
# index : 5819 , original text : 答复: ticket_no1538811::company center authorization , translated text : Reply: ticket_no1538811::company center authorization
# index : 5827 , original text : 答复: ticket_no1538811::company center authorization , translated text : Reply: ticket_no1538811::company center authorization
# index : 5833 , original text : s&op , translated text : s & on
# index : 6015 , original text : check router wifi (router: sao-pollaurido-mercedes-ap)- site: south_amerirtca - sp - são bernardo campo (mercedes benz) , translated text : check wifi router (router: sao-pollaurido-mercedes-ap) - site: south_amerirtca - sp - são bernardo campo (mercedes benz)
# index : 6035 , original text : kurtyar khty , translated text : kurtyar khty
# index : 6036 , original text : vvrttraja , translated text : vvrttraja
# index : 6059 , original text : tr: rappel: vous avez un nouveau message ! **** spam **** , translated text : tr: reminder: you have a new message! **** spam ****
# index : 6064 , original text : scanner im werk germany steel funktionieren nicht! , translated text : scanners in the germany steel plant do not work!
# index : 6210 , original text : support für stöhrmann \xosdfhbu gtbfkisl , translated text : support for stöhrmann \ xosdfhbu gtbfkisl
# index : 6229 , original text : tablet - dell 7350 - 电脑开机启动蓝屏 , translated text : tablet-dell 7350-computer starts with a blue screen
# index : 6267 , original text : check router wifi - site: south_amerirtca - sp - são bernardo campo (mercedes benz) , translated text : check wifi router - site: south_amerirtca - sp - são bernardo campo (mercedes benz)
# index : 6437 , original text : fi/co issue - sto 5019143086  , translated text : fi / co issue - hundred 5019143086
# index : 6440 , original text : EU_tool -> sinterleitstand (sls) -> beilageproben -> auswerten, form "beilage und tms proben", input of ald2 and ald3 data , translated text : EU_tool -> sinter control station (als) -> sample attachment -> evaluate, form "sample attachment and tms", input of ald2 and ald3 data
# index : 6547 , original text : erp plm - change bom plant_248 , translated text : erp plm - change bom plant_248
# index : 6657 , original text : awyw7217971 , translated text : October 17971
# index : 7105 , original text : abended job in job_scheduler: Job_1338 , translated text : evening job in job scheduler: Job 1338
# index : 7106 , original text : abended job in job_scheduler: Job_1388 , translated text : abended job in job_scheduler: Job_1388
# index : 7108 , original text : abended job in job_scheduler: Job_1332 , translated text : evening job in job scheduler: Job 1332
# index : 7120 , original text : abended job in job_scheduler: Job_1148 , translated text : evening job in job scheduler: Job 1148
# index : 7125 , original text : abended job in job_scheduler: Job_1141 , translated text : evening job in job scheduler: Job 1141
# index : 7137 , original text : abended job in job_scheduler: Job_1852 , translated text : evening job in job scheduler: Job 1852
# index : 7156 , original text : abended job in job_scheduler: Job_1379 , translated text : evening job in job scheduler: Job 1379
# index : 7168 , original text : abended job in job_scheduler: Job_1387 , translated text : abended job in job_scheduler: Job_1387
# index : 7185 , original text : abended job in job_scheduler: Job_1853 , translated text : evening job in job scheduler: Job 1853
# index : 7186 , original text : abended job in job_scheduler: Job_1402 , translated text : abended job in job_scheduler: Job_1402
# index : 7187 , original text : abended job in job_scheduler: Job_1403 , translated text : abended job in job_scheduler: Job_1403
# index : 7188 , original text : abended job in job_scheduler: Job_1417 , translated text : abended job in job_scheduler: Job_1417
# index : 7197 , original text : abended job in job_scheduler: Job_1854 , translated text : evening job in job scheduler: Job 1854
# index : 7220 , original text : abended job in job_scheduler: SID_32arc2 , translated text : abended job in job_scheduler: SID_32arc2
# index : 7222 , original text : abended job in job_scheduler: Job_1142 , translated text : evening job in job scheduler: Job 1142
# index : 7227 , original text : abended job in job_scheduler: Job_3049 , translated text : evening job in job scheduler: Job 3049
# index : 7233 , original text : abended job in job_scheduler: pp_EU_tool_netch_keheu1 , translated text : abended job in job_scheduler: pp_EU_tool_netch_keheu1
# index : 7260 , original text : abended job in job_scheduler: pp_EU_tool_netch_ap1 , translated text : abended job in job_scheduler: pp_EU_tool_netch_ap1
# index : 7287 , original text : abended job in job_scheduler: Job_1148 , translated text : evening job in job scheduler: Job 1148
# index : 7313 , original text : abended job in job_scheduler: hr_tooldcvcgenratn , translated text : abended job in job_scheduler: hr_tooldcvcgenratn
# index : 7322 , original text : abended job in job_scheduler: Job_1320 , translated text : evening job in job scheduler: Job 1320
# index : 7377 , original text : abended job in job_scheduler: SID_32hotf , translated text : abended job in job_scheduler: SID_32hotf
# index : 7431 , original text : 答复: help for mm#4866474 24800776 , translated text : Reply: help for mm#4866474 24800776
# index : 7446 , original text : abended job in job_scheduler: Job_2600 , translated text : evening job in job scheduler: Job 2600
# index : 7447 , original text : abended job in job_scheduler: Job_2584 , translated text : abended job in job_scheduler: Job_2584
# index : 7448 , original text : abended job in job_scheduler: Job_2599 , translated text : abended job in job_scheduler: Job_2599
# index : 7460 , original text : abended job in job_scheduler: pp_EU_tool_netch_ap2 , translated text : abended job in job_scheduler: pp_EU_tool_netch_ap2
# index : 7468 , original text : abended job in job_scheduler: hr_tooldcvcgenratn , translated text : abended job in job_scheduler: hr_tooldcvcgenratn
# index : 7470 , original text : abended job in job_scheduler: Job_2827 , translated text : abended job in job_scheduler: Job_2827
# index : 7559 , original text : abended job in job_scheduler: Job_593 , translated text : abended job in job_scheduler: Job_593
# index : 7567 , original text : abended job in job_scheduler: Job_483 , translated text : evening job in job scheduler: Job 483
# index : 7582 , original text : abended job in job_scheduler: Job_3186 , translated text : evening job in job scheduler: Job 3186
# index : 7583 , original text : abended job in job_scheduler: Job_2114 , translated text : abended job in job_scheduler: Job_2114
# index : 7587 , original text : abended job in job_scheduler: snp_heu_5_regen , translated text : Abended job in job_scheduler: snp_heu_5_regen
# index : 7591 , original text : abended job in job_scheduler: snp_heu_1_regen , translated text : Abended job in job_scheduler: snp_heu_1_regen
# index : 7593 , original text : abended job in job_scheduler: SID_37hoti , translated text : abended job in job_scheduler: SID_37hoti
# index : 7597 , original text : abended job in job_scheduler: Job_1343 , translated text : evening job in job scheduler: Job 1343
# index : 7598 , original text : abended job in job_scheduler: SID_9cold , translated text : abended job in job_scheduler: SID_9cold
# index : 7601 , original text : abended job in job_scheduler: SID_29cold , translated text : abended job in job_scheduler: SID_29cold
# index : 7603 , original text : abended job in job_scheduler: Job_727 , translated text : abended job in job_scheduler: Job_727
# index : 7605 , original text : abended job in job_scheduler: Job_717 , translated text : abended job in job_scheduler: Job_717
# index : 7607 , original text : abended job in job_scheduler: Job_571 , translated text : evening job in job scheduler: Job 571
# index : 7608 , original text : abended job in job_scheduler: SID_48cold , translated text : abended job in job_scheduler: SID_48cold
# index : 7611 , original text : abended job in job_scheduler: Job_737 , translated text : evening job in job scheduler: Job 737
# index : 7619 , original text : abended job in job_scheduler: Job_1989 , translated text : evening job in job scheduler: Job 1989
# index : 7620 , original text : abended job in job_scheduler: Job_1907 , translated text : evening job in job scheduler: Job 1907
# index : 7621 , original text : abended job in job_scheduler: Job_1949 , translated text : evening job in job scheduler: Job 1949
# index : 7626 , original text : abended job in job_scheduler: Job_1148 , translated text : evening job in job scheduler: Job 1148
# index : 7627 , original text : abended job in job_scheduler: Job_1141 , translated text : evening job in job scheduler: Job 1141
# index : 7634 , original text : abended job in job_scheduler: hr_tooldcvcgenratn , translated text : abended job in job_scheduler: hr_tooldcvcgenratn
# index : 7642 , original text : delete blancog (olifgtmpio gargtcia blagtnco) , translated text : delete blancog (olifgtmpio gargtcia blagtnco)
# index : 7648 , original text : abended job in job_scheduler: Job_1918b , translated text : abended job in job_scheduler: Job_1918b
# index : 7704 , original text : abended job in job_scheduler: Job_499 , translated text : evening job in job scheduler: Job 499
# index : 7714 , original text : abended job in job_scheduler: Job_2049 , translated text : abended job in job_scheduler: Job_2049
# index : 7716 , original text : abended job in job_scheduler: Job_1960 , translated text : evening job in job scheduler: Job 1960
# index : 7732 , original text : abended job in job_scheduler: Job_1623 , translated text : abended job in job_scheduler: Job_1623
# index : 7733 , original text : abended job in job_scheduler: Job_1488 , translated text : abended job in job_scheduler: Job_1488
# index : 7734 , original text : abended job in job_scheduler: Job_1491 , translated text : abended job in job_scheduler: Job_1491
# index : 7735 , original text : abended job in job_scheduler: Job_1493 , translated text : abended job in job_scheduler: Job_1493
# index : 7736 , original text : abended job in job_scheduler: Job_2114 , translated text : abended job in job_scheduler: Job_2114
# index : 7738 , original text : abended job in job_scheduler: hr_tooldcvcgenratn , translated text : abended job in job_scheduler: hr_tooldcvcgenratn
# index : 7739 , original text : abended job in job_scheduler: Job_2318 , translated text : abended job in job_scheduler: Job_2318
# index : 7757 , original text : abended job in job_scheduler: Job_1967d , translated text : abend job in job scheduler: Job 1967
# index : 7823 , original text : abended job in job_scheduler: SID_37hotf , translated text : abended job in job_scheduler: SID_37hotf
# index : 7835 , original text : dell 4 in 1 , translated text : of the 4 in 1
# index : 7842 , original text : abended job in job_scheduler: Job_1148 , translated text : evening job in job scheduler: Job 1148
# index : 7851 , original text : abended job in job_scheduler: Job_461 , translated text : evening job in job scheduler: Job 461
# index : 7924 , original text : abended job in job_scheduler: Job_3182 , translated text : evening job in job scheduler: Job 3182
# index : 7927 , original text : abended job in job_scheduler: Job_593 , translated text : abended job in job_scheduler: Job_593
# index : 7952 , original text : abended job in job_scheduler: Job_549 , translated text : evening job in job scheduler: Job 549
# index : 7954 , original text : abended job in job_scheduler: SID_37hoti , translated text : abended job in job_scheduler: SID_37hoti
# index : 7962 , original text : abended job in job_scheduler: Job_1320 , translated text : evening job in job scheduler: Job 1320
# index : 8102 , original text : abended job in job_scheduler: Job_1142 , translated text : evening job in job scheduler: Job 1142
# index : 8105 , original text : abended job in job_scheduler: Job_549 , translated text : evening job in job scheduler: Job 549
# index : 8107 , original text : abended job in job_scheduler: SID_50filesys , translated text : abended job in job_scheduler: SID_50filesys
# index : 8108 , original text : abended job in job_scheduler: Job_1305 , translated text : evening job in job scheduler: Job 1305
# index : 8113 , original text : delete sto 5018072616 & 5018966647  , translated text : ceremony at 5018072616 & 5018966647
# index : 8118 , original text : abended job in job_scheduler: Job_1320 , translated text : evening job in job scheduler: Job 1320
# index : 8223 , original text : abended job in job_scheduler: Job_3181 , translated text : evening job in job scheduler: Job 3181
# index : 8231 , original text : abended job in job_scheduler: Job_501 , translated text : evening job in job scheduler: Job 501
# index : 8233 , original text : abended job in job_scheduler: Job_489 , translated text : evening job in job scheduler: Job 489
# index : 8244 , original text : abended job in job_scheduler: Job_2584 , translated text : abended job in job_scheduler: Job_2584
# index : 8247 , original text : abended job in job_scheduler: Job_481 , translated text : evening job in job scheduler: Job 481
# index : 8266 , original text : abended job in job_scheduler: Job_2114 , translated text : abended job in job_scheduler: Job_2114
# index : 8268 , original text : abended job in job_scheduler: Job_1640 , translated text : evening job in job scheduler: Job 1640
# index : 8269 , original text : abended job in job_scheduler: snp_heu_5_regen , translated text : Abended job in job_scheduler: snp_heu_5_regen
# index : 8272 , original text : abended job in job_scheduler: bwhrattr , translated text : abended job in job_scheduler: bwhrattr
# index : 8276 , original text : abended job in job_scheduler: snp_heu_1_regen , translated text : Abended job in job_scheduler: snp_heu_1_regen
# index : 8280 , original text : abended job in job_scheduler: Job_1305 , translated text : evening job in job scheduler: Job 1305
# index : 8282 , original text : abended job in job_scheduler: Job_1315 , translated text : abended job in job_scheduler: Job_1315
# index : 8284 , original text : abended job in job_scheduler: Job_1383 , translated text : abended job in job_scheduler: Job_1383
# index : 8285 , original text : abended job in job_scheduler: Job_1142 , translated text : evening job in job scheduler: Job 1142
# index : 8287 , original text : abended job in job_scheduler: SID_51_start_hana_slt , translated text : Abended job in job_scheduler: SID_51_start_hana_slt
# index : 8290 , original text : abended job in job_scheduler: SID_51start , translated text : abended job in job_scheduler: SID_51start
# index : 8293 , original text : abended job in job_scheduler: SID_47cold , translated text : abended job in job_scheduler: SID_47cold
# index : 8298 , original text : abended job in job_scheduler: Job_3032 , translated text : evening job in job scheduler: Job 3032
# index : 8299 , original text : abended job in job_scheduler: SID_51stop , translated text : abended job in job_scheduler: SID_51stop
# index : 8300 , original text : abended job in job_scheduler: Job_1665 , translated text : evening job in job scheduler: Job 1665
# index : 8301 , original text : abended job in job_scheduler: SID_51_stop_hana_slt , translated text : abended job in job_scheduler: SID_51_stop_hana_slt
# index : 8302 , original text : abended job in job_scheduler: Job_1428 , translated text : evening job in job scheduler: Job 1428
# index : 8303 , original text : abended job in job_scheduler: Job_2078 , translated text : abended job in job_scheduler: Job_2078
# index : 8310 , original text : abended job in job_scheduler: apo_cif_pds5_eu , translated text : Abended job in job_scheduler: apo_cif_pds5_eu
# index : 8311 , original text : abended job in job_scheduler: Job_1319 , translated text : abended job in job_scheduler: Job_1319
# index : 8313 , original text : abended job in job_scheduler: Job_1141 , translated text : evening job in job scheduler: Job 1141
# index : 8348 , original text : abended job in job_scheduler: Job_3194 , translated text : evening job in job scheduler: Job 3194
# index : 8350 , original text : abended job in job_scheduler: Job_1390 , translated text : evening job in job scheduler: Job 1390
# index : 8424 , original text : abended job in job_scheduler: Job_593 , translated text : abended job in job_scheduler: Job_593
# index : 8427 , original text : abended job in job_scheduler: Job_467 , translated text : evening job in job scheduler: Job 467
# index : 8434 , original text : abended job in job_scheduler: Job_481 , translated text : evening job in job scheduler: Job 481
# index : 8440 , original text : abended job in job_scheduler: Job_483 , translated text : evening job in job scheduler: Job 483
# index : 8445 , original text : aw: SID_1 erp , translated text : Or: SID_1 erp
# index : 8452 , original text : abended job in job_scheduler: Job_1148 , translated text : evening job in job scheduler: Job 1148
# index : 8454 , original text : abended job in job_scheduler: Job_1141 , translated text : evening job in job scheduler: Job 1141
# index : 8473 , original text : ess portal , translated text : ess portal
# index : 8490 , original text : machine não está funcionando , translated text : machine is not working

# %%
for x in desc_indices:
  text = df['Description'][x]
  time.sleep(6)
  translation = translator.translate(text,dest='en')
  translated_text = translation.text
  df['Description'][x] = translated_text
  print("index : {} , original text : {} , translated text : {}".format(x,text,translated_text))
# Out:
# index : 4 , original text : skype error  , translated text : skype error
# index : 124 , original text : from: tvcdfqgp nrbcqwgj
# sent: friday, october 28, 2016 3:13 pm
# to: nwfodmhc exurcwkm
# subject:  se ha bloqueado en forma temporal la sincronización de su dispositivo móvil mediante exchange activesync hasta que su administrador autorice el acceso.
#
# hi
#
# i received this message and our local it expert has told me to open a ticket.
#
#  , translated text : from: tvcdfqgp nrbcqwgj
# sent: friday, october 28, 2016 3:13 pm
# to: nwfodmhc exurcwkm
# subject: Your mobile device has been temporarily blocked from syncing via exchange activesync until your administrator authorizes access.
#
# hi
#
# i received this message and our local it expert has told me to open a ticket.
# index : 251 , original text : bitte passwort für fygrwuna gomcekzi e-mail zurücksetzen
# bitte neues passwort zu cwrikael.oanmsecr@gmail.com (manager)  , translated text : please reset password for fygrwuna gomcekzi e-mail
# please new password to cwrikael.oanmsecr@gmail.com (manager)
# index : 272 , original text : drucker / scanner em85678
#
#  scanner findet pfad nicht mehr! , translated text : printer / scanner em85678
#
#  scanner can no longer find path!
# index : 514 , original text : from: rjsulvat uanigkqc
# sent: monday, october 24, 2016 7:36 pm
# to: nwfodmhc exurcwkm
# subject: thadasgg fwd: problem with outlook
#
# it is again
#
#
#
# отправлено с iphone
#
# начало переадресованного сообщения:
# от: "rjsulvat uanigkqc" <rjsulvat.uanigkqc@gmail.com>
# кому: "nwfodmhc exurcwkm" <nwfodmhc.exurcwkm@gmail.com>
# тема: problem with outlook
# hello.
#
# i cannot start outlook
#
#
#
#
# отправлено с iphone
#
#
#  , translated text : from: rjsulvat uanigkqc
# sent: monday, october 24, 2016 7:36 pm
# to: nwfodmhc exurcwkm
# subject: thadasgg fwd: problem with outlook
#
# it is again
#
#
#
# sent from iphone
#
# start of forwarded message:
# from: "rjsulvat uanigkqc" <rjsulvat.uanigkqc@gmail.com>
# to "nwfodmhc exurcwkm" <nwfodmhc.exurcwkm@gmail.com>
# topic: problem with outlook
# hello.
#
# i cannot start outlook
#
#
#
#
# sent from iphone
# index : 605 , original text :
#
# received from: qbewrpfu.lwibmxzo@gmail.com
#
# mit freundlichen grüßen / best  , translated text : received from: qbewrpfu.lwibmxzo@gmail.com
#
# with best regards / best
# index : 621 , original text : uacyltoe hxgaycze , translated text : uacyltoe hxgaycze
# index : 764 , original text :
#
# received from: byclpwmv.esafrtbh@gmail.com
#
# [cid:image001.jpg@01d22b85.01e698a0]
#
# mit freundlichen grüßen / best  , translated text : received from: byclpwmv.esafrtbh@gmail.com
#
# [cid: image001.jpg@01d22b85.01e698a0]
#
# with best regards / best
# index : 765 , original text :
#
# received from: byclpwmv.esafrtbh@gmail.com
#
# [cid:image001.jpg@01d22b84.b25aac90]
#
# mit freundlichen grüßen / best  , translated text : received from: byclpwmv.esafrtbh@gmail.com
#
# [cid: image001.jpg@01d22b84.b25aac90]
#
# with best regards / best
# index : 777 , original text :
#
# received from: iboltufk.ezfnvcqp@gmail.com
#
# üdvözlettel / mit freundlichen grüßen / with best  , translated text : received from: iboltufk.ezfnvcqp@gmail.com
#
# üdvözlettel / with best regards / with best
# index : 863 , original text : working with the systems is almost impossible. the processing of orders is no longer possible at the moment
# das arbeiten mit den systemen ist fast nicht möglich. das abarbeiten von aufträgen ist zur zeit nicht mehr möglich , translated text : working with the systems is almost impossible. the processing of orders is no longer possible at the moment
# working with the systems is almost impossible. processing of orders is currently no longer possible
# index : 864 , original text : gehe einmal davon aus das herr aurwddwacher zum ende oktober das unternehmen verlässt bzw. in ruhestand/rente geht.
#
# im prozess der löschung des accounts (ticketing_tool – vorlage employee status termination) kann unter „special instuctrion" eine sogenannte delegation angegeben werden.
#
# somit erhält derjenige dem die postfach delegiert wurde zugriff für einen bestimmten zeitraum.
#
# die vorlage wird normalerweise vom vorgesetzten / bzw. zuständigen hr-abteilung ausgefüllt und sollte mit beiden abgesprochen werden.
#  , translated text : assume that mr aurwddwacher leaves the company or retires at the end of october.
#
# In the process of deleting the account (ticketing_tool - template employee status termination), a so-called delegation can be specified under "special instuctrion".
#
# thus the person to whom the mailbox was delegated receives access for a certain period of time.
#
# the template is usually filled out by the superior / or responsible HR department and should be discussed with both.
# index : 909 , original text :
#
# received from: trgqbeax.hfyzudql@gmail.com
#
# please restore the complete file
#
# HostName_598/hr_fd/mitarbeiter/azubis/…
#
# including all files under azubis
#
#
# danke + viele grüße
# trgqbeax hfyzudql
#  , translated text : received from: trgqbeax.hfyzudql@gmail.com
#
# please restore the complete file
#
# HostName_598 / hr_fd / employees / trainees / ...
#
# including all files under apprentices
#
#
# thank you + best regards
# trgqbeax hfyzudql
# index : 942 , original text : zugriff auf verzeichnis angefragt.
# folder access requested. HostName_768
#
# benutzer id ?
# user id ?
#
# benutzer die position titel?
# user's position title ?
#
# verzeichnis?
# folder t:\corpbusinessdev\monthly financial review\fy17\2016-9> (october 14, 2016)
#
# art des zugriffs?
# type of access ? (read only or full control) ? , translated text : access to directory requested.
# folder access requested. HostName_768
#
# user id?
# user id?
#
# user position title?
# user's position title?
#
# directory?
# folder t: \ corpbusinessdev \ monthly financial review \ fy17 \ 2016-9> (october 14, 2016)
#
# type of access?
# type of access? (read only or full control)?
# index : 967 , original text :
#
# received from: soldfnbq.uhnbsvqd@gmail.com
#
# hallo,
#
# ersuche alle meine passwörter zurückzusetzen, da gesperrt. crm,erp,vpn
#
# hello,
#
# all my passwords are locked. crm, erp, vpn
#
# mit freundlichen grüßen/ best  , translated text : received from: soldfnbq.uhnbsvqd@gmail.com
#
# Hello,
#
# I ask to reset all my passwords because they are locked. crm, erp, vpn
#
# Hello,
#
# all my passwords are locked. crm, erp, vpn
#
# with best regards / best
# index : 1016 , original text :
#
# received from: lzvdyouh.imqgfadb@gmail.com
#
# hallo,
#
# ich kann mich nicht in das impact award programdntym  einloggen oder mein pass-wort zurücksetzen.
#
#
# mit freundlichen grüßen
#
# lzvdyouh imqgfadb
#  , translated text : received from: lzvdyouh.imqgfadb@gmail.com
#
# Hello,
#
# i cannot log into the impact award program or reset my password.
#
#
# Best regards
#
# lzvdyouh imqgfadb
# index : 1018 , original text : please see below in red:
#
# viele grüße / best  , translated text : please see below in red:
#
# many greetings / best
# index : 1044 , original text : mein erp passwort funktioniert nicht. ich bin gesperrt. , translated text : my erp password doesn't work. I'm blocked, I'm banned.
# index : 1053 , original text : bitte erp kennwort zurücksetzen. , translated text : please reset erp password.
# index : 1143 , original text : das folgende word-dokument kann nicht mehr bearbeitet werden: \\edksm003\qs\zeugnis_kunden\134\134257\134257.doc (der cursor springt ständig auf seite 11). , translated text : the following word document can no longer be edited: \\ edksm003 \ qs \ zeugnis_kunden \ 134 \ 134257 \ 134257.doc (the cursor constantly jumps to page 11).
# index : 1146 , original text : hallo,
#
# bitte für jannek hündling zugriff auf den ordner department / ausbildung.
#
# mit freundlichen grüßen / best  , translated text : Hello,
#
# please access the folder department / education for jannek hündling.
#
# with best regards / best
# index : 1169 , original text : hallo ,
#
# bitte lese- u. schreibberechtigung für niptbwdq csenjruz einrichten. ist mit sbtvploj mwtrouyl besprochen.
#
# gruß
#
# lhmxposv lnpgjhus
# betriebsabteilungsleiter technische dienste
# lhmxposv.lnpgjhus@gmail.com
#
#
# geschäftsführer/managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
#
# sitz/registered office: germany - registergerirtcht/listed in the court register: germany
# persönlich haftende gesellschafterin/general partner: company company beteiligungs gmbh
# sitz/registered office: fürth/bay. - registergerirtcht/listed in the court regster: fürth
#
# von: niptbwdq csenjruz
# gesendet: montag, 17. oktober 2016 12:07
# an: jionmpsf wnkpzcmv; xmlbfjpg yegzbvru; dhoalycb yopvwrjq; lhmxposv lnpgjhus; sbtvploj mwtrouyl; joerg passiep; cwryvksu cedsairg
# betreff: aw: maschinenumstellung
#
# bei mir klappt es nicht.
#
#
#
# mit freundlichen grüßen
#
# niptbwdq csenjruz
# servicecenter instandhaltung
# niptbwdq.csenjruz@gmail.com
#  , translated text : Hello ,
#
# please read and Set up write permission for niptbwdq csenjruz. it is discussed with sbtvploj mwtrouyl.
#
# greeting
#
# lhmxposv lnpgjhus
# head of technical services department
# lhmxposv.lnpgjhus@gmail.com
#
#
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
#
# registered office: germany - registergerirtcht / listed in the court register: germany
# general partner: company company Beteiligungs gmbh
# registered office: fürth / bay. - registergerirtcht / listed in the court regster: fürth
#
# by: niptbwdq csenjruz
# sent: monday, october 17th, 2016 12:07 pm
# to: jionmpsf wnkpzcmv; xmlbfjpg yegzbvru; dhoalycb yopvwrjq; lhmxposv lnpgjhus; sbtvploj mwtrouyl; joerg passiep; cwryvksu cedsairg
# subject: aw: machine conversion
#
# it doesn't work for me.
#
#
#
# Best regards
#
# niptbwdq csenjruz
# service center maintenance
# niptbwdq.csenjruz@gmail.com
# index : 1288 , original text : keine rückmeldungen und zuteillisten möglich , translated text : no feedback and parts lists possible
# index : 1532 , original text :
#
# received from: rcmziuob.xhblozqe@gmail.com
#
# hello,
#
# i need accses to this report.
#
# \\HostName_702\departments\pubreports\fy17<file://HostName_702/departments/pubreports/fy17>
# [cid:image001.png@01d22559.75e00b60]
# vielen dank
# mit freundlichen grüßen / best  , translated text : received from: rcmziuob.xhblozqe@gmail.com
#
# hello,
#
# i need accses to this report.
#
# \\HostName_702\departments\pubreports\fy17<file://HostName_702/departments/pubreports/fy17>
# [cid:image001.png@01d22559.75e00b60]
# vielen dank
# mit freundlichen grüßen / best
# index : 1550 , original text :
#
# received from: qhyoiwls.uynrhiva@gmail.com
#
# hi,
#
# please check my computer – excel runs slowly !
#
# [cid:image001.png@01d22538.3ed1aa50]
# [cid:image002.png@01d22539.ccb60450]
#
# [cid:image003.png@01d2253a.835b8630]
#
# qhyoiwls uynrhiva
# analyst planning & reporting
# qhyoiwls.uynrhiva@gmail.com
#
#
# company shared services gmbh
# geschäftsführer: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
#
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: qhyoiwls.uynrhiva@gmail.com
#
# Hi,
#
# please check my computer - excel runs slowly!
#
# [cid: image001.png@01d22538.3ed1aa50]
# [cid: image002.png@01d22539.ccb60450]
#
# [cid: image003.png@01d2253a.835b8630]
#
# qhyoiwls uynrhiva
# analyst planning & reporting
# qhyoiwls.uynrhiva@gmail.com
#
#
# company shared services gmbh
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
#
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 1608 , original text :
#
# received from: nbdljruw.axcrspyh@gmail.com
#
# hallo zusammen,
#
# es werden bei mir keine wifi verbindungen mehr angezeigt.
# zuhause kann ich mich nicht mehr einwählen.
#
#
# bitte um hilfe.
#
# danke!
#
# mit freundlichen grüßen / best  , translated text : received from: nbdljruw.axcrspyh@gmail.com
#
# Hello everybody,
#
# I no longer see any wifi connections.
# I can no longer dial in at home.
#
#
# Please help.
#
# thank you!
#
# with best regards / best
# index : 1630 , original text :
#
# received from: xahuklgm.dqvkfjlb@gmail.com
#
# drucker  defekt
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: xahuklgm.dqvkfjlb@gmail.com
#
# printer defective
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 1667 , original text : hallo,
# bitte nur das passwort für "appricatehub.com" (impact award) zurücksetzen, da auch die sicherheitsfrage: "wie hieß die erste schule, die sie besucht haben?" nicht korrekt beantwortet werden kann.
# danke. , translated text : Hello,
# please only reset the password for "appricatehub.com" (impact award), as the security question: "What was the name of the first school you attended?" cannot be answered correctly.
# thank you.
# index : 1757 , original text : 发件人: white, ben <ben.white@hr_tool.com>
# 发送时间: 2016年10月11日 9:00:30
# 收件人: eva li; dyhtuiel.hiyhugins@company.com; stefyty parkeyhrt
# 抄送: haiwei.liang@hr_tool.com; patience, rob
# 主题: re: company intepmov imjukbqhing plan
#
# hi eva,
# can you work with your local it team to determine your desktop ip address and provide it to dyhtuiel and stefyty.
#
# hi dyhtuiel, stefyty,
# eva is a miowvyrs qkspyrdm located in the apac office . please check that the routing is in place from her network to connect over the vpn to hr_tool ( 12.161.199.3   to   185.42.190.22 ).
#
#  , translated text : 发件人: white, ben <ben.white@hr_tool.com>
# 发送时间: 2016年10月11日 9:00:30
# 收件人: eva li; dyhtuiel.hiyhugins@company.com; stefyty parkeyhrt
# 抄送: haiwei.liang@hr_tool.com; patience, rob
# 主题: re: company intepmov imjukbqhing plan
#
# hi eva,
# can you work with your local it team to determine your desktop ip address and provide it to dyhtuiel and stefyty.
#
# hi dyhtuiel, stefyty,
# eva is a miowvyrs qkspyrdm located in the apac office . please check that the routing is in place from her network to connect over the vpn to hr_tool ( 12.161.199.3   to   185.42.190.22 ).
# index : 1785 , original text : bitte passwort für benutzer "franhtyuj1" zurücksetzten, wurde mehrfach falsch eingegeben.
# danke , translated text : please reset the password for user "franhtyuj1", it was entered incorrectly several times.
# thank you
# index : 1790 , original text :
#
# received from: agjzikpf.nhfrbxek@gmail.com
#
# hi,
#
# i just tried to change my password via passwordmanager and locked me totally.
#
# would you please be so kind and unlock me again so that i can change it again ?
#
# mit freundlichen grüßen
# agjzikpf nhfrbxek
# analyst logistics
# agjzikpf.nhfrbxek@gmail.com<mailto:agjzikpf.nhfrbxek@gmail.com>
#
# company shared services gmbh
# geschäftsführer: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: agjzikpf.nhfrbxek@gmail.com
#
# Hi,
#
# i just tried to change my password via password manager and locked me totally.
#
# would you please be so kind and unlock me again so that i can change it again?
#
# Best regards
# agjzikpf nhfrbxek
# analyst logistics
# agjzikpf.nhfrbxek@gmail.com <mailto: agjzikpf.nhfrbxek@gmail.com>
#
# company shared services gmbh
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 1975 , original text : from: ftnijxup sbltduco
# sent: saturday, october 08, 2016 8:29 pm
# to: nwfodmhc exurcwkm
# subject: wg: die synchronisierung mit exchange activesync ist auf ihrem gerät vorübergehend blockiert, bis der zugriff vom administrator gewährt wird.
#
# help desk,
# please take my new iphone 6s out of quarantine.
#
#  , translated text : from: ftnijxup sbltduco
# sent: saturday, october 08, 2016 8:29 pm
# to: nwfodmhc exurcwkm
# subject: wg: the synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator.
#
# help desk,
# please take my new iphone 6s out of quarantine.
# index : 2108 , original text :
#
# received from: uagqromi.sqgtkmci@gmail.com
#
# [cid:image001.png@01d22075.f8d4be00]
#
# uagqromi sqgtkmci
# controller
# uagqromi.sqgtkmci@gmail.com<mailto:uagqromi.sqgtkmci@gmail.com>
#
# <
#
# [cid:image002.png@01d22075.f8d4be00]
#
#
#
# 本通信は記載された人物のみを対象として使用されるものとし、特権的かつ機密情報を含み、適用される法律に基づいた情報開示から除外されるものとします。正当な受取人以外のいかなる第三者による本通信の配布、流通、再販は固く禁じられています。また本通信が誤って送信された場合は、送信者に連絡の上、本通信を削除してください。
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: uagqromi.sqgtkmci@gmail.com
#
# [cid:image001.png@01d22075.f8d4be00]
#
# uagqromi sqgtkmci
# controller
# uagqromi.sqgtkmci@gmail.com <mailto:uagqromi.sqgtkmci@gmail.com>
#
# <
#
# [cid:image002.png@01d22075.f8d4be00]
#
#
#
# This Communication shall be used only for the persons listed and shall contain privileged and confidential information and shall be excluded from disclosure under applicable law. The distribution, distribution or resale of this Communication by any third party other than the authorized recipient is strictly prohibited. If this communication is sent by mistake, please contact the sender and delete this communication.
# [#+company/posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 2155 , original text : i never received access to tghkris wickhamtf's person folder on the network drive - i did get access to her collaboration_platform drive, but not her network folder.  i know her network folder is where she saved a lot of information - i really need to have access to this folder to access her documents.  also, i'm not sure why the communications i'm receiving regarding her collaboration_platform collaboration_platform are in german.
#
#
# die endgültige löschung des collaboration_platform for business von gflewxmn qnxhoryg ist in 7 tagen geplant. sie haben immer noch zeit, um wichtige dokumente an einen anderen speicherort zu kopieren. nach 7 tagen wird das collaboration_platform for business von gflewxmn qnxhoryg endgültig gelöscht. wechseln sie zum collaboration_platform for business von gflewxmn qnxhoryg unter " , translated text : i never received access to tghkris wickhamtf's person folder on the network drive - i did get access to her collaboration_platform drive, but not her network folder. i know her network folder is where she saved a lot of information - i really need to have access to this folder to access her documents. Also, i'm not sure why the communications i'm receiving regarding her collaboration_platform collaboration_platform are in german.
#
#
# the final deletion of the collaboration_platform for business from gflewxmn qnxhoryg is planned in 7 days. you still have time to copy important documents to another location. after 7 days the collaboration_platform for business from gflewxmn qnxhoryg will be permanently deleted. switch to the collaboration_platform for business from gflewxmn qnxhoryg under "
# index : 2294 , original text :
#
# received from: lgeuniqf.ijsnyxgf@gmail.com
#
# hallo kollegen,
#
# bitte mal prüfen, warum der kollege diehm diese frage gestellt bekommt auf nein klickt & sich dann nicht einloggen kann?
#
# dank & gruß
#
#
# [cid:hardcopy-cid]
#  , translated text : received from: lgeuniqf.ijsnyxgf@gmail.com
#
# Hello fellow colleagues,
#
# please check why the colleague Diehm is asked this question, clicks on no and then cannot log in?
#
# thanks & greetings
#
#
# [cid: hardcopy-cid]
# index : 2316 , original text :
#
# received from: ovhtgsxd.dcqhnrmy@gmail.com
#
# it help,
#
# i can't login erp SID_34 from home by vpn with error message below,  can you help?
#
#
# [cid:image001.png@01SID_35f0c.dcfb21c0]
#
#
# juhu jojfufn
# ap logistics manager
# e: ovhtgsxd.dcqhnrmy@gmail.com<mailto:ovhtgsxd.dcqhnrmy@gmail.com>
#
#
#
# 本讯息仅供指定的接收人使用，其中可能包含适用法律项下特许的、保密的和禁止披露的内容。除指定的接收人外，严禁其他任何人传播、分发或复制本讯息。如果您误收到本讯息，请通知发件人并将讯息删除。
# [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: ovhtgsxd.dcqhnrmy@gmail.com
#
# it help,
#
# i can't login erp SID_34 from home by vpn with error message below, can you help?
#
#
# [cid:image001.png@01SID_35f0c.dcfb21c0]
#
#
# juhu jojfufn
# ap logistics manager
# e: ovhtgsxd.dcqhnrmy@gmail.com<mailto:ovhtgsxd.dcqhnrmy@gmail.com>
#
#
#
# This message is for the use of designated recipients only, and it may contain content that is licensed, confidential and prohibited from disclosure under applicable laws. Except for the designated recipient, it is strictly forbidden for anyone else to spread, distribute or copy this message. If you have received this message in error, please notify the sender and delete the message.
# [
# select the following link to view the disclaimer in an alternate language.
# index : 2383 , original text : hallo ,
#
# mein pc zeigt blaue seite mit vielen weißen buchstaben.
# pc nr. 212622
# typ: optiplex 790
#
# bitte helfen!
#
# best  , translated text : Hello ,
#
# my pc shows a blue side with lots of white letters.
# pc no. 212622
# type: optiplex 790
#
# please help!
#
# best
# index : 2403 , original text :
#
# received from: tgafnyzb.hnevrcuj@gmail.com
#
# hallo,
#
# das öffnen von pdf-files aus engineering tool dauert heute extrem lange. manchmal erscheint auch diese meldung, ohne dass das file geöffnet wird:
#
# [cid:image001.png@01SID_35e3f.829dfa90]
#
# mit freundlichen grüßen / best  , translated text : received from: tgafnyzb.hnevrcuj@gmail.com
#
# Hello,
#
# opening pdf files from engineering tools takes an extremely long time. sometimes this message also appears without the file being opened:
#
# [cid: image001.png@01SID_35e3f.829dfa90]
#
# with best regards / best
# index : 2415 , original text :
# zugriff auf verzeichnis angefragt.
# folder access requested.
#
# benutzer id ?
# user id ?ahujajtyhur
#
# benutzer die position titel?
# user's position title ?executive sales admin
#
# verzeichnis?
# folder ?\\891245132\scan
#
# art des zugriffs?
# type of access ? (read only or full control) ?full
#
# name des vorgesetzten?
# manager name?cobsfvjz apkqmrdu
#
# received from: ohdrnswl.rezuibdt@gmail.com
#
# hi,
#
# please help to assign scanner to my system 891245132.
#
# best  , translated text : access to directory requested.
# folder access requested.
#
# user id?
# user id? ahujajtyhur
#
# user position title?
# user's position title? executive sales admin
#
# directory?
# folder? \\ 891245132 \ scan
#
# type of access?
# type of access? (read only or full control)? full
#
# Name of supervisor?
# manager name? cobsfvjz apkqmrdu
#
# received from: ohdrnswl.rezuibdt@gmail.com
#
# Hi,
#
# please help to assign scanner to my system 891245132.
#
# best
# index : 2422 , original text : mr. kothyherr has not received any mail from ethics since a long time. he thinks he should have received at least 2-3 mails during this period. that is why he is unable to do the course.
# he insists ethics to look into it.
#
#
#
# received from: ecoljnvt.lbdqmvfs@gmail.com
#
# hallo kollegen,
#
# ich sollte eigentlich meine ethics vorgänge abarbeiten.
#
# dazu habe ich jedoch keinerlei erinnerungsinformationen bekommen noch einen link wie ich in das portal komme.
#
# deswegen habe ich versucht über hub in das portal zu kommen.
#
# dazu habe ich auf login  gedrückt!
#
# [cid:image005.jpg@01SID_35e26.0dda3340]
#
# dann auf den button deutsch.
#
# [cid:image006.jpg@01SID_35e26.0dda3340]
#
# dann kommt jedoch keine offene session!
#
# was ist zu tun?
#
# mit freundlichen grüßen / best  , translated text : mr. kothyherr has not received any mail from ethics since a long time. he thinks he should have received at least 2-3 mails during this period. that is why he is unable to do the course.
# he insists ethics to look into it.
#
#
#
# received from: ecoljnvt.lbdqmvfs@gmail.com
#
# Hello fellow colleagues,
#
# i should actually work through my ethics procedures.
#
# however, I have not received any reminder information or a link on how to get into the portal.
#
# that's why i tried to access the portal via hub.
#
# for this I pressed on login!
#
# [cid: image005.jpg@01SID_35e26.0dda3340]
#
# then on the button deutsch.
#
# [cid: image006.jpg@01SID_35e26.0dda3340]
#
# then there is no open session!
#
# What should I do?
#
# with best regards / best
# index : 2439 , original text :
#
# received from: hbmwlprq.ilfvyodx@gmail.com
#
# [cid:image001.png@01SID_35e17.ad30bfe0]
#
# mit freundlichem gruß / kind  , translated text : received from: hbmwlprq.ilfvyodx@gmail.com
#
# [cid: image001.png@01SID_35e17.ad30bfe0]
#
# best regards / child
# index : 2551 , original text :
#
# received from: qgrbnjiu.hidzlfma@gmail.com
#
# hi
#
# i have just started having below system massage and it prompts every time i move from erp nord to nord, bothering me. please advise what this is about, and what should i do on this?
#
# [cid:image001.png@01SID_35d90.73d9b7b0]
#
#
#
# qgrbnjiu hidzlfma
# manager, warehouse & distribution
# qgrbnjiu.hidzlfma@gmail.com<mailto:qgrbnjiu.hidzlfma@gmail.com>
#
#
#
# 本通信は記載された人物のみを対象として使用されるものとし、特権的かつ機密情報を含み、適用される法律に基づいた情報開示から除外されるものとします。正当な受取人以外のいかなる第三者による本通信の配布、流通、再販は固く禁じられています。また本通信が誤って送信された場合は、送信者に連絡の上、本通信を削除してください。
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: qgrbnjiu.hidzlfma@gmail.com
#
# hi
#
# i have just started having below system massage and it prompts every time i move from erp nord to nord, bothering me. please advise what this is about, and what should i do on this?
#
# [cid:image001.png@01SID_35d90.73d9b7b0]
#
#
#
# qgrbnjiu hidzlfma
# manager, warehouse & distribution
# qgrbnjiu.hidzlfma@gmail.com <mailto:qgrbnjiu.hidzlfma@gmail.com>
#
#
#
# This Communication shall be used only for the persons listed and shall contain privileged and confidential information and shall be excluded from disclosure under applicable law. The distribution, distribution or resale of this Communication by any third party other than the authorized recipient is strictly prohibited. If this communication is sent by mistake, please contact the sender and delete this communication.
# [#+company/posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 2721 , original text : from: lmwohkbd ucziatex
# sent: friday, september 30, 2016 11:42 am
# to: nyifqpmv kfirxjag
# subject: aw: travel expense manager
#
# hello
#
# transaktion „pr05" also doesn't work for personal no's 56595674 and 5634561.
#
# mit freundlichen grüßen
#
# lmwohkbd ucziatex
# programdnty engineering europe
# lmwohkbd.ucziatex@gmail.com
#
# geschäftsführer: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
# von: lmwohkbd ucziatex
# gesendet: freitag, 30. september 2016 08:03
# an: nyifqpmv kfirxjag <nmtszgbr.wnthvqgm@gmail.com>
# betreff: travel expense manager
#
# hello
#
# „travel expense manager" doesn't work!
#
#
#
#
# mit freundlichen grüßen
#
# lmwohkbd ucziatex
# programdnty engineering europe
# lmwohkbd.ucziatex@gmail.com
#
#  , translated text : from: lmwohkbd ucziatex
# sent: friday, september 30, 2016 11:42 am
# to: nyifqpmv kfirxjag
# subject: aw: travel expense manager
#
# Hello
#
# transaction "pr05" also doesn't work for personal no's 56595674 and 5634561.
#
# Best regards
#
# lmwohkbd ucziatex
# programdnty engineering europe
# lmwohkbd.ucziatex@gmail.com
#
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
# by: lmwohkbd ucziatex
# Sent: Friday, September 30th, 2016 8:03 am
# to: nyifqpmv kfirxjag <nmtszgbr.wnthvqgm@gmail.com>
# subject: travel expense manager
#
# Hello
#
# "Travel expense manager" doesn't work!
#
#
#
#
# Best regards
#
# lmwohkbd ucziatex
# programdnty engineering europe
# lmwohkbd.ucziatex@gmail.com
# index : 2841 , original text : mm 4983099
# bestellnumer 5019289193
#  , translated text : mm 4983099
# order number 5019289193
# index : 2878 , original text : from: tsbnfixp numwqahj
# sent: wednesday, september 28, 2016 9:01 pm
# to: nwfodmhc exurcwkm
# subject: amar wg: die synchronisierung mit exchange activesync ist auf ihrem gerät vorübergehend blockiert, bis der zugriff vom administrator gewährt wird.
# importance: high
#
# please usa access for that company owned device.
# user-id: grbhybrdg
# tsbnfixp numwqahj
#
# thanking you in anticipation!
#
# oqlcdvwi pulcqkzo
#
#
# von: microsoft outlook
# gesendet: mittwoch, 28. september 2016 17:29
# an: tsbnfixp numwqahj <tsbnfixp.numwqahj@gmail.com>
# betreff: die synchronisierung mit exchange activesync ist auf ihrem gerät vorübergehend blockiert, bis der zugriff vom administrator gewährt wird.
#
# der zugriff von ihrem mobilen gerät auf inhalte über exchange activesync ist vorrübergehend blockiert, da es in quarantäne gestellt ist. sie müssen keine aktion durchführen. der inhalt wird automatisch heruntergeladen, sobald der zugriff vom administrator gewährt wird.
#
# please ignore the above paragraph. we cannot change it or delete it.
#
# special note 30-jan-2015: the microsoft outlook app for ios and android released yesterday is not currently approved software for accessing company e-mail. until it is uacyltoe hxgayczeed and approved, please consider using one of the other (1) the embedded e-mail software in your mobile device (2) the browser on your mobile device or (3) the microsoft owa app published for your mobile device platform.
#
# beginning 01-mar-2012 employees, with supervisor approval, may use personally owned mobile devices to access outlook email. company is moving forward and providing the opportstorage_product for our employees to use specified personally owned devices to allow for productivity improvement and enable work-life balance. this is an addition to the policy for company owned devices.
#
# currently approved handheld devices can be found in this policy:
#
# wireless mobility technical document
#
# the above policy will be updated as other devices are approved for use.
#
# if you own an approved device and would like to take advantage of this opportstorage_product you can submit a ticketing_tool ticket to the it global support center (gsc). if it is a personally owned device, you need to attach the agreement form found in the wireless mobility standard procedure. this agreement must be signed by you and your next level supervisor and provided to the gsc prior to a ticket being entered. you can attach the signed form to the ticket or send the signed form to the gsc and they will attach it.
#
# any ticket without the signed form will be cancelled. you have 2 weeks to process and submit the form before your device will be denied (deleted from quarantine).
#
# wireless mobility standard procedure
# informationen zu ihrem mobilen gerät:
# gerätemodell: iphone6c2
# gerätetyp: iphone
# geräte-id: fvqfj874r56gj3r4jb39kdgu3s
# gerätebetriebssystem: ios 10.0.sartlgeo lhqksbdx4a403
# gerätebenutzer-agent: apple-iphone6c2/1401.403
# geräte-imei:
# exchange activesync-version: 16.0
# gerätezugriffsstatus: quarantined
# grund für gerätezugriffsstatus: global
# um 28.09.2016 15:28:41 an tsbnfixp.numwqahj@gmail.com gesendet.
#  , translated text : from: tsbnfixp numwqahj
# sent: wednesday, september 28, 2016 9:01 pm
# to: nwfodmhc exurcwkm
# subject: amar wg: synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator.
# importance: high
#
# please usa access for that company owned device.
# user-id: grbhybrdg
# tsbnfixp numwqahj
#
# thanking you in anticipation!
#
# oqlcdvwi pulcqkzo
#
#
# from: microsoft outlook
# Broadcast: Wednesday, September 28, 2016 5:29 PM
# to: tsbnfixp numwqahj <tsbnfixp.numwqahj@gmail.com>
# re: the synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator.
#
# access from your mobile device to content via exchange activesync is temporarily blocked because it is in quarantine. you don't need to take any action. the content will be downloaded automatically as soon as access is granted by the administrator.
#
# please ignore the above paragraph. we cannot change it or delete it.
#
# special note 30-jan-2015: the microsoft outlook app for ios and android released yesterday is not currently approved software for accessing company e-mail. until it is uacyltoe hxgayczeed and approved, please consider using one of the other (1) the embedded e-mail software in your mobile device (2) the browser on your mobile device or (3) the microsoft owa app published for your mobile device platform.
#
# beginning 01-mar-2012 employees, with supervisor approval, may use personally owned mobile devices to access outlook email. company is moving forward and providing the opportstorage_product for our employees to use specified personally owned devices to allow for productivity improvement and enable work-life balance. This is an addition to the policy for company owned devices.
#
# currently approved handheld devices can be found in this policy:
#
# wireless mobility technical document
#
# the above policy will be updated as other devices are approved for use.
#
# if you own an approved device and would like to take advantage of this opportstorage_product you can submit a ticketing_tool ticket to the it global support center (gsc). if it is a personally owned device, you need to attach the agreement form found in the wireless mobility standard procedure. This agreement must be signed by you and your next level supervisor and provided to the gsc prior to a ticket being entered. You can attach the signed form to the ticket or send the signed form to the gsc and they will attach it.
#
# any ticket without the signed form will be canceled. you have 2 weeks to process and submit the form before your device will be denied (deleted from quarantine).
#
# wireless mobility standard procedure
# information about your mobile device:
# device model: iphone6c2
# device type: iphone
# device id: fvqfj874r56gj3r4jb39kdgu3s
# device operating system: ios 10.0.sartlgeo lhqksbdx4a403
# device user agent: apple-iphone6c2 / 1401.403
# device-imei:
# exchange activesync version: 16.0
# device access status: quarantined
# reason for device access status: global
# at 09/28/2016 3:28:41 PM to tsbnfixp.numwqahj@gmail.com.
# index : 2974 , original text :
#
# received from: yzbjhmpw.vzrulkog@gmail.com
#
# [cid:image001.png@01SID_35974.fdbf2930]
#
#
#
#
#
# mit freundlichem gruß
#
# ulrike aßmann
# custom solutions engineering europe  drilling&countersinking
# yzbjhmpw.vzrulkog@gmail.com<mailto:yzbjhmpw.vzrulkog@gmail.com>
# t:+49-911-0846609
# f:+49-911-0846631
#
# company shared services gmbh, wehlauer strasse 73, d-90766 fürth, www.company.com<
#
# company shared services gmbh
# geschäftsführer: phvkowml azbtkqwx, naruedlk mpvhakdq
# sitz der gesellschaft: fürth/bay. - registergerirtcht: fürth/bay. hrb 10171
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: yzbjhmpw.vzrulkog@gmail.com
#
# [cid: image001.png@01SID_35974.fdbf2930]
#
#
#
#
#
# Sincerely
#
# ulrike aßmann
# custom solutions engineering europe drilling & countersinking
# yzbjhmpw.vzrulkog@gmail.com <mailto: yzbjhmpw.vzrulkog@gmail.com>
# t: + 49-911-0846609
# f: + 49-911-0846631
#
# company shared services gmbh, wehlauer strasse 73, d-90766 fürth, www.company.com <
#
# company shared services gmbh
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
# registered office of the company: fürth / bay. - registered law: fürth / bay. hrb 10171
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 3235 , original text : hallo liebe kollegen,
#
# warum habe ich diese e-mail bekommen?
# hat jemand etwas modifiziert in meine e-mail postfach?
#
# üdvözlettel / mit freundlichen grüßen / best  , translated text : Hello dear colleagues,
#
# why did i get this e-mail?
# has someone modified something in my e-mail inbox?
#
# üdvözlettel / best regards / best
# index : 3381 , original text :
#
# received from: jogtse.mhytusa@company.com
#
# hello
#
# could you please help us to add the customers below to engineering tool software
#
# 81945970
#
# maquinados de precision de mex
#
# 81039422
#
# magonza sa de cv
#
# 81039927
#
# evercast s.a. de c.v.
#
# 81030720
#
# tecnologia en maquinados hidra
#
#
#
# saludos
#
#
# johjkse luartusa rahymos
#
# representante de ventas zona bajio
#
#
# este mensaje está destinado al uso exclusivo de la persona a quien está dirigido y puede contener información privilegiada, confidencial y que está exenta de ser revelada conforme con lo dispuesto en la legislación vigente. toda difusión, distribución o reproducción de este mensaje por parte de otra persona que no sea el receptor al que está destinado queda estrictamente prohibida. si recibe este mensaje por error, se ruega que lo notifique al remitente y borre este mensaje.
# [#+company/posts>[
# select the following link to view the disclaimer in an alternate language.
#
#
#
# este mensaje está destinado al uso exclusivo de la persona a quien está dirigido y puede contener información privilegiada, confidencial y que está exenta de ser revelada conforme con lo dispuesto en la legislación vigente. toda difusión, distribución o reproducción de este mensaje por parte de otra persona que no sea el receptor al que está destinado queda estrictamente prohibida. si recibe este mensaje por error, se ruega que lo notifique al remitente y borre este mensaje.
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: jogtse.mhytusa@company.com
#
# Hello
#
# could you please help us to add the customers below to engineering tool software
#
# 81945970
#
# mex precision machining
#
# 81039422
#
# magonza sa de cv
#
# 81039927
#
# evercast s.a. of c.v.
#
# 81030720
#
# hydra machining technology
#
#
#
# regards
#
#
# johjkse luartusa rahymos
#
# bajio sales representative
#
#
# This message is intended for the exclusive use of the person to whom it is addressed and may contain privileged, confidential information that is exempt from being disclosed in accordance with the provisions of current legislation. Any dissemination, distribution or reproduction of this message by someone other than the intended recipient is strictly prohibited. If you receive this message in error, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
#
#
#
# This message is intended for the exclusive use of the person to whom it is addressed and may contain privileged, confidential information that is exempt from being disclosed in accordance with the provisions of current legislation. Any dissemination, distribution or reproduction of this message by someone other than the intended recipient is strictly prohibited. If you receive this message in error, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 3673 , original text : die synchronisierung mit exchange activesync ist auf ihrem gerät vorübergehend blockiert, bis der zugriff vom administrator gewährt wird. , translated text : synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator.
# index : 3872 , original text : could you reset my company mobile phone. details are below.
#
# cihaz modeli: iphone7c2
# cihaz türü: iphone
# cihaz kimliği: 8hnorau8ap7era614bd7lb3t7c
# cihaz işletim sistemi: ios 10.0.sartlgeo lhqksbdx4a403
# cihaz kullanıcı aracısı: apple-iphone7c2/1401.403
# cihaz imei: 352090078991606
# exchange activesync sürümü: 16.1
# cihaz erişim durumu: quarantined
# cihaz erişim durumu nedeni: global
#  , translated text : could you reset my company mobile phone. Details are below.
#
# device model: iphone7c2
# device type: iphone
# device id: 8hnorau8ap7era614bd7lb3t7c
# device operating system: ios 10.0.sartlgeo lhqksbdx4a403
# device user agent: apple-iphone7c2 / 1401.403
# device imei: 352090078991606
# exchange activesync version: 16.1
# device access status: quarantined
# device access state reason: global
# index : 4067 , original text :
#
# received from: wsczgfal.hjfklsdg@gmail.com
#
# witam,
#
# zgłaszam kłopoty z engineering_tool-em
#
# [cid:image001.png@01SID_351c2.c943d840]
#
# nie można zrobić synchronizacji, brak raportów itp.
#
# pozdrawiam/best  , translated text : received from: wsczgfal.hjfklsdg@gmail.com
#
# Hello,
#
# I'm reporting trouble with engineering_tool
#
# [cid: image001.png@01SID_351c2.c943d840]
#
# can't do sync, no reports etc.
#
# greet / best
# index : 4084 , original text : 请将密码设置为：sdguo1609 , translated text : Please set the password as: sdguo1609
# index : 4330 , original text : fyi
#
# von: axesnghb cyzuomxa
# gesendet: donnerstag, 15. september 2016 10:19
# an: ughzilfm cfibdamq
# cc: tmqfjard qzhgdoua
# betreff: tmqfjard qzhgdoua : berechtigung für EU_tool- module
#
#
# hallo herr bghakch,
#
#
# herr tmqfjard qzhgdoua, stamm- nr. 100937,   benötigt vollen zugriff auf folgende EU_tool- module :
#
# chargenverwaltung
#
# pulverleitstand
#
#
#
#
# mit freundlichen grüßen
#
#  preuß
# supervisor rod production germany
# axesnghb.cyzuomxa@gmail.com
#
# geschäftsführer/managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
# sitz/registered office: germany
#
# persönlich haftende gesellschafterin/general partner: company gmbh
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
#
# select the following link to view the disclaimer in an alternate language.
#  , translated text : fyi
#
# by: axesnghb cyzuomxa
# Sent: Thursday, September 15, 2016 10:19 am
# to: ughzilfm cfibdamq
# cc: tmqfjard qzhgdoua
# subject: tmqfjard qzhgdoua: authorization for EU_tool- module
#
#
# hello mr bghakch,
#
#
# mr tmqfjard qzhgdoua, trunk no. 100937, requires full access to the following EU_tool modules:
#
# batch management
#
# powder control station
#
#
#
#
# Best regards
#
#  prussia
# supervisor rod production germany
# axesnghb.cyzuomxa@gmail.com
#
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
# registered office: germany
#
# general partner: company gmbh
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
#
# select the following link to view the disclaimer in an alternate language.
# index : 4336 , original text : hallo ,
#
# der monitor von ahmet gök im materiallager macht probleme.
# kannst du dir das bitte anschauen.
#  , translated text : Hello ,
#
# the monitor from ahmet gök in the material warehouse causes problems.
# can you please have a look at that.
# index : 4390 , original text :
#
# received from: lixwgnto.krutnylz@gmail.com
#
# please unlock user ghjvreicj immediately in erp and extend the account to 31 dec 16.
# it is immediately needed – tomorrow is our py run!!!!
#
# von: tszvorba wtldpncx [mailto:jreichard@ppstrixner.de]
# gesendet: mittwoch, 14. september 2016 16:57
# an: nkjtoxwv wqtlzvxu
# cc: lixwgnto krutnylz
# betreff: in erp gesperrt - bitte dringend wieder frei schalten
# wichtigkeit: hoch
#
# hallo herr hohgajnn,
#
# ich wollte mich eben ein weiteres mal anmelden und habe auch sicher die korrekten anmeldedaten eingegeben.
# leider bin ich nun gesperrt.
# in anbetracht der bevorstehenden abrechnung benötige ich dringend eine freischaltung in erp.
#
# vielen dank im voraus und viele grüße
#
#
# tszvorba wtldpncx
# teamleitung
#
# [logo neu final klein]
#
# personal partner strixner gmbh
#
#
#
# [cid:image005.jpg@01d20ea9.0c16ac00]
#
#
#
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: lixwgnto.krutnylz@gmail.com
#
# please unlock user ghjvreicj immediately in erp and extend the account to 31 dec 16.
# it is immediately needed - tomorrow is our py run !!!!
#
# by: tszvorba wtldpncx [mailto: jreichard@ppstrixner.de]
# Broadcast: Wednesday, September 14, 2016 4:57 PM
# to: nkjtoxwv wqtlzvxu
# cc: lixwgnto krutnylz
# subject: blocked in erp - please activate again urgently
# Importance: High
#
# Hello Mr. Hohgajnn,
#
# ...
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: ptuchwad.yzvrlcqa@gmail.com
#
# Hello
#
# can not start on computer outlook and crm syncs for hours
# this also blocks other things (e.g. engineering_tool)
#
# ask for help - sitting at the computer
#
#
#
# Sincerely yours
# -uwe schröck
# technical advice and sales
# ptuchwad.yzvrlcqa@gmail.com <mailto: ptuchwad.yzvrlcqa@gmail.com>
# mobile 0175 4356 741 <tel: 0175% 204356% 20741>
#
# company deutschland gmbh / max-planck-straße 13 / d-61381 germany /www.company.com <
#
# company deutschland gmbh
# managing directors: rfwlsoej yvtjzkaw, harald male
# Registered office of the company: germany / hgermany - registration law: bad homburg / hgermany hrb 7492
#
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 7462 , original text : dear it，
#
# 以下是sipppr的入口链接。
#
#
#
# 我登录进去后 pdf文件不能编辑，帮忙看看是什么问题，adobe reader 版本需要更新？
#
# 如下两个链接：
#
#
#
#
#
#
# best  , translated text : dear it,
#
# The following is the entry link for sipppr.
#
#
#
# After I log in, the pdf file cannot be edited. Please help to find out what the problem is. The adobe reader version needs to be updated?
#
# The following two links:
#
#
#
#
#
#
# best
# index : 7534 , original text : collaboration_platform online is not opening.
#
# error : diese seite kann nicht angezeigt warden. , translated text : collaboration platform online is not opening.
# error: this page cannot be displayed.
# index : 7724 , original text :
#
# received from: franhtyu.liu@company.com
#
# franhtyu liu would like to recall the message, "ticket_no1536413 -- comments added".
#
#
# 本讯息仅供指定的接收人使用，其中可能包含适用法律项下特许的、保密的和禁止披露的内容。除指定的接收人外，严禁其他任何人传播、分发或复制本讯息。如果您误收到本讯息，请通知发件人并将讯息删除。
# [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: franhtyu.liu@company.com
#
# franhtyu liu would like to recall the message, "ticket_no1536413 - comments added".
#
#
# This message is for the use of designated recipients only, and it may contain content that is licensed, confidential and prohibited from disclosure under applicable laws. Except for the designated recipient, it is strictly forbidden for anyone else to spread, distribute or copy this message. If you have received this message in error, please notify the sender and delete the message.
# [
# select the following link to view the disclaimer in an alternate language.
# index : 7813 , original text : es kann keine auftrag gedruckt werden. ziehe fehler.  , translated text : no order can be printed. draw bugs.
# index : 7817 , original text :
#
# received from: krdvgzeh.yboasemp@gmail.com
#
# üdvözlettel / mit freundlichen grüßen / best  , translated text : received from: krdvgzeh.yboasemp@gmail.com
#
# üdvözlettel / best regards / best
# index : 7821 , original text : error:
# verbindung zu system production_order_interface_app-fu mit destination
# production_order_interface_vendor-connc-fu fehlerhaft:
# fehler beim öffnen einer rfc-verbindung (cpic-call
# (1). , translated text : error:
# connection to system production_order_interface_app-fu with destination
# production_order_interface_vendor-connc-fu incorrect:
# error when opening an rfc connection (cpic-call
# (1).
# index : 7822 , original text :
#
# received from: sxhcapoe.kbluefip@gmail.com
#
# hello,
# path to the folder:
# \\HostName_705\departments\lean\lean³-projekte\lean-projekte_geplant\fy17<file:///\\HostName_705\departments\lean\lean³-projekte\lean-projekte_geplant\fy17>
#
#
# --
# mit freundlichen grüßen / best  , translated text : received from: sxhcapoe.kbluefip@gmail.com
#
# Hello,
# path to the folder:
# \\ HostName_705 \ departments \ lean \ lean³-projects \ lean-projects_planned \ fy17 <file: /// \\ HostName_705 \ departments \ lean \ lean³-projects \ lean-projects_planned \ fy17>
#
#
# -
# with best regards / best
# index : 7825 , original text :
#
# received from: gsnuhpji.qpyfctwl@gmail.com
#
# es wird nichts mehr ausgedruckt
# fehlermeldung
# [cid:image001.png@01d1f3ba.6428d800]
#
# mit freundlichen grüßen / best  , translated text : received from: gsnuhpji.qpyfctwl@gmail.com
#
# nothing is printed out anymore
# error message
# [cid: image001.png@01d1f3ba.6428d800]
#
# with best regards / best
# index : 7896 , original text : zugriff auf verzeichnis angefragt.
# folder access requested.
#
# benutzer id ?
# user id karagtfma
#
# benutzer die position titel?
# user's position title  manager commodities amerirtcas
#
# verzeichnis?
# folder //HostName_768   all items under purchasing
#
# art des zugriffs?
# type of access ? (read only or full control) full control
#
# name des vorgesetzten?
# manager name? , translated text : access to directory requested.
# folder access requested.
#
# user id?
# user id karagtfma
#
# user position title?
# user's position title manager commodities amerirtcas
#
# directory?
# folder // HostName_768 all items under purchasing
#
# type of access?
# type of access? (read only or full control) full control
#
# Name of supervisor?
# manager name?
# index : 7940 , original text : das passwort wurde meinerseits falsch eingegeben. bitte passwort zurücksetzen (engineering tool und erp). danke
#  , translated text : the password was entered incorrectly on my part. please reset password (engineering tool and erp). thank you
# index : 8012 , original text : see att , translated text : see att
# index : 8018 , original text : date of email: 07/20/2016 (i have attached both email, the one i sent and was not delivered and the other i have received with the delivery error message)
# sender's name: uidgt olibercsu (kbnfxpsy.gehxzayq@gmail.com)
# recipient if not caller: jgnxyahz cixzwuyf (jgnxyahz.cixzwuyf@gmail.com)
# delivery failure code: 0x9115121f-0x9115121f-0x000501
# delivery failure text:sua mensagem não foi recebida por um ou mais dos destinatários.
#
#       assunto: enc: curso: "customer logistics services (cls)"
#       enviada em: 20/07/2016 19:56
#
# não é possível encontrar os seguintes destinatários:
#
#       jgnxyahz cixzwuyf em 20/07/2016 19:56
#             esta mensagem não pôde ser enviada. tente enviar a mensagem novamente mais tarde ou contate o administrador da rede. o erro a operação do cliente falhou. é [0x9115121f-0x9115121f-0x000501].
#  , translated text : date of email: 07/20/2016 (i have attached both email, the one i sent and was not delivered and the other i have received with the delivery error message)
# sender's name: uidgt olibercsu (kbnfxpsy.gehxzayq@gmail.com)
# recipient if not caller: jgnxyahz cixzwuyf (jgnxyahz.cixzwuyf@gmail.com)
# delivery failure code: 0x9115121f-0x9115121f-0x000501
# delivery failure text: your message was not received by one or more of the recipients.
#
#       subject: enc: course: "customer logistics services (cls)"
#       sent on: 07/20/2016 19:56
#
# the following recipients cannot be found:
#
#       jgnxyahz cixzwuyf on 7/20/2016 7:56 PM
#             this message could not be sent. try sending the message again later or contact your network administrator. the error the client operation failed. is [0x9115121f-0x9115121f-0x000501].
# index : 8025 , original text :
#
# received from: trgqbeax.hfyzudql@gmail.com
#
# please restore from august 5th 2016
#
# westes$(\\HostName_598<file:///\\HostName_598>) / betriebliche regelungen und bv / bv / anlage 2a bv bonus im ad fy17.docx
#
#
#
#
# danke + viele grüße
# trgqbeax hfyzudql
#
# mit freundlichen grüßen |  best  , translated text : received from: trgqbeax.hfyzudql@gmail.com
#
# please restore from august 5th 2016
#
# westes $ (\\ HostName_598 <file: /// \\ HostName_598>) / operational regulations and bv / bv / annex 2a bv bonus in ad fy17.docx
#
#
#
#
# thank you + best regards
# trgqbeax hfyzudql
#
# with best regards | best
# index : 8224 , original text : stepfhryhan needs access to below collaboration_platform links.
#
# urlaubsplanung (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/urlaubsplanung)
# 3p pläne (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/3p%20pl%e4ne)
#
# allgemeines (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/allgemeines)
# berirtchtswesen gebiet nord (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/berirtchtswesen%20gebiet%20nord)
#
# crm teamordner (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/crm%20teamordner)
#
# teamcall teammeeting (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/teamcall%20teammeeting)
#
# top 5 projekte (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/top%205%20projekte)
#
#
#
# hallo sabrthy,
#
# wie weit sind wir in diesem thema? habe noch kein ticket erhalten…
#
# mit freundlichen grüßen
# nizholae bjnqikym
# anwendungstechniker i application engineer
# nizholae.bjnqikym@gmail.com
#
# company deutschland gmbh
#
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
#
# select the following link to view the disclaimer in an alternate language.
#
# von: nizholae bjnqikym
# gesendet: donnerstag, 21. juli 2016 12:16
# an: aorthyme rnsuipbk <aorthyme.rnsuipbk@gmail.com>
# betreff: aw: no access to netweaver.
#
# danke sabrthy…
#
# mit freundlichen grüßen
# nizholae bjnqikym
# anwendungstechniker i application engineer
# nizholae.bjnqikym@gmail.com
#
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
#
# select the following link to view the disclaimer in an alternate language.
#
# von: aorthyme rnsuipbk
# gesendet: donnerstag, 21. juli 2016 12:03
# an: nizholae bjnqikym <nizholae.bjnqikym@gmail.com>
# betreff: re: no access to netweaver.
#
# hallo stepfhryhan,
#
# das nimmt ein bisschen zeit. ich erfasse ein ticket dazu.
#
#
# warm  , translated text : stepfhryhan needs access to below collaboration_platform links.
#
# urlaubsplanung (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / urlaubsplanung)
# 3p pläne (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / 3p% 20pl% e4ne)
#
# allgemeines (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / allgemeines)
# berirtchtswesen area nord (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / berirtchtswesen% 20gebiet% 20nord)
#
# crm teamordner (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / crm% 20teamordner)
#
# teamcall teammeeting (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / teamcall% 20teammeeting)
#
# top 5 projects (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / top% 205% 20projekte)
#
#
#
# hello sabrthy,
#
# how far are we in this topic? have not received a ticket yet…
#
# with kind regards
# nizholae bjnqikym
# application technician and application engineer
# nizholae.bjnqikym@gmail.com
#
# company deutschland gmbh
#
#
#
#
# this communication is unique and intended solely for the use of the addressee and may contain information that is protected, confidential or in accordance with applicable law from disclosure. the dissemination, distribution or multiplication of this communication by persons who are not the intended recipient is strictly prohibited. if this message was entered into them due to an accident, please notify the sender and delete this message.
#
# select the following link to view the disclaimer in an alternate language.
#
# von: nizholae bjnqikym
# Posted: Thu Jul 21, 2016 12:16 pm Post subject:
# an: aorthyme rnsuipbk <aorthyme.rnsuipbk@gmail.com>
# regards: aw: no access to netweaver.
#
# danke sabrthy…
#
# with kind regards
# nizholae bjnqikym
# application technician and application engineer
# nizholae.bjnqikym@gmail.com
#
#
#
#
# this communication is unique and intended solely for the use of the addressee and may contain information that is protected, confidential or in accordance with applicable law from disclosure. the dissemination, distribution or multiplication of this communication by persons who are not the intended recipient is strictly prohibited. if this message was entered into them due to an accident, please notify the sender and delete this message.
#
# select the following link to view the disclaimer in an alternate language.
#
# by: aorthyme rnsuipbk
# Posted: Thu Jul 21, 2016 12:03 pm Post subject:
# an: nizholae bjnqikym <nizholae.bjnqikym@gmail.com>
# regards: re: no access to netweaver.
#
# hello stepfhryhan,
#
# that takes a little time. I'm collecting a ticket for that.
#
#
# warm
# index : 8419 , original text :  user id : vvrtgwildj
# name : johghajknnes wildschuetz
#
# user logging in for the first time and getting
#
# error : die sicherheisdatenbank auf dem server enthält kein computerkonto für diese arbeitsstationsvertrauensstellung
# error: the security database on the server does not contain a computer account for this workstation trust relationship
# computer name : efdl8111226
#
# contact # :
#  , translated text : user id: vvrtgwildj
# name: johghajknnes wildschuetz
#
# user logging in for the first time and getting
#
# error: the security database on the server does not contain a computer account for this workstation trust relationship
# error: the security database on the server does not contain a computer account for this workstation trust relationship
# computer name: efdl8111226
#
# contact #:
# index : 8459 , original text : from: ntydihzo aeptfbgs
# sent: friday, august 05, 2016 2:51 am
# to: nwfodmhc exurcwkm
# subject: wg: die synchronisierung mit exchange activesync ist auf ihrem gerät vorübergehend blockiert, bis der zugriff vom administrator gewährt wird.
# importance: high
#
# hi it help team,
#
# please unblock my new company device.
#
#  , translated text : from: ntydihzo aeptfbgs
# sent: friday, august 05, 2016 2:51 am
# to: nwfodmhc exurcwkm
# subject: wg: the synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator.
# importance: high
#
# hi it help team,
#
# please unblock my new company device.

# %%
for x in joint_indices:
  text_sd = df['Short description'][x]
  text_desc = df['Description'][x]
  time.sleep(6)
  translation_sd = translator.translate(text_sd,dest='en')
  translation_desc = translator.translate(text_desc,dest='en')
  df['Short description'][x] = translation_sd.text
  df['Description'][x] = translation_desc.text
  print("index : {} , text1 : {} , text2 : {}".format(x,df['Short description'][x],df['Description'][x]))
# Out:
# index : 164 , text1 : Withdrawn: ticket_no1564867 - comments added , text2 : received from: abcdri@company.com
#
# windy shi will withdraw the email "ticket_no1564867 - comments added".
#
#
# This message is for the use of designated recipients only, and it may contain content that is licensed, confidential and prohibited from disclosure under applicable laws. Except for the designated recipient, it is strictly forbidden for anyone else to spread, distribute or copy this message. If you have received this message in error, please notify the sender and delete the message.
# [
# select the following link to view the disclaimer in an alternate language.
# index : 186 , text1 : Qingdao Xinghe Electromechanical Shipment Notification Email Setting , text2 : from:
# sent: friday, october 28, 2016 7:20 am
# to: nwfodmhc exurcwkm
# subject: re: Qingdao Xinghe Electromechanical Shipment Notification Email Setting
#
# dear,
# pls help to update customer 4563729890 shipment notification email address: abcdegy@gmail.com
#
#
# b.
# index : 222 , text1 : support for fa.gstry \ arexjftu ohxdwngl , text2 : support for fa.konnica \ arexjftu ohxdwngl
# index : 223 , text1 : problems with bluescreen. , text2 : Hello ,
#
# it happened again. the pc hung itself up again and again and only presented me with a blue screen with white letters.
#
# what can we do?
# index : 255 , text1 : problems with drive z: \ laeusvjo fvaihgpx , text2 : problems with drive z: \ laeusvjo fvaihgpx
# index : 265 , text1 : netweaver no longer works , text2 : received from: fcyuqvoj.ajqeidlm@gmail.com
#
# Hello,
#
# netweaver no longer works or I can no longer open it.
#
#
#
#
#
# [cid: image001.png@01d23026.26b6a440]
#
#
#
#
#
# with best regards / best
# index : 270 , text1 : new password for account name tgryhu hgygrtui , text2 : new password for account name tgryhu hgygrtui. password for this account no longer works. employee is present on early shift in kw4456 and 4567.
# index : 276 , text1 : Outlook receives the folder in the box and becomes a folder every day, and the office prompts to update. , text2 : Outlook receives the folder in the box and becomes a folder every day, and the office prompts to update.
# index : 302 , text1 : EU_tool is very slow adgtym \ ywqgrbnx jwnsyzbv \ jionmpsf wnkpzcmv , text2 : EU_tool is very slow adgtym \ ywqgrbnx jwnsyzbv \ jionmpsf wnkpzcmv
# index : 304 , text1 : pick up old eq \ wrcktgbd wzrgyunp , text2 : pick up old eq \ wrcktgbd wzrgyunp
# index : 306 , text1 : support for we111 \ zlqfptjx xnklbfua , text2 : support for we111 \ zlqfptjx xnklbfua
# index : 335 , text1 : urgent: classroom 1. intercom does not work. , text2 : training room 1. intercom does not work.
# index : 339 , text1 : Blocked account. , text2 : Blocked account.
# index : 357 , text1 : EU_tool does not update every 15 minutes , text2 : EU_tool does not update every 15 minutes
# index : 363 , text1 : calendar entries - qdxyifhj zbwtunpy , text2 : hello, please have a look. thank you.
# index : 365 , text1 : label printer wk 44567 no longer prints , text2 : label printer wk 44567 no longer prints
# index : 368 , text1 : data cannot be downloaded , text2 : data cannot be downloaded.
# the machine is at a standstill.
#
# machine name: wam77035673
#
# file are used by udo. trhsysba@gmail.com sent.
# Files are saved in zip and .exe format
# index : 370 , text1 : erp training room: 7 cannot connect beamer , text2 : erp training room: 7 cannot connect beamer
#
# reopened as user called in again. please refer to tkt: inplant_868331
# index : 441 , text1 : problems with portal \ knlrgsiv cqvuexjz , text2 : problems with portal \ knlrgsiv cqvuexjz
# index : 446 , text1 : setup rechner ewel8323865 für hr.thrydad (third consulting) \ puxsvfwr cwkjruni , text2 : setup rechner ewel8323865 für hr.thrydad (third consulting) \ puxsvfwr cwkjruni
# index : 450 , text1 : please reactivate account ewel8323865 \ laptop for a hr auditor \ account for trhfyd sugajadd is active. please call back. , text2 : please reactivate account ewel8323865 \ laptop for a hr auditor \ account for trhfyd sugajadd is active. please call back.
# fyi
#
# by: mfyivqes cpihaxbs
# Broadcast: Tuesday, October 25, 2016 12:54 PM
# to: ughzilfm cfibdamq
# subject: re: please reactivate account ewel8323865 \ laptop for a hr auditor \ account for rhfyd sugajadd is active. please call back.
#
# Hello ,
#
# please open a ticker to help, they can do that
#
# greetings
# index : 453 , text1 : problems with erpgui \ tmqfjard qzhgdoua , text2 : problems with erpgui \ tmqfjard qzhgdoua
# index : 454 , text1 : support for fa.thrydsss-funke \ laeusvjo fvaihgpx , text2 : support for fa.thrydsss-funke \ laeusvjo fvaihgpx
# index : 455 , text1 : replace illustrated tape \ printer we68678 \ vepxdgot poezmwny , text2 : replace illustrated tape \ printer we68678 \ vepxdgot poezmwny
# index : 463 , text1 : phone gigaset m2 ex professional (tel. :) is no longer charging. connection defective. , text2 : phone gigaset m2 ex professional (tel. :) is no longer charging. connection defective.
# index : 466 , text1 : user wk_ksem15462 blocked , text2 : user wk_ksem15462 blocked
# index : 469 , text1 : After the IE browser opens the crm system, it prompts that the user has been logged out and cannot log in to the crm system. , text2 : After the IE browser opens the crm system, it prompts that the user has been logged out and cannot log in to the crm system.
# index : 481 , text1 : time data for germany steel are missing , text2 : since yesterday around 3 p.m. all time data are missing. data is urgently needed for daily evaluations (performance level, etc.)
# index : 487 , text1 : msd-Office 2013 Outlook cannot be opened, showing that it cannot create a new stack protection page , text2 : please provide details of the issue.
# [‎2016/‎10/‎25 9:36] melhduty gqchtedl:
# hi
# My computer mailbox can't be opened
# Can you help me?
# Thank you
# [‎2016/‎10/‎25 9:38] melhduty gqchtedl:
# Show system error
# Cannot create a new stack guard page
# [‎2016/‎10/‎25 9:40] obuwfnkm ufpwmybi:
# Share your desktop with me
# [‎2016/‎10/‎25 9:41] melhduty gqchtedl:
# id
# index : 488 , text1 : I can't see the folder of a3 (\\HostName_17\teams\business\ a3), please help to figure it out. sahtym wanthryg , text2 : I can't see the folder of a3 (\\HostName_17\teams\business\ a3), please help to figure it out. sahtym wanthryg
# index : 555 , text1 : problems with fuser unit we101 \ qvncizuf ueiybanz , text2 : problems with fuser unit we101 \ qvncizuf ueiybanz
# index : 570 , text1 : printer malfunction , text2 : received from: fdqjsygx.aivdjqtr@gmail.com
#
# Hello,
#
# the printer "em96" does not scan any documents.
#
# Error message: Check access failed for the following destinations:
#
#                 \\ HostName_579 \ _kmscan \ em96 <file: /// \\ HostName_579 \ _kmscan \ em96>: the path cannot be found.
#
# the error cannot be remedied even by switching it on and off several times.
#
# with best regards / best
# index : 572 , text1 : erp- locked failed attempts password locked , text2 : please activate erp failed attempts
# index : 574 , text1 : r45 machine pc defective , text2 : pc of machine r45 no longer starts up.
# index : 578 , text1 : EU_tool in germany steel without function - feedback is not possible !!!! , text2 : EU_tool in germany steel without function - feedback is not possible !!!!
# index : 582 , text1 : wk38 - qdxyifhj zbwtunpy , text2 : hello, can you see where the e-mail button is on the printer. he is gone! :-) thank you. Uwe
# index : 586 , text1 : problems with bluescreen , text2 : Hello ,
#
# the computer at my workplace just got out of the car again and only displayed a blue screen with white letters.
#
# please have a look at it on site.
# index : 589 , text1 : problems with lan for computer erosion machine \ dtlmbcrx mwuateyx , text2 : problems with lan for computer erosion machine \ dtlmbcrx mwuateyx
# index : 595 , text1 : network drives on quattro-4206, quattro-4201, quattro-4204 not connected since sunday. , text2 : network drives on quattro-4206, quattro-4201, quattro-4204 not connected since sunday.
# index : 608 , text1 : Label printer in the area of ​​final inspection Germany defective , text2 : dysfunction
# index : 610 , text1 : printer wk1678 , text2 : received from: inqogkxz.rgmslhjn@gmail.com
#
# hello help,
# printer wk1678 no longer works properly.
# labels shift.
# please inform mr. himghtmelreich.
# many thanks
#
#
#
# best
# index : 618 , text1 : Outlook won't open , text2 : When opening outlook, an error of outlook.ost file is displayed and the program is automatically closed.
# index : 628 , text1 : Office excel, powerpoint prompts errors when opening some files. , text2 : Office excel, powerpoint prompts an error when opening some files, and some files in the computer and mail cannot be opened.
# index : 744 , text1 : printer in lion uacyltoe hxgayczeraum knicrhtyt paper \ dtlmbcrx mwuateyx , text2 : printer in lion uacyltoe hxgayczeraum knicrhtyt paper \ dtlmbcrx mwuateyx
# index : 745 , text1 : need access to shift planner , text2 : please set up access to the following path: departments (\\ HostName_737) (m :) -> programdntyme -> shift planner
#
# user: freybtrhsdl
# index : 751 , text1 : we111 only issues an error message , text2 : we111 only outputs an error message:
# register in the network
# register the network settings.
# not all processes can be completed.
# wait a moment \ vzqomdgt jwoqbuml
# index : 755 , text1 : label printer does not work , text2 : label printer in the final inspection defense does not issue any labels
# index : 757 , text1 : calculator for length measuring machine uacyltoe hxgayczeen \ xosdfhbu gtbfkisl , text2 : calculator for length measuring machine uacyltoe hxgayczeen \ xosdfhbu gtbfkisl
# index : 761 , text1 : cable lan 10m supply \ gogtyekhan merdivan , text2 : cable lan 10m supply \ gogtyekhan merdivan
# index : 769 , text1 : backup for computer lasplant_119 \ pfjwinbg ljtzbdqg , text2 : backup for computer lasplant_119 \ pfjwinbg ljtzbdqg
# index : 773 , text1 : EU_tool no longer works (EU_tool is not working) , text2 : EU_tool no longer works
# index : 779 , text1 : collaboration platform not available - no internet access , text2 : collaboration platform not available - no internet access
# index : 782 , text1 : EU_tool does not work , text2 : EU_tool does not work
# index : 784 , text1 : reincker wzs 60 r 241 kentip department , text2 : pc no longer boots up after restart or it aborts the boot process during the boot sequence, please check, thank you.
# index : 791 , text1 : erp password forgotten id: fenthgh45 erp password was forgotten , text2 : received from: jmxqhrfa.vawptbfl@gmail.com
#
# Hello it
#
#                erp password forgotten id: fenthgh45 erp password was forgotten
#
#                and self-service system password was forgotten, too.
#                I also forgot my login password for the reset password website
#                even worse, all systems were locked.
#                Have been locked
#                do me a fever to unlock them
# index : 879 , text1 : barcode over word label printing , text2 : i want to print a number letter in label printing as a barcode over word label printing
# with the font coSID_4428 this does not work so that I can read it with a scan gun
#
# phone:
# index : 884 , text1 : please set user gogtyektdgwo correctly. After logging in, all network drives are missing , text2 : please set user gogtyektdgwo correctly. After logging in, all network drives are missing
# index : 887 , text1 : support for roboworker \ sandblasting \ xwirzvda okhyipgr , text2 : support for roboworker \ sandblasting \ xwirzvda okhyipgr
# index : 893 , text1 : phone in "meeting room 3" phone number 263 in germany the ringtone does not work. , text2 : if someone calls from outside then the phone does not ring. please have a look, thank you.
# index : 904 , text1 : problems with barcode labels \ volume format too big \ vzqomdgt jwoqbuml , text2 : problems with barcode labels \ volume format too big \ vz qomdgt jwoqbuml
# index : 906 , text1 : the monitor on our length measuring machine is defective. , text2 : good morning hkydrfdw,
#
# the monitor on our length measuring machine is defective.
# please provide a replacement monitor at short notice.
# thank you
# index : 907 , text1 : release for folder applications was cut ??? , text2 : please release again
# index : 913 , text1 : write rights for ksdvp3, ce_leiter , text2 : write rights for ksdvp3, ce_leiter
# index : 924 , text1 : since October 20th, 2016 06:00 mesz server problems qmsoft not applicable. , text2 : since October 20th, 2016 06:00 mesz server problems qmsoft not applicable.
# index : 982 , text1 : business_client cannot log in , text2 : received from: ktghvuwr.uwtakcmj@gmail.com
#
# hello
#
# Please help to solve the problem of business_client unable to log in, that is, open the business_client software, and now it cannot log in:
#
# 1. After connecting to vpn, logging in from the software side does not work, the display is as follows:
#
# [cid:image001.jpg@01d22a56.4f7ef4c0]
# 2. Log in from the web version, the display is as follows, but I cannot log in:
#
# [cid:image002.jpg@01d22a56.4f7ef4c0]
#
#
#
# ktghvuwr uwtakcmj
# sr. application engineer
# optimization team
# ktghvuwr.uwtakcmj@gmail.com<mailto:ktghvuwr.uwtakcmj@gmail.com>
# index : 993 , text1 : please set scanner for we111. printer has been reset to factory settings (konica). , text2 : please set scanner for we111. printer has been reset to factory settings (konica).
# index : 1011 , text1 : need access to \\ eagcldaten \ aese \ line \ csd_emealeitung , text2 : need access to \\ eagcldaten \ aese \ line \ csd_emealeitung
# index : 1034 , text1 : fan defective \ industrial control monitor \ nipt wdq csenjruz , text2 : fan defective \ industrial control monitor \ nipt wdq csenjruz
# index : 1036 , text1 : problems with camera and monitor. , text2 : good morning dhthykts,
#
# to connect the camera to the new monitor, we need a cable from hdmi to this light gray connector on the dell monitor. at least that's how the first camera is built. if there are other alternatives we are of course also open to them.
# index : 1038 , text1 : problems with fp \ computer hangs \ ksxchbaf rhquvzfm , text2 : problems with fp \ computer hangs \ ksxchbaf rhquvzfm
# index : 1047 , text1 : pc at EU_tool-station 21 in Germany no longer works. , text2 : pc at the EU_tool-station 21 (or bde21) in Germany no longer works.
# display writes hard drive errors.
# index : 1048 , text1 : connection to the internet server not possible due to administration rights - , text2 : Error message in the mail: this process was canceled due to restrictions. please contact the system administrator
#
# no hyperlink possible to open!
# index : 1051 , text1 : erp account entsperren , text2 : please unlock the erp account of fygrwuna gomcekzi.
# index : 1057 , text1 : Connection between printer em98 and pc eemw8144353 cannot be established , text2 : Connection between printer em98 and pc eemw8144353 cannot be established
# index : 1059 , text1 : Power supply or power plug defective - PC goods receipt , text2 : please check power supply unit or power plug on pc evhw8114354 (incoming goods) and repair if necessary.
# pc can only be switched on after moving the plug.
# index : 1081 , text1 : Yonyou software problem , text2 : When opening a closed sales order, it displays "Cannot create a new link in manual or distributed transaction mode"
# index : 1134 , text1 : odbc error - system error 126: the specified module was not found. driver not loaded , text2 : I would like to create a serial letter, but cannot open my data source (excel list)?
#  system error 126 ??? I ask for help! thank you.
# index : 1149 , text1 : erp and EU_tool are very slow , text2 : EU_tool sometimes doesn't work at all
# index : 1155 , text1 : erp reacts extremely slowly , text2 : transactions in erp take too long
# index : 1156 , text1 : supply monitor for video measuring machine \ oziflwma nhgvmqdl , text2 : supply monitor for video measuring machine \ oziflwma nhgvmqdl
# index : 1157 , text1 : problems with outlook \ cwivnxuk izmxqfud , text2 : problems with outlook \ cwivnxuk izmxqfud
# index : 1158 , text1 : Optiplex790 computer defective \ ewew8323670 \ xpugntjv zcaermdt , text2 : Optiplex790 computer defective \ ewew8323670 \ xpugntjv zcaermdt
# index : 1175 , text1 : please activate the iphone-6 001 to receive mail. , text2 : received from: rtnyumbg.yzemkhbq@gmail.com
#
# Hello everybody,
# please activate the iphone-6 001 to receive mail.
# thank you
#
# Best regards
# rtnyumbg yzemkhbq / tel
#
#
# [cid: image001.jpg@01d22919.634da5c0]
#
#
#
# Best regards
#
# rtnyumbg yzemkhbq
#
# techn. Consulting and Sales
# rtnyumbg.yzemkhbq@gmail.com <mailto: rtnyumbg.yzemkhbq@gmail.com>
# company deutschland gmbh
# max-planck-straße 13 <x-apple-data-detectors: // 1>
# <x-apple-data-detectors: // 1>
#
# company deutschland gmbh
# managing directors: rfwlsoej yvtjzkaw, harald male, mr. pinkow
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 1178 , text1 : No sound from the phone , text2 : No sound from the phone
# index : 1244 , text1 : Calculator for EU_tool rods hangs up. \ spdczoth vajtodny , text2 : Calculator for EU_tool rods hangs up. \ spdczoth vajtodny
# index : 1247 , text1 : Computer for information status defective \ problems with fan \ niptbwdq csenjruz , text2 : Computer for information status defective \ problems with fan \ niptbwdq csenjruz
# index : 1248 , text1 : we need usb-stick (16gb) for the 1st year of apprenticeship (4 pieces). , text2 : Hello ,
#
# we need usb-stick (16gb) for the 1st year of apprenticeship (4 pieces).
# index : 1271 , text1 : fe10 The text on the copied paper is not clear , text2 : fe10 The text on the copied paper is not clear
# index : 1272 , text1 : problems with user again only temporary! \ merdivan \ xwirzvda okhyipgr , text2 : problems with user again only temporary! \ merdivan \ xwirzvda okhyipgr
# index : 1273 , text1 : login error lync \ qidgvtwa qvbutayx , text2 : login error lync \ qidgvtwa qvbutayx
# index : 1274 , text1 : dvi interface without function. , text2 : dvi interface without function. probably defective graphics card.
# index : 1275 , text1 : EU_tool does not work , text2 : error message: system error & h91115116 (). unknown error
# index : 1277 , text1 : bob j , text2 : Hello,
#
# bob-j doesn't work again.
# do we have a system error?
#
# bob j goes back not even.
# do we have a system failure?
#
#
# Best regards
# best
# index : 1279 , text1 : After changing the password, company connect can log in, but cannot be used , text2 : After changing the password, company connect can log in, but cannot be used
# index : 1282 , text1 : r126 pc def. possibly power supply unit , text2 : r126 pc def. possibly power supply unit
# index : 1283 , text1 : no data transfer from the erp database to the imaje inkjet printer , text2 : please send it to local IT support smpijawb eawkpgqf on site immediately to analyze errors
# complete delivery of the works in germany is available !!!!!!!
# index : 1286 , text1 : EU_tool and batch management does not work. , text2 : EU_tool and batch management does not work.
# index : 1289 , text1 : server problems qm-soft not applicable , text2 : server problems qm-soft not applicable
# index : 1344 , text1 : pc on r241 in hall c near office nesner does not start up , text2 : Invite it-Germany, as a replacement pc is already installed and a new one has been ordered.
# index : 1429 , text1 : phone defective , text2 : phone defective
# index : 1434 , text1 : Replace monitor \ dhoalycb yopvwrjq , text2 : Replace monitor \ dhoalycb yopvwrjq
# index : 1445 , text1 : Recover account access dyqekzuc djhznybt - urgently , text2 : received from: urpbyoke.vwcbhmds@gmail.com
#
# dyqekzuc djhznybt is sitting next to me. he can no longer open his account.
#
# many greetings, best
# index : 1451 , text1 : problems with the display of open emails , text2 : received from: ecoljnvt.lbdqmvfs@gmail.com
#
# Hello ,
#
# For some time now all open emails are no longer displayed in my outlook.
#
# [cid: image003.jpg@01d225f8.ca2168f0]
#
# I always have to press the blue highlighted field to be able to see further emails.
# this is only possible if I have a connection to the exchange server.
# since this is not always the case, please set accordingly so that I can always read all emails.
#
# with best regards / best
# index : 1452 , text1 : The attendance system can't enter, please deal with it. Thank you! , text2 : The attendance system can't enter, please deal with it. Thank you!
# index : 1512 , text1 : erp inbox, I am not in the work center no. 51111937 = pe_emea_fu3 = aerospace group entered , text2 : workflow of my group is not visible to me, not in work center no. 51111937 = pe_emea_fu3 = aerospace group entered
# index : 1537 , text1 : problems with LAN on the computer \ we_wu113 \ essa \ wrcktgbd wzrgyunp , text2 : problems with LAN on the computer \ we_wu113 \ essa \ wrcktgbd wzrgyunp
# index : 1538 , text1 : pdf files do not open , text2 : pdf files do not open
# index : 1543 , text1 : problems with portal \ user: gogtyekthyto \ vzqomdgt jwoqbuml , text2 : problems with portal \ user: gogtyekthyto \ vzqomdgt jwoqbuml
# index : 1548 , text1 : printer em93 makes random spots on the printouts / copies !!! , text2 : printer em93 makes random spots on the printouts / copies !!!
# index : 1552 , text1 : problems with lan \ youfzmgp xvysrnmb , text2 : problems with lan \ youfzmgp xvysrnmb
# index : 1565 , text1 : data transfer not possible! , text2 : no data transfer from pc to machine possible!
#
# plant: plant_107
# work center: ebm052
# machine: 45162335/03
# pc: eemwx004016
# programdntym: winprodnc
#
# contact person: r. wunthyder
# index : 1568 , text1 : The computer cannot open the web page. , text2 : Hello Zhang Gong!
# My computer cannot be connected to the company network (but 163, etc.), the information is as follows: (crm cannot log in, vpn cannot connect, ethics cannot connect, but mail can be received normally)
# How to solve?
# index : 1622 , text1 : after I opened outlook and clicked on an e-mail, a blue circle comes up that turns and I do nothing , text2 : make more. urgently ask for help. my mobile tel. No.
# index : 1641 , text1 : problems with EU_tool \ error when logging off the order \ ypladjeu wzfryxav , text2 : problems with EU_tool \ error when logging off the order \ ypladjeu wzfryxav
# index : 1644 , text1 : laptop byclpwmv esafrtbh defective , text2 : laptop byclpwmv esafrtbh defective
# index : 1648 , text1 : printer problems with em021 in germany , text2 : received from: mobaidfx.gviwlsrm@gmail.com
#
# Hello everybody,
#
# the printer em021 no longer prints via the entry "letterhead".
# please correct settings.
#
# thank you in advance.
#
# with best regards / best
# index : 1656 , text1 : problems with EU_tool \ tmqfjard qzhgdoua , text2 : problems with EU_tool \ tmqfjard qzhgdoua
# index : 1657 , text1 : please create a folder in the team drive fürth , text2 : received from: osjqfbvw.hlmgrfpx@gmail.com
#
# would you please create a folder in the team drive fürth.
#
# name: hr-tr
#
# full access: rtnzvplq erhmuncq
#                               rtgdcoun pngufmvq
#                               naruedlk mpvhakdq
#                               efodqiuh tpfnzkli
#                               rcwpvkyb exgjscql
#                               gabryltke schütt
#
#
# many thanks.
#
# gabryltke schütt
# Human Resources
# osjqfbvw.hlmgrfpx@gmail.com <mailto: osjqfbvw.hlmgrfpx@gmail.com>
#
#
# company shared services gmbh
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 1664 , text1 : machine pc r239 without function -> please check , text2 : machine pc r239 without function -> please check
# index : 1665 , text1 : faxing purchase orders directly from the po has been failing for everyone since yesterday. , text2 : faxing purchase orders directly from the po has been failing for everyone since yesterday.
# faxing from the purchase orders directly from the po has been unsuccessful since yesterday.
# index : 1666 , text1 : Computer for erosion machine defective \ youfzmgp xvysrnmb , text2 : Computer for erosion machine defective \ youfzmgp xvysrnmb
# index : 1673 , text1 : mouse defective \ niptbwdq csenjruz , text2 : mouse defective \ niptbwdq csenjruz
# index : 1674 , text1 : problems with ws cad \ wsboedtj yvlswgxb , text2 : problems with ws cad \ wsboedtj yvlswgxb
# index : 1678 , text1 : problems with skype , text2 : received from: fmhlugqk.dpraethi@gmail.com
#
# hello dear colleagues,
#
# i can't start skype. always comes this error message:
# [cid: image001.png@01d22469.6086f8f0]
#
# üdvözlettel / best regards / best
# index : 1700 , text1 : Account is locked , text2 : The user forgets the password, causing the account to be locked
# index : 1701 , text1 : An error is displayed after entering the username and password , text2 : After entering the user name and password when logging in, it shows that the user name and password are wrong
# index : 1704 , text1 : Account is locked , text2 : User account locked, request to unlock
# index : 1710 , text1 : Product and warehouse are not in line , text2 : Error in the warehouse where the product is located. st6p -100/+325 lot number 16-9-16
# index : 1711 , text1 : Boot black screen , text2 : After the computer starts, the screen is blank, and the host has no alarm
# index : 1712 , text1 : Outlook repeatedly asks for password , text2 : Outlook password box pops up repeatedly, asking for a password, unable to receive emails
# index : 1736 , text1 : the synchronization with exchange activesync is temporarily blocked on your device until it is accessed by the administra , text2 : from: lhejbwkc xbmyvnqf
# sent: tuesday, october 11, 2016 5:48 pm
# to: nwfodmhc exurcwkm
# subject: dan fw: the synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator.
# importance: high
#
# dear all
#
# please activate my new iphone, it is a company owned device.
# index : 1766 , text1 : hand scanner on pc evhw8114203 on r208 still does not work after replacement; , text2 : hand scanner on pc evhw8114203 with r208 still does not work after replacement please check and replace again if necessary;
# index : 1770 , text1 : monitor defekt \ nipt wdq csenjruz , text2 : monitor defekt \ nipt wdq csenjruz
# index : 1771 , text1 : create hip 10 replacement hard drive! , text2 : create hip 10 replacement hard drive!
# index : 1772 , text1 : create a new folder in the info of EU_tool (please create new folder) , text2 : received from: qavdrpfu.ylfwnbkr@gmail.com
#
# Hello,
#
# please create a new path in the EU_tool under info.
#
# [cid: image001.png@01d223c0.fSID_21c960] [cid: image002.jpg@01d223c0.fSID_21c960]
#
# [cid: image003.jpg@01d223c0.fSID_21c960]
#
# create a new directory under impact award.
# please use erp pm as a designation.
#
# the files for visualization are on
# i: \ hand books \ erp pm <file: /// \\ HostName_579 \ info \ hand books \ erp% 20pm>
#
# [cid: image004.jpg@01d223c0.fSID_21c960]
#
# reason:
# [10/13/16 3:19 pm] qavdrpfu ylfwnbkr:
# i have created some traiyctrhbkm plvnuxmrterial for our shopflor workers for our new erp pm system for creating breakdown notifications
# so they will have a chance to look into this traiyctrhbkm plvnuxmrterial when they want to do any notification fjaqbgnld yukdzwxs people.
# because we still started with erp pm and our old system was a part of EU_tool
# called azm.
#
#
#
#
#
#
# with best regards / best
# index : 1774 , text1 : replicate , text2 : received from: trgqbeax.hfyzudql@gmail.com
#
# Hello
#
# Unfortunately, my laptop only replicates rudimentary in the company network. I get the latest emails on my iphone. other colleagues here at the site have the same problem.
#
#
# [cid: image001.png@01d223be.6f558640]
#
#
#
# with best regards | best
# index : 1780 , text1 : barcode scanner defective \ paternoster , text2 : barcode scanner defective \ paternoster
# index : 1784 , text1 : check the settings on the alfa set measuring device. , text2 : The settings on the rollomatic alfa set measuring device must be checked according to the instructions.
# index : 1789 , text1 : erp training room: 7 cannot connect beamer , text2 : erp training room: 7 cannot connect beamer
# index : 1793 , text1 : hurry up !!! monitor defective , text2 : monitor defective
# for hr. tjzohmve wusgaozx
#
# new construction 6 floor, # 503
# index : 1805 , text1 : wifi is not online , text2 : wifi is not online
# index : 1807 , text1 : Cannot create a skype meeting. There is no skype online meeting add-in on the outlook calendar. , text2 : Cannot create a skype meeting. There is no skype online meeting add-in on the outlook calendar.
# index : 1808 , text1 : My Outlook print emails are set in portrait orientation, and they are all landscape orientation. Can you help me see it? , text2 : My Outlook print emails are set in portrait orientation, and they are all landscape orientation. Can you help me see it?
# dizquolf hlykecxa
# ap accountant
# dizquolf.hlykecxa@gmail.com
# index : 1829 , text1 : i can't open my vpn , text2 : i can't open my vpn
# index : 1867 , text1 : problems with laser02 \ pfjwinbg ljtzbdqg , text2 : problems with laser02 \ pfjwinbg ljtzbdqg
# index : 1868 , text1 : problems with lasplant_119 \ pfjwinbg ljtzbdqg , text2 : problems with lasplant_119 \ pfjwinbg ljtzbdqg
# index : 1872 , text1 : Resetting the passwords for accounts vvwtyeidt, vvftgors, vvnergtubj, vvthygschj , text2 : Resetting the passwords for accounts vvwtyeidt, vvftgors, vvnergtubj, vvthygschj
# index : 1885 , text1 : automatic registration , text2 : when i call outlook, the computer also wants to connect to collaboration_platform (?) at the same time.
#
# that means: log in with your business or school account. but when I enter my email address and password nothing happens.
# the constant fade in is very annoying
#
# please remedy
#
# my phone number is
# index : 1890 , text1 : pick up old it equipment (2x cad ws nd monitor) \ umykjweg jpwrfuhk , text2 : pick up old it equipment (2x cad ws nd monitor) \ umykjweg jpwrfuhk
# index : 1899 , text1 : problems with we110 \ the printer queue is currently not running \ fdyietau dvsyxwbu , text2 : problems with we110 \ the printer queue is currently not running \ fdyietau dvsyxwbu
# index : 1913 , text1 : reset password , text2 : reset password
# index : 1914 , text1 : skype does not load on the pc. , text2 : skype is not loaded by the browser even after a long wait
# index : 1922 , text1 : EU_tool, charge management, pdv , text2 : the EU_tool, batch management and pdv systems run absolutely badly.
# you can "not" really work with them like that.
# index : 1935 , text1 : msd crm--outlook keeps showing that it is starting up and cannot enter the normal interface. , text2 : please provide details of the issue.
# Outlook keeps showing that it is starting and cannot enter the normal interface.
# index : 1954 , text1 : Reinstall the system on the laptop , text2 : Reinstall my laptop in the system
# index : 1955 , text1 : A linked file cannot be opened , text2 : A link file cannot be opened, indicating that the version is low
# index : 1990 , text1 : ms outlook2013 keeps showing that it is starting up and cannot display the normal interface , text2 : please provide details of the issue.
# ms outlook2013 keeps showing that it is starting up and cannot display the normal interface
# index : 2003 , text1 : Reply: password_management_tool , text2 : received from: weqocbnu.eoixcpvy@gmail.com
#
# hi all
#
#
# please reset my password for SID_78 for my entering error more than 3 times.
#
# user name: caoryhuq
#
#
#
# For daily business, please send to south.service@company.com <mailto: please send to south.service@company.com> public mailbox
#
# best
# index : 2004 , text1 : If the computer login password is forgotten, reset the password. , text2 : If the computer login password is forgotten, reset the password.
# index : 2036 , text1 : password geoyhurg chriuimjiann , text2 : received from: nsoikcyf.jhybqael@gmail.com
#
# please activate my passwords.
# plase unlook my password
# chrithysgd
#
#
#
# with best regards / best
# index : 2045 , text1 : uacyltoe hxgaycze , text2 : uacyltoe hxgaycze
# index : 2064 , text1 : instructions for password_management_tool , text2 : instructions for password_management_tool
# index : 2070 , text1 : uacyltoe hxgaycze , text2 : uacyltoe hxgaycze
# index : 2071 , text1 : hand scanner on pc evhw8114202 without function -> rep. or replace; , text2 : hand scanner on pc evhw8114202 without function -> rep. or replace (pc in hall c at r208 erp terminal)
# index : 2085 , text1 : need a numeric keypad for the left hand. , text2 : Hello .
#
# need a numeric keypad for the left hand.
# index : 2086 , text1 : EU_tool runs very slowly in the Germany plant. Feedback can no longer be entered (runtime error). , text2 : No feedback can currently be entered in EU_tool. error "runtime error".
# index : 2093 , text1 : automatic data processing qa does not work , text2 : automatic data processing does not work
# index : 2100 , text1 : purchasing, online catalog de-technical trade does not work , text2 : purchasing, online catalog de-technical trade does not work
# index : 2144 , text1 : password geoyhurg chriuimjiann , text2 : received from: nsoikcyf.jhybqael@gmail.com
#
# please activate your password and account
#
#
# with best regards / best
# index : 2156 , text1 : problems with com port \ maschine stöhrmann \ eaodcgsw trmzwbyc , text2 : problems with com port \ maschine stöhrmann \ eaodcgsw trmzwbyc
# index : 2162 , text1 : password geoyhurg chriuimjiann , text2 : received from: nsoikcyf.jhybqael@gmail.com
#
# please activate my passwords
#
#
# with best regards / best
# index : 2171 , text1 : system pc on the hip 10 high-pressure sintering system does not start! , text2 : system pc on the hip 10 high-pressure sintering system does not start!
# index : 2180 , text1 : problems with proof of salary print \ eaodcgsw trmzwbyc , text2 : problems with proof of salary print \ eaodcgsw trmzwbyc
# index : 2182 , text1 : problems with wlan laptop \ weszfyok fbadnjhu , text2 : problems with wlan laptop \ weszfyok fbadnjhu
# index : 2186 , text1 : problems with we_wu160 \ jionmpsf wnkpzcmv , text2 : problems with we_wu160 \ jionmpsf wnkpzcmv
# index : 2187 , text1 : rfa analyzer monitor defective , text2 : Hello ,
#
# can you take a look at our laboratory and the rfa analyzer monitor is defective.
#
# rclqfpgt tbnovxdp is the contact person.
# index : 2192 , text1 : uacyltoe hxgaycze , text2 : uacyltoe hxgaycze
# index : 2211 , text1 : no data comparison between EU_tool and erp in germany! , text2 : no data comparison between EU_tool and erp in germany!
# index : 2212 , text1 : no network access , text2 : i only have access to the internal hard drive on my pc. printing works, but no access to e.g. the printer server.
# index : 2260 , text1 : problems with pf3 port 13 , text2 : received from: ughzilfm.cfibdamq@gmail.com
#
# Hello ,
#
# port for ewew8323846 pf 3 port 13 does not deliver a correct ip.
# Please check .
# index : 2282 , text1 : wk38 -> qdxyifhj zbwtunpy , text2 : Halo ,
# the printer is causing problems with printing. please check the settings. thank you. Uwe
# index : 2285 , text1 : problems with vpn \ weszfyok fbadnjhu , text2 : problems with vpn \ weszfyok fbadnjhu
# index : 2286 , text1 : problems with portal \ franjuz urbghty , text2 : problems with portal \ franjuz urbghty
# index : 2301 , text1 : problems with alicona after update \ jionmpsf wnkpzcmv , text2 : problems with alicona after update \ jionmpsf wnkpzcmv
# index : 2307 , text1 : problems with accessing drawings - netweaver business client , text2 : received from: ecoljnvt.lbdqmvfs@gmail.com
#
# dear colleagues,
#
# I cannot open the netweaver business clint.
#
# when I press the corresponding app (already connected via vpn), the following message appears:
#
# [cid: image001.png@01SID_35ee0.18647971]
#
# ask for your support
#
# with best regards / best
# index : 2354 , text1 : no audio on the 7350s , text2 : no audio on the 7350s
# index : 2359 , text1 : ticket update on: implant 866142 , text2 : ticket update on: implant 866142
# index : 2382 , text1 : EU_tool ws ewew8323843 does not work \ jionmpsf wnkpzcmv , text2 : EU_tool ws ewew8323843 does not work \ jionmpsf wnkpzcmv
# index : 2389 , text1 : user lndypaqg dhqwtcsr (gogtyekthyto) has his password in erp SID_34 verggermany. , text2 : user lndypaqg dhqwtcsr (gogtyekthyto) has his password in erp SID_34 verggermany.
# index : 2405 , text1 : problems with ie \ vzqomdgt jwoqbuml , text2 : problems with ie \ vzqomdgt jwoqbuml
# index : 2406 , text1 : sinic general error: 3155 odbc vmsliazh ltksxmyv driver query timeout \ jionmpsf wnkpzcmv , text2 : sinic general error: 3155 odbc vmsliazh ltksxmyv driver query timeout \ jionmpsf wnkpzcmv
# index : 2407 , text1 : problems with printer we110 \ fdyietau dvsyxwbu , text2 : Hello ,
#
# our copier in the classroom is also defective (minolta we 110).
#
# can you please have a look.
# index : 2420 , text1 : app problems , text2 : received from: ecoljnvt.lbdqmvfs@gmail.com
#
# Hello fellow colleagues,
#
# In my outlook there is a field that there is an app problem.
#
# What should I do?
#
# [cid: image003.jpg@01SID_35e28.2c1d0470]
#
# with best regards / best
# index : 2438 , text1 : can not login , text2 : can not login
# index : 2610 , text1 : Travel expense accounting in ERP not possible! , text2 : received from: byclpwmv.esafrtbh@gmail.com
#
# Hello,
#
# Travel expense accounting in ERP is unfortunately not possible. see error message below:
# [cid: image001.jpg@01SID_35be6.bd6e34b0]
#
#
#
# with best regards / best
# index : 2696 , text1 : not possible to log in to outlook , text2 : login to outlook since changing password not possible
# tel:
# index : 2708 , text1 : problems with printing \ measuring machine for bars \ eaodcgsw trmzwbyc , text2 : problems with printing \ measuring machine for bars \ eaodcgsw trmzwbyc
# index : 2709 , text1 : support for alicona \ jionmpsf wnkpzcmv , text2 : support for alicona \ jionmpsf wnkpzcmv
# index : 2726 , text1 : problems with skype and outlook \ user: dardabthyr , text2 : problems with skype and outlook \ user: dardabthyr
# index : 2727 , text1 : problems with skype and outlook \ dardabthyr , text2 : problems with skype and outlook \ dardabthyr
# index : 2728 , text1 : can you please get 2 usb sticks 16 gb again one of us broke , text2 : can you please get 2 usb sticks 16 gb again one of us broke
# index : 2729 , text1 : our copier we 95 (hp laserjet) shows the error message "transfer unit missing". , text2 : our copier we 95 (hp laserjet) shows the error message "transfer unit missing".
# index : 2735 , text1 : vpn installation-transfer to He Zhengping , text2 : received from: tuqrvowp.fxmzkvqo@gmail.com
#
# Please help to install the vpn software, thank you Zhengping
#
#
# tuqrvowp fxmzkvqo Qian Tangxin
# human resources
# tuqrvowp.fxmzkvqo@gmail.com<mailto:tuqrvowp.fxmzkvqo@gmail.com>
#
#
# Shanghai Shengyang Superfine Powder Co., Ltd.
# 1508 Chenqiao Road, Fengxian District, Shanghai
# Post Code: 201400
# index : 2801 , text1 : phone with the number 1038091558 is defective. sintering germany. please repair. , text2 : phone with the number is broken. sintering germany. please repair.
# index : 2803 , text1 : problems with vpn \ wxstfouy isjzcotm , text2 : problems with vpn \ wxstfouy isjzcotm
# index : 2831 , text1 : shared folder for m: kvp3 , text2 : shared folder for m: kvp3
# index : 2835 , text1 : problems with companyguest \ bctypmjw cbhnxafz , text2 : problems with companyguest \ bctypmjw cbhnxafz
# index : 2836 , text1 : problems with hp printer local. \ petljhxi bocxgins , text2 : problems with hp printer local. \ petljhxi bocxgins
# index : 2837 , text1 : I need help with changing the password / and with skype - microphone connection! , text2 : I need help with changing the password / and with skype - microphone connection!
# because i can hear others at skype meetings but they can't hear me.
# index : 2854 , text1 : outlook doesn't work , text2 : on the computer evhw8114148 outlook no longer works.
# index : 2864 , text1 : vpn cannot log in. , text2 : [‎2016/‎9/‎29 9:14] daisy huang:
# hi, vpn changed according to the settings in the email, why can’t I get on board?
# your system failed for antivirus check. please ensure the following is true and try again or contact your administrator: your antivirus software is enabled. it is up to date (antivirus database no older than 30 days) you have recently scanned your system (not longer than 7 days ago)
# [‎2016/‎9/‎29 9:15] obuwfnkm ufpwmybi:
# There is a problem with your antivirus software
# Virus database is not updated
# index : 2927 , text1 : problems with ie \ niptbwdq csenjruz , text2 : problems with ie \ niptbwdq csenjruz
# index : 2933 , text1 : problems with portal \ acqpinyd ecygimqd , text2 : problems with portal \ acqpinyd ecygimqd
# index : 2935 , text1 : problems with portal. \ hcuixqgj mavxgqbs , text2 : problems with portal. \ hcuixqgj mavxgqbs
# index : 2945 , text1 : read and write permission for HostName_753 \ production , text2 : read and write permission for HostName_753 \ production
# index : 2957 , text1 : Set up pc eemw8144241 so that the barcode is displayed and can be printed out , text2 : Set up pc eemw8144241 so that the barcode is displayed and can be printed out
# ebs office a. thicker
# index : 2959 , text1 : folder approval for m: kvp3 and ce_leiter , text2 : folder approval for m: kvp3 and ce_leiter
# index : 2971 , text1 : printer em06 in the delivery area. always the same delivery note 10 times. only then will the correct one be printed out. , text2 : printer em06 in the delivery area. always the same delivery note 10 times. only then will the correct one be printed out. erp problem
# index : 2979 , text1 : hp2 hot pressing furnace data transmission card, the data cannot be updated, please help me to transfer it to Xiaohe , text2 : hp2 hot pressing furnace data transmission card, the data cannot be updated, please help me to transfer it to Xiaohe
# index : 2985 , text1 : password Mrs. koburvmc jwzlebap # 51117 , text2 : received from: mobaidfx.gviwlsrm@gmail.com
#
# Hello,
#
# mrs rieß will start work again on tuesday, october 4th.
#
# please reassign your password.
#
# Ms. Riess is expected to be available in the office from 8 a.m. to 10 a.m.
#
# with best regards / best
# index : 2992 , text1 : outlook indexing , text2 : i have not been able to use my search in outlook for about 1 week because the message "your elements are currently being indexed by outlook" appears.
# I also let my pc run over the weekend with the outlook open, but so far it has always been the same.
# currently 10,809 elements still need to be indexed.
# yesterday there were around 2,500 elements.
# I have massive problems because I can't find emails from a year ago with the search function.
# index : 3006 , text1 : After win8.1 system prompts to update, all application software cannot be opened. , text2 : After win8.1 system prompts to update, all application software cannot be opened.
# index : 3009 , text1 : Yonyou-Inventory account does not match existing inventory , text2 : Yonyou-Inventory account does not match with existing inventory, product code: 112001960200, inventory ledger 15kg, existing inventory 75kg
# index : 3067 , text1 : computer ewew8323527 \ bluescreen \ wrcktgbd wzrgyunp , text2 : computer ewew8323527 \ bluescreen \ wrcktgbd wzrgyunp
# index : 3069 , text1 : problems with hp4050 \ error 41.1 \ lxvunpiz mgjxwept , text2 : problems with hp4050 \ error 41.1 \ lxvunpiz mgjxwept
# index : 3070 , text1 : computer ewew8323612 very slow. \ lxvunpiz mgjxwept , text2 : computer ewew8323612 very slow. \ lxvunpiz mgjxwept
# index : 3094 , text1 : problems with printer mp16 , text2 : problems with printer mp16
#
# Error message: "Transport unit is missing, or motor error has occurred
# this is a leasing printer.
# index : 3107 , text1 : printer dell 1350cnw prints all pages with a gray haze , text2 : prints prints everything grayed out
# index : 3119 , text1 : Computer hard disk failure, request repair. , text2 : Computer hard disk failure, request repair.
# index : 3132 , text1 : hr_tool-etime The system cannot log in, it always shows that the application database is being loaded , text2 : hr_tool-etime The system cannot log in, it always shows that the application database is being loaded
# index : 3136 , text1 : Email cannot be activated , text2 : The mailbox cannot be activated, prompting that a new stack protection page cannot be created.
# index : 3161 , text1 : copy of telephone bill , text2 : I request to provide a copy of the cell phone bill for the period from June 20 to September 20, 2016
# index : 3223 , text1 : archiving of e-mails , text2 : received from: anivdcor.rbmfhiox@gmail.com
#
# [cid: image003.jpg@01SID_35804.fbc60480]
#
# hello it,
#
# i archive my mails in a folder structure.
# unfortunately i keep finding folders that suddenly have no more content
# whats going on here?
#
# greeting
# achim
#
# anivdcor rbmfhiox
# sales manager
# sales germany
#
# anivdcor.rbmfhiox@gmail.com <mailto: anivdcor.rbmfhiox@gmail.com>
#
#
# company deutschland gmbh
# managing directors: rfwlsoej yvtjzkaw, phvkowml azbtkqwx, naruedlk mpvhakdq
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 3258 , text1 : reinstall company barcode für ewew8323753 \zlqfptjx xnklbfua , text2 : reinstall company barcode für ewew8323753 \zlqfptjx xnklbfua
# index : 3259 , text1 : no email received from the address p.eggert@karl-roll.de. , text2 : Nothing can be received or sent from this address.
# index : 3278 , text1 : support for computer measuring device \ jionmpsf wnkpzcmv , text2 : support for computer measuring device \ jionmpsf wnkpzcmv
# index : 3280 , text1 : We_wu160 computer does not work. , text2 : We_wu160 computer does not work.
# index : 3281 , text1 : computer for viotto does not work , text2 : computer for viotto does not work
# index : 3299 , text1 : Outlook cannot log in, it keeps showing that it is starting. , text2 : Outlook cannot log in, it keeps showing that it is starting.
# index : 3302 , text1 : After Baidu search-the new web page cannot be opened , text2 : received from: ktghvuwr.uwtakcmj@gmail.com
#
# hello it
#
# After Baidu search-the new web page cannot be opened, as shown in the attachment, please help or provide a solution.
#
# Thank you!
#
#
# ktghvuwr uwtakcmj
# sr. application engineer
# optimization team
# ktghvuwr.uwtakcmj@gmail.com<mailto:ktghvuwr.uwtakcmj@gmail.com>
# ...
# index : 7270 , text1 : no azm messages possible , text2 : no azm messages can be entered in the EU_tool
#
# in EU_tool, azm messages cannot be registered.
# index : 7286 , text1 : problem with landline phone , text2 : received from: jctnelqs.lansuiwe@gmail.com
#
# Dear ladies and gentlemen,
#
# on my landline phone, the information on the display has only been incompletely visible for some time.
# several horizontal lines make the display illegible.
#
# my phone number is 09279 / 80-155.
#
# please remedy.
#
# Sincerely
#
# jctnelqs lansuiwe
# quality assurance
# jctnelqs.lansuiwe@gmail.com <mailto: jctnelqs.lansuiwe@gmail.com>
# index : 7294 , text1 : not going to skype meeting , text2 : The skype meeting cannot be accessed from the link in the mailbox.
# index : 7299 , text1 : The intern reported an error when logging in to office365 to download the email attachment (transferred to He Zhengping) , text2 : An intern reports an error when logging in to office365 to download the email attachment
# index : 7301 , text1 : Restaurant TV cannot play video files , text2 : The restaurant TV cannot play the video file, please assist Xiaohe to complete it. Thank you!
# index : 7306 , text1 : The power cord of the milling computer is damaged , text2 : The computer power cord and network cable in the control room on the third floor of the powder mill are damaged due to high temperature and need to be replaced.
# index : 7307 , text1 : skype for business failure , text2 : Suddenly, no skype for business can be found in the system
# index : 7308 , text1 : Spelling and grammar errors , text2 : When editing ppt, it always pops up "Cannot check spelling and grammar errors", and it cannot be installed.
# index : 7309 , text1 : computer malfunction , text2 : The operating system of the computer controlled by the tensile testing machine of the quality control department started very slowly and the control software was lost.
# index : 7342 , text1 : Keyboard on r246 and r247 defective. , text2 : Keyboard on r246 and r247 defective. please change. (individual buttons no longer work)
# index : 7392 , text1 : problems with lan \ wxstfouy isjzcotm , text2 : problems with lan \ wxstfouy isjzcotm
# index : 7396 , text1 : problems with opening documents in the intranet with internet explorer. \ xmlbfjpg yegzbvru , text2 : problems with opening documents in the intranet with internet explorer. \ xmlbfjpg yegzbvru
# index : 7407 , text1 : please call back , text2 : received from: zkgfcyvx.sgxeatyb@gmail.com
#  thank you
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 7410 , text1 : authorization time management av , text2 : hello mister buses,
#
# would you please send this to it via ticket or to
#
# help@company.com
#
#
#
# with best regards / best
# index : 7423 , text1 : email notification , text2 : received from: trgqbeax.hfyzudql@gmail.com
#
# [cid: image001.png@01d1f7b0.223a83e0]
#
#
# unfortunately the field "from" has been lost ☹
#
#
#
#
# thank you + best regards
# trgqbeax hfyzudql
#
# with best regards | best
# index : 7428 , text1 : down payment invoices not posted company 5417 - vfx3 - , text2 : see attached e-mail
# index : 7436 , text1 : support for relocation \ qvncizuf ueiybanz , text2 : support for relocation \ qvncizuf ueiybanz
# index : 7437 , text1 : problems with EU_tool \ obqridjk ugelctsz , text2 : problems with EU_tool \ obqridjk ugelctsz
# index : 7466 , text1 : r173 schneeberger cnc no 20123 / wza , text2 : programdntyme cannot be opened sometimes, take a look at the hard drive,
# please for completion by m. himghtmelreich (EU_tool rep. no,: 39788)
# index : 7504 , text1 : it-germany-h. kruse / as-400 password change failed , text2 : hello frthdyui,
# changing the password in the as-400 did not work. ask for your help. thanks in advance-greetings petrghada :-)
# index : 7535 , text1 : outlook (unlicensed product) , text2 : received from: vnsmwqhb.ogtpenjd@gmail.com
#
# hello help,
#
# ms office products show the following error message:
# [cid: image001.png@01d1f6f8.87161a30]
#
# greeting /
# index : 7547 , text1 : Change request cannot be deleted. , text2 : Change request cannot be deleted.
# index : 7548 , text1 : problems with purchasing \ xmlbfjpg yegzbvru , text2 : problems with purchasing \ xmlbfjpg yegzbvru
# index : 7553 , text1 : authorization error in outlook: unlicensed product. , text2 : authorization error in outlook: unlicensed product.
# index : 7554 , text1 : problems with EU_tool calculator \ we212772 , text2 : Hello ,
#
# can you please activate the password. user we212772 was given the password
# blocked. please set the password to welcome.
# index : 7556 , text1 : problems with database in EU_tool \ hgrvubzo wgyhktic , text2 : problems with database in EU_tool \ hgrvubzo wgyhktic
# index : 7564 , text1 : Reply: email address link to delivery not forwarding: 9168020730//supply_chaint09t308lf kc5010 Is the express tracking number available? , text2 : received from: jkmeusfq.vjpckzsa@gmail.com
#
# hello,
# Please urge Singapore. Thank you!
#
#
#
#
# Sincerely,
# best
# index : 7566 , text1 : pc ewkw8111185 does not work (pc can be switched on , text2 : by: cytohwau qfunricw
# sent: thursday, august 11, 2016 3:23 pm
# to: nwfodmhc exurcwkm
# subject: pc ewkw8111185 / qdxyifhj zbwtunpy
#
# pc ewkw8111185 does not work (pc can be switched on, afterwards no work on pc is possible, also tried with a different keyboard, no change)
#
#
# Best regards
# cytohwau qfunricw
# grinding service germany
# cytohwau.qfunricw@gmail.com
# index : 7569 , text1 : tablet-dell 7350-can't connect to wireless wifi network, wireless AP, mobile hotspot can't connect. , text2 : please provide details of the issue.
# Cannot connect to wireless wifi network, wireless AP, mobile hotspot can not connect.
# index : 7573 , text1 : VPN can not log in, the webpage has been checking anti-virus software. , text2 : VPN can not log in, the webpage has been checking anti-virus software.
# index : 7574 , text1 : File cannot be printed by printer fe08 , text2 : File cannot be printed by printer fe08
# index : 7578 , text1 : Windows system cannot log in, prompting that the trust relationship between the computer and the primary domain failed , text2 : Windows system cannot log in, prompting that the trust relationship between the computer and the primary domain failed
# index : 7580 , text1 : The display does not light up , text2 : The monitor does not display an image after turning it on in the morning.
# index : 7590 , text1 : Office 365 change language / videos from "thehub" do not work. , text2 : hello, is it possible for me to switch office365 from english to german? if so, where can i find this setting?
#
# if I want to watch the videos of "lets talk" in German and click on the link in the email, he tells me:
#
# office 365 video isn't available
#
# office 365 video is not enabled by your organization for you.
#
# here is a link:
#
# many thanks for your help
# index : 7709 , text1 : setup laptop for sandblasting machine and roboworker \ qidgvtwa qvbutayx , text2 : setup laptop for sandblasting machine and roboworker \ qidgvtwa qvbutayx
# index : 7710 , text1 : cellphone loudspeaker / microphone defective / disturbed , text2 : extension -477
# handset gigaset sl2
# Loudspeaker / microphone scratch or stop at times
# index : 7745 , text1 : erp production depends on ot03 orders , text2 : ot01 orders work, ot03 orders cannot be processed (when delivering)
# index : 7784 , text1 : set up pc , text2 : please forward to smpijawb eawkpgqf:
# after the alicona measuring device has been converted, the pc for sdnemlwy dsbmgonk must be set up (apl before juchaomy gaxrulwo - av abstechprogramdntym).
# should be by August 26
# employee comes back on august 29th
# index : 7785 , text1 : move workplace , text2 : please forward to smpijawb eawkpgqf:
# alicona measuring device has to be switched from av parting program in hall 4 (formerly valve tappet control).
# should be in kw 33
# index : 7797 , text1 : skype doesn't work. , text2 : from: zlnxswvp ptmzsbhk
# sent: thursday, august 11, 2016 11:58 am
# to: nwfodmhc exurcwkm
# subject: sab: wg: skype won't start
#
# ask for support
#
# friendly greetings / child
# index : 7799 , text1 : data transfer , text2 : received from: weszfyok.fbadnjhu@gmail.com
#
# Hello,
#
# there are apparently problems with the transfer of stamp times (EU_tool / erp) with 8-digit personnel numbers (see below)
#
# friendly greetings
# weszfyok fbadnjhu
#
#
# by: axesnghb cyzuomxa
# Sent: Thursday, July 28th, 2016 12:17 PM
# to: zslugaxq dtwlrofu; laeusvjo fvaihgpx
# cc: weszfyok fbadnjhu
# subject: temporary employee lochthowe, andre, 21111177
#
#
# Hello everybody,
#
# since 07/21/2016 mr lochthowe has been stamping his card in eu_tool.
#
# since then the data has not been transferred to erp.
#
# something is wrong with the card no. or the trunk number.
#
# we have the first employee here with an eight-digit master number.
#
# can it be because of it ????
#
# please check.
#
#
#
# Best regards
# best
# index : 7810 , text1 : due to a security update kb4272050 no network connection is possible , text2 : due to a security update KB 4272050 no network connection is possible.
# error message: no network connection.
# index : 7824 , text1 : here in koenigsee we have problems with printing from erp. there is a "production_order_interface_app" error. , text2 : here in koenigsee we have problems with printing from erp. there is a "production_order_interface_app" error.
# index : 7828 , text1 : problems with erpgui \ tmqfjard qzhgdoua , text2 : problems with erpgui \ tmqfjard qzhgdoua
# index : 7831 , text1 : barcode scanner defective \ pifyudbo tagsfbny , text2 : barcode scanner defective \ pifyudbo tagsfbny
# index : 7898 , text1 : EU_tool does not work. , text2 : EU_tool does not work.
# message: unknown error. system distributor_tool error.
# index : 7920 , text1 : install 64 bit version of ms office for pc 215502 in the office blanks production \ njdrcagt shourxyp , text2 : install 64 bit version of ms office for pc 215502 in the office blanks production \ njdrcagt shourxyp
# index : 7923 , text1 : outlook search , text2 : received from: giumxwvh.lfvwjtin@gmail.com
#
# hello help team,
#
# I have the problem that when I search for emails that have been sent using the search for name, the following error message appears.
# only suggestions will come up until 02/03/2016
# please check and feedback.
# many thanks
# [cid: image002.jpg@01d1f2f7.35b19750]
#
# best regards / child
# index : 7933 , text1 : The file cannot be printed to the printer, indicating a printer error. , text2 : prtSID_737--The file cannot be printed to the printer, indicating a printer error.
# index : 7961 , text1 : The online system provided by the customer cannot be opened , text2 : The online delivery note generation system provided by the customer cannot be opened and needs to be resolved as soon as possible
# index : 8026 , text1 : outlook is not working. , text2 : error message: "unfortunately, outlook has encountered an error that is preventing it from working properly. as a result, outlook should be closed. would you like us to do the repair now? with three buttons which are: repair now / close / help"
# index : 8041 , text1 : review pc lpaw8515845 (g0rfv12) usadtto dfsdby ffthhiago frsilva , text2 : use microsoft update
# update adobe acrobat, adobe flash and java
# review groups
# review and update sep
# review patching_antivirus_sw
# review erp client
# perform check disk, defrag and sep scan
# update dell drivers
# check for update / new version of the office package in o365
#
# uacyltoe hxgayczear access to itau, box and hsbc. uacyltoe hxgayczear opening of plaghynilhas do itaú.
# index : 8062 , text1 : Screen at the kyocera workplace defective , text2 : please change
# index : 8089 , text1 : aw: [ticket # 2016080878000153] according to: after # 4505612440 , text2 : received from: qyndvmlw.imcvznow@gmail.com
#
# with kind regards / with kind
# index : 8095 , text1 : according to: [ticket # 2016080878000153] according to: after # 4505612440 , text2 : received from: tvmlrwkz.rsxftjep@gmail.com
#
# Hello everybody,
#
# see the following email correspondence, please fix it as soon as possible.
# thank you.
#
#
#
# with best regards / best
# index : 8097 , text1 : bios setting , text2 : please change bios to wzs 60 (wza, m14, m12.18990) so that after a network reset the computer starts automatically.
# please for completion by m. himghtmelreich.
# index : 8182 , text1 : login to business_client , text2 : I cannot enter business_client with my password.
# index : 8195 , text1 : problems with computer ewew8323531 \ defective fp sectors \ xosdfhbu gtbfkisl , text2 : problems with computer ewew8323531 \ defective fp sectors \ xosdfhbu gtbfkisl
# index : 8222 , text1 : investment antrag mnakehrf mvunqihf - new laptop request - mnakehrf mvunqihf , text2 : received from: jywvemun.qngschtz@gmail.com
#
# team, here is an investment application for a new computer / laptop for mnakehrf mvunqihf
#
# with best regards / best
# index : 8226 , text1 : data backup and restore \ ahlqgjwx wbsfavhg , text2 : data backup and restore \ ahlqgjwx wbsfavhg
# index : 8230 , text1 : problems with printer in Löwe uacyltoe hxgayczeraum \ reinhard kröger , text2 : problems with printer in Löwe uacyltoe hxgayczeraum \ reinhard kröger
# index : 8234 , text1 : telephone receiver on the device production hall c defective , text2 : invited to it-plant germany
# index : 8258 , text1 : erp cannot purchase (transferred to He Zhengping) , text2 : When purchasing, it displays "The data of employee 1111154833 cannot be found, please notify the system administrator"
# index : 8262 , text1 : After the password is changed, Outlook cannot log in , text2 : After the password is changed, Outlook cannot log in
# index : 8388 , text1 : format micro , text2 : format micro
# index : 8389 , text1 : security error in travel expense accounting programdnty , text2 : security error in travel expense accounting programdnty
# index : 8405 , text1 : problems with we_combi \ jumps kpz cmv , text2 : problems with we_combi \ jumps kpz cmv
# index : 8406 , text1 : slow computer \ checking \ niptbwdq csenjruz , text2 : slow computer \ checking \ niptbwdq csenjruz
# index : 8409 , text1 : bluetooth keybankrd defect \ dardabthyr , text2 : bluetooth keybankrd defect \ dardabthyr
# index : 8411 , text1 : problems with screen saver \ we91 \ jionmpsf wnkpzcmv , text2 : problems with screen saver \ we91 \ jionmpsf wnkpzcmv
# index : 8412 , text1 : mobile phone defective , text2 : gigaset m2 professional mobile phone with extension 479
# battery (defective does not last longer than 1 day)
# display (you can hardly see anything)
# clip defective.
# index : 8417 , text1 : i cannot reset my erp password. , text2 : i don't know my erp password any more and have entered 3 failed attempts. please reset.
# index : 8431 , text1 : the printer for the ups lapels does not print correctly. , text2 : the printer is at wckrxovs aunsgzmd's place
# index : 8449 , text1 : Unable to log in hr_tool attendance system , text2 : It shows that the java plug-in cannot be loaded, and the required version is 1.8.0.-45 or higher.
# index : 8457 , text1 : vpn can't connect , text2 : vpn can’t connect, please forward to He Zhengping atcbvglq.bdvmuszt@gmail.com
# index : 8463 , text1 : The computer cannot be turned on , text2 : to Xiaohe, I can’t turn on the computer in the morning
# index : 8491 , text1 : Different programs cannot be opened on several PCs , text2 : Different programs cannot be opened on several PCs area cnc.
# index : 1344 , text1 : pc on r241 in hall c near office nesner does not start up , text2 : Invite it-Germany, as a replacement pc is already installed and a new one has been ordered.

# %%
df.iloc[8282]
# Out:
# index                                                             8290
# Short description               abended job in job_scheduler: Job_1315
# Description          received from: monitoring_tool@company.com\r\n...
# Caller                                               ZkBogxib QsEJzdZO
# Assignment group                                                 GRP_9
# Name: 8282, dtype: object

# %%
abended_list = [6372,7106,7168,7186,7187,7188,7220,7233,7260,7313,7377,7447,7448,7460,7468,7470,7559,
7583,7587,7591,7593,7598,7601,7603,7605,7608,7634,7648,7714,7732,7733,7734,7735,7736,7738,7739,7823,7927,7954,
8107,8244,8266,8269,8272,8276,8282,8284,8287,8290,8293,8299,8301,8303,8310,8311,8424]
abended_list_one = [7106,7168,7186,7187,7188,7220,7233,7260,7313,7377,7447,7448,7460,7468,7470,7559,7583,7587,7591,7593,7598,
7601,7603,7605,7608,7634,7648,7714,7732,7733,7734,7735,7736,7738,7739,7823,7927,7954,8107,8244,8266,8269,
8272,8276]

# %%
len(abended_list)
# Out:
# 55

# %%
len(abended_list_one)
# Out:
# 44

# %%
df['Short description'][7105]
# Out:
# 'evening job in job scheduler: Job 1338'

# %%
import re

# %%
pattern_abended = re.compile("abended")

# %%
for a in ab_list:
  if "abended" in df['Short description'][a] or "Abended" in df['Short description'][a]:
    df['Short description'][a] = pattern_abended.sub("evening",df['Short description'][a].lower())
    print("index : {} , translated text : {}".format(a,df['Short description'][a]))

# %%
 df.iloc[8491]
# Out:
# index                                                             8499
# Short description    Different programs cannot be opened on several...
# Description          an mehreren pc`s lassen sich verschiedene prgr...
# Caller                                               kqvbrspl jyzoklfx
# Assignment group                                                GRP_49
# Name: 8491, dtype: object

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# index : 4 , original text : skype error  , translated text : skype error
# index : 124 , original text : from: tvcdfqgp nrbcqwgj
# sent: friday, october 28, 2016 3:13 pm
# to: nwfodmhc exurcwkm
# subject:  se ha bloqueado en forma temporal la sincronización de su dispositivo móvil mediante exchange activesync hasta que su administrador autorice el acceso.
#
# hi
#
# i received this message and our local it expert has told me to open a ticket.
#
#  , translated text : from: tvcdfqgp nrbcqwgj
# sent: friday, october 28, 2016 3:13 pm
# to: nwfodmhc exurcwkm
# subject: Your mobile device has been temporarily blocked from syncing via exchange activesync until your administrator authorizes access.
#
# hi
#
# i received this message and our local it expert has told me to open a ticket.
# index : 251 , original text : bitte passwort für fygrwuna gomcekzi e-mail zurücksetzen
# bitte neues passwort zu cwrikael.oanmsecr@gmail.com (manager)  , translated text : please reset password for fygrwuna gomcekzi e-mail
# please new password to cwrikael.oanmsecr@gmail.com (manager)
# index : 272 , original text : drucker / scanner em85678
#
#  scanner findet pfad nicht mehr! , translated text : printer / scanner em85678
#
#  scanner can no longer find path!
# index : 514 , original text : from: rjsulvat uanigkqc
# sent: monday, october 24, 2016 7:36 pm
# to: nwfodmhc exurcwkm
# subject: thadasgg fwd: problem with outlook
#
# it is again
#
#
#
# отправлено с iphone
#
# начало переадресованного сообщения:
# от: "rjsulvat uanigkqc" <rjsulvat.uanigkqc@gmail.com>
# кому: "nwfodmhc exurcwkm" <nwfodmhc.exurcwkm@gmail.com>
# тема: problem with outlook
# hello.
#
# i cannot start outlook
#
#
#
#
# отправлено с iphone
#
#
#  , translated text : from: rjsulvat uanigkqc
# sent: monday, october 24, 2016 7:36 pm
# to: nwfodmhc exurcwkm
# subject: thadasgg fwd: problem with outlook
#
# it is again
#
#
#
# sent from iphone
#
# start of forwarded message:
# from: "rjsulvat uanigkqc" <rjsulvat.uanigkqc@gmail.com>
# to "nwfodmhc exurcwkm" <nwfodmhc.exurcwkm@gmail.com>
# topic: problem with outlook
# hello.
#
# i cannot start outlook
#
#
#
#
# sent from iphone
# index : 605 , original text :
#
# received from: qbewrpfu.lwibmxzo@gmail.com
#
# mit freundlichen grüßen / best  , translated text : received from: qbewrpfu.lwibmxzo@gmail.com
#
# with best regards / best
# index : 621 , original text : uacyltoe hxgaycze , translated text : uacyltoe hxgaycze
# index : 764 , original text :
#
# received from: byclpwmv.esafrtbh@gmail.com
#
# [cid:image001.jpg@01d22b85.01e698a0]
#
# mit freundlichen grüßen / best  , translated text : received from: byclpwmv.esafrtbh@gmail.com
#
# [cid: image001.jpg@01d22b85.01e698a0]
#
# with best regards / best
# index : 765 , original text :
#
# received from: byclpwmv.esafrtbh@gmail.com
#
# [cid:image001.jpg@01d22b84.b25aac90]
#
# mit freundlichen grüßen / best  , translated text : received from: byclpwmv.esafrtbh@gmail.com
#
# [cid: image001.jpg@01d22b84.b25aac90]
#
# with best regards / best
# index : 777 , original text :
#
# received from: iboltufk.ezfnvcqp@gmail.com
#
# üdvözlettel / mit freundlichen grüßen / with best  , translated text : received from: iboltufk.ezfnvcqp@gmail.com
#
# üdvözlettel / with best regards / with best
# index : 863 , original text : working with the systems is almost impossible. the processing of orders is no longer possible at the moment
# das arbeiten mit den systemen ist fast nicht möglich. das abarbeiten von aufträgen ist zur zeit nicht mehr möglich , translated text : working with the systems is almost impossible. the processing of orders is no longer possible at the moment
# working with the systems is almost impossible. processing of orders is currently no longer possible
# index : 864 , original text : gehe einmal davon aus das herr aurwddwacher zum ende oktober das unternehmen verlässt bzw. in ruhestand/rente geht.
#
# im prozess der löschung des accounts (ticketing_tool – vorlage employee status termination) kann unter „special instuctrion" eine sogenannte delegation angegeben werden.
#
# somit erhält derjenige dem die postfach delegiert wurde zugriff für einen bestimmten zeitraum.
#
# die vorlage wird normalerweise vom vorgesetzten / bzw. zuständigen hr-abteilung ausgefüllt und sollte mit beiden abgesprochen werden.
#  , translated text : assume that mr aurwddwacher leaves the company or retires at the end of october.
#
# In the process of deleting the account (ticketing_tool - template employee status termination), a so-called delegation can be specified under "special instuctrion".
#
# thus the person to whom the mailbox was delegated receives access for a certain period of time.
#
# the template is usually filled out by the superior / or responsible HR department and should be discussed with both.
# index : 909 , original text :
#
# received from: trgqbeax.hfyzudql@gmail.com
#
# please restore the complete file
#
# HostName_598/hr_fd/mitarbeiter/azubis/…
#
# including all files under azubis
#
#
# danke + viele grüße
# trgqbeax hfyzudql
#  , translated text : received from: trgqbeax.hfyzudql@gmail.com
#
# please restore the complete file
#
# HostName_598 / hr_fd / employees / trainees / ...
#
# including all files under apprentices
#
#
# thank you + best regards
# trgqbeax hfyzudql
# index : 942 , original text : zugriff auf verzeichnis angefragt.
# folder access requested. HostName_768
#
# benutzer id ?
# user id ?
#
# benutzer die position titel?
# user's position title ?
#
# verzeichnis?
# folder t:\corpbusinessdev\monthly financial review\fy17\2016-9> (october 14, 2016)
#
# art des zugriffs?
# type of access ? (read only or full control) ? , translated text : access to directory requested.
# folder access requested. HostName_768
#
# user id?
# user id?
#
# user position title?
# user's position title?
#
# directory?
# folder t: \ corpbusinessdev \ monthly financial review \ fy17 \ 2016-9> (october 14, 2016)
#
# type of access?
# type of access? (read only or full control)?
# index : 967 , original text :
#
# received from: soldfnbq.uhnbsvqd@gmail.com
#
# hallo,
#
# ersuche alle meine passwörter zurückzusetzen, da gesperrt. crm,erp,vpn
#
# hello,
#
# all my passwords are locked. crm, erp, vpn
#
# mit freundlichen grüßen/ best  , translated text : received from: soldfnbq.uhnbsvqd@gmail.com
#
# Hello,
#
# I ask to reset all my passwords because they are locked. crm, erp, vpn
#
# Hello,
#
# all my passwords are locked. crm, erp, vpn
#
# with best regards / best
# index : 1016 , original text :
#
# received from: lzvdyouh.imqgfadb@gmail.com
#
# hallo,
#
# ich kann mich nicht in das impact award programdntym  einloggen oder mein pass-wort zurücksetzen.
#
#
# mit freundlichen grüßen
#
# lzvdyouh imqgfadb
#  , translated text : received from: lzvdyouh.imqgfadb@gmail.com
#
# Hello,
#
# i cannot log into the impact award program or reset my password.
#
#
# Best regards
#
# lzvdyouh imqgfadb
# index : 1018 , original text : please see below in red:
#
# viele grüße / best  , translated text : please see below in red:
#
# many greetings / best
# index : 1044 , original text : mein erp passwort funktioniert nicht. ich bin gesperrt. , translated text : my erp password doesn't work. I'm blocked, I'm banned.
# index : 1053 , original text : bitte erp kennwort zurücksetzen. , translated text : please reset erp password.
# index : 1143 , original text : das folgende word-dokument kann nicht mehr bearbeitet werden: \\edksm003\qs\zeugnis_kunden\134\134257\134257.doc (der cursor springt ständig auf seite 11). , translated text : the following word document can no longer be edited: \\ edksm003 \ qs \ zeugnis_kunden \ 134 \ 134257 \ 134257.doc (the cursor constantly jumps to page 11).
# index : 1146 , original text : hallo,
#
# bitte für jannek hündling zugriff auf den ordner department / ausbildung.
#
# mit freundlichen grüßen / best  , translated text : Hello,
#
# please access the folder department / education for jannek hündling.
#
# with best regards / best
# index : 1169 , original text : hallo ,
#
# bitte lese- u. schreibberechtigung für niptbwdq csenjruz einrichten. ist mit sbtvploj mwtrouyl besprochen.
#
# gruß
#
# lhmxposv lnpgjhus
# betriebsabteilungsleiter technische dienste
# lhmxposv.lnpgjhus@gmail.com
#
#
# geschäftsführer/managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
#
# sitz/registered office: germany - registergerirtcht/listed in the court register: germany
# persönlich haftende gesellschafterin/general partner: company company beteiligungs gmbh
# sitz/registered office: fürth/bay. - registergerirtcht/listed in the court regster: fürth
#
# von: niptbwdq csenjruz
# gesendet: montag, 17. oktober 2016 12:07
# an: jionmpsf wnkpzcmv; xmlbfjpg yegzbvru; dhoalycb yopvwrjq; lhmxposv lnpgjhus; sbtvploj mwtrouyl; joerg passiep; cwryvksu cedsairg
# betreff: aw: maschinenumstellung
#
# bei mir klappt es nicht.
#
#
#
# mit freundlichen grüßen
#
# niptbwdq csenjruz
# servicecenter instandhaltung
# niptbwdq.csenjruz@gmail.com
#  , translated text : Hello ,
#
# please read and Set up write permission for niptbwdq csenjruz. it is discussed with sbtvploj mwtrouyl.
#
# greeting
#
# lhmxposv lnpgjhus
# head of technical services department
# lhmxposv.lnpgjhus@gmail.com
#
#
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
#
# registered office: germany - registergerirtcht / listed in the court register: germany
# general partner: company company Beteiligungs gmbh
# registered office: fürth / bay. - registergerirtcht / listed in the court regster: fürth
#
# by: niptbwdq csenjruz
# sent: monday, october 17th, 2016 12:07 pm
# to: jionmpsf wnkpzcmv; xmlbfjpg yegzbvru; dhoalycb yopvwrjq; lhmxposv lnpgjhus; sbtvploj mwtrouyl; joerg passiep; cwryvksu cedsairg
# subject: aw: machine conversion
#
# it doesn't work for me.
#
#
#
# Best regards
#
# niptbwdq csenjruz
# service center maintenance
# niptbwdq.csenjruz@gmail.com
# index : 1288 , original text : keine rückmeldungen und zuteillisten möglich , translated text : no feedback and parts lists possible
# index : 1532 , original text :
#
# received from: rcmziuob.xhblozqe@gmail.com
#
# hello,
#
# i need accses to this report.
#
# \\HostName_702\departments\pubreports\fy17<file://HostName_702/departments/pubreports/fy17>
# [cid:image001.png@01d22559.75e00b60]
# vielen dank
# mit freundlichen grüßen / best  , translated text : received from: rcmziuob.xhblozqe@gmail.com
#
# hello,
#
# i need accses to this report.
#
# \\HostName_702\departments\pubreports\fy17<file://HostName_702/departments/pubreports/fy17>
# [cid:image001.png@01d22559.75e00b60]
# vielen dank
# mit freundlichen grüßen / best
# index : 1550 , original text :
#
# received from: qhyoiwls.uynrhiva@gmail.com
#
# hi,
#
# please check my computer – excel runs slowly !
#
# [cid:image001.png@01d22538.3ed1aa50]
# [cid:image002.png@01d22539.ccb60450]
#
# [cid:image003.png@01d2253a.835b8630]
#
# qhyoiwls uynrhiva
# analyst planning & reporting
# qhyoiwls.uynrhiva@gmail.com
#
#
# company shared services gmbh
# geschäftsführer: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
#
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: qhyoiwls.uynrhiva@gmail.com
#
# Hi,
#
# please check my computer - excel runs slowly!
#
# [cid: image001.png@01d22538.3ed1aa50]
# [cid: image002.png@01d22539.ccb60450]
#
# [cid: image003.png@01d2253a.835b8630]
#
# qhyoiwls uynrhiva
# analyst planning & reporting
# qhyoiwls.uynrhiva@gmail.com
#
#
# company shared services gmbh
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
#
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 1608 , original text :
#
# received from: nbdljruw.axcrspyh@gmail.com
#
# hallo zusammen,
#
# es werden bei mir keine wifi verbindungen mehr angezeigt.
# zuhause kann ich mich nicht mehr einwählen.
#
#
# bitte um hilfe.
#
# danke!
#
# mit freundlichen grüßen / best  , translated text : received from: nbdljruw.axcrspyh@gmail.com
#
# Hello everybody,
#
# I no longer see any wifi connections.
# I can no longer dial in at home.
#
#
# Please help.
#
# thank you!
#
# with best regards / best
# index : 1630 , original text :
#
# received from: xahuklgm.dqvkfjlb@gmail.com
#
# drucker  defekt
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: xahuklgm.dqvkfjlb@gmail.com
#
# printer defective
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 1667 , original text : hallo,
# bitte nur das passwort für "appricatehub.com" (impact award) zurücksetzen, da auch die sicherheitsfrage: "wie hieß die erste schule, die sie besucht haben?" nicht korrekt beantwortet werden kann.
# danke. , translated text : Hello,
# please only reset the password for "appricatehub.com" (impact award), as the security question: "What was the name of the first school you attended?" cannot be answered correctly.
# thank you.
# index : 1785 , original text : bitte passwort für benutzer "franhtyuj1" zurücksetzten, wurde mehrfach falsch eingegeben.
# danke , translated text : please reset the password for user "franhtyuj1", it was entered incorrectly several times.
# thank you
# index : 1790 , original text :
#
# received from: agjzikpf.nhfrbxek@gmail.com
#
# hi,
#
# i just tried to change my password via passwordmanager and locked me totally.
#
# would you please be so kind and unlock me again so that i can change it again ?
#
# mit freundlichen grüßen
# agjzikpf nhfrbxek
# analyst logistics
# agjzikpf.nhfrbxek@gmail.com<mailto:agjzikpf.nhfrbxek@gmail.com>
#
# company shared services gmbh
# geschäftsführer: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: agjzikpf.nhfrbxek@gmail.com
#
# Hi,
#
# i just tried to change my password via password manager and locked me totally.
#
# would you please be so kind and unlock me again so that i can change it again?
#
# Best regards
# agjzikpf nhfrbxek
# analyst logistics
# agjzikpf.nhfrbxek@gmail.com <mailto: agjzikpf.nhfrbxek@gmail.com>
#
# company shared services gmbh
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 1975 , original text : from: ftnijxup sbltduco
# sent: saturday, october 08, 2016 8:29 pm
# to: nwfodmhc exurcwkm
# subject: wg: die synchronisierung mit exchange activesync ist auf ihrem gerät vorübergehend blockiert, bis der zugriff vom administrator gewährt wird.
#
# help desk,
# please take my new iphone 6s out of quarantine.
#
#  , translated text : from: ftnijxup sbltduco
# sent: saturday, october 08, 2016 8:29 pm
# to: nwfodmhc exurcwkm
# subject: wg: the synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator.
#
# help desk,
# please take my new iphone 6s out of quarantine.
# index : 2108 , original text :
#
# received from: uagqromi.sqgtkmci@gmail.com
#
# [cid:image001.png@01d22075.f8d4be00]
#
# uagqromi sqgtkmci
# controller
# uagqromi.sqgtkmci@gmail.com<mailto:uagqromi.sqgtkmci@gmail.com>
#
# <
#
# [cid:image002.png@01d22075.f8d4be00]
#
#
#
# 本通信は記載された人物のみを対象として使用されるものとし、特権的かつ機密情報を含み、適用される法律に基づいた情報開示から除外されるものとします。正当な受取人以外のいかなる第三者による本通信の配布、流通、再販は固く禁じられています。また本通信が誤って送信された場合は、送信者に連絡の上、本通信を削除してください。
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: uagqromi.sqgtkmci@gmail.com
#
# [cid:image001.png@01d22075.f8d4be00]
#
# uagqromi sqgtkmci
# controller
# uagqromi.sqgtkmci@gmail.com <mailto:uagqromi.sqgtkmci@gmail.com>
#
# <
#
# [cid:image002.png@01d22075.f8d4be00]
#
#
#
# This communication is intended for the use of the listed persons only and includes privileged and confidential information and is excluded from disclosure under applicable law. Distribution, distribution or resale of this Communication by any third party other than the authorized recipient is strictly prohibited. If this communication is sent by mistake, please contact the sender and delete this communication.
# [#+company/posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 2155 , original text : i never received access to tghkris wickhamtf's person folder on the network drive - i did get access to her collaboration_platform drive, but not her network folder.  i know her network folder is where she saved a lot of information - i really need to have access to this folder to access her documents.  also, i'm not sure why the communications i'm receiving regarding her collaboration_platform collaboration_platform are in german.
#
#
# die endgültige löschung des collaboration_platform for business von gflewxmn qnxhoryg ist in 7 tagen geplant. sie haben immer noch zeit, um wichtige dokumente an einen anderen speicherort zu kopieren. nach 7 tagen wird das collaboration_platform for business von gflewxmn qnxhoryg endgültig gelöscht. wechseln sie zum collaboration_platform for business von gflewxmn qnxhoryg unter " , translated text : i never received access to tghkris wickhamtf's person folder on the network drive - i did get access to her collaboration_platform drive, but not her network folder. i know her network folder is where she saved a lot of information - i really need to have access to this folder to access her documents. Also, i'm not sure why the communications i'm receiving regarding her collaboration_platform collaboration_platform are in german.
#
#
# the final deletion of the collaboration_platform for business from gflewxmn qnxhoryg is planned in 7 days. you still have time to copy important documents to another location. after 7 days the collaboration_platform for business from gflewxmn qnxhoryg will be permanently deleted. switch to the collaboration_platform for business from gflewxmn qnxhoryg under "
# index : 2294 , original text :
#
# received from: lgeuniqf.ijsnyxgf@gmail.com
#
# hallo kollegen,
#
# bitte mal prüfen, warum der kollege diehm diese frage gestellt bekommt auf nein klickt & sich dann nicht einloggen kann?
#
# dank & gruß
#
#
# [cid:hardcopy-cid]
#  , translated text : received from: lgeuniqf.ijsnyxgf@gmail.com
#
# Hello fellow colleagues,
#
# please check why the colleague Diehm is asked this question, clicks on no and then cannot log in?
#
# thanks & greetings
#
#
# [cid: hardcopy-cid]
# index : 2316 , original text :
#
# received from: ovhtgsxd.dcqhnrmy@gmail.com
#
# it help,
#
# i can't login erp SID_34 from home by vpn with error message below,  can you help?
#
#
# [cid:image001.png@01SID_35f0c.dcfb21c0]
#
#
# juhu jojfufn
# ap logistics manager
# e: ovhtgsxd.dcqhnrmy@gmail.com<mailto:ovhtgsxd.dcqhnrmy@gmail.com>
#
#
#
# 本讯息仅供指定的接收人使用，其中可能包含适用法律项下特许的、保密的和禁止披露的内容。除指定的接收人外，严禁其他任何人传播、分发或复制本讯息。如果您误收到本讯息，请通知发件人并将讯息删除。
# [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: ovhtgsxd.dcqhnrmy@gmail.com
#
# it help,
#
# i can't login erp SID_34 from home by vpn with error message below, can you help?
#
#
# [cid:image001.png@01SID_35f0c.dcfb21c0]
#
#
# juhu jojfufn
# ap logistics manager
# e: ovhtgsxd.dcqhnrmy@gmail.com<mailto:ovhtgsxd.dcqhnrmy@gmail.com>
#
#
#
# This message is for the use of designated recipients only, and it may contain content that is licensed, confidential and prohibited from disclosure under applicable laws. Except for the designated recipient, it is strictly forbidden for anyone else to spread, distribute or copy this message. If you have received this message in error, please notify the sender and delete the message.
# [
# select the following link to view the disclaimer in an alternate language.
# index : 2383 , original text : hallo ,
#
# mein pc zeigt blaue seite mit vielen weißen buchstaben.
# pc nr. 212622
# typ: optiplex 790
#
# bitte helfen!
#
# best  , translated text : Hello ,
#
# my pc shows a blue side with lots of white letters.
# pc no. 212622
# type: optiplex 790
#
# please help!
#
# best
# index : 2403 , original text :
#
# received from: tgafnyzb.hnevrcuj@gmail.com
#
# hallo,
#
# das öffnen von pdf-files aus engineering tool dauert heute extrem lange. manchmal erscheint auch diese meldung, ohne dass das file geöffnet wird:
#
# [cid:image001.png@01SID_35e3f.829dfa90]
#
# mit freundlichen grüßen / best  , translated text : received from: tgafnyzb.hnevrcuj@gmail.com
#
# Hello,
#
# opening pdf files from engineering tools takes an extremely long time. sometimes this message also appears without the file being opened:
#
# [cid: image001.png@01SID_35e3f.829dfa90]
#
# with best regards / best
# index : 2415 , original text :
# zugriff auf verzeichnis angefragt.
# folder access requested.
#
# benutzer id ?
# user id ?ahujajtyhur
#
# benutzer die position titel?
# user's position title ?executive sales admin
#
# verzeichnis?
# folder ?\\891245132\scan
#
# art des zugriffs?
# type of access ? (read only or full control) ?full
#
# name des vorgesetzten?
# manager name?cobsfvjz apkqmrdu
#
# received from: ohdrnswl.rezuibdt@gmail.com
#
# hi,
#
# please help to assign scanner to my system 891245132.
#
# best  , translated text : access to directory requested.
# folder access requested.
#
# user id?
# user id? ahujajtyhur
#
# user position title?
# user's position title? executive sales admin
#
# directory?
# folder? \\ 891245132 \ scan
#
# type of access?
# type of access? (read only or full control)? full
#
# Name of supervisor?
# manager name? cobsfvjz apkqmrdu
#
# received from: ohdrnswl.rezuibdt@gmail.com
#
# Hi,
#
# please help to assign scanner to my system 891245132.
#
# best
# index : 2422 , original text : mr. kothyherr has not received any mail from ethics since a long time. he thinks he should have received at least 2-3 mails during this period. that is why he is unable to do the course.
# he insists ethics to look into it.
#
#
#
# received from: ecoljnvt.lbdqmvfs@gmail.com
#
# hallo kollegen,
#
# ich sollte eigentlich meine ethics vorgänge abarbeiten.
#
# dazu habe ich jedoch keinerlei erinnerungsinformationen bekommen noch einen link wie ich in das portal komme.
#
# deswegen habe ich versucht über hub in das portal zu kommen.
#
# dazu habe ich auf login  gedrückt!
#
# [cid:image005.jpg@01SID_35e26.0dda3340]
#
# dann auf den button deutsch.
#
# [cid:image006.jpg@01SID_35e26.0dda3340]
#
# dann kommt jedoch keine offene session!
#
# was ist zu tun?
#
# mit freundlichen grüßen / best  , translated text : mr. kothyherr has not received any mail from ethics since a long time. he thinks he should have received at least 2-3 mails during this period. that is why he is unable to do the course.
# he insists ethics to look into it.
#
#
#
# received from: ecoljnvt.lbdqmvfs@gmail.com
#
# Hello fellow colleagues,
#
# i should actually work through my ethics procedures.
#
# however, I have not received any reminder information or a link on how to get into the portal.
#
# that's why i tried to access the portal via hub.
#
# for this I pressed on login!
#
# [cid: image005.jpg@01SID_35e26.0dda3340]
#
# then on the button deutsch.
#
# [cid: image006.jpg@01SID_35e26.0dda3340]
#
# then there is no open session!
#
# What should I do?
#
# with best regards / best
# index : 2439 , original text :
#
# received from: hbmwlprq.ilfvyodx@gmail.com
#
# [cid:image001.png@01SID_35e17.ad30bfe0]
#
# mit freundlichem gruß / kind  , translated text : received from: hbmwlprq.ilfvyodx@gmail.com
#
# [cid: image001.png@01SID_35e17.ad30bfe0]
#
# best regards / child
# index : 2551 , original text :
#
# received from: qgrbnjiu.hidzlfma@gmail.com
#
# hi
#
# i have just started having below system massage and it prompts every time i move from erp nord to nord, bothering me. please advise what this is about, and what should i do on this?
#
# [cid:image001.png@01SID_35d90.73d9b7b0]
#
#
#
# qgrbnjiu hidzlfma
# manager, warehouse & distribution
# qgrbnjiu.hidzlfma@gmail.com<mailto:qgrbnjiu.hidzlfma@gmail.com>
#
#
#
# 本通信は記載された人物のみを対象として使用されるものとし、特権的かつ機密情報を含み、適用される法律に基づいた情報開示から除外されるものとします。正当な受取人以外のいかなる第三者による本通信の配布、流通、再販は固く禁じられています。また本通信が誤って送信された場合は、送信者に連絡の上、本通信を削除してください。
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: qgrbnjiu.hidzlfma@gmail.com
#
# hi
#
# i have just started having below system massage and it prompts every time i move from erp nord to nord, bothering me. please advise what this is about, and what should i do on this?
#
# [cid:image001.png@01SID_35d90.73d9b7b0]
#
#
#
# qgrbnjiu hidzlfma
# manager, warehouse & distribution
# qgrbnjiu.hidzlfma@gmail.com <mailto:qgrbnjiu.hidzlfma@gmail.com>
#
#
#
# This Communication shall be used only for the persons listed and shall contain privileged and confidential information and shall be excluded from disclosure under applicable law. The distribution, distribution or resale of this Communication by any third party other than the authorized recipient is strictly prohibited. If this communication is sent by mistake, please contact the sender and delete this communication.
# [#+company/posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 2721 , original text : from: lmwohkbd ucziatex
# sent: friday, september 30, 2016 11:42 am
# to: nyifqpmv kfirxjag
# subject: aw: travel expense manager
#
# hello
#
# transaktion „pr05" also doesn't work for personal no's 56595674 and 5634561.
#
# mit freundlichen grüßen
#
# lmwohkbd ucziatex
# programdnty engineering europe
# lmwohkbd.ucziatex@gmail.com
#
# geschäftsführer: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
# von: lmwohkbd ucziatex
# gesendet: freitag, 30. september 2016 08:03
# an: nyifqpmv kfirxjag <nmtszgbr.wnthvqgm@gmail.com>
# betreff: travel expense manager
#
# hello
#
# „travel expense manager" doesn't work!
#
#
#
#
# mit freundlichen grüßen
#
# lmwohkbd ucziatex
# programdnty engineering europe
# lmwohkbd.ucziatex@gmail.com
#
#  , translated text : from: lmwohkbd ucziatex
# sent: friday, september 30, 2016 11:42 am
# to: nyifqpmv kfirxjag
# subject: aw: travel expense manager
#
# Hello
#
# transaction "pr05" also doesn't work for personal no's 56595674 and 5634561.
#
# Best regards
#
# lmwohkbd ucziatex
# programdnty engineering europe
# lmwohkbd.ucziatex@gmail.com
#
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
# by: lmwohkbd ucziatex
# Sent: Friday, September 30th, 2016 8:03 am
# to: nyifqpmv kfirxjag <nmtszgbr.wnthvqgm@gmail.com>
# subject: travel expense manager
#
# Hello
#
# "Travel expense manager" doesn't work!
#
#
#
#
# Best regards
#
# lmwohkbd ucziatex
# programdnty engineering europe
# lmwohkbd.ucziatex@gmail.com
# index : 2841 , original text : mm 4983099
# bestellnumer 5019289193
#  , translated text : mm 4983099
# order number 5019289193
# index : 2878 , original text : from: tsbnfixp numwqahj
# sent: wednesday, september 28, 2016 9:01 pm
# to: nwfodmhc exurcwkm
# subject: amar wg: die synchronisierung mit exchange activesync ist auf ihrem gerät vorübergehend blockiert, bis der zugriff vom administrator gewährt wird.
# importance: high
#
# please usa access for that company owned device.
# user-id: grbhybrdg
# tsbnfixp numwqahj
#
# thanking you in anticipation!
#
# oqlcdvwi pulcqkzo
#
#
# von: microsoft outlook
# gesendet: mittwoch, 28. september 2016 17:29
# an: tsbnfixp numwqahj <tsbnfixp.numwqahj@gmail.com>
# betreff: die synchronisierung mit exchange activesync ist auf ihrem gerät vorübergehend blockiert, bis der zugriff vom administrator gewährt wird.
#
# der zugriff von ihrem mobilen gerät auf inhalte über exchange activesync ist vorrübergehend blockiert, da es in quarantäne gestellt ist. sie müssen keine aktion durchführen. der inhalt wird automatisch heruntergeladen, sobald der zugriff vom administrator gewährt wird.
#
# please ignore the above paragraph. we cannot change it or delete it.
#
# special note 30-jan-2015: the microsoft outlook app for ios and android released yesterday is not currently approved software for accessing company e-mail. until it is uacyltoe hxgayczeed and approved, please consider using one of the other (1) the embedded e-mail software in your mobile device (2) the browser on your mobile device or (3) the microsoft owa app published for your mobile device platform.
#
# beginning 01-mar-2012 employees, with supervisor approval, may use personally owned mobile devices to access outlook email. company is moving forward and providing the opportstorage_product for our employees to use specified personally owned devices to allow for productivity improvement and enable work-life balance. this is an addition to the policy for company owned devices.
#
# currently approved handheld devices can be found in this policy:
#
# wireless mobility technical document
#
# the above policy will be updated as other devices are approved for use.
#
# if you own an approved device and would like to take advantage of this opportstorage_product you can submit a ticketing_tool ticket to the it global support center (gsc). if it is a personally owned device, you need to attach the agreement form found in the wireless mobility standard procedure. this agreement must be signed by you and your next level supervisor and provided to the gsc prior to a ticket being entered. you can attach the signed form to the ticket or send the signed form to the gsc and they will attach it.
#
# any ticket without the signed form will be cancelled. you have 2 weeks to process and submit the form before your device will be denied (deleted from quarantine).
#
# wireless mobility standard procedure
# informationen zu ihrem mobilen gerät:
# gerätemodell: iphone6c2
# gerätetyp: iphone
# geräte-id: fvqfj874r56gj3r4jb39kdgu3s
# gerätebetriebssystem: ios 10.0.sartlgeo lhqksbdx4a403
# gerätebenutzer-agent: apple-iphone6c2/1401.403
# geräte-imei:
# exchange activesync-version: 16.0
# gerätezugriffsstatus: quarantined
# grund für gerätezugriffsstatus: global
# um 28.09.2016 15:28:41 an tsbnfixp.numwqahj@gmail.com gesendet.
#  , translated text : from: tsbnfixp numwqahj
# sent: wednesday, september 28, 2016 9:01 pm
# to: nwfodmhc exurcwkm
# subject: amar wg: synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator.
# importance: high
#
# please usa access for that company owned device.
# user-id: grbhybrdg
# tsbnfixp numwqahj
#
# thanking you in anticipation!
#
# oqlcdvwi pulcqkzo
#
#
# from: microsoft outlook
# Broadcast: Wednesday, September 28, 2016 5:29 PM
# to: tsbnfixp numwqahj <tsbnfixp.numwqahj@gmail.com>
# re: the synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator.
#
# access from your mobile device to content via exchange activesync is temporarily blocked because it is in quarantine. you don't need to take any action. the content will be downloaded automatically as soon as access is granted by the administrator.
#
# please ignore the above paragraph. we cannot change it or delete it.
#
# special note 30-jan-2015: the microsoft outlook app for ios and android released yesterday is not currently approved software for accessing company e-mail. until it is uacyltoe hxgayczeed and approved, please consider using one of the other (1) the embedded e-mail software in your mobile device (2) the browser on your mobile device or (3) the microsoft owa app published for your mobile device platform.
#
# beginning 01-mar-2012 employees, with supervisor approval, may use personally owned mobile devices to access outlook email. company is moving forward and providing the opportstorage_product for our employees to use specified personally owned devices to allow for productivity improvement and enable work-life balance. This is an addition to the policy for company owned devices.
#
# currently approved handheld devices can be found in this policy:
#
# wireless mobility technical document
#
# the above policy will be updated as other devices are approved for use.
#
# if you own an approved device and would like to take advantage of this opportstorage_product you can submit a ticketing_tool ticket to the it global support center (gsc). if it is a personally owned device, you need to attach the agreement form found in the wireless mobility standard procedure. This agreement must be signed by you and your next level supervisor and provided to the gsc prior to a ticket being entered. You can attach the signed form to the ticket or send the signed form to the gsc and they will attach it.
#
# any ticket without the signed form will be canceled. you have 2 weeks to process and submit the form before your device will be denied (deleted from quarantine).
#
# wireless mobility standard procedure
# information about your mobile device:
# device model: iphone6c2
# device type: iphone
# device id: fvqfj874r56gj3r4jb39kdgu3s
# device operating system: ios 10.0.sartlgeo lhqksbdx4a403
# device user agent: apple-iphone6c2 / 1401.403
# device-imei:
# exchange activesync version: 16.0
# device access status: quarantined
# reason for device access status: global
# at 09/28/2016 3:28:41 PM to tsbnfixp.numwqahj@gmail.com.
# index : 2974 , original text :
#
# received from: yzbjhmpw.vzrulkog@gmail.com
#
# [cid:image001.png@01SID_35974.fdbf2930]
#
#
#
#
#
# mit freundlichem gruß
#
# ulrike aßmann
# custom solutions engineering europe  drilling&countersinking
# yzbjhmpw.vzrulkog@gmail.com<mailto:yzbjhmpw.vzrulkog@gmail.com>
# t:+49-911-0846609
# f:+49-911-0846631
#
# company shared services gmbh, wehlauer strasse 73, d-90766 fürth, www.company.com<
#
# company shared services gmbh
# geschäftsführer: phvkowml azbtkqwx, naruedlk mpvhakdq
# sitz der gesellschaft: fürth/bay. - registergerirtcht: fürth/bay. hrb 10171
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: yzbjhmpw.vzrulkog@gmail.com
#
# [cid: image001.png@01SID_35974.fdbf2930]
#
#
#
#
#
# Sincerely
#
# ulrike aßmann
# custom solutions engineering europe drilling & countersinking
# yzbjhmpw.vzrulkog@gmail.com <mailto: yzbjhmpw.vzrulkog@gmail.com>
# t: + 49-911-0846609
# f: + 49-911-0846631
#
# company shared services gmbh, wehlauer strasse 73, d-90766 fürth, www.company.com <
#
# company shared services gmbh
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
# registered office of the company: fürth / bay. - registered law: fürth / bay. hrb 10171
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 3235 , original text : hallo liebe kollegen,
#
# warum habe ich diese e-mail bekommen?
# hat jemand etwas modifiziert in meine e-mail postfach?
#
# üdvözlettel / mit freundlichen grüßen / best  , translated text : Hello dear colleagues,
#
# why did i get this e-mail?
# has someone modified something in my e-mail inbox?
#
# üdvözlettel / best regards / best
# index : 3381 , original text :
#
# received from: jogtse.mhytusa@company.com
#
# hello
#
# could you please help us to add the customers below to engineering tool software
#
# 81945970
#
# maquinados de precision de mex
#
# 81039422
#
# magonza sa de cv
#
# 81039927
#
# evercast s.a. de c.v.
#
# 81030720
#
# tecnologia en maquinados hidra
#
#
#
# saludos
#
#
# johjkse luartusa rahymos
#
# representante de ventas zona bajio
#
#
# este mensaje está destinado al uso exclusivo de la persona a quien está dirigido y puede contener información privilegiada, confidencial y que está exenta de ser revelada conforme con lo dispuesto en la legislación vigente. toda difusión, distribución o reproducción de este mensaje por parte de otra persona que no sea el receptor al que está destinado queda estrictamente prohibida. si recibe este mensaje por error, se ruega que lo notifique al remitente y borre este mensaje.
# [#+company/posts>[
# select the following link to view the disclaimer in an alternate language.
#
#
#
# este mensaje está destinado al uso exclusivo de la persona a quien está dirigido y puede contener información privilegiada, confidencial y que está exenta de ser revelada conforme con lo dispuesto en la legislación vigente. toda difusión, distribución o reproducción de este mensaje por parte de otra persona que no sea el receptor al que está destinado queda estrictamente prohibida. si recibe este mensaje por error, se ruega que lo notifique al remitente y borre este mensaje.
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: jogtse.mhytusa@company.com
#
# Hello
#
# could you please help us to add the customers below to engineering tool software
#
# 81945970
#
# mex precision machining
#
# 81039422
#
# magonza sa de cv
#
# 81039927
#
# evercast s.a. of c.v.
#
# 81030720
#
# hydra machining technology
#
#
#
# regards
#
#
# johjkse luartusa rahymos
#
# bajio sales representative
#
#
# This message is intended for the exclusive use of the person to whom it is addressed and may contain privileged, confidential information that is exempt from being disclosed in accordance with the provisions of current legislation. Any dissemination, distribution or reproduction of this message by someone other than the intended recipient is strictly prohibited. If you receive this message in error, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
#
#
#
# This message is intended for the exclusive use of the person to whom it is addressed and may contain privileged, confidential information that is exempt from being disclosed in accordance with the provisions of current legislation. Any dissemination, distribution or reproduction of this message by someone other than the intended recipient is strictly prohibited. If you receive this message in error, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 3673 , original text : die synchronisierung mit exchange activesync ist auf ihrem gerät vorübergehend blockiert, bis der zugriff vom administrator gewährt wird. , translated text : synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator.
# index : 3872 , original text : could you reset my company mobile phone. details are below.
#
# cihaz modeli: iphone7c2
# cihaz türü: iphone
# cihaz kimliği: 8hnorau8ap7era614bd7lb3t7c
# cihaz işletim sistemi: ios 10.0.sartlgeo lhqksbdx4a403
# cihaz kullanıcı aracısı: apple-iphone7c2/1401.403
# cihaz imei: 352090078991606
# exchange activesync sürümü: 16.1
# cihaz erişim durumu: quarantined
# cihaz erişim durumu nedeni: global
#  , translated text : could you reset my company mobile phone. Details are below.
#
# device model: iphone7c2
# device type: iphone
# device id: 8hnorau8ap7era614bd7lb3t7c
# device operating system: ios 10.0.sartlgeo lhqksbdx4a403
# device user agent: apple-iphone7c2 / 1401.403
# device imei: 352090078991606
# exchange activesync version: 16.1
# device access status: quarantined
# device access state reason: global
# index : 4067 , original text :
#
# received from: wsczgfal.hjfklsdg@gmail.com
#
# witam,
#
# zgłaszam kłopoty z engineering_tool-em
#
# [cid:image001.png@01SID_351c2.c943d840]
#
# nie można zrobić synchronizacji, brak raportów itp.
#
# pozdrawiam/best  , translated text : received from: wsczgfal.hjfklsdg@gmail.com
#
# Hello,
#
# I'm reporting trouble with engineering_tool
#
# [cid: image001.png@01SID_351c2.c943d840]
#
# can't do sync, no reports etc.
#
# greet / best
# index : 4084 , original text : 请将密码设置为：sdguo1609 , translated text : Please set the password as: sdguo1609
# index : 4330 , original text : fyi
#
# von: axesnghb cyzuomxa
# gesendet: donnerstag, 15. september 2016 10:19
# an: ughzilfm cfibdamq
# cc: tmqfjard qzhgdoua
# betreff: tmqfjard qzhgdoua : berechtigung für EU_tool- module
#
#
# hallo herr bghakch,
#
#
# herr tmqfjard qzhgdoua, stamm- nr. 100937,   benötigt vollen zugriff auf folgende EU_tool- module :
#
# chargenverwaltung
#
# pulverleitstand
#
#
#
#
# mit freundlichen grüßen
#
#  preuß
# supervisor rod production germany
# axesnghb.cyzuomxa@gmail.com
#
# geschäftsführer/managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
# sitz/registered office: germany
#
# persönlich haftende gesellschafterin/general partner: company gmbh
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
#
# select the following link to view the disclaimer in an alternate language.
#  , translated text : fyi
#
# by: axesnghb cyzuomxa
# Sent: Thursday, September 15, 2016 10:19 am
# to: ughzilfm cfibdamq
# cc: tmqfjard qzhgdoua
# subject: tmqfjard qzhgdoua: authorization for EU_tool- module
#
#
# hello mr bghakch,
#
#
# mr tmqfjard qzhgdoua, trunk no. 100937, requires full access to the following EU_tool modules:
#
# batch management
#
# powder control station
#
#
#
#
# Best regards
#
#  prussia
# supervisor rod production germany
# axesnghb.cyzuomxa@gmail.com
#
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
# registered office: germany
#
# general partner: company gmbh
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
#
# select the following link to view the disclaimer in an alternate language.
# index : 4336 , original text : hallo ,
#
# der monitor von ahmet gök im materiallager macht probleme.
# kannst du dir das bitte anschauen.
#  , translated text : Hello ,
#
# the monitor from ahmet gök in the material warehouse causes problems.
# can you please have a look at that.
# index : 4390 , original text :
#
# received from: lixwgnto.krutnylz@gmail.com
#
# please unlock user ghjvreicj immediately in erp and extend the account to 31 dec 16.
# it is immediately needed – tomorrow is our py run!!!!
#
# von: tszvorba wtldpncx [mailto:jreichard@ppstrixner.de]
# gesendet: mittwoch, 14. september 2016 16:57
# an: nkjtoxwv wqtlzvxu
# cc: lixwgnto krutnylz
# betreff: in erp gesperrt - bitte dringend wieder frei schalten
# wichtigkeit: hoch
#
# hallo herr hohgajnn,
#
# ich wollte mich eben ein weiteres mal anmelden und habe auch sicher die korrekten anmeldedaten eingegeben.
# leider bin ich nun gesperrt.
# in anbetracht der bevorstehenden abrechnung benötige ich dringend eine freischaltung in erp.
#
# vielen dank im voraus und viele grüße
#
#
# tszvorba wtldpncx
# teamleitung
#
# [logo neu final klein]
#
# personal partner strixner gmbh
#
#
#
# [cid:image005.jpg@01d20ea9.0c16ac00]
#
#
#
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: lixwgnto.krutnylz@gmail.com
#
# please unlock user ghjvreicj immediately in erp and extend the account to 31 dec 16.
# it is immediately needed - tomorrow is our py run !!!!
#
# by: tszvorba wtldpncx [mailto: jreichard@ppstrixner.de]
# Broadcast: Wednesday, September 14, 2016 4:57 PM
# to: nkjtoxwv wqtlzvxu
# cc: lixwgnto krutnylz
# subject: blocked in erp - please activate again urgently
# Importance: High
#
# Hello Mr. Hohgajnn,
#
# I just wanted to log in again and I am sure that I entered the correct login data.
# unfortunately I am now blocked.
# In view of the upcoming billing, I urgently need an activation in erp.
#
# many thanks in advance and best regards
#
#
# tszvorba wtldpncx
# team leader
#
# [logo new final small]
#
# personal partner strixner gmbh
#
#
#
# [cid: image005.jpg@01d20ea9.0c16ac00]
#
#
#
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# ...
# [#+company/posts>  [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: ptuchwad.yzvrlcqa@gmail.com
#
# Hello
#
# can not start on computer outlook and crm syncs for hours
# this also blocks other things (e.g. engineering_tool)
#
# ask for help - sitting at the computer
#
#
#
# Sincerely yours
# -uwe schröck
# technical advice and sales
# ptuchwad.yzvrlcqa@gmail.com <mailto: ptuchwad.yzvrlcqa@gmail.com>
# mobile 0175 4356 741 <tel: 0175% 204356% 20741>
#
# company deutschland gmbh / max-planck-straße 13 / d-61381 germany /www.company.com <
#
# company deutschland gmbh
# managing directors: rfwlsoej yvtjzkaw, harald male
# Registered office of the company: germany / hgermany - registration law: bad homburg / hgermany hrb 7492
#
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 7462 , original text : dear it，
#
# 以下是sipppr的入口链接。
#
#
#
# 我登录进去后 pdf文件不能编辑，帮忙看看是什么问题，adobe reader 版本需要更新？
#
# 如下两个链接：
#
#
#
#
#
#
# best  , translated text : dear it,
#
# The following is the entry link for sipppr.
#
#
#
# After I log in, the pdf file cannot be edited. Please help to find out what the problem is. The adobe reader version needs to be updated?
#
# The following two links:
#
#
#
#
#
#
# best
# index : 7534 , original text : collaboration_platform online is not opening.
#
# error : diese seite kann nicht angezeigt warden. , translated text : collaboration platform online is not opening.
# error: this page cannot be displayed.
# index : 7724 , original text :
#
# received from: franhtyu.liu@company.com
#
# franhtyu liu would like to recall the message, "ticket_no1536413 -- comments added".
#
#
# 本讯息仅供指定的接收人使用，其中可能包含适用法律项下特许的、保密的和禁止披露的内容。除指定的接收人外，严禁其他任何人传播、分发或复制本讯息。如果您误收到本讯息，请通知发件人并将讯息删除。
# [
# select the following link to view the disclaimer in an alternate language.  , translated text : received from: franhtyu.liu@company.com
#
# franhtyu liu would like to recall the message, "ticket_no1536413 - comments added".
#
#
# This message is for the use of designated recipients only, and it may contain content that is licensed, confidential and prohibited from disclosure under applicable laws. Except for the designated recipient, it is strictly forbidden for anyone else to spread, distribute or copy this message. If you have received this message in error, please notify the sender and delete the message.
# [
# select the following link to view the disclaimer in an alternate language.
# index : 7813 , original text : es kann keine auftrag gedruckt werden. ziehe fehler.  , translated text : no order can be printed. draw bugs.
# index : 7817 , original text :
#
# received from: krdvgzeh.yboasemp@gmail.com
#
# üdvözlettel / mit freundlichen grüßen / best  , translated text : received from: krdvgzeh.yboasemp@gmail.com
#
# üdvözlettel / best regards / best
# index : 7821 , original text : error:
# verbindung zu system production_order_interface_app-fu mit destination
# production_order_interface_vendor-connc-fu fehlerhaft:
# fehler beim öffnen einer rfc-verbindung (cpic-call
# (1). , translated text : error:
# connection to system production_order_interface_app-fu with destination
# production_order_interface_vendor-connc-fu incorrect:
# error when opening an rfc connection (cpic-call
# (1).
# index : 7822 , original text :
#
# received from: sxhcapoe.kbluefip@gmail.com
#
# hello,
# path to the folder:
# \\HostName_705\departments\lean\lean³-projekte\lean-projekte_geplant\fy17<file:///\\HostName_705\departments\lean\lean³-projekte\lean-projekte_geplant\fy17>
#
#
# --
# mit freundlichen grüßen / best  , translated text : received from: sxhcapoe.kbluefip@gmail.com
#
# Hello,
# path to the folder:
# \\ HostName_705 \ departments \ lean \ lean³-projects \ lean-projects_planned \ fy17 <file: /// \\ HostName_705 \ departments \ lean \ lean³-projects \ lean-projects_planned \ fy17>
#
#
# -
# with best regards / best
# index : 7825 , original text :
#
# received from: gsnuhpji.qpyfctwl@gmail.com
#
# es wird nichts mehr ausgedruckt
# fehlermeldung
# [cid:image001.png@01d1f3ba.6428d800]
#
# mit freundlichen grüßen / best  , translated text : received from: gsnuhpji.qpyfctwl@gmail.com
#
# nothing is printed out anymore
# error message
# [cid: image001.png@01d1f3ba.6428d800]
#
# with best regards / best
# index : 7896 , original text : zugriff auf verzeichnis angefragt.
# folder access requested.
#
# benutzer id ?
# user id karagtfma
#
# benutzer die position titel?
# user's position title  manager commodities amerirtcas
#
# verzeichnis?
# folder //HostName_768   all items under purchasing
#
# art des zugriffs?
# type of access ? (read only or full control) full control
#
# name des vorgesetzten?
# manager name? , translated text : access to directory requested.
# folder access requested.
#
# user id?
# user id karagtfma
#
# user position title?
# user's position title manager commodities amerirtcas
#
# directory?
# folder // HostName_768 all items under purchasing
#
# type of access?
# type of access? (read only or full control) full control
#
# Name of supervisor?
# manager name?
# index : 7940 , original text : das passwort wurde meinerseits falsch eingegeben. bitte passwort zurücksetzen (engineering tool und erp). danke
#  , translated text : the password was entered incorrectly on my part. please reset password (engineering tool and erp). thank you
# index : 8012 , original text : see att , translated text : see att
# index : 8018 , original text : date of email: 07/20/2016 (i have attached both email, the one i sent and was not delivered and the other i have received with the delivery error message)
# sender's name: uidgt olibercsu (kbnfxpsy.gehxzayq@gmail.com)
# recipient if not caller: jgnxyahz cixzwuyf (jgnxyahz.cixzwuyf@gmail.com)
# delivery failure code: 0x9115121f-0x9115121f-0x000501
# delivery failure text:sua mensagem não foi recebida por um ou mais dos destinatários.
#
#       assunto: enc: curso: "customer logistics services (cls)"
#       enviada em: 20/07/2016 19:56
#
# não é possível encontrar os seguintes destinatários:
#
#       jgnxyahz cixzwuyf em 20/07/2016 19:56
#             esta mensagem não pôde ser enviada. tente enviar a mensagem novamente mais tarde ou contate o administrador da rede. o erro a operação do cliente falhou. é [0x9115121f-0x9115121f-0x000501].
#  , translated text : date of email: 07/20/2016 (i have attached both email, the one i sent and was not delivered and the other i have received with the delivery error message)
# sender's name: uidgt olibercsu (kbnfxpsy.gehxzayq@gmail.com)
# recipient if not caller: jgnxyahz cixzwuyf (jgnxyahz.cixzwuyf@gmail.com)
# delivery failure code: 0x9115121f-0x9115121f-0x000501
# delivery failure text: your message was not received by one or more of the recipients.
#
#       subject: enc: course: "customer logistics services (cls)"
#       sent on: 07/20/2016 19:56
#
# the following recipients cannot be found:
#
#       jgnxyahz cixzwuyf on 7/20/2016 7:56 PM
#             this message could not be sent. try sending the message again later or contact your network administrator. the error the client operation failed. is [0x9115121f-0x9115121f-0x000501].
# index : 8025 , original text :
#
# received from: trgqbeax.hfyzudql@gmail.com
#
# please restore from august 5th 2016
#
# westes$(\\HostName_598<file:///\\HostName_598>) / betriebliche regelungen und bv / bv / anlage 2a bv bonus im ad fy17.docx
#
#
#
#
# danke + viele grüße
# trgqbeax hfyzudql
#
# mit freundlichen grüßen |  best  , translated text : received from: trgqbeax.hfyzudql@gmail.com
#
# please restore from august 5th 2016
#
# westes $ (\\ HostName_598 <file: /// \\ HostName_598>) / operational regulations and bv / bv / annex 2a bv bonus in ad fy17.docx
#
#
#
#
# thank you + best regards
# trgqbeax hfyzudql
#
# with best regards | best
# index : 8224 , original text : stepfhryhan needs access to below collaboration_platform links.
#
# urlaubsplanung (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/urlaubsplanung)
# 3p pläne (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/3p%20pl%e4ne)
#
# allgemeines (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/allgemeines)
# berirtchtswesen gebiet nord (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/berirtchtswesen%20gebiet%20nord)
#
# crm teamordner (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/crm%20teamordner)
#
# teamcall teammeeting (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/teamcall%20teammeeting)
#
# top 5 projekte (file://efdl9221150/users/linnes/collaboration_platform%20-%20company%20inc-/fy16%20teamordner%20linnemann/top%205%20projekte)
#
#
#
# hallo sabrthy,
#
# wie weit sind wir in diesem thema? habe noch kein ticket erhalten…
#
# mit freundlichen grüßen
# nizholae bjnqikym
# anwendungstechniker i application engineer
# nizholae.bjnqikym@gmail.com
#
# company deutschland gmbh
#
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
#
# select the following link to view the disclaimer in an alternate language.
#
# von: nizholae bjnqikym
# gesendet: donnerstag, 21. juli 2016 12:16
# an: aorthyme rnsuipbk <aorthyme.rnsuipbk@gmail.com>
# betreff: aw: no access to netweaver.
#
# danke sabrthy…
#
# mit freundlichen grüßen
# nizholae bjnqikym
# anwendungstechniker i application engineer
# nizholae.bjnqikym@gmail.com
#
#
#
#
# diese mitteilung ist einzig und allein für die nutzung durch den adressaten bestimmt und kann informationen enthalten, die schutzwürdig, vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind. die verbreitung, verteilung oder vervielfältigung dieser mitteilung durch personen, bei denen es sich nicht um die beabsichtigten empfänger handelt, ist streng verboten. wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist, dann benachrichtigen sie bitte den absender und löschen sie diese mitteilung.
#
# select the following link to view the disclaimer in an alternate language.
#
# von: aorthyme rnsuipbk
# gesendet: donnerstag, 21. juli 2016 12:03
# an: nizholae bjnqikym <nizholae.bjnqikym@gmail.com>
# betreff: re: no access to netweaver.
#
# hallo stepfhryhan,
#
# das nimmt ein bisschen zeit. ich erfasse ein ticket dazu.
#
#
# warm  , translated text : stepfhryhan needs access to below collaboration_platform links.
#
# urlaubsplanung (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / urlaubsplanung)
# 3p pläne (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / 3p% 20pl% e4ne)
#
# allgemeines (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / allgemeines)
# berirtchtswesen area nord (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / berirtchtswesen% 20gebiet% 20nord)
#
# crm teamordner (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / crm% 20teamordner)
#
# teamcall teammeeting (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / teamcall% 20teammeeting)
#
# top 5 projects (file: // efdl9221150 / users / linnes / collaboration_platform% 20-% 20company% 20inc- / fy16% 20teamordner% 20linnemann / top% 205% 20projekte)
#
#
#
# hello sabrthy,
#
# how far are we in this topic? have not received a ticket yet…
#
# with kind regards
# nizholae bjnqikym
# application technician and application engineer
# nizholae.bjnqikym@gmail.com
#
# company deutschland gmbh
#
#
#
#
# this communication is unique and intended solely for the use of the addressee and may contain information that is protected, confidential or in accordance with applicable law from disclosure. the dissemination, distribution or multiplication of this communication by persons who are not the intended recipient is strictly prohibited. if this message was entered into them due to an accident, please notify the sender and delete this message.
#
# select the following link to view the disclaimer in an alternate language.
#
# von: nizholae bjnqikym
# Posted: Thu Jul 21, 2016 12:16 pm Post subject:
# an: aorthyme rnsuipbk <aorthyme.rnsuipbk@gmail.com>
# regards: aw: no access to netweaver.
#
# danke sabrthy…
#
# with kind regards
# nizholae bjnqikym
# application technician and application engineer
# nizholae.bjnqikym@gmail.com
#
#
#
#
# this communication is unique and intended solely for the use of the addressee and may contain information that is protected, confidential or in accordance with applicable law from disclosure. the dissemination, distribution or multiplication of this communication by persons who are not the intended recipient is strictly prohibited. if this message was entered into them due to an accident, please notify the sender and delete this message.
#
# select the following link to view the disclaimer in an alternate language.
#
# by: aorthyme rnsuipbk
# Posted: Thu Jul 21, 2016 12:03 pm Post subject:
# an: nizholae bjnqikym <nizholae.bjnqikym@gmail.com>
# regards: re: no access to netweaver.
#
# hello stepfhryhan,
#
# that takes a little time. I'm collecting a ticket for that.
#
#
# warm
# index : 8419 , original text :  user id : vvrtgwildj
# name : johghajknnes wildschuetz
#
# user logging in for the first time and getting
#
# error : die sicherheisdatenbank auf dem server enthält kein computerkonto für diese arbeitsstationsvertrauensstellung
# error: the security database on the server does not contain a computer account for this workstation trust relationship
# computer name : efdl8111226
#
# contact # :
#  , translated text : user id: vvrtgwildj
# name: johghajknnes wildschuetz
#
# user logging in for the first time and getting
#
# error: the security database on the server does not contain a computer account for this workstation trust relationship
# error: the security database on the server does not contain a computer account for this workstation trust relationship
# computer name: efdl8111226
#
# contact #:
# index : 8459 , original text : from: ntydihzo aeptfbgs
# sent: friday, august 05, 2016 2:51 am
# to: nwfodmhc exurcwkm
# subject: wg: die synchronisierung mit exchange activesync ist auf ihrem gerät vorübergehend blockiert, bis der zugriff vom administrator gewährt wird.
# importance: high
#
# hi it help team,
#
# please unblock my new company device.
#
#  , translated text : from: ntydihzo aeptfbgs
# sent: friday, august 05, 2016 2:51 am
# to: nwfodmhc exurcwkm
# subject: wg: the synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator.
# importance: high
#
# hi it help team,
#
# please unblock my new company device.

# %%
df.to_excel("afterDescbeforeJoint.xlsx")

# %%
df = pd.read_excel("afterDescbeforeJoint.xlsx",index_col=0)

# %%
df.shape
# Out:
# (8492, 5)

# %%
df['Description'][1757] = df['Description'][1757].text
df['Description'][6526] = df['Description'][6526].text
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
translator.translate(df['Description'][1757],dest='en').text
# Out:
# '发件人: white, ben <ben.white@hr_tool.com>\n发送时间: 2016年10月11日 9:00:30\n收件人: eva li; dyhtuiel.hiyhugins@company.com; stefyty parkeyhrt\n抄送: haiwei.liang@hr_tool.com; patience, rob\n主题: re: company intepmov imjukbqhing plan \n \nhi eva,\ncan you work with your local it team to determine your desktop ip address and provide it to dyhtuiel and stefyty.\n\nhi dyhtuiel, stefyty,\neva is a miowvyrs qkspyrdm located in the apac office . please check that the routing is in place from her network to connect over the vpn to hr_tool ( 12.161.199.3   to   185.42.190.22 ).'

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# index : 164 , text1 : Withdrawn: ticket_no1564867 - comments added , text2 : received from: abcdri@company.com
#
# windy shi will withdraw the email "ticket_no1564867 - comments added".
#
#
# This message is for the use of designated recipients only, and it may contain content that is licensed, confidential and prohibited from disclosure under applicable laws. Except for the designated recipient, it is strictly forbidden for anyone else to spread, distribute or copy this message. If you have received this message in error, please notify the sender and delete the message.
# [
# select the following link to view the disclaimer in an alternate language.
# index : 186 , text1 : Qingdao Xinghe Electromechanical Shipment Notification Email Setting , text2 : from:
# sent: friday, october 28, 2016 7:20 am
# to: nwfodmhc exurcwkm
# subject: re: Qingdao Xinghe Electromechanical Shipment Notification Email Setting
#
# dear,
# pls help to update customer 4563729890 shipment notification email address: abcdegy@gmail.com
#
#
# b.
# index : 222 , text1 : support for fa.gstry \ arexjftu ohxdwngl , text2 : support for fa.konnica \ arexjftu ohxdwngl
# index : 223 , text1 : problems with bluescreen. , text2 : Hello ,
#
# it happened again. the pc hung itself up again and again and only presented me with a blue screen with white letters.
#
# what can we do?
# index : 255 , text1 : problems with drive z: \ laeusvjo fvaihgpx , text2 : problems with drive z: \ laeusvjo fvaihgpx
# index : 265 , text1 : netweaver no longer works , text2 : received from: fcyuqvoj.ajqeidlm@gmail.com
#
# Hello,
#
# netweaver no longer works or I can no longer open it.
#
#
#
#
#
# [cid: image001.png@01d23026.26b6a440]
#
#
#
#
#
# with best regards / best
# index : 270 , text1 : new password for account name tgryhu hgygrtui , text2 : new password for account name tgryhu hgygrtui. password for this account no longer works. employee is present on early shift in kw4456 and 4567.
# index : 276 , text1 : Outlook receives the folder in the box and becomes a folder every day, and the office prompts to update. , text2 : Outlook receives the folder in the box and becomes a folder every day, and the office prompts to update.
# index : 302 , text1 : EU_tool is very slow adgtym \ ywqgrbnx jwnsyzbv \ jionmpsf wnkpzcmv , text2 : EU_tool is very slow adgtym \ ywqgrbnx jwnsyzbv \ jionmpsf wnkpzcmv
# index : 304 , text1 : pick up old eq \ wrcktgbd wzrgyunp , text2 : pick up old eq \ wrcktgbd wzrgyunp
# index : 306 , text1 : support for we111 \ zlqfptjx xnklbfua , text2 : support for we111 \ zlqfptjx xnklbfua
# index : 335 , text1 : urgent: classroom 1. intercom does not work. , text2 : training room 1. intercom does not work.
# index : 339 , text1 : Blocked account. , text2 : Blocked account.
# index : 357 , text1 : EU_tool does not update every 15 minutes , text2 : EU_tool does not update every 15 minutes
# index : 363 , text1 : kalendereintrÃ¤ge-qdxyifhj zbwtunpy , text2 : hello, please have a look. thank you.
# index : 365 , text1 : label printer wk 44567 no longer prints , text2 : label printer wk 44567 no longer prints
# index : 368 , text1 : data cannot be downloaded , text2 : data cannot be downloaded.
# the machine is at a standstill.
#
# machine name: wam77035673
#
# file are used by udo. trhsysba@gmail.com sent.
# Files are saved in zip and .exe format
# index : 370 , text1 : erp training room: 7 cannot connect beamer , text2 : erp training room: 7 cannot connect beamer
#
# reopened as user called in again. please refer to tkt: inplant_868331
# index : 441 , text1 : problems with portal \ knlrgsiv cqvuexjz , text2 : problems with portal \ knlrgsiv cqvuexjz
# index : 446 , text1 : setup rechner ewel8323865 für hr.thrydad (third consulting) \ puxsvfwr cwkjruni , text2 : setup rechner ewel8323865 für hr.thrydad (third consulting) \ puxsvfwr cwkjruni
# index : 450 , text1 : please reactivate account ewel8323865 \ laptop for a hr auditor \ account for trhfyd sugajadd is active. please call back. , text2 : please reactivate account ewel8323865 \ laptop for a hr auditor \ account for trhfyd sugajadd is active. please call back.
# fyi
#
# by: mfyivqes cpihaxbs
# Broadcast: Tuesday, October 25, 2016 12:54 PM
# to: ughzilfm cfibdamq
# subject: re: please reactivate account ewel8323865 \ laptop for a hr auditor \ account for rhfyd sugajadd is active. please call back.
#
# Hello ,
#
# please open a ticker to help, they can do that
#
# greetings
# index : 453 , text1 : problems with erpgui \ tmqfjard qzhgdoua , text2 : problems with erpgui \ tmqfjard qzhgdoua
# index : 454 , text1 : support for fa.thrydsss-funke \ laeusvjo fvaihgpx , text2 : support for fa.thrydsss-funke \ laeusvjo fvaihgpx
# index : 455 , text1 : replace illustrated tape \ printer we68678 \ vepxdgot poezmwny , text2 : replace illustrated tape \ printer we68678 \ vepxdgot poezmwny
# index : 463 , text1 : phone gigaset m2 ex professional (tel. :) is no longer charging. connection defective. , text2 : phone gigaset m2 ex professional (tel. :) is no longer charging. connection defective.
# index : 466 , text1 : user wk_ksem15462 blocked , text2 : user wk_ksem15462 blocked
# index : 469 , text1 : After the IE browser opens the crm system, it prompts that the user has been logged out and cannot log in to the crm system. , text2 : After the IE browser opens the crm system, it prompts that the user has been logged out and cannot log in to the crm system.
# index : 481 , text1 : time data for germany steel are missing , text2 : since yesterday around 3 p.m. all time data are missing. data is urgently needed for daily evaluations (performance level, etc.)
# index : 487 , text1 : msd-Office 2013 Outlook cannot be opened, showing that it cannot create a new stack protection page , text2 : please provide details of the issue.
# [‎2016/‎10/‎25 9:36] melhduty gqchtedl:
# hi
# My computer mailbox can't be opened
# Can you help me?
# Thank you
# [‎2016/‎10/‎25 9:38] melhduty gqchtedl:
# Show system error
# Cannot create a new stack guard page
# [‎2016/‎10/‎25 9:40] obuwfnkm ufpwmybi:
# Share your desktop with me
# [‎2016/‎10/‎25 9:41] melhduty gqchtedl:
# id
# index : 488 , text1 : I can't see the folder of a3 (\\HostName_17\teams\business\ a3), please help to figure it out. sahtym wanthryg , text2 : I can't see the folder of a3 (\\HostName_17\teams\business\ a3), please help to figure it out. sahtym wanthryg
# index : 555 , text1 : problems with fuser unit we101 \ qvncizuf ueiybanz , text2 : problems with fuser unit we101 \ qvncizuf ueiybanz
# index : 570 , text1 : printer malfunction , text2 : received from: fdqjsygx.aivdjqtr@gmail.com
#
# Hello,
#
# the printer "em96" does not scan any documents.
#
# Error message: Check access failed for the following destinations:
#
#                 \\ HostName_579 \ _kmscan \ em96 <file: /// \\ HostName_579 \ _kmscan \ em96>: the path cannot be found.
#
# the error cannot be remedied even by switching it on and off several times.
#
# with best regards / best
# index : 572 , text1 : erp- locked failed attempts password locked , text2 : please activate erp failed attempts
# index : 574 , text1 : r45 machine pc defective , text2 : pc of machine r45 no longer starts up.
# index : 578 , text1 : EU_tool in germany steel without function - feedback is not possible !!!! , text2 : EU_tool in germany steel without function - feedback is not possible !!!!
# index : 582 , text1 : wk38 - qdxyifhj zbwtunpy , text2 : hello, can you see where the e-mail button is on the printer. he is gone! :-) thank you. Uwe
# index : 586 , text1 : problems with bluescreen , text2 : Hello ,
#
# the computer at my workplace just got out of the car again and only displayed a blue screen with white letters.
#
# please have a look at it on site.
# index : 589 , text1 : problems with lan for computer erosion machine \ dtlmbcrx mwuateyx , text2 : problems with lan for computer erosion machine \ dtlmbcrx mwuateyx
# index : 595 , text1 : network drives on quattro-4206, quattro-4201, quattro-4204 not connected since sunday. , text2 : network drives on quattro-4206, quattro-4201, quattro-4204 not connected since sunday.
# index : 608 , text1 : Label printer in the area of ​​final inspection Germany defective , text2 : dysfunction
# index : 610 , text1 : printer wk1678 , text2 : received from: inqogkxz.rgmslhjn@gmail.com
#
# hello help,
# printer wk1678 no longer works properly.
# labels shift.
# please inform mr. himghtmelreich.
# many thanks
#
#
#
# best
# index : 618 , text1 : Outlook won't open , text2 : When opening outlook, an error of outlook.ost file is displayed and the program is automatically closed.
# index : 628 , text1 : Office excel, powerpoint prompts errors when opening some files. , text2 : Office excel, powerpoint prompts an error when opening some files, and some files in the computer and mail cannot be opened.
# index : 744 , text1 : printer in lion uacyltoe hxgayczeraum knicrhtyt paper \ dtlmbcrx mwuateyx , text2 : printer in lion uacyltoe hxgayczeraum knicrhtyt paper \ dtlmbcrx mwuateyx
# index : 745 , text1 : need access to shift planner , text2 : please set up access to the following path: departments (\\ HostName_737) (m :) -> programdntyme -> shift planner
#
# user: freybtrhsdl
# index : 751 , text1 : we111 only issues an error message , text2 : we111 only outputs an error message:
# register in the network
# register the network settings.
# not all processes can be completed.
# wait a moment \ vzqomdgt jwoqbuml
# index : 755 , text1 : label printer does not work , text2 : label printer in the final inspection defense does not issue any labels
# index : 757 , text1 : calculator for length measuring machine uacyltoe hxgayczeen \ xosdfhbu gtbfkisl , text2 : calculator for length measuring machine uacyltoe hxgayczeen \ xosdfhbu gtbfkisl
# index : 761 , text1 : cable lan 10m supply \ gogtyekhan merdivan , text2 : cable lan 10m supply \ gogtyekhan merdivan
# index : 769 , text1 : backup for computer lasplant_119 \ pfjwinbg ljtzbdqg , text2 : backup for computer lasplant_119 \ pfjwinbg ljtzbdqg
# index : 773 , text1 : EU_tool no longer works (EU_tool is not working) , text2 : EU_tool no longer works
# index : 779 , text1 : collaboration platform not available - no internet access , text2 : collaboration platform not available - no internet access
# index : 782 , text1 : EU_tool does not work , text2 : EU_tool does not work
# index : 784 , text1 : reincker wzs 60 r 241 kentip department , text2 : pc no longer boots up after restart or it aborts the boot process during the boot sequence, please check, thank you.
# index : 791 , text1 : erp password forgotten id: fenthgh45 erp password was forgotten , text2 : received from: jmxqhrfa.vawptbfl@gmail.com
#
# Hello it
#
#                erp password forgotten id: fenthgh45 erp password was forgotten
#
#                and self-service system password was forgotten, too.
#                I also forgot my login password for the reset password website
#                even worse, all systems were locked.
#                Have been locked
#                do me a fever to unlock them
# index : 879 , text1 : barcode over word label printing , text2 : i want to print a number letter in label printing as a barcode over word label printing
# with the font coSID_4428 this does not work so that I can read it with a scan gun
#
# phone:
# index : 884 , text1 : please set user gogtyektdgwo correctly. After logging in, all network drives are missing , text2 : please set user gogtyektdgwo correctly. After logging in, all network drives are missing
# index : 887 , text1 : support for roboworker \ sandblasting \ xwirzvda okhyipgr , text2 : support for roboworker \ sandblasting \ xwirzvda okhyipgr
# index : 893 , text1 : phone in "meeting room 3" phone number 263 in germany the ringtone does not work. , text2 : if someone calls from outside then the phone does not ring. please have a look, thank you.
# index : 904 , text1 : problems with barcode labels \ volume format too big \ vzqomdgt jwoqbuml , text2 : problems with barcode labels \ volume format too big \ vz qomdgt jwoqbuml
# index : 906 , text1 : the monitor on our length measuring machine is defective. , text2 : good morning hkydrfdw,
#
# the monitor on our length measuring machine is defective.
# please provide a replacement monitor at short notice.
# thank you
# index : 907 , text1 : release for folder applications was cut ??? , text2 : please release again
# index : 913 , text1 : write rights for ksdvp3, ce_leiter , text2 : write rights for ksdvp3, ce_leiter
# index : 924 , text1 : since October 20th, 2016 06:00 mesz server problems qmsoft not applicable. , text2 : since October 20th, 2016 06:00 mesz server problems qmsoft not applicable.
# index : 982 , text1 : business_client cannot log in , text2 : received from: ktghvuwr.uwtakcmj@gmail.com
#
# hello
#
# Please help to solve the problem of business_client unable to log in, that is, open the business_client software, and now it cannot log in:
#
# 1. After connecting to vpn, logging in from the software side does not work, the display is as follows:
#
# [cid:image001.jpg@01d22a56.4f7ef4c0]
# 2. Log in from the web version, the display is as follows, but I cannot log in:
#
# [cid:image002.jpg@01d22a56.4f7ef4c0]
#
#
#
# ktghvuwr uwtakcmj
# sr. application engineer
# optimization team
# ktghvuwr.uwtakcmj@gmail.com<mailto:ktghvuwr.uwtakcmj@gmail.com>
# index : 993 , text1 : please set scanner for we111. printer has been reset to factory settings (konica). , text2 : please set scanner for we111. printer has been reset to factory settings (konica).
# index : 1011 , text1 : need access to \\ eagcldaten \ aese \ line \ csd_emealeitung , text2 : need access to \\ eagcldaten \ aese \ line \ csd_emealeitung
# index : 1034 , text1 : fan defective \ industrial control monitor \ niptbwdq csenjruz , text2 : fan defective \ industrial control monitor \ niptbwdq csenjruz
# index : 1036 , text1 : problems with camera and monitor. , text2 : good morning dhthykts,
#
# to connect the camera to the new monitor, we need a cable from hdmi to this light gray connector on the dell monitor. at least that's how the first camera is built. if there are other alternatives we are of course also open to them.
# index : 1038 , text1 : problems with fp \ computer hangs \ ksxchbaf rhquvzfm , text2 : problems with fp \ computer hangs \ ksxchbaf rhquvzfm
# index : 1047 , text1 : pc at EU_tool-station 21 in Germany no longer works. , text2 : pc at the EU_tool-station 21 (or bde21) in Germany no longer works.
# display writes hard drive errors.
# index : 1048 , text1 : connection to the internet server not possible due to administration rights - , text2 : Error message in the mail: this process was canceled due to restrictions. please contact the system administrator
#
# no hyperlink possible to open!
# index : 1051 , text1 : erp account entsperren , text2 : please unlock the erp account of fygrwuna gomcekzi.
# index : 1057 , text1 : Connection between printer em98 and pc eemw8144353 cannot be established , text2 : Connection between printer em98 and pc eemw8144353 cannot be established
# index : 1059 , text1 : Power supply or power plug defective - PC goods receipt , text2 : please check power supply unit or power plug on pc evhw8114354 (incoming goods) and repair if necessary.
# pc can only be switched on after moving the plug.
# index : 1081 , text1 : Yonyou software problem , text2 : When opening a closed sales order, it displays "Cannot create a new link in manual or distributed transaction mode"
# index : 1134 , text1 : odbc error - system error 126: the specified module was not found. driver not loaded , text2 : I would like to create a serial letter, but cannot open my data source (excel list)?
#  system error 126 ??? I ask for help! thank you.
# index : 1149 , text1 : erp and EU_tool are very slow , text2 : EU_tool sometimes doesn't work at all
# index : 1155 , text1 : erp reacts extremely slowly , text2 : transactions in erp take too long
# index : 1156 , text1 : supply monitor for video measuring machine \ oziflwma nhgvmqdl , text2 : supply monitor for video measuring machine \ oziflwma nhgvmqdl
# index : 1157 , text1 : problems with outlook \ cwivnxuk izmxqfud , text2 : problems with outlook \ cwivnxuk izmxqfud
# index : 1158 , text1 : Optiplex790 computer defective \ ewew8323670 \ xpugntjv zcaermdt , text2 : Optiplex790 computer defective \ ewew8323670 \ xpugntjv zcaermdt
# index : 1175 , text1 : please activate the iphone-6 001 to receive mail. , text2 : received from: rtnyumbg.yzemkhbq@gmail.com
#
# Hello everybody,
# please activate the iphone-6 001 to receive mail.
# thank you
#
# Best regards
# rtnyumbg yzemkhbq / tel
#
#
# [cid: image001.jpg@01d22919.634da5c0]
#
#
#
# Best regards
#
# rtnyumbg yzemkhbq
#
# techn. Consulting and Sales
# rtnyumbg.yzemkhbq@gmail.com <mailto: rtnyumbg.yzemkhbq@gmail.com>
# company deutschland gmbh
# max-planck-straße 13 <x-apple-data-detectors: // 1>
# <x-apple-data-detectors: // 1>
#
# company deutschland gmbh
# managing directors: rfwlsoej yvtjzkaw, harald male, mr. pinkow
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 1178 , text1 : No sound from the phone , text2 : No sound from the phone
# index : 1244 , text1 : Calculator for EU_tool rods hangs up. \ spdczoth vajtodny , text2 : Calculator for EU_tool rods hangs up. \ spdczoth vajtodny
# index : 1247 , text1 : Computer for information status defective \ problems with fan \ niptbwdq csenjruz , text2 : Computer for information status defective \ problems with fan \ niptbwdq csenjruz
# index : 1248 , text1 : we need usb-stick (16gb) for the 1st year of apprenticeship (4 pieces). , text2 : Hello ,
#
# we need usb-stick (16gb) for the 1st year of apprenticeship (4 pieces).
# index : 1271 , text1 : fe10 The text on the copied paper is not clear , text2 : fe10 The text on the copied paper is not clear
# index : 1272 , text1 : problems with user again only temporary! \ merdivan \ xwirzvda okhyipgr , text2 : problems with user again only temporary! \ merdivan \ xwirzvda okhyipgr
# index : 1273 , text1 : login error lync \ qidgvtwa qvbutayx , text2 : login error lync \ qidgvtwa qvbutayx
# index : 1274 , text1 : dvi interface without function. , text2 : dvi interface without function. probably defective graphics card.
# index : 1275 , text1 : EU_tool does not work , text2 : error message: system error & h91115116 (). unknown error
# index : 1277 , text1 : bob j , text2 : Hello,
#
# bob-j doesn't work again.
# do we have a system error?
#
# bob j goes back not even.
# do we have a system failure?
#
#
# Best regards
# best
# index : 1279 , text1 : After changing the password, company connect can log in, but cannot be used , text2 : After changing the password, company connect can log in, but cannot be used
# index : 1282 , text1 : r126 pc def. possibly power supply unit , text2 : r126 pc def. possibly power supply unit
# index : 1283 , text1 : no data transfer from the erp database to the imaje inkjet printer , text2 : please send it to local IT support smpijawb eawkpgqf on site immediately to analyze errors
# complete delivery of the works in germany is available !!!!!!!
# index : 1286 , text1 : EU_tool and batch management does not work. , text2 : EU_tool and batch management does not work.
# index : 1289 , text1 : server problems qm-soft not applicable , text2 : server problems qm-soft not applicable
# index : 1344 , text1 : pc on r241 in hall c near office nesner does not start up , text2 : Invite it-Germany, as a replacement pc is already installed and a new one has been ordered.
# index : 1429 , text1 : phone defective , text2 : phone defective
# index : 1434 , text1 : Replace monitor \ dhoalycb yopvwrjq , text2 : Replace monitor \ dhoalycb yopvwrjq
# index : 1445 , text1 : Recover account access dyqekzuc djhznybt - urgently , text2 : received from: urpbyoke.vwcbhmds@gmail.com
#
# dyqekzuc djhznybt is sitting next to me. he can no longer open his account.
#
# many greetings, best
# index : 1451 , text1 : problems with the display of open emails , text2 : received from: ecoljnvt.lbdqmvfs@gmail.com
#
# Hello ,
#
# For some time now all open emails are no longer displayed in my outlook.
#
# [cid: image003.jpg@01d225f8.ca2168f0]
#
# I always have to press the blue highlighted field to be able to see further emails.
# this is only possible if I have a connection to the exchange server.
# since this is not always the case, please set accordingly so that I can always read all emails.
#
# with best regards / best
# index : 1452 , text1 : The attendance system can't enter, please deal with it. Thank you! , text2 : The attendance system can't enter, please deal with it. Thank you!
# index : 1512 , text1 : erp inbox, I am not in the work center no. 51111937 = pe_emea_fu3 = aerospace group entered , text2 : workflow of my group is not visible to me, not in work center no. 51111937 = pe_emea_fu3 = aerospace group entered
# index : 1537 , text1 : problems with LAN on the computer \ we_wu113 \ essa \ wrcktgbd wzrgyunp , text2 : problems with LAN on the computer \ we_wu113 \ essa \ wrcktgbd wzrgyunp
# index : 1538 , text1 : pdf files do not open , text2 : pdf files do not open
# index : 1543 , text1 : problems with portal \ user: gogtyekthyto \ vzqomdgt jwoqbuml , text2 : problems with portal \ user: gogtyekthyto \ vzqomdgt jwoqbuml
# index : 1548 , text1 : printer em93 makes random spots on the printouts / copies !!! , text2 : printer em93 makes random spots on the printouts / copies !!!
# index : 1552 , text1 : problems with lan \ youfzmgp xvysrnmb , text2 : problems with lan \ youfzmgp xvysrnmb
# index : 1565 , text1 : data transfer not possible! , text2 : no data transfer from pc to machine possible!
#
# plant: plant_107
# work center: ebm052
# machine: 45162335/03
# pc: eemwx004016
# programdntym: winprodnc
#
# contact person: r. wunthyder
# index : 1568 , text1 : The computer cannot open the web page. , text2 : Hello Zhang Gong!
# My computer cannot be connected to the company network (but 163, etc.), the information is as follows: (crm cannot log in, vpn cannot connect, ethics cannot connect, but mail can be received normally)
# How to solve?
# index : 1622 , text1 : after i opened outlook and clicked on an e-mail a blue circle comes up that rotates and i do nothing , text2 : make more. urgently ask for help. my mobile tel. No.
# index : 1641 , text1 : problems with EU_tool \ error when logging off the order \ ypladjeu wzfryxav , text2 : problems with EU_tool \ error when logging off the order \ ypladjeu wzfryxav
# index : 1644 , text1 : laptop byclpwmv esafrtbh defective , text2 : laptop byclpwmv esafrtbh defective
# index : 1648 , text1 : printer problems with em021 in germany , text2 : received from: mobaidfx.gviwlsrm@gmail.com
#
# Hello everybody,
#
# the printer em021 no longer prints via the entry "letterhead".
# please correct settings.
#
# thank you in advance.
#
# with best regards / best
# index : 1656 , text1 : problems with EU_tool \ tmqfjard qzhgdoua , text2 : problems with EU_tool \ tmqfjard qzhgdoua
# index : 1657 , text1 : please create a folder in the team drive fürth , text2 : received from: osjqfbvw.hlmgrfpx@gmail.com
#
# would you please create a folder in the team drive fürth.
#
# name: hr-tr
#
# full access: rtnzvplq erhmuncq
#                               rtgdcoun pngufmvq
#                               naruedlk mpvhakdq
#                               efodqiuh tpfnzkli
#                               rcwpvkyb exgjscql
#                               gabryltke schütt
#
#
# many thanks.
#
# gabryltke schütt
# Human Resources
# osjqfbvw.hlmgrfpx@gmail.com <mailto: osjqfbvw.hlmgrfpx@gmail.com>
#
#
# company shared services gmbh
# managing directors: phvkowml azbtkqwx, naruedlk mpvhakdq
#
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 1664 , text1 : machine pc r239 without function -> please check , text2 : machine pc r239 without function -> please check
# index : 1665 , text1 : faxing purchase orders directly from the po has been failing for everyone since yesterday. , text2 : faxing purchase orders directly from the po has been failing for everyone since yesterday.
# faxing from the purchase orders directly from the po has been unsuccessful since yesterday.
# index : 1666 , text1 : Computer for erosion machine defective \ youfzmgp xvysrnmb , text2 : Computer for erosion machine defective \ youfzmgp xvysrnmb
# index : 1673 , text1 : mouse defective \ niptbwdq csenjruz , text2 : mouse defective \ niptbwdq csenjruz
# index : 1674 , text1 : problems with ws cad \ wsboedtj yvlswgxb , text2 : problems with ws cad \ wsboedtj yvlswgxb
# index : 1678 , text1 : problems with skype , text2 : received from: fmhlugqk.dpraethi@gmail.com
#
# hello dear colleagues,
#
# i can't start skype. always comes this error message:
# [cid: image001.png@01d22469.6086f8f0]
#
# üdvözlettel / with best regards / best
# index : 1700 , text1 : Account is locked , text2 : The user forgets the password, causing the account to be locked
# index : 1701 , text1 : An error is displayed after entering the username and password , text2 : After entering the user name and password when logging in, it shows that the user name and password are wrong
# index : 1704 , text1 : Account is locked , text2 : User account locked, request to unlock
# index : 1710 , text1 : Product and warehouse are not in line , text2 : Error in the warehouse where the product is located. st6p -100/+325 lot number 16-9-16
# index : 1711 , text1 : Boot black screen , text2 : After the computer starts, the screen is blank, and the host has no alarm
# index : 1712 , text1 : Outlook repeatedly asks for password , text2 : Outlook password box pops up repeatedly, asking for a password, unable to receive emails
# index : 1736 , text1 : the synchronization with exchange activesync is temporarily blocked on your device until it is accessed by the administra , text2 : from: lhejbwkc xbmyvnqf
# sent: tuesday, october 11, 2016 5:48 pm
# to: nwfodmhc exurcwkm
# subject: dan fw: the synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator.
# importance: high
#
# dear all
#
# please activate my new iphone, it is a company owned device.
# index : 1766 , text1 : hand scanner on pc evhw8114203 on r208 still does not work after replacement; , text2 : hand scanner on pc evhw8114203 with r208 still does not work after replacement please check and replace again if necessary;
# index : 1770 , text1 : monitor defekt \ nipt wdq csenjruz , text2 : monitor defekt \ nipt wdq csenjruz
# index : 1771 , text1 : create hip 10 replacement hard drive! , text2 : create hip 10 replacement hard drive!
# index : 1772 , text1 : create a new folder in the info of EU_tool (please create new folder) , text2 : received from: qavdrpfu.ylfwnbkr@gmail.com
#
# Hello,
#
# please create a new path in the EU_tool under info.
#
# [cid: image001.png@01d223c0.fSID_21c960] [cid: image002.jpg@01d223c0.fSID_21c960]
#
# [cid: image003.jpg@01d223c0.fSID_21c960]
#
# create a new directory under impact award.
# please use erp pm as a designation.
#
# the files for visualization are on
# i: \ hand books \ erp pm <file: /// \\ HostName_579 \ info \ hand books \ erp% 20pm>
#
# [cid: image004.jpg@01d223c0.fSID_21c960]
#
# reason:
# [10/13/16 3:19 pm] qavdrpfu ylfwnbkr:
# i have created some traiyctrhbkm plvnuxmrterial for our shopflor workers for our new erp pm system for creating breakdown notifications
# so they will have a chance to look into this traiyctrhbkm plvnuxmrterial when they want to do any notification fjaqbgnld yukdzwxs people.
# because we still started with erp pm and our old system was a part of EU_tool
# called azm.
#
#
#
#
#
#
# with best regards / best
# index : 1774 , text1 : replicate , text2 : received from: trgqbeax.hfyzudql@gmail.com
#
# Hello
#
# Unfortunately, my laptop only replicates rudimentary in the company network. I get the latest emails on my iphone. other colleagues here at the site have the same problem.
#
#
# [cid: image001.png@01d223be.6f558640]
#
#
#
# with best regards | best
# index : 1780 , text1 : barcode scanner defective \ paternoster , text2 : barcode scanner defective \ paternoster
# index : 1784 , text1 : check the settings on the alfa set measuring device. , text2 : The settings on the rollomatic alfa set measuring device must be checked according to the instructions.
# index : 1789 , text1 : erp training room: 7 cannot connect beamer , text2 : erp training room: 7 cannot connect beamer
# index : 1793 , text1 : hurry up !!! monitor defective , text2 : monitor defective
# for hr. tjzohmve wusgaozx
#
# new construction 6 floor, # 503
# index : 1805 , text1 : wifi is not online , text2 : wifi is not online
# index : 1807 , text1 : Cannot create a skype meeting. There is no skype online meeting add-in on the outlook calendar. , text2 : Cannot create a skype meeting. There is no skype online meeting add-in on the outlook calendar.
# index : 1808 , text1 : My Outlook print emails are set in portrait orientation, and they are all landscape orientation. Can you help me see it? , text2 : My Outlook print emails are set in portrait orientation, and they are all landscape orientation. Can you help me see it?
# dizquolf hlykecxa
# ap accountant
# dizquolf.hlykecxa@gmail.com
# index : 1829 , text1 : i can't open my vpn , text2 : i can't open my vpn
# index : 1867 , text1 : problems with laser02 \ pfjwinbg ljtzbdqg , text2 : problems with laser02 \ pfjwinbg ljtzbdqg
# index : 1868 , text1 : problems with lasplant_119 \ pfjwinbg ljtzbdqg , text2 : problems with lasplant_119 \ pfjwinbg ljtzbdqg
# index : 1872 , text1 : Resetting the passwords for accounts vvwtyeidt, vvftgors, vvnergtubj, vvthygschj , text2 : Resetting the passwords for accounts vvwtyeidt, vvftgors, vvnergtubj, vvthygschj
# index : 1885 , text1 : automatic registration , text2 : when i call outlook, the computer also wants to connect to collaboration_platform (?) at the same time.
#
# that means: log in with your business or school account. but when I enter my email address and password nothing happens.
# the constant fade in is very annoying
#
# please remedy
#
# my phone number is
# index : 1890 , text1 : pick up old it equipment (2x cad ws nd monitor) \ umykjweg jpwrfuhk , text2 : pick up old it equipment (2x cad ws nd monitor) \ umykjweg jpwrfuhk
# index : 1899 , text1 : problems with we110 \ the printer queue is currently not running \ fdyietau dvsyxwbu , text2 : problems with we110 \ the printer queue is currently not running \ fdyietau dvsyxwbu
# index : 1913 , text1 : reset password , text2 : reset password
# index : 1914 , text1 : skype does not load on the pc. , text2 : skype is not loaded by the browser even after a long wait
# index : 1922 , text1 : EU_tool, charge management, pdv , text2 : the EU_tool, batch management and pdv systems run absolutely badly.
# you can "not" really work with them like that.
# index : 1935 , text1 : msd crm--outlook keeps showing that it is starting up and cannot enter the normal interface. , text2 : please provide details of the issue.
# Outlook keeps showing that it is starting and cannot enter the normal interface.
# index : 1954 , text1 : Reinstall the system on the laptop , text2 : Reinstall my laptop in the system
# index : 1955 , text1 : A linked file cannot be opened , text2 : A link file cannot be opened, indicating that the version is low
# index : 1990 , text1 : ms outlook2013 keeps showing that it is starting up and cannot display normal interface , text2 : please provide details of the issue.
# ms outlook2013 keeps showing that it is starting up and cannot display the normal interface
# index : 2003 , text1 : Reply: password_management_tool , text2 : received from: weqocbnu.eoixcpvy@gmail.com
#
# hi all
#
#
# please reset my password for SID_78 for my entering error more than 3 times.
#
# user name: caoryhuq
#
#
#
# For daily business, please send to south.service@company.com <mailto: please send to south.service@company.com> public mailbox
#
# best
# index : 2004 , text1 : If the computer login password is forgotten, reset the password. , text2 : If the computer login password is forgotten, reset the password.
# index : 2036 , text1 : password geoyhurg chriuimjiann , text2 : received from: nsoikcyf.jhybqael@gmail.com
#
# please activate my passwords.
# plase unlook my password
# chrithysgd
#
#
#
# with best regards / best
# index : 2045 , text1 : uacyltoe hxgaycze , text2 : uacyltoe hxgaycze
# index : 2064 , text1 : instructions for password_management_tool , text2 : instructions for password_management_tool
# index : 2070 , text1 : uacyltoe hxgaycze , text2 : uacyltoe hxgaycze
# index : 2071 , text1 : hand scanner on pc evhw8114202 without function -> rep. or replace; , text2 : hand scanner on pc evhw8114202 without function -> rep. or replace (pc in hall c at r208 erp terminal)
# index : 2085 , text1 : need a numeric keypad for the left hand. , text2 : Hello .
#
# need a numeric keypad for the left hand.
# index : 2086 , text1 : EU_tool runs very slowly in the Germany plant. Feedback can no longer be entered (runtime error). , text2 : No feedback can currently be entered in EU_tool. error "runtime error".
# index : 2093 , text1 : automatic data processing qa does not work , text2 : automatic data processing does not work
# index : 2100 , text1 : purchasing, online catalog de-technical trade does not work , text2 : purchasing, online catalog de-technical trade does not work
# index : 2144 , text1 : password geoyhurg chriuimjiann , text2 : received from: nsoikcyf.jhybqael@gmail.com
#
# please activate your password and account
#
#
# with best regards / best
# index : 2156 , text1 : problems with com port \ maschine stöhrmann \ eaodcgsw trmzwbyc , text2 : problems with com port \ maschine stöhrmann \ eaodcgsw trmzwbyc
# index : 2162 , text1 : password geoyhurg chriuimjiann , text2 : received from: nsoikcyf.jhybqael@gmail.com
#
# please activate my passwords
#
#
# with best regards / best
# index : 2171 , text1 : system pc on the hip 10 high-pressure sintering system does not start! , text2 : system pc on the hip 10 high-pressure sintering system does not start!
# index : 2180 , text1 : problems with proof of salary print \ eaodcgsw trmzwbyc , text2 : problems with proof of salary print \ eaodcgsw trmzwbyc
# index : 2182 , text1 : problems with wlan laptop \ weszfyok fbadnjhu , text2 : problems with wlan laptop \ weszfyok fbadnjhu
# index : 2186 , text1 : problems with we_wu160 \ jionmpsf wnkpzcmv , text2 : problems with we_wu160 \ jionmpsf wnkpzcmv
# index : 2187 , text1 : rfa analyzer monitor defective , text2 : Hello ,
#
# can you take a look at our laboratory and the rfa analyzer monitor is defective.
#
# rclqfpgt tbnovxdp is the contact person.
# index : 2192 , text1 : uacyltoe hxgaycze , text2 : uacyltoe hxgaycze
# index : 2211 , text1 : no data comparison between EU_tool and erp in germany! , text2 : no data comparison between EU_tool and erp in germany!
# index : 2212 , text1 : no network access , text2 : i only have access to the internal hard drive on my pc. printing works, but no access to e.g. the printer server.
# index : 2260 , text1 : problems with pf3 port 13 , text2 : received from: ughzilfm.cfibdamq@gmail.com
#
# Hello ,
#
# port for ewew8323846 pf 3 port 13 does not deliver a correct ip.
# Please check .
# index : 2282 , text1 : wk38 -> qdxyifhj zbwtunpy , text2 : Halo ,
# the printer is causing problems with printing. please check the settings. thank you. Uwe
# index : 2285 , text1 : problems with vpn \ weszfyok fbadnjhu , text2 : problems with vpn \ weszfyok fbadnjhu
# index : 2286 , text1 : problems with portal \ franjuz urbghty , text2 : problems with portal \ franjuz urbghty
# index : 2301 , text1 : problems with alicona after update \ jionmpsf wnkpzcmv , text2 : problems with alicona after update \ jionmpsf wnkpzcmv
# index : 2307 , text1 : problems with accessing drawings - netweaver business client , text2 : received from: ecoljnvt.lbdqmvfs@gmail.com
#
# dear colleagues,
#
# I cannot open the netweaver business clint.
#
# when I press the corresponding app (already connected via vpn), the following message appears:
#
# [cid: image001.png@01SID_35ee0.18647971]
#
# ask for your support
#
# with best regards / best
# index : 2354 , text1 : no audio on the 7350s , text2 : no audio on the 7350s
# index : 2359 , text1 : ticket update on: implant 866142 , text2 : ticket update on: implant 866142
# index : 2382 , text1 : EU_tool ws ewew8323843 does not work \ jionmpsf wnkpzcmv , text2 : EU_tool ws ewew8323843 does not work \ jionmpsf wnkpzcmv
# index : 2389 , text1 : user lndypaqg dhqwtcsr (gogtyekthyto) has his password in erp SID_34 verggermany. , text2 : user lndypaqg dhqwtcsr (gogtyekthyto) has his password in erp SID_34 verggermany.
# index : 2405 , text1 : problems with ie \ vzqomdgt jwoqbuml , text2 : problems with ie \ vzqomdgt jwoqbuml
# index : 2406 , text1 : sinic general error: 3155 odbc vmsliazh ltksxmyv driver query timeout \ jionmpsf wnkpzcmv , text2 : sinic general error: 3155 odbc vmsliazh ltksxmyv driver query timeout \ jionmpsf wnkpzcmv
# index : 2407 , text1 : problems with printer we110 \ fdyietau dvsyxwbu , text2 : Hello ,
#
# our copier in the classroom is also defective (minolta we 110).
#
# can you please have a look.
# index : 2420 , text1 : app problems , text2 : received from: ecoljnvt.lbdqmvfs@gmail.com
#
# Hello fellow colleagues,
#
# In my outlook there is a field that there is an app problem.
#
# What should I do?
#
# [cid: image003.jpg@01SID_35e28.2c1d0470]
#
# with best regards / best
# index : 2438 , text1 : can not login , text2 : can not login
# index : 2610 , text1 : travel expense accounting in erp not possible! , text2 : received from: byclpwmv.esafrtbh@gmail.com
#
# Hello,
#
# Travel expense accounting in ERP is unfortunately not possible. see error message below:
# [cid: image001.jpg@01SID_35be6.bd6e34b0]
#
#
#
# with best regards / best
# index : 2696 , text1 : not possible to log in to outlook , text2 : login to outlook since changing password not possible
# tel:
# index : 2708 , text1 : problems with printing \ measuring machine for bars \ eaodcgsw trmzwbyc , text2 : problems with printing \ measuring machine for bars \ eaodcgsw trmzwbyc
# index : 2709 , text1 : support for alicona \ jionmpsf wnkpzcmv , text2 : support for alicona \ jionmpsf wnkpzcmv
# index : 2726 , text1 : problems with skype and outlook \ user: dardabthyr , text2 : problems with skype and outlook \ user: dardabthyr
# index : 2727 , text1 : problems with skype and outlook \ dardabthyr , text2 : problems with skype and outlook \ dardabthyr
# index : 2728 , text1 : can you please get 2 usb sticks 16 gb again one of us broke , text2 : can you please get 2 usb sticks 16 gb again one of us broke
# index : 2729 , text1 : our copier we 95 (hp laserjet) shows the error message "transfer unit missing". , text2 : our copier we 95 (hp laserjet) shows the error message "transfer unit missing".
# index : 2735 , text1 : vpn installation-transfer to He Zhengping , text2 : received from: tuqrvowp.fxmzkvqo@gmail.com
#
# Please help to install the vpn software, thank you Zhengping
#
#
# tuqrvowp fxmzkvqo Qian Tangxin
# human resources
# tuqrvowp.fxmzkvqo@gmail.com<mailto:tuqrvowp.fxmzkvqo@gmail.com>
#
#
# Shanghai Shengyang Superfine Powder Co., Ltd.
# 1508 Chenqiao Road, Fengxian District, Shanghai
# Post Code: 201400
# index : 2801 , text1 : phone with the number 1038091558 is defective. sintering germany. please repair. , text2 : phone with the number is broken. sintering germany. please repair.
# index : 2803 , text1 : problems with vpn \ wxstfouy isjzcotm , text2 : problems with vpn \ wxstfouy isjzcotm
# index : 2831 , text1 : shared folder for m: kvp3 , text2 : shared folder for m: kvp3
# index : 2835 , text1 : problems with companyguest \ bctypmjw cbhnxafz , text2 : problems with companyguest \ bctypmjw cbhnxafz
# index : 2836 , text1 : problems with hp printer local. \ petljhxi bocxgins , text2 : problems with hp printer local. \ petljhxi bocxgins
# index : 2837 , text1 : I need help with changing the password / and with skype - microphone connection! , text2 : I need help with changing the password / and with skype - microphone connection!
# because i can hear others at skype meetings but they can't hear me.
# index : 2854 , text1 : outlook doesn't work , text2 : on the computer evhw8114148 outlook no longer works.
# index : 2864 , text1 : vpn cannot log in. , text2 : [‎2016/‎9/‎29 9:14] daisy huang:
# hi, vpn changed according to the settings in the email, why can’t I get on board?
# your system failed for antivirus check. please ensure the following is true and try again or contact your administrator: your antivirus software is enabled. it is up to date (antivirus database no older than 30 days) you have recently scanned your system (not longer than 7 days ago)
# [‎2016/‎9/‎29 9:15] obuwfnkm ufpwmybi:
# There is a problem with your antivirus software
# Virus database is not updated
# index : 2927 , text1 : problems with ie \ niptbwdq csenjruz , text2 : problems with ie \ niptbwdq csenjruz
# index : 2933 , text1 : problems with portal \ acqpinyd ecygimqd , text2 : problems with portal \ acqpinyd ecygimqd
# index : 2935 , text1 : problems with portal. \ hcuixqgj mavxgqbs , text2 : problems with portal. \ hcuixqgj mavxgqbs
# index : 2945 , text1 : read and write permission for HostName_753 \ production , text2 : read and write permission for HostName_753 \ production
# index : 2957 , text1 : Set up pc eemw8144241 so that the barcode is displayed and can be printed out , text2 : Set up pc eemw8144241 so that the barcode is displayed and can be printed out
# ebs office a. thicker
# index : 2959 , text1 : folder approval for m: kvp3 and ce_leiter , text2 : folder approval for m: kvp3 and ce_leiter
# index : 2971 , text1 : printer em06 in the delivery area. always the same delivery note 10 times. only then will the correct one be printed out. , text2 : printer em06 in the delivery area. always the same delivery note 10 times. only then will the correct one be printed out. erp problem
# index : 2979 , text1 : hp2 hot pressing furnace data transmission card, the data cannot be updated, please help me to transfer it to Xiaohe , text2 : hp2 hot pressing furnace data transmission card, the data cannot be updated, please help me to transfer it to Xiaohe
# index : 2985 , text1 : password Mrs. koburvmc jwzlebap # 51117 , text2 : received from: mobaidfx.gviwlsrm@gmail.com
#
# Hello,
#
# mrs rieß will start work again on tuesday, october 4th.
#
# please reassign your password.
#
# Ms. Riess is expected to be available in the office from 8 a.m. to 10 a.m.
#
# with best regards / best
# index : 2992 , text1 : outlook indexing , text2 : i have not been able to use my search in outlook for about 1 week because the message "your elements are currently being indexed by outlook" appears.
# I also let my pc run over the weekend with the outlook open, but so far it has always been the same.
# currently 10,809 elements still need to be indexed.
# yesterday there were around 2,500 elements.
# I have massive problems because I can't find emails from a year ago with the search function.
# index : 3006 , text1 : After win8.1 system prompts to update, all application software cannot be opened. , text2 : After win8.1 system prompts to update, all application software cannot be opened.
# index : 3009 , text1 : Yonyou-Inventory account does not match existing inventory , text2 : Yonyou-Inventory account does not match with existing inventory, product code: 112001960200, inventory ledger 15kg, existing inventory 75kg
# index : 3067 , text1 : computer ewew8323527 \ bluescreen \ wrcktgbd wzrgyunp , text2 : computer ewew8323527 \ bluescreen \ wrcktgbd wzrgyunp
# index : 3069 , text1 : problems with hp4050 \ error 41.1 \ lxvunpiz mgjxwept , text2 : problems with hp4050 \ error 41.1 \ lxvunpiz mgjxwept
# index : 3070 , text1 : computer ewew8323612 very slow. \ lxvunpiz mgjxwept , text2 : computer ewew8323612 very slow. \ lxvunpiz mgjxwept
# index : 3094 , text1 : problems with printer mp16 , text2 : problems with printer mp16
#
# Error message: "Transport unit is missing, or motor error has occurred
# this is a leasing printer.
# index : 3107 , text1 : printer dell 1350cnw prints all pages with a gray haze , text2 : prints prints everything grayed out
# index : 3119 , text1 : Computer hard disk failure, request repair. , text2 : Computer hard disk failure, request repair.
# index : 3132 , text1 : hr_tool-etime The system cannot log in, it always shows that the application database is being loaded , text2 : hr_tool-etime The system cannot log in, it always shows that the application database is being loaded
# index : 3136 , text1 : Email cannot be activated , text2 : The mailbox cannot be activated, prompting that a new stack protection page cannot be created.
# index : 3161 , text1 : copy of telephone bill , text2 : I request to provide a copy of the cell phone bill for the period from June 20 to September 20, 2016
# index : 3223 , text1 : archiving of e-mails , text2 : received from: anivdcor.rbmfhiox@gmail.com
#
# [cid: image003.jpg@01SID_35804.fbc60480]
#
# hello it,
#
# i archive my mails in a folder structure.
# unfortunately i keep finding folders that suddenly have no more content
# whats going on here?
#
# greeting
# achim
#
# anivdcor rbmfhiox
# sales manager
# sales germany
#
# anivdcor.rbmfhiox@gmail.com <mailto: anivdcor.rbmfhiox@gmail.com>
#
#
# company deutschland gmbh
# managing directors: rfwlsoej yvtjzkaw, phvkowml azbtkqwx, naruedlk mpvhakdq
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 3258 , text1 : reinstall company barcode für ewew8323753 \zlqfptjx xnklbfua , text2 : reinstall company barcode für ewew8323753 \zlqfptjx xnklbfua
# index : 3259 , text1 : no email received from the address p.eggert@karl-roll.de. , text2 : Nothing can be received or sent from this address.
# index : 3278 , text1 : support for computer measuring device \ jionmpsf wnkpzcmv , text2 : support for computer measuring device \ jionmpsf wnkpzcmv
# index : 3280 , text1 : We_wu160 computer does not work. , text2 : We_wu160 computer does not work.
# index : 3281 , text1 : computer for viotto does not work , text2 : computer for viotto does not work
# ...
# index : 7270 , text1 : no azm messages possible , text2 : no azm messages can be entered in the EU_tool
#
# in EU_tool, azm messages cannot be registered.
# index : 7286 , text1 : problem with landline phone , text2 : received from: jctnelqs.lansuiwe@gmail.com
#
# Dear ladies and gentlemen,
#
# on my landline phone, the information on the display has only been incompletely visible for some time.
# several horizontal lines make the display illegible.
#
# my phone number is 09279 / 80-155.
#
# please remedy.
#
# Sincerely
#
# jctnelqs lansuiwe
# quality assurance
# jctnelqs.lansuiwe@gmail.com <mailto: jctnelqs.lansuiwe@gmail.com>
# index : 7294 , text1 : not going to skype meeting , text2 : The skype meeting cannot be accessed from the link in the mailbox.
# index : 7299 , text1 : The intern reported an error when logging in to office365 to download the email attachment (transferred to He Zhengping) , text2 : Interns report an error when logging in to office365 to download email attachments
# index : 7301 , text1 : Restaurant TV cannot play video files , text2 : The restaurant TV cannot play the video file, please assist Xiaohe to complete it. Thank you!
# index : 7306 , text1 : The power cord of the milling computer is damaged , text2 : The computer power cord and network cable in the control room on the third floor of the powder mill are damaged due to high temperature and need to be replaced.
# index : 7307 , text1 : skype for business failure , text2 : Suddenly, no skype for business can be found in the system
# index : 7308 , text1 : Spelling and grammar errors , text2 : When editing ppt, it always pops up "Cannot check spelling and grammar errors", and it cannot be installed.
# index : 7309 , text1 : computer malfunction , text2 : The operating system of the computer controlled by the tensile testing machine of the quality control department started very slowly and the control software was lost.
# index : 7342 , text1 : Keyboard on r246 and r247 defective. , text2 : Keyboard on r246 and r247 defective. please change. (individual buttons no longer work)
# index : 7392 , text1 : problems with lan \ wxstfouy isjzcotm , text2 : problems with lan \ wxstfouy isjzcotm
# index : 7396 , text1 : problems with opening documents in the intranet with internet explorer. \ xmlbfjpg yegzbvru , text2 : problems with opening documents in the intranet with internet explorer. \ xmlbfjpg yegzbvru
# index : 7407 , text1 : please call back , text2 : received from: zkgfcyvx.sgxeatyb@gmail.com
#  thank you
#
#
# This communication is intended solely for the use of the addressee and may contain information that is confidential, worthy of protection or excluded from disclosure under applicable law. the distribution, distribution or reproduction of this communication by persons other than the intended recipients is strictly prohibited. if you have received this message by mistake, please notify the sender and delete this message.
# [# + company / posts> [
# select the following link to view the disclaimer in an alternate language.
# index : 7410 , text1 : authorization time management av , text2 : hello mister buses,
#
# would you please send this to it via ticket or to
#
# help@company.com
#
#
#
# with best regards / best
# index : 7423 , text1 : email notification , text2 : received from: trgqbeax.hfyzudql@gmail.com
#
# [cid: image001.png@01d1f7b0.223a83e0]
#
#
# unfortunately the field "from" has been lost ☹
#
#
#
#
# thank you + best regards
# trgqbeax hfyzudql
#
# with best regards | best
# index : 7428 , text1 : down payment invoices not posted company 5417 - vfx3 - , text2 : see attached e-mail
# index : 7436 , text1 : support for relocation \ qvncizuf ueiybanz , text2 : support for relocation \ qvncizuf ueiybanz
# index : 7437 , text1 : problems with EU_tool \ obqridjk ugelctsz , text2 : problems with EU_tool \ obqridjk ugelctsz
# index : 7466 , text1 : r173 schneeberger cnc no 20123 / wza , text2 : programdntyme cannot be opened sometimes, take a look at the hard drive,
# please for completion by m. himghtmelreich (EU_tool rep.no,: 39788)
# index : 7504 , text1 : it-germany-h. kruse / as-400 password change failed , text2 : hello frthdyui,
# changing the password in the as-400 did not work. ask for your help. thanks in advance-greetings petrghada :-)
# index : 7535 , text1 : outlook (unlicensed product) , text2 : received from: vnsmwqhb.ogtpenjd@gmail.com
#
# hello help,
#
# ms office products show the following error message:
# [cid: image001.png@01d1f6f8.87161a30]
#
# greeting /
# index : 7547 , text1 : Change request cannot be deleted. , text2 : Change request cannot be deleted.
# index : 7548 , text1 : problems with purchasing \ xmlbfjpg yegzbvru , text2 : problems with purchasing \ xmlbfjpg yegzbvru
# index : 7553 , text1 : authorization error in outlook: unlicensed product. , text2 : authorization error in outlook: unlicensed product.
# index : 7554 , text1 : problems with EU_tool calculator \ we212772 , text2 : Hello ,
#
# can you please activate the password. user we212772 was given the password
# blocked. please set the password to welcome.
# index : 7556 , text1 : problems with database in EU_tool \ hgrvubzo wgyhktic , text2 : problems with database in EU_tool \ hgrvubzo wgyhktic
# index : 7564 , text1 : Reply: email address link to delivery not forwarding: 9168020730//supply_chaint09t308lf kc5010 Is the express tracking number available? , text2 : received from: jkmeusfq.vjpckzsa@gmail.com
#
# hello,
# Please urge Singapore. Thank you!
#
#
#
#
# Sincerely,
# best
# index : 7566 , text1 : pc ewkw8111185 does not work (pc can be switched on , text2 : by: cytohwau qfunricw
# sent: thursday, august 11, 2016 3:23 pm
# to: nwfodmhc exurcwkm
# subject: pc ewkw8111185 / qdxyifhj zbwtunpy
#
# pc ewkw8111185 does not work (pc can be switched on, afterwards no work on pc is possible, also tried with a different keyboard, no change)
#
#
# Best regards
# cytohwau qfunricw
# grinding service germany
# cytohwau.qfunricw@gmail.com
# index : 7569 , text1 : tablet-dell 7350-can't connect to wireless wifi network, wireless AP, mobile hotspot can't connect. , text2 : please provide details of the issue.
# Cannot connect to wireless wifi network, wireless AP, mobile hotspot can not connect.
# index : 7573 , text1 : VPN can not log in, the webpage has been checking anti-virus software. , text2 : VPN can not log in, the webpage has been checking anti-virus software.
# index : 7574 , text1 : File cannot be printed by printer fe08 , text2 : File cannot be printed by printer fe08
# index : 7578 , text1 : Windows system cannot log in, prompting that the trust relationship between the computer and the primary domain failed , text2 : Windows system cannot log in, prompting that the trust relationship between the computer and the primary domain failed
# index : 7580 , text1 : The display does not light up , text2 : The monitor does not display an image after turning it on in the morning.
# index : 7590 , text1 : Office 365 change language / videos from "thehub" do not work. , text2 : hello, is it possible for me to switch office365 from english to german? if so, where can i find this setting?
#
# if I want to watch the videos of "lets talk" in German and click on the link in the email, he tells me:
#
# office 365 video isn't available
#
# office 365 video is not enabled by your organization for you.
#
# here is a link:
#
# many thanks for your help
# index : 7709 , text1 : setup laptop for sandblasting machine and roboworker \ qidgvtwa qvbutayx , text2 : setup laptop for sandblasting machine and roboworker \ qidgvtwa qvbutayx
# index : 7710 , text1 : cellphone loudspeaker / microphone defective / disturbed , text2 : extension -477
# handset gigaset sl2
# Loudspeaker / microphone scratch or stop at times
# index : 7745 , text1 : erp production depends on ot03 orders , text2 : ot01 orders work, ot03 orders cannot be processed (when delivering)
# index : 7784 , text1 : set up pc , text2 : please forward to smpijawb eawkpgqf:
# after the alicona measuring device has been converted, the pc for sdnemlwy dsbmgonk must be set up (apl before juchaomy gaxrulwo - av abstechprogramdntym).
# should be by August 26
# employee comes back on august 29th
# index : 7785 , text1 : move workplace , text2 : please forward to smpijawb eawkpgqf:
# alicona measuring device has to be switched from av parting program in hall 4 (formerly valve tappet control).
# should be in kw 33
# index : 7797 , text1 : skype doesn't work. , text2 : from: zlnxswvp ptmzsbhk
# sent: thursday, august 11, 2016 11:58 am
# to: nwfodmhc exurcwkm
# subject: sab: wg: skype won't start
#
# ask for support
#
# friendly greetings / child
# index : 7799 , text1 : data transfer , text2 : received from: weszfyok.fbadnjhu@gmail.com
#
# Hello,
#
# there are apparently problems with the transfer of stamp times (EU_tool / erp) with 8-digit personnel numbers (see below)
#
# friendly greetings
# weszfyok fbadnjhu
#
#
# by: axesnghb cyzuomxa
# Sent: Thursday, July 28th, 2016 12:17 PM
# to: zslugaxq dtwlrofu; laeusvjo fvaihgpx
# cc: weszfyok fbadnjhu
# subject: temporary employee lochthowe, andre, 21111177
#
#
# Hello everybody,
#
# since 07/21/2016 mr lochthowe has been stamping his card in eu_tool.
#
# since then the data has not been transferred to erp.
#
# something is wrong with the card no. or the trunk number.
#
# we have the first employee here with an eight-digit master number.
#
# can it be because of it ????
#
# please check.
#
#
#
# Best regards
# best
# index : 7810 , text1 : due to a security update kb4272050 no network connection is possible , text2 : due to a security update KB 4272050 no network connection is possible.
# error message: no network connection.
# index : 7824 , text1 : here in koenigsee we have problems with printing from erp. there is a "production_order_interface_app" error. , text2 : here in koenigsee we have problems with printing from erp. there is a "production_order_interface_app" error.
# index : 7828 , text1 : problems with erpgui \ tmqfjard qzhgdoua , text2 : problems with erpgui \ tmqfjard qzhgdoua
# index : 7831 , text1 : barcode scanner defective \ pifyudbo tagsfbny , text2 : barcode scanner defective \ pifyudbo tagsfbny
# index : 7898 , text1 : EU_tool does not work. , text2 : EU_tool does not work.
# message: unknown error. system distributor_tool error.
# index : 7920 , text1 : install 64 bit version of ms office for pc 215502 in the office blanks production \ njdrcagt shourxyp , text2 : install 64 bit version of ms office for pc 215502 in the office blanks production \ njdrcagt shourxyp
# index : 7923 , text1 : outlook search , text2 : received from: giumxwvh.lfvwjtin@gmail.com
#
# hello help team,
#
# I have the problem that when I search for emails that have been sent using the search for name, the following error message appears.
# only suggestions will come up until 02/03/2016
# please check and feedback.
# many thanks
# [cid: image002.jpg@01d1f2f7.35b19750]
#
# best regards / child
# index : 7933 , text1 : The file cannot be printed to the printer, indicating a printer error. , text2 : prtSID_737--The file cannot be printed to the printer, indicating a printer error.
# index : 7961 , text1 : The online system provided by the customer cannot be opened , text2 : The online delivery note generation system provided by the customer cannot be opened and needs to be resolved as soon as possible
# index : 8026 , text1 : outlook is not working. , text2 : error message: "unfortunately, outlook has encountered an error that is preventing it from working properly. as a result, outlook should be closed. would you like us to do the repair now? with three buttons which are: repair now / close / help"
# index : 8041 , text1 : review pc lpaw8515845 (g0rfv12) usadtto dfsdby ffthhiago frsilva , text2 : use microsoft update
# update adobe acrobat, adobe flash and java
# review groups
# review and update sep
# review patching_antivirus_sw
# review erp client
# perform check disk, defrag and sep scan
# update dell drivers
# check for update / new version of the office package in o365
#
# uacyltoe hxgayczear access to itau, box and hsbc. uacyltoe hxgayczear opening of plaghynilhas do itaú.
# index : 8062 , text1 : Screen at the kyocera workplace defective , text2 : please change
# index : 8089 , text1 : aw: [ticket # 2016080878000153] according to: after # 4505612440 , text2 : received from: qyndvmlw.imcvznow@gmail.com
#
# with kind regards / with kind
# index : 8095 , text1 : according to: [ticket # 2016080878000153] according to: after # 4505612440 , text2 : received from: tvmlrwkz.rsxftjep@gmail.com
#
# Hello everybody,
#
# see the following email correspondence, please fix it as soon as possible.
# thank you.
#
#
#
# with best regards / best
# index : 8097 , text1 : bios setting , text2 : please change bios to wzs 60 (wza, m14, m12.18990) so that the computer starts automatically after a network reset.
# please for completion by m. himghtmelreich.
# index : 8182 , text1 : login to business_client , text2 : I cannot enter business_client with my password.
# index : 8195 , text1 : problems with computer ewew8323531 \ defective fp sectors \ xosdfhbu gtbfkisl , text2 : problems with computer ewew8323531 \ defective fp sectors \ xosdfhbu gtbfkisl
# index : 8222 , text1 : investment antrag mnakehrf mvunqihf - new laptop request - mnakehrf mvunqihf , text2 : received from: jywvemun.qngschtz@gmail.com
#
# team, here is an investment application for a new computer / laptop for mnakehrf mvunqihf
#
# with best regards / best
# index : 8226 , text1 : data backup and restore \ ahlqgjwx wbsfavhg , text2 : data backup and restore \ ahlqgjwx wbsfavhg
# index : 8230 , text1 : problems with printer in Löwe uacyltoe hxgayczeraum \ reinhard kröger , text2 : problems with printer in Löwe uacyltoe hxgayczeraum \ reinhard kröger
# index : 8234 , text1 : telephone receiver on the device production hall c defective , text2 : invited to it-plant germany
# index : 8258 , text1 : erp cannot purchase (transferred to He Zhengping) , text2 : When purchasing, it displays "The data of employee 1111154833 cannot be found, please notify the system administrator"
# index : 8262 , text1 : After the password is changed, Outlook cannot log in , text2 : After the password is changed, Outlook cannot log in
# index : 8388 , text1 : format micro , text2 : format micro
# index : 8389 , text1 : security error in travel expense accounting programdnty , text2 : security error in travel expense accounting programdnty
# index : 8405 , text1 : problems with we_combi \ jumps kpz cmv , text2 : problems with we_combi \ jumps kpz cmv
# index : 8406 , text1 : slow computer \ checking \ niptbwdq csenjruz , text2 : slow computer \ checking \ niptbwdq csenjruz
# index : 8409 , text1 : bluetooth keybankrd defect \ dardabthyr , text2 : bluetooth keybankrd defect \ dardabthyr
# index : 8411 , text1 : problems with screen saver \ we91 \ jionmpsf wnkpzcmv , text2 : problems with screen saver \ we91 \ jionmpsf wnkpzcmv
# index : 8412 , text1 : mobile phone defective , text2 : gigaset m2 professional mobile phone with extension 479
# battery (defective does not last longer than 1 day)
# display (you can hardly see anything)
# clip defective.
# index : 8417 , text1 : i cannot reset my erp password. , text2 : i don't know my erp password anymore and i have entered 3 failed attempts. please reset.
# index : 8431 , text1 : the printer for the ups-lapels does not print correctly. , text2 : the printer is at wckrxovs aunsgzmd's place
# index : 8449 , text1 : Unable to log in hr_tool attendance system , text2 : It shows that the java plug-in cannot be loaded, and the required version is 1.8.0.-45 or higher.
# index : 8457 , text1 : vpn can't connect , text2 : vpn can’t connect, please forward to He Zhengping atcbvglq.bdvmuszt@gmail.com
# index : 8463 , text1 : The computer cannot be turned on , text2 : to Xiaohe, I can’t turn on the computer in the morning
# index : 8491 , text1 : Different programs cannot be opened on several PCs , text2 : Different programs cannot be opened on several PCs area cnc.
# index : 1344 , text1 : pc on r241 in hall c near office nesner does not start up , text2 : Invite it-Germany, as a replacement pc is already installed and a new one has been ordered.

# %%
df.head(5)
# Out:
#    index              Short description  ...             Caller Assignment group
# 0      0                    login issue  ...  spxjnwir pjlcoqds            GRP_0
# 1      1                        outlook  ...  hmjdrvpb komuaywn            GRP_0
# 2      2             cant log in to vpn  ...  eylqgodm ybqkwiam            GRP_0
# 3      3  unable to access hr_tool page  ...  xbkucsvz gcpydteq            GRP_0
# 4      4                   skype error   ...  owlgqjme qhcozdfx            GRP_0
#
# [5 rows x 5 columns]

# %%
df.to_excel("translated_ansi_encoded_utf8_decoded_v4.xlsx",index=True)

# %%
df = pd.read_excel("translated_ansi_encoded_utf8_decoded_v4.xlsx",index_col=0)

# %% [markdown]
# # 5. HTML Parsing using html unescape

# %%
import re
import string
import html

# %%
df = pd.read_excel("translated_ansi_encoded_utf8_decoded_v4.xlsx",index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8492 entries, 0 to 8491
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Short description  8492 non-null   object
#  1   Description        8492 non-null   object
#  2   Caller             8492 non-null   object
#  3   Assignment group   8492 non-null   object
# dtypes: object(4)
# memory usage: 331.7+ KB

# %%
df['Description'] = df['Description'].apply(html.unescape)
df['Short description'] = df['Short description'].apply(html.unescape)

# %%
# df.to_excel("unescape.xlsx",index=True)

# %% [markdown]
# # 6. Pattern Search and Remove

# %% [markdown]
# **Creating the patterns that need to be removed, these should be applied in the sequence as below**

# %%
pattern_url = re.compile('https?://\S+|www\.\S+') # to remove urls
pattern_email = re.compile('\S+@\S+') # to remove email IDs
pattern_special = re.compile('[^0-9a-zA-Z\']') # to remove all special characters other than numbers,text and apostrophe
pattern_extra_whitespace = re.compile("\s+") # to remove extra whitespaces
pattern_digits = re.compile('[0-9]') # to remove digits

# Dates get removed due to number and special character removal

# %% [markdown]
# ## *Problem 2 : Need to figure out a way to handle roman numerals*

# %% [markdown]
# Set of functions to remove unwanted characters

# %%
def removeURL(txt):
  if re.search(pattern_url, txt):
    txt = pattern_url.sub('',txt)
    return txt
  else:
    return txt

# %%
def removeEmail(txt):
  if re.search(pattern_email, txt):
    txt = pattern_email.sub('',txt)
    return txt
  else:
    return txt

# %%
def removeSpecial(txt):
  if re.search(pattern_special, txt):
    txt = pattern_special.sub(' ',txt)
    return txt
  else:
    return txt

# %%
def removeExtraWhitespace(txt):
  if re.search(pattern_extra_whitespace, txt):
    txt = pattern_extra_whitespace.sub(' ',txt)
    return txt
  else:
    return txt

# %%
def removeDigits(txt):
  if re.search(pattern_digits, txt):
    txt = pattern_digits.sub('',txt)
    return txt
  else:
    return txt

# %% [markdown]
# Applying the above functions to the "Short description" and "Description" columns

# %%
df['Short description'] = df['Short description'].apply(removeURL)
df['Short description'] = df['Short description'].apply(removeEmail)
df['Short description'] = df['Short description'].apply(removeSpecial)
df['Short description'] = df['Short description'].apply(removeExtraWhitespace)
df['Short description'] = df['Short description'].apply(removeDigits)
df['Description'] = df['Description'].apply(removeURL)
df['Description'] = df['Description'].apply(removeEmail)
df['Description'] = df['Description'].apply(removeSpecial)
df['Description'] = df['Description'].apply(removeExtraWhitespace)
df['Description'] = df['Description'].apply(removeDigits)

# %%
# df.to_excel("cleaned_translated_ansi_encoded_utf8_decoded_v4.xlsx",index=True)

# %% [markdown]
# # 7. Expand Contractions

# %% [markdown]
# **The below list can be expanded to include more contractions**
# Currently it has the ones available in the dataset only
#
# The below list of functions are applied sequentially

# %%
contractionList = {"i'm":"i am","i m\s":"i am ","im":"i am","i've":"i have","i'd":"i would","i'll":"i will","can't":"cannot","couldn't":"could not",
"doesn't":"does not","didn't":"did not","don't": "do not","won't":"will not","wouldn't":"would not","shouldn't":"should not",
"it's": "it is","you're" : "you are","we're" : "we are","they're":"they are","isn't":"is not","that's":"that is","aren't":"are not",
"she's":"she is","here's":"here is","let's":"let us","ma'am":"maam","isn't":"is not","should've":"should have","wasn't":"was not",
"that'll":"that will","weren't":"were not","he's":"he is","we've":"we have","they've":"they have","there's":"there is","what's":"what is",
"how's":"how is","hasn't":"has not","that's":"that is","what's":"what is","let's":"let us","here's":"here is","wasn't":"was not",
"haven't":"have not","who's":"whose","weren't":"were not","hasn't":"has not","haven't":"have not"}

# %%
pattern_apostrophe = re.compile('\'')
pattern_space_before = re.compile('\s\'')

# %%
def removeSpaceBetweenContraction(txt):
  if re.search(pattern_space_before, txt):
    txt = pattern_space_before.sub('\'',txt)
    return txt
  else:
    return txt

# %%
def removeApostrophe(txt):
  if re.search(pattern_apostrophe, txt):
    txt = pattern_apostrophe.sub('',txt)
    return txt
  else:
    return txt

# %%
df['Short description'] = df['Short description'].apply(removeSpaceBetweenContraction)
df['Description'] = df['Description'].apply(removeSpaceBetweenContraction)

# %%
def expandContractions(txt):
   for key in contractionList.keys():
    if len(re.findall(key,txt))!=0:
      value = contractionList[key]
      txt = re.sub(key,value,txt)
      return txt
    else:
      return txt

# %%
df['Short description'] = df['Short description'].apply(expandContractions)
df['Description'] = df['Description'].apply(expandContractions)

# %%
df['Short description'] = df['Short description'].apply(removeApostrophe)
df['Description'] = df['Description'].apply(removeApostrophe)

# %%
def leftStrip(txt):
  return txt.lstrip()

# %%
def rightStrip(txt):
  return txt.rstrip()

# %%
df['Short description'] = df['Short description'].apply(leftStrip)
df['Description'] = df['Description'].apply(leftStrip)
df['Short description'] = df['Short description'].apply(rightStrip)
df['Description'] = df['Description'].apply(rightStrip)

# %% [markdown]
# # 8. Stopwords Removal

# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()
from spacy.lang.en.stop_words import STOP_WORDS

# %% [markdown]
# Caller Names list from Caller column to remove from the dataset

# %%
caller_list = df['Caller'].unique().tolist()
# caller_name_list=[]
# for g in range(len(caller_list)):
#   caller_name_list.append(caller_list[g].split()[0])
#   caller_name_list.append(caller_list[g].split()[1])
print(len(caller_list))
# Out:
# 2948

# %%
def replaceNonsenseWords(txt):
  for text in caller_list:
    if len(re.findall(text,txt))!=0:
      print(text)
      print(txt)
      txt = re.sub(text,'',txt)
      print(txt)
  return txt

# %%
df['Short description'] = df['Short description'].apply(replaceNonsenseWords)
# Out:
# ecwtrjnq jpecxuty
# call for ecwtrjnq jpecxuty
# call for
# ecwtrjnq jpecxuty
# call for ecwtrjnq jpecxuty
# call for
# yhmwxsqj ugnthxky
# user yhmwxsqj ugnthxky having issues logging to outlook
# user  having issues logging to outlook
# wseacnvi azvixyqg
# reset the password for wseacnvi azvixyqg on erp qa erp
# reset the password for  on erp qa erp
# hckvpary emxbpkwy
# reset passwords for hckvpary emxbpkwy using password management tool password reset
# reset passwords for  using password management tool password reset
# ijeqpkrz nwtehsyx
# unable to access password management tool id password manager ijeqpkrz nwtehsyx grauw
# unable to access password management tool id password manager  grauw
# arexjftu ohxdwngl
# support for fa gstry arexjftu ohxdwngl
# support for fa gstry
# ecwtrjnq jpecxuty
# call for ecwtrjnq jpecxuty
# call for
# fygrwuna gomcekzi
# reset the password for fygrwuna gomcekzi on e mail
# reset the password for  on e mail
# laeusvjo fvaihgpx
# problems with drive z laeusvjo fvaihgpx
# problems with drive z
# hprdlbxf nozjtgwi
# company email to private phone hprdlbxf nozjtgwi
# company email to private phone
# jionmpsf wnkpzcmv
# EU tool is very slow adgtym ywqgrbnx jwnsyzbv jionmpsf wnkpzcmv
# EU tool is very slow adgtym ywqgrbnx jwnsyzbv
# wrcktgbd wzrgyunp
# pick up old eq wrcktgbd wzrgyunp
# pick up old eq
# wrcktgbd wzrgyunp
# probleme lan an tgeyd we wu wrcktgbd wzrgyunp
# probleme lan an tgeyd we wu
# zlqfptjx xnklbfua
# support for we zlqfptjx xnklbfua
# support for we
# rtnzvplq erhmuncq
# urgent access to rtnzvplq erhmuncq disconnected
# urgent access to  disconnected
# laeusvjo fvaihgpx
# install EU tool laeusvjo fvaihgpx
# install EU tool
# qdxyifhj zbwtunpy
# calendar entries qdxyifhj zbwtunpy
# calendar entries
# yscgjexz hxlbvjgf
# password reset for yscgjexz hxlbvjgf
# password reset for
# bkzcfmse naslrwdb
# cannot open excel files from HostName  departments hrm pricing current pricing fy and bkzcfmse naslrwdb can
# cannot open excel files from HostName  departments hrm pricing current pricing fy and  can
# prgewfly ndtfvple
# reset passwords for prgewfly ndtfvple using password management tool password reset
# reset passwords for  using password management tool password reset
# prgewfly ndtfvple
# reset the password for prgewfly ndtfvple on erp development erp
# reset the password for  on erp development erp
# oncidblt ucewizyd
# recall incident ticket no has been assigned to oncidblt ucewizyd
# recall incident ticket no has been assigned to
# knlrgsiv cqvuexjz
# query what license does knlrgsiv cqvuexjz has
# query what license does  has
# dnlhsgyo newducsl
# reset the password for dnlhsgyo newducsl on erp production erp
# reset the password for  on erp production erp
# knlrgsiv cqvuexjz
# problems with portal knlrgsiv cqvuexjz
# problems with portal
# puxsvfwr cwkjruni
# setup rechner ewel f r hr thrydad third consulting puxsvfwr cwkjruni
# setup rechner ewel f r hr thrydad third consulting
# qnxfegjw rljdhmwb
# reset passwords for qnxfegjw rljdhmwb using password management tool password reset
# reset passwords for  using password management tool password reset
# tmqfjard qzhgdoua
# problems with erpgui tmqfjard qzhgdoua
# problems with erpgui
# laeusvjo fvaihgpx
# support for fa thrydsss funke laeusvjo fvaihgpx
# support for fa thrydsss funke
# vepxdgot poezmwny
# replace illustrated tape printer we vepxdgot poezmwny
# replace illustrated tape printer we
# qpixeudn rjlziysd
# purchasingupstreamsso and ad for qpixeudn rjlziysd
# purchasingupstreamsso and ad for
# eluvxqhw gpbfkqeu
# a k ndigung for eluvxqhw gpbfkqeu  effective    has been approved
# a k ndigung for   effective    has been approved
# mgvpoyqd tnlshpwb
# reset passwords for mgvpoyqd tnlshpwb using password management tool password reset
# reset passwords for  using password management tool password reset
# qvncizuf ueiybanz
# problems with fuser unit we qvncizuf ueiybanz
# problems with fuser unit we
# efrjkspc sfhbunrp
# efrjkspc sfhbunrp your windows password is expiring soon
#  your windows password is expiring soon
# bfnvjgxd trqmnpvu
# reset passwords for bfnvjgxd trqmnpvu using password management tool password reset
# reset passwords for  using password management tool password reset
# qdxyifhj zbwtunpy
# wk qdxyifhj zbwtunpy
# wk
# dtlmbcrx mwuateyx
# problems with lan for computer erosion machine dtlmbcrx mwuateyx
# problems with lan for computer erosion machine
# jgxmafwk mlroijfp
# reset the password for jgxmafwk mlroijfp on erp production hcm
# reset the password for  on erp production hcm
# qkgnwxto dwtivjrp
# reset passwords for qkgnwxto dwtivjrp using password management tool password reset
# reset passwords for  using password management tool password reset
# dtlmbcrx mwuateyx
# printer in lion uacyltoe hxgayczeraum knicrhtyt paper dtlmbcrx mwuateyx
# printer in lion uacyltoe hxgayczeraum knicrhtyt paper
# lndypaqg dhqwtcsr
# reinstall hardcopy und EU tool lndypaqg dhqwtcsr
# reinstall hardcopy und EU tool
# xosdfhbu gtbfkisl
# calculator for length measuring machine uacyltoe hxgayczeen xosdfhbu gtbfkisl
# calculator for length measuring machine uacyltoe hxgayczeen
# pfjwinbg ljtzbdqg
# backup for computer lasplant  pfjwinbg ljtzbdqg
# backup for computer lasplant
# lpoebzsc grknswyo
# please usa sasqkjqh lwddkqddq access to printer cl ps per lpoebzsc grknswyo
# please usa sasqkjqh lwddkqddq access to printer cl ps per
# axcbfuqo yiagubvh
# access to http bddjwwwdw for axcbfuqo yiagubvh
# access to http bddjwwwdw for
# xvwchsdg pladjmxt
# xvwchsdg pladjmxt employee termination pn
#  employee termination pn
# ecwtrjnq jpecxuty
# called in to get in touch with ecwtrjnq jpecxuty
# called in to get in touch with
# xwirzvda okhyipgr
# support for roboworker sandblasting xwirzvda okhyipgr
# support for roboworker sandblasting
# lndypaqg dhqwtcsr
# setup new ws lndypaqg dhqwtcsr
# setup new ws
# vzqomdgt jwoqbuml
# problems with barcode labels volume format too big vzqomdgt jwoqbuml
# problems with barcode labels volume format too big
# usalikfj lfmpxbcn
# setup new ws in br usalikfj lfmpxbcn
# setup new ws in br
# arsbtkvd qieagkos
# reset the password for arsbtkvd qieagkos on erp production erp
# reset the password for  on erp production erp
# rgpvdhcm mgvpabsj
# access to erp SID  for user rgpvdhcm mgvpabsj
# access to erp SID  for user
# usalikfj lfmpxbcn
# probleme mit login in br usalikfj lfmpxbcn
# probleme mit login in br
# qidgvtwa qvbutayx
# reinstall win qidgvtwa qvbutayx
# reinstall win
# ksxchbaf rhquvzfm
# problems with fp computer hangs ksxchbaf rhquvzfm
# problems with fp computer hangs
# soldfnbq uhnbsvqd
# reset passwords for soldfnbq uhnbsvqd using password management tool password reset
# reset passwords for  using password management tool password reset
# soldfnbq uhnbsvqd
# reset passwords for soldfnbq uhnbsvqd using password management tool password reset
# reset passwords for  using password management tool password reset
# fygrwuna gomcekzi
# reset passwords for fygrwuna gomcekzi using password management tool password reset
# reset passwords for  using password management tool password reset
# fygrwuna gomcekzi
# reset passwords for fygrwuna gomcekzi using password management tool password reset
# reset passwords for  using password management tool password reset
# blktuiae jzakfmhw
# need access to sharepont approved by blktuiae jzakfmhw please find attachment
# need access to sharepont approved by  please find attachment
# rzxfgmcu xprwayoc
# reset the password for rzxfgmcu xprwayoc on other impact award
# reset the password for  on other impact award
# wvdxnkhf jirecvta
# reset passwords for wvdxnkhf jirecvta using password management tool password reset
# reset passwords for  using password management tool password reset
# cwivnxuk izmxqfud
# problems with outlook cwivnxuk izmxqfud
# problems with outlook
# xpugntjv zcaermdt
# Optiplex computer defective ewew xpugntjv zcaermdt
# Optiplex computer defective ewew
# jionmpsf wnkpzcmv
# setup EU tool we wu  jionmpsf wnkpzcmv
# setup EU tool we wu
# pxvjczdt kizsjfpq
# reset passwords for pxvjczdt kizsjfpq using password management tool password reset
# reset passwords for  using password management tool password reset
# fduinmtw yofhirjs
# password reset rqeuest for SID  erp for fduinmtw yofhirjs hixsodl
# password reset rqeuest for SID  erp for  hixsodl
# zneyrlhg bfiwanze
# forward bcxfhekz bplfrniss emails to zneyrlhg bfiwanze
# forward bcxfhekz bplfrniss emails to
# bcxfhekz bplfrnis
# forward bcxfhekz bplfrniss emails to
# forward s emails to
# spdczoth vajtodny
# Calculator for EU tool rods hangs up spdczoth vajtodny
# Calculator for EU tool rods hangs up
# ldmwqubi sovqeynk
# reset passwords for ldmwqubi sovqeynk using password management tool password reset
# reset passwords for  using password management tool password reset
# niptbwdq csenjruz
# Computer for information status defective problems with fan niptbwdq csenjruz
# Computer for information status defective problems with fan
# mdvlkbac uhefoqtg
# reset the password for mdvlkbac uhefoqtg on erp production erp
# reset the password for  on erp production erp
# xwirzvda okhyipgr
# problems with user again only temporary merdivan xwirzvda okhyipgr
# problems with user again only temporary merdivan
# qidgvtwa qvbutayx
# login error lync qidgvtwa qvbutayx
# login error lync
# cubdsrml znewqgop
# reset passwords for cubdsrml znewqgop using password management tool password reset
# reset passwords for  using password management tool password reset
# sewilrxm cbikymvf
# create telephony software id for the gso new hire sewilrxm cbikymvf
# create telephony software id for the gso new hire
# dhoalycb yopvwrjq
# Replace monitor dhoalycb yopvwrjq
# Replace monitor
# qidgvtwa qvbutayx
# install office ewel qidgvtwa qvbutayx
# install office ewel
# szockfpj izohlgcq
# setup new ws szockfpj izohlgcq
# setup new ws
# qdztknml hpcxnyrq
# setup new ws qdztknml hpcxnyrq
# setup new ws
# dyqekzuc djhznybt
# Recover account access dyqekzuc djhznybt urgently
# Recover account access  urgently
# imjwbogq xfizlnap
# reset the password for imjwbogq xfizlnap on erp production erp
# reset the password for  on erp production erp
# bnoupaki cpeioxdz
# reset passwords for bnoupaki cpeioxdz using password management tool password reset
# reset passwords for  using password management tool password reset
# jidhewlg jufskody
# reset SID  password for jidhewlg jufskody
# reset SID  password for
# lpoebzsc grknswyo
# home folder share delegation of dtheb mulhylen mullthyed to lpoebzsc grknswyo marthhty
# home folder share delegation of dtheb mulhylen mullthyed to  marthhty
# wrcktgbd wzrgyunp
# problems with LAN on the computer we wu essa wrcktgbd wzrgyunp
# problems with LAN on the computer we wu essa
# vzqomdgt jwoqbuml
# problems with portal user gogtyekthyto vzqomdgt jwoqbuml
# problems with portal user gogtyekthyto
# xaykwtrf amlswjfr
# reset the password for xaykwtrf amlswjfr on erp produktion erp
# reset the password for  on erp produktion erp
# youfzmgp xvysrnmb
# problems with lan youfzmgp xvysrnmb
# problems with lan
# ypladjeu wzfryxav
# problems with EU tool error when logging off the order ypladjeu wzfryxav
# problems with EU tool error when logging off the order
# byclpwmv esafrtbh
# laptop byclpwmv esafrtbh defective
# laptop  defective
# tmqfjard qzhgdoua
# problems with EU tool tmqfjard qzhgdoua
# problems with EU tool
# wcrbmgon kcudbnrw
# reset the password for wcrbmgon kcudbnrw on e mail
# reset the password for  on e mail
# youfzmgp xvysrnmb
# Computer for erosion machine defective youfzmgp xvysrnmb
# Computer for erosion machine defective
# xbsckemt durnfyxb
# reset the password for xbsckemt durnfyxb on sonstiges
# reset the password for  on sonstiges
# niptbwdq csenjruz
# mouse defective niptbwdq csenjruz
# mouse defective
# wsboedtj yvlswgxb
# problems with ws cad wsboedtj yvlswgxb
# problems with ws cad
# eglavnhx uprodleq
# reset passwords for eglavnhx uprodleq using password management tool password reset
# reset passwords for  using password management tool password reset
# lxfnwyuv bqmjyprz
# setup we ewewx lxfnwyuv bqmjyprz
# setup we ewewx
# lxfnwyuv bqmjyprz
# setup we ewew lxfnwyuv bqmjyprz
# setup we ewew
# eglavnhx uprodleq
# reset the password for eglavnhx uprodleq on erp produktion erp
# reset the password for  on erp produktion erp
# buyoipdj fceymwtz
# vip  reset the password for buyoipdj fceymwtz on other phone system interaction desktop
# vip  reset the password for  on other phone system interaction desktop
# hybiaxlk lawptzir
# reset passwords for hybiaxlk lawptzir using password management tool password reset
# reset passwords for  using password management tool password reset
# fylrosuk kedgmiul
# reset passwords for fylrosuk kedgmiul using password management tool password reset
# reset passwords for  using password management tool password reset
# fylrosuk kedgmiul
# reset passwords for fylrosuk kedgmiul using password management tool password reset
# reset passwords for  using password management tool password reset
# kslhobgj cyhvefna
# reset the password for kslhobgj cyhvefna on other interaction desktop
# reset the password for  on other interaction desktop
# pfjwinbg ljtzbdqg
# problems with laser pfjwinbg ljtzbdqg
# problems with laser
# pfjwinbg ljtzbdqg
# problems with lasplant  pfjwinbg ljtzbdqg
# problems with lasplant
# umykjweg jpwrfuhk
# pick up old it equipment x cad ws nd monitor umykjweg jpwrfuhk
# pick up old it equipment x cad ws nd monitor
# rhaycqjg arcgonvy
# install hardcopy ewew rhaycqjg arcgonvy
# install hardcopy ewew
# fdyietau dvsyxwbu
# problems with we the printer queue is currently not running fdyietau dvsyxwbu
# problems with we the printer queue is currently not running
# jvpkulxw ovuweygj
# reset passwords for jvpkulxw ovuweygj using password management tool password reset
# reset passwords for  using password management tool password reset
# vhjkdqop tkhafgrc
# unlock account email in cell phone the user vhjkdqop tkhafgrc id sanchrtyn
# unlock account email in cell phone the user  id sanchrtyn
# hnyeajrw ctxjsolz
# install drucker we ewew hnyeajrw ctxjsolz
# install drucker we ewew
# lxfnwyuv bqmjyprz
# install drucker we ewew lxfnwyuv bqmjyprz
# install drucker we ewew
# ugyothfz ugrmkdhx
# issue with outlook profile and skype for business ugyothfz ugrmkdhx ambals
# issue with outlook profile and skype for business  ambals
# gjisfonb odwfhmze
# reset passwords for gjisfonb odwfhmze using password management tool password reset
# reset passwords for  using password management tool password reset
# eaodcgsw trmzwbyc
# problems with com port maschine st hrmann eaodcgsw trmzwbyc
# problems with com port maschine st hrmann
# eaodcgsw trmzwbyc
# problems with proof of salary print eaodcgsw trmzwbyc
# problems with proof of salary print
# weszfyok fbadnjhu
# problems with wlan laptop weszfyok fbadnjhu
# problems with wlan laptop
# jionmpsf wnkpzcmv
# problems with we wu jionmpsf wnkpzcmv
# problems with we wu
# qdxyifhj zbwtunpy
# wk qdxyifhj zbwtunpy
# wk
# weszfyok fbadnjhu
# problems with vpn weszfyok fbadnjhu
# problems with vpn
# jionmpsf wnkpzcmv
# problems with alicona after update jionmpsf wnkpzcmv
# problems with alicona after update
# jionmpsf wnkpzcmv
# setup we wu jionmpsf wnkpzcmv
# setup we wu
# owtlmpuv oicrjsfh
# missing owtlmpuv oicrjsfh in my team calendar page
# missing  in my team calendar page
# fueiklyv jargqpkm
# reset the password for fueiklyv jargqpkm on erp production erp
# reset the password for  on erp production erp
# jionmpsf wnkpzcmv
# EU tool ws ewew does not work jionmpsf wnkpzcmv
# EU tool ws ewew does not work
# wrcktgbd wzrgyunp
# bluescreen ewew wrcktgbd wzrgyunp
# bluescreen ewew
# lndypaqg dhqwtcsr
# user lndypaqg dhqwtcsr gogtyekthyto has his password in erp SID  verggermany
# user  gogtyekthyto has his password in erp SID  verggermany
# vzqomdgt jwoqbuml
# problems with ie vzqomdgt jwoqbuml
# problems with ie
# jionmpsf wnkpzcmv
# sinic general error  odbc vmsliazh ltksxmyv driver query timeout jionmpsf wnkpzcmv
# sinic general error  odbc vmsliazh ltksxmyv driver query timeout
# fdyietau dvsyxwbu
# problems with printer we fdyietau dvsyxwbu
# problems with printer we
# kxmidsga zokivdfa
# not able to login to ethics portal kxmidsga zokivdfa
# not able to login to ethics portal
# omiwzbue auvolfhp
# printing request request transaction print to a different printer please contact omiwzbue auvolfhp for info
# printing request request transaction print to a different printer please contact  for info
# jmusidzr sratdeol
# reset the password for jmusidzr sratdeol on erp production hcm
# reset the password for  on erp production hcm
# dqowbefk prgxwzco
# reset the password for dqowbefk prgxwzco on erp production hcm
# reset the password for  on erp production hcm
# bxeagsmt zrwdgsco
# reset passwords for bxeagsmt zrwdgsco using password management tool password reset
# reset passwords for  using password management tool password reset
# bxeagsmt zrwdgsco
# reset passwords for bxeagsmt zrwdgsco using password management tool password reset
# reset passwords for  using password management tool password reset
# lbxugpjw cnmfbdui
# lbxugpjw cnmfbdui mobile phone changed
#  mobile phone changed
# prgewfly ndtfvple
# reset passwords for prgewfly ndtfvple using password management tool password reset
# reset passwords for  using password management tool password reset
# zifujpvr vxfkwaqh
# zifujpvr vxfkwaqh
#
# horeduca ogrhivnm
# the e mail account of horeduca ogrhivnm has come up in my outlook folders
# the e mail account of  has come up in my outlook folders
# wxdvjoct ckxwtoam
# reset passwords for wxdvjoct ckxwtoam using password management tool password reset
# reset passwords for  using password management tool password reset
# ytzpxhql ntfxgpms
# reset passwords for ytzpxhql ntfxgpms using password management tool password reset
# reset passwords for  using password management tool password reset
# kehtxprg uekapfzt
# user kehtxprg uekapfzt is not able to access erp SID
# user  is not able to access erp SID
# eaodcgsw trmzwbyc
# problems with printing measuring machine for bars eaodcgsw trmzwbyc
# problems with printing measuring machine for bars
# jionmpsf wnkpzcmv
# support for alicona jionmpsf wnkpzcmv
# support for alicona
# ecwtrjnq jpecxuty
# call for ecwtrjnq jpecxuty
# call for
# fkuqjwit jgcsaqzi
# reset passwords for fkuqjwit jgcsaqzi using password management tool password reset
# reset passwords for  using password management tool password reset
# hzmxwdrs tcbjyqps
# reset passwords for hzmxwdrs tcbjyqps using password management tool password reset
# reset passwords for  using password management tool password reset
# wxstfouy isjzcotm
# problems with vpn wxstfouy isjzcotm
# problems with vpn
# mqjdyizg amhywoqg
# mqjdyizg amhywoqg issues with purchasing access
#  issues with purchasing access
# xszoedmc gmhkdsnw
# xszoedmc gmhkdsnw or skype contract library access to janhetgdyu fox chatgrylouy
#  or skype contract library access to janhetgdyu fox chatgrylouy
# acqpinyd ecygimqd
# reinstall EU tool und hardcopy acqpinyd ecygimqd
# reinstall EU tool und hardcopy
# bctypmjw cbhnxafz
# problems with companyguest bctypmjw cbhnxafz
# problems with companyguest
# petljhxi bocxgins
# problems with hp printer local petljhxi bocxgins
# problems with hp printer local
# ughzilfm cfibdamq
# ughzilfm cfibdamq wanted details to check for company guest
#  wanted details to check for company guest
# vuxdrbng owqplduj
# vuxdrbng owqplduj s k
#  s k
# vuxdrbng owqplduj
# setup new ws vuxdrbng owqplduj
# setup new ws
# bzwrchnd ysfiwvmo
# reset the password for bzwrchnd ysfiwvmo on windows
# reset the password for  on windows
# ytzpxhql ntfxgpms
# reset passwords for ytzpxhql ntfxgpms using password management tool password reset
# reset passwords for  using password management tool password reset
# ytzpxhql ntfxgpms
# reset passwords for ytzpxhql ntfxgpms using password management tool password reset
# reset passwords for  using password management tool password reset
# ytzpxhql ntfxgpms
# reset passwords for ytzpxhql ntfxgpms using password management tool password reset
# reset passwords for  using password management tool password reset
# ughzilfm cfibdamq
# ughzilfm cfibdamq called requesting for the appreciate hub link
#  called requesting for the appreciate hub link
# niptbwdq csenjruz
# problems with ie niptbwdq csenjruz
# problems with ie
# hcuixqgj mavxgqbs
# s to k for hcuixqgj mavxgqbs
# s to k for
# acqpinyd ecygimqd
# install we ewew acqpinyd ecygimqd
# install we ewew
# acqpinyd ecygimqd
# problems with portal acqpinyd ecygimqd
# problems with portal
# hcuixqgj mavxgqbs
# problems with portal hcuixqgj mavxgqbs
# problems with portal
# ughzilfm cfibdamq
# ughzilfm cfibdamq called in to reset password for zlnfpuam aktplhre
#  called in to reset password for zlnfpuam aktplhre
# zlnfpuam aktplhre
#  called in to reset password for zlnfpuam aktplhre
#  called in to reset password for
# zlnfpuam aktplhre
# setup new ws zlnfpuam aktplhre
# setup new ws
# fqhlvcxn zdfymgjp
# fqhlvcxn zdfymgjp wants to share the file fqhlvcxn zdfymgjp pdf with you
#  wants to share the file  pdf with you
# fueiklyv jargqpkm
# reset the password for fueiklyv jargqpkm on erp production bw
# reset the password for  on erp production bw
# fueiklyv jargqpkm
# reset the password for fueiklyv jargqpkm on erp production erp
# reset the password for  on erp production erp
# wrcktgbd wzrgyunp
# computer ewew bluescreen wrcktgbd wzrgyunp
# computer ewew bluescreen
# wrcktgbd wzrgyunp
# reinstall hardkopy we wu wrcktgbd wzrgyunp
# reinstall hardkopy we wu
# lxvunpiz mgjxwept
# problems with hp error   lxvunpiz mgjxwept
# problems with hp error
# lxvunpiz mgjxwept
# computer ewew very slow lxvunpiz mgjxwept
# computer ewew very slow
# sgnubadl gpkovbah
# setup new ws sgnubadl gpkovbah
# setup new ws
# ecwtrjnq jpecxuty
# call for ecwtrjnq jpecxuty
# call for
# pumjbcna scluvtyj
# reset the password for pumjbcna scluvtyj on erp qa hcm
# reset the password for  on erp qa hcm
# pumjbcna scluvtyj
# reset passwords for pumjbcna scluvtyj using password management tool password reset
# reset passwords for  using password management tool password reset
# inxsupmy zhwmifvx
# add the inxsupmy zhwmifvx to materials management purchasing
# add the  to materials management purchasing
# cyxieuwk rekwlqmu
# cannot find dr cyxieuwk rekwlqmu in ticketing tool
# cannot find dr  in ticketing tool
# cyvdluja oxrkfpbz
# reset the password for cyvdluja oxrkfpbz on other telephony software
# reset the password for  on other telephony software
# wrcktgbd wzrgyunp
# reinstall EU tool ewew wrcktgbd wzrgyunp
# reinstall EU tool ewew
# ecwtrjnq jpecxuty
# call for ecwtrjnq jpecxuty
# call for
# qekdgaim wagshrzl
# reset the password for qekdgaim wagshrzl on erp production erp
# reset the password for  on erp production erp
# zlqfptjx xnklbfua
# reinstall company barcode f r ewew zlqfptjx xnklbfua
# reinstall company barcode f r ewew
# jionmpsf wnkpzcmv
# support for computer measuring device jionmpsf wnkpzcmv
# support for computer measuring device
# zbxljotu cbunzrak
# zbxljotu cbunzrak your invoice for order no  from
#  your invoice for order no  from
# oweklxnm ubayizsq
# reset the password for oweklxnm ubayizsq on windows login
# reset the password for  on windows login
# xwirzvda okhyipgr
# install EU tool and bls calculator olympus xwirzvda okhyipgr
# install EU tool and bls calculator olympus
# jionmpsf wnkpzcmv
# setup new ws ewew jionmpsf wnkpzcmv
# setup new ws ewew
# difozlav dgbfptos
# probleme mit collaboration platform infopath difozlav dgbfptos
# probleme mit collaboration platform infopath
# qoybxkfh dwcmxuea
# reset passwords for qoybxkfh dwcmxuea using password management tool password reset
# reset passwords for  using password management tool password reset
# rtpcnyhq ceqmwkhi
# add the rtpcnyhq ceqmwkhi to materials management purchasing
# add the  to materials management purchasing
# rlhuwmve krcfhoxj
# reset the password for rlhuwmve krcfhoxj on erp qa erp
# reset the password for  on erp qa erp
# qdxyifhj zbwtunpy
# bluetooth headset cannot connect to pc assign to qdxyifhj zbwtunpy germany
# bluetooth headset cannot connect to pc assign to  germany
# bwgldaoe aczyfqjr
# reset the password for bwgldaoe aczyfqjr on erp qa erp
# reset the password for  on erp qa erp
# jionmpsf wnkpzcmv
# problems with erpgui jionmpsf wnkpzcmv
# problems with erpgui
# jxphgfmb gjbtuwek
# access point defekt jxphgfmb gjbtuwek
# access point defekt
# kwehgxts agdsqbwv
# problems with outlook kwehgxts agdsqbwv
# problems with outlook
# niptbwdq csenjruz
# problems with skype difozlav dgbfptos niptbwdq csenjruz
# problems with skype difozlav dgbfptos
# difozlav dgbfptos
# problems with skype difozlav dgbfptos
# problems with skype
# qdbfemro mcsqzlvd
# reset passwords for qdbfemro mcsqzlvd using password management tool password reset
# reset passwords for  using password management tool password reset
# sdlixwmb zvygmnco
# need to check if sdlixwmb zvygmncos account is locked
# need to check if s account is locked
# nozahtbr ubznqpsy
# problems with symantec conference room rods nozahtbr ubznqpsy
# problems with symantec conference room rods
# mvhcoqed konjdmwq
# reset passwords for mvhcoqed konjdmwq using password management tool password reset
# reset passwords for  using password management tool password reset
# mvhcoqed konjdmwq
# reset passwords for mvhcoqed konjdmwq using password management tool password reset
# reset passwords for  using password management tool password reset
# qipzctgs wjhtbpfr
# qipzctgs wjhtbpfr need network account so he can get email and etime
#  need network account so he can get email and etime
# yolktfas fyoxqgvh
# replace monitor across from yolktfas fyoxqgvh a different cable is needed
# replace monitor across from  a different cable is needed
# kxmidsga zokivdfa
# crm portal login issue kxmidsga zokivdfa
# crm portal login issue
# tjlizqgc ngvwoukp
# access to tjlizqgc ngvwoukp calendars
# access to  calendars
# jerydwbn gdylnaue
# reset passwords for jerydwbn gdylnaue using password management tool password reset
# reset passwords for  using password management tool password reset
# dmexgspl mruzqhac
# reset passwords for dmexgspl mruzqhac using password management tool password reset
# reset passwords for  using password management tool password reset
# hgyvopct dhckfmbq
# reset passwords for hgyvopct dhckfmbq using password management tool password reset
# reset passwords for  using password management tool password reset
# mjvfxnka zvjxuahe
# mjvfxnka zvjxuahe is not able to add campaign global hard machining to his opportunities
#  is not able to add campaign global hard machining to his opportunities
# ahlqgjwx wbsfavhg
# install pdfmailer ahlqgjwx wbsfavhg
# install pdfmailer
# hybegvwo dbgrtqhs
# call to check if hybegvwo dbgrtqhs account is disabled
# call to check if  account is disabled
# vsdtxwry ngkcdjye
# problems with erpgui vsdtxwry ngkcdjye
# problems with erpgui
# tuzkadxv rxloutpn
# user tuzkadxv rxloutpn cannot use the run report
# user  cannot use the run report
# jvshydix rzpmnylt
# jvshydix rzpmnylt general query
#  general query
# qcxivzag vyucbagx
# called to unlock ad account for user qcxivzag vyucbagx
# called to unlock ad account for user
# tfsehruw dzrgpkyn
# reset the password for tfsehruw dzrgpkyn on erp production erp
# reset the password for  on erp production erp
# ecwtrjnq jpecxuty
# call for ecwtrjnq jpecxuty
# call for
# tmqfjard qzhgdoua
# mr tmqfjard qzhgdoua ordinary no  requires full access to the following EU tool modules
# mr  ordinary no  requires full access to the following EU tool modules
# jionmpsf wnkpzcmv
# replace cable vga jionmpsf wnkpzcmv
# replace cable vga
# tmqfjard qzhgdoua
# install pulverleitstand tmqfjard qzhgdoua
# install pulverleitstand
# bfqnvezs vwkasnxe
# incorrect formatting in pdf bfqnvezs vwkasnxe
# incorrect formatting in pdf
# vaigycet jtgmpdcr
# install pulverleitstand vaigycet jtgmpdcr
# install pulverleitstand
# qohfjpna exphkims
# office  for qohfjpna exphkims shows activation required
# office  for  shows activation required
# ahydmrbu fjymgtvo
# reset the password for ahydmrbu fjymgtvo on other telephony software
# reset the password for  on other telephony software
# hcuixqgj mavxgqbs
# service kit  for we supply hcuixqgj mavxgqbs
# service kit  for we supply
# dtlmbcrx mwuateyx
# probleme mit office dtlmbcrx mwuateyx
# probleme mit office
# tmqfjard qzhgdoua
# problems with batch management tmqfjard qzhgdoua
# problems with batch management
# howfanzi siavgtby
# problems with batch management howfanzi siavgtby
# problems with batch management
# uadkqcsj xtmjlari
# setup new ws uadkqcsj xtmjlari
# setup new ws
# ujtmipzv cwdzunxs
# problems with portal ujtmipzv cwdzunxs
# problems with portal
# xwirzvda okhyipgr
# time recording does not work we qs quality management xwirzvda okhyipgr
# time recording does not work we qs quality management
# vzqomdgt jwoqbuml
# install company barcode for ewew vzqomdgt jwoqbuml
# install company barcode for ewew
# tfazwrdv upwonzvd
# user tfazwrdv upwonzvd s pc name has been changed to atcl old pc name atclx
# user  s pc name has been changed to atcl old pc name atclx
# pfjwinbg ljtzbdqg
# problems with opening m wsb exe we wu pfjwinbg ljtzbdqg
# problems with opening m wsb exe we wu
# mobaidfx gviwlsrm
# reset the password for mobaidfx gviwlsrm on erp produktion hcm
# reset the password for  on erp produktion hcm
# zlqfptjx xnklbfua
# install kis ewew zlqfptjx xnklbfua
# install kis ewew
# pfjwinbg ljtzbdqg
# install zebra we wu pfjwinbg ljtzbdqg
# install zebra we wu
# vzqomdgt jwoqbuml
# install company barcode for ewew vzqomdgt jwoqbuml
# install company barcode for ewew
# vzqomdgt jwoqbuml
# install company barcode for ewew vzqomdgt jwoqbuml
# install company barcode for ewew
# vmthcrkf iceyusnd
# unlock exchange active sync for ios for vmthcrkf iceyusnd pipfhypeu company device
# unlock exchange active sync for ios for  pipfhypeu company device
# znqcljxt azvoespk
# need access to znqcljxt azvoespks collaboration platform
# need access to s collaboration platform
# jionmpsf wnkpzcmv
# computer for steli measuring device does not work jionmpsf wnkpzcmv
# computer for steli measuring device does not work
# hxwtidja ixahzmvf
# supply usb extension cable hxwtidja ixahzmvf
# supply usb extension cable
# cudgevmx waqslrbd
# Computer does not start after update ewew cudgevmx waqslrbd
# Computer does not start after update ewew
# cubdsrml znewqgop
# reset passwords for cubdsrml znewqgop using password management tool password reset
# reset passwords for  using password management tool password reset
# iwtvrhnz rxiumhfk
# reset the password for iwtvrhnz rxiumhfk on erp production erp
# reset the password for  on erp production erp
# qmglkaru qiwhfkdv
# please send expense report  to qmglkaru qiwhfkdv for approval
# please send expense report  to  for approval
# bejvhsfx dmvsclhp
# problleme mit EU tool we bejvhsfx dmvsclhp
# problleme mit EU tool we
# lbxgodfu usperhki
# hello i am lbxgodfu usperhki from company italy ive vpn profile is not working
# hello i am  from company italy ive vpn profile is not working
# sgnubadl gpkovbah
# install win ewew sgnubadl gpkovbah
# install win ewew
# sgnubadl gpkovbah
# install win ewew sgnubadl gpkovbah
# install win ewew
# vzqomdgt jwoqbuml
# install win ewew vzqomdgt jwoqbuml
# install win ewew
# vzqomdgt jwoqbuml
# install win ewew vzqomdgt jwoqbuml
# install win ewew
# yolktfas fyoxqgvh
# reset passwords for yolktfas fyoxqgvh using password management tool password reset
# reset passwords for  using password management tool password reset
# yzugpdco nsyapewg
# dob report showing blank data for yzugpdco nsyapewg
# dob report showing blank data for
# tsicojkp kghaozew
# reset the password for tsicojkp kghaozew on windows login
# reset the password for  on windows login
# tsicojkp kghaozew
# reset passwords for tsicojkp kghaozew using password management tool password reset
# reset passwords for  using password management tool password reset
# pfjwinbg ljtzbdqg
# install zebra we wu pfjwinbg ljtzbdqg
# install zebra we wu
# hotwlygp afukzhnm
# hotwlygp afukzhnm frequent account lockout
#  frequent account lockout
# dknejifu dljvtebc
# problems with we printer does not print dknejifu dljvtebc
# problems with we printer does not print
# ugawcoye jcfqgviy
# reset passwords for ugawcoye jcfqgviy using password management tool password reset
# reset passwords for  using password management tool password reset
# zlqfptjx xnklbfua
# install EU tool and zebra ewew zlqfptjx xnklbfua
# install EU tool and zebra ewew
# kxmidsga zokivdfa
# laptop login issue kxmidsga zokivdfa
# laptop login issue
# axesnghb cyzuomxa
# problems with outlook axesnghb cyzuomxa
# problems with outlook
# pyeothbl agfxelwz
# reset passwords for pyeothbl agfxelwz using password management tool password reset
# reset passwords for  using password management tool password reset
# pyeothbl agfxelwz
# reset passwords for pyeothbl agfxelwz using password management tool password reset
# reset passwords for  using password management tool password reset
# guldiwmn aroqwuvz
# reset the password for guldiwmn aroqwuvz on erp production erp
# reset the password for  on erp production erp
# wrcktgbd wzrgyunp
# problems with ewew wrcktgbd wzrgyunp
# problems with ewew
# wcupoaty fqnzwphj
# keyboard defective wcupoaty fqnzwphj
# keyboard defective
# qgilmtyc gmscovxa
# reset passwords for qgilmtyc gmscovxa using password management tool password reset
# reset passwords for  using password management tool password reset
# rlhuwmve krcfhoxj
# reset passwords for rlhuwmve krcfhoxj using password management tool password reset
# reset passwords for  using password management tool password reset
# vaigycet jtgmpdcr
# defective fiber optic line box defective vaigycet jtgmpdcr
# defective fiber optic line box defective
# bxeagsmt zrwdgsco
# reset passwords for bxeagsmt zrwdgsco using password management tool password reset
# reset passwords for  using password management tool password reset
# wrcktgbd wzrgyunp
# on check we wu essa presse box flashes continuously wrcktgbd wzrgyunp
# on check we wu essa presse box flashes continuously
# niptbwdq csenjruz
# setup computer for repair information niptbwdq csenjruz
# setup computer for repair information
# jionmpsf wnkpzcmv
# problem with screen saver at the sinic stations jionmpsf wnkpzcmv
# problem with screen saver at the sinic stations
# ghaltiek lsuepvyx
# problems with portal ghaltiek lsuepvyx
# problems with portal
# efbwiadp dicafxhv
# i get warehouse toolmails meant for efbwiadp dicafxhv
# i get warehouse toolmails meant for
# jvxtfhkg heptuizn
# request in behalf of jvxtfhkg heptuizn
# request in behalf of
# qycgdfhz iqshzdru
# reset passwords for qycgdfhz iqshzdru using password management tool password reset
# reset passwords for  using password management tool password reset
# nmpworvu upgtrvnj
# nmpworvu upgtrvnj monitor display issue
#  monitor display issue
# vzqomdgt jwoqbuml
# problems with erpgui ewewx vzqomdgt jwoqbuml
# problems with erpgui ewewx
# vzqomdgt jwoqbuml
# problems with erpgui ewewx vzqomdgt jwoqbuml
# problems with erpgui ewewx
# pfjwinbg ljtzbdqg
# problems with labels print laser  we wu pfjwinbg ljtzbdqg
# problems with labels print laser  we wu
# pfjwinbg ljtzbdqg
# problems with labels print laser  we wu pfjwinbg ljtzbdqg
# problems with labels print laser  we wu
# qnigujek kopqcjdh
# setup new ws computer repair qnigujek kopqcjdh
# setup new ws computer repair
# arsbtkvd qieagkos
# reset the password for arsbtkvd qieagkos on erp production erp
# reset the password for  on erp production erp
# cyvdluja oxrkfpbz
# reset the password for cyvdluja oxrkfpbz on other telephony software
# reset the password for  on other telephony software
# qgwypesz fzsdnmrk
# operator forgot login password qgwypesz fzsdnmrk user id zemboks
# operator forgot login password  user id zemboks
# byclpwmv esafrtbh
# byclpwmv esafrtbh is unable to login to ticketing tool
#  is unable to login to ticketing tool
# ughzilfm cfibdamq
# ughzilfm cfibdamq called to check if the account are active
#  called to check if the account are active
# dslamtcb ezbmonjr
# ticket update on inc from dslamtcb ezbmonjr
# ticket update on inc from
# xjmpacye qgxrptnf
# xjmpacye qgxrptnf cannot send delivery notes via zz mails
#  cannot send delivery notes via zz mails
# vzqomdgt jwoqbuml
# setup outlook incoming goods vzqomdgt jwoqbuml
# setup outlook incoming goods
# bxeagsmt zrwdgsco
# reset passwords for bxeagsmt zrwdgsco using password management tool password reset
# reset passwords for  using password management tool password reset
# bctypmjw cbhnxafz
# reactivate old laptop hr mghllenbecfnfk bctypmjw cbhnxafz
# reactivate old laptop hr mghllenbecfnfk
# bctypmjw cbhnxafz
# reinstall office bctypmjw cbhnxafz
# reinstall office
# xaqzisrk ahbgjrqz
# problems with EU tool we wu xaqzisrk ahbgjrqz
# problems with EU tool we wu
# jywvemun qngschtz
# folder access for jywvemun qngschtz
# folder access for
# tqvpohwj tbkywpqz
# ticket update regarding ticket no from tqvpohwj tbkywpqz
# ticket update regarding ticket no from
# cpmaidhj elbaqmtp
# reset passwords for cpmaidhj elbaqmtp using password management tool password reset
# reset passwords for  using password management tool password reset
# ghaltiek lsuepvyx
# ess access for user ghaltiek lsuepvyx yesilc
# ess access for user  yesilc
# xaqzisrk ahbgjrqz
# setup new ws strahlraum xaqzisrk ahbgjrqz
# setup new ws strahlraum
# ujtmipzv cwdzunxs
# setup new ws strahlraum ujtmipzv cwdzunxs
# setup new ws strahlraum
# rfvmeyho qgtxjsdc
# the printer does not print hp  rfvmeyho qgtxjsdc
# the printer does not print hp
# nfayqjhg kyswcpei
# setup new ws computer old forge nfayqjhg kyswcpei
# setup new ws computer old forge
# bxeagsmt zrwdgsco
# reset passwords for bxeagsmt zrwdgsco using password management tool password reset
# reset passwords for  using password management tool password reset
# ughzilfm cfibdamq
# password reset request by ughzilfm cfibdamq
# password reset request by
# btelgpcx nrlfhbmu
# reset the password for btelgpcx nrlfhbmu on erp production erp
# reset the password for  on erp production erp
# lqjoagzt gqueiatx
# registration account mp ek on the pc empwa set up   If you have any queries extension  at lqjoagzt gqueiatx
# registration account mp ek on the pc empwa set up   If you have any queries extension  at
# htvepyua izgulrcf
# Replace monitor htvepyua izgulrcf
# Replace monitor
# vzqomdgt jwoqbuml
# network not available for scan please check we and we vzqomdgt jwoqbuml
# network not available for scan please check we and we
# xwirzvda okhyipgr
# problems with we wu xwirzvda okhyipgr
# problems with we wu
# ompeztak ilkpqtjh
# problems with kiosk ompeztak ilkpqtjh bur am orde
# problems with kiosk  bur am orde
# bxeagsmt zrwdgsco
# reset passwords for bxeagsmt zrwdgsco using password management tool password reset
# reset passwords for  using password management tool password reset
# ljpgedia bzqcwsgf
# reset the password for ljpgedia bzqcwsgf on erp production erp
# reset the password for  on erp production erp
# ofwxjriq rwcxkflq
# nicrhty wanted to set ooo from ofwxjriq rwcxkflqs mailbox
# nicrhty wanted to set ooo from s mailbox
# xwirzvda okhyipgr
# support for conversion ewew xwirzvda okhyipgr
# support for conversion ewew
# lpfzasmv cleoprzq
# support for conversion ewew lpfzasmv cleoprzq
# support for conversion ewew
# howfanzi siavgtby
# problems with computer ewewx howfanzi siavgtby
# problems with computer ewewx
# xosdfhbu gtbfkisl
# support for st hrmann xosdfhbu gtbfkisl
# support for st hrmann
# znqcljxt azvoespk
# need access to znqcljxt azvoespks emails
# need access to s emails
# vsdtxwry ngkcdjye
# problems with erpgui vsdtxwry ngkcdjye
# problems with erpgui
# cwfzldts dlmukhyn
# user cwfzldts dlmukhyn cannot create purchasing requistions out of punch out catalogues
# user  cannot create purchasing requistions out of punch out catalogues
# niptbwdq csenjruz
# support for conversion we port  niptbwdq csenjruz
# support for conversion we port
# niptbwdq csenjruz
# conversion computer ewew port  niptbwdq csenjruz
# conversion computer ewew port
# nfayqjhg kyswcpei
# setup new ws instandsetzung nfayqjhg kyswcpei
# setup new ws instandsetzung
# qwynjdbk eamnvwyh
# support for relocation qwynjdbk eamnvwyh
# support for relocation
# igkqpndy swqndxhl
# reset the password for igkqpndy swqndxhl on other telephony software
# reset the password for  on other telephony software
# niptbwdq csenjruz
# problems with vpn st hrmann niptbwdq csenjruz
# problems with vpn st hrmann
# nuksytoh whovmtez
# add user nuksytoh whovmtez sbcheyu to ad group eagcutview
# add user  sbcheyu to ad group eagcutview
# xpugntjv zcaermdt
# problems with shift planning xpugntjv zcaermdt
# problems with shift planning
# bfqnvezs vwkasnxe
# probleme mit archiving tool bfqnvezs vwkasnxe
# probleme mit archiving tool
# sqlmtixr urhbvfgd
# problems with erpgui sqlmtixr urhbvfgd
# problems with erpgui
# xmlbfjpg yegzbvru
# problems with java xmlbfjpg yegzbvru
# problems with java
# wqfzjycu omleknjd
# ticket update on ticket no from wqfzjycu omleknjd
# ticket update on ticket no from
# chkmejsn lvidgknc
# reset the password for chkmejsn lvidgknc on erp production erp
# reset the password for  on erp production erp
# cwfzldts dlmukhyn
# user cwfzldts dlmukhyn cannot create purchasing requistions out of punch out catalogues
# user  cannot create purchasing requistions out of punch out catalogues
# wrcktgbd wzrgyunp
# setup rechner ewew wrcktgbd wzrgyunp
# setup rechner ewew
# puxsvfwr cwkjruni
# problems with lan in the meeting room puxsvfwr cwkjruni
# problems with lan in the meeting room
# pzjelyxg vstyaouc
# reset passwords for pzjelyxg vstyaouc using password management tool password reset
# reset passwords for  using password management tool password reset
# horeduca ogrhivnm
# reset passwords for horeduca ogrhivnm using password management tool password reset
# reset passwords for  using password management tool password reset
# ughzilfm cfibdamq
# erp SID  password reset requested by ughzilfm cfibdamq
# erp SID  password reset requested by
# mfvkxghn mzjasxqd
# reset the password for mfvkxghn mzjasxqd on other SID  in erp
# reset the password for  on other SID  in erp
# ypladjeu wzfryxav
# problems with login ypladjeu wzfryxav
# problems with login
# dtlmbcrx mwuateyx
# problems with outlook dtlmbcrx mwuateyx
# problems with outlook
# puxsvfwr cwkjruni
# printer does not work puxsvfwr cwkjruni
# printer does not work
# wvdxnkhf jirecvta
# reset passwords for wvdxnkhf jirecvta using password management tool password reset
# reset passwords for  using password management tool password reset
# qidgvtwa qvbutayx
# setup new laptop for roboworker qidgvtwa qvbutayx
# setup new laptop for roboworker
# sqlmtixr urhbvfgd
# setup new ws sqlmtixr urhbvfgd
# setup new ws
# tzrekwqf homwadbs
# company email accounts tzrekwqf homwadbs
# company email accounts
# niptbwdq csenjruz
# support for osterwalder niptbwdq csenjruz
# support for osterwalder
# tmqfjard qzhgdoua
# problems with erpgui tmqfjard qzhgdoua
# problems with erpgui
# qvncizuf ueiybanz
# pick up old it equipment qvncizuf ueiybanz
# pick up old it equipment
# qasdhyzm yuglsrwx
# unlock account email in cell phone the users qasdhyzm yuglsrwx id nasftgcijj and rspqvzgu vroanwhu id silvgtyar
# unlock account email in cell phone the users  id nasftgcijj and rspqvzgu vroanwhu id silvgtyar
# fniqhjtg qrfuetpw
# reset the password for fniqhjtg qrfuetpw on windows login
# reset the password for  on windows login
# xmlbfjpg yegzbvru
# Check wireless access point born  born  and conference room born  xmlbfjpg yegzbvru
# Check wireless access point born  born  and conference room born
# xwirzvda okhyipgr
# problems with lan ewew xwirzvda okhyipgr
# problems with lan ewew
# xwirzvda okhyipgr
# problems with lan ewew xwirzvda okhyipgr
# problems with lan ewew
# jxphgfmb gjbtuwek
# wireless access point does not work jxphgfmb gjbtuwek
# wireless access point does not work
# ezrsdgfc hofgvwel
# reset passwords for ezrsdgfc hofgvwel using password management tool password reset
# reset passwords for  using password management tool password reset
# ezrsdgfc hofgvwel
# reset passwords for ezrsdgfc hofgvwel using password management tool password reset
# reset passwords for  using password management tool password reset
# zslugaxq dtwlrofu
# problems with scanner and printer zslugaxq dtwlrofu
# problems with scanner and printer
# wxstfouy isjzcotm
# Pick up old it equipment wxstfouy isjzcotm
# Pick up old it equipment
# wxstfouy isjzcotm
# problems with login wxstfouy isjzcotm
# problems with login
# szcbhvwe edpouqjl
# reset the password for szcbhvwe edpouqjl on erp production erp
# reset the password for  on erp production erp
# wvdxnkhf jirecvta
# wvdxnkhf jirecvta has issues to connect company wifi network in f rth
#  has issues to connect company wifi network in f rth
# ahlqgjwx wbsfavhg
# install ie ahlqgjwx wbsfavhg
# install ie
# wxstfouy isjzcotm
# problems with lan wxstfouy isjzcotm
# problems with lan
# xmlbfjpg yegzbvru
# problems with opening documents in the intranet with internet explorer xmlbfjpg yegzbvru
# problems with opening documents in the intranet with internet explorer
# qvncizuf ueiybanz
# support for relocation qvncizuf ueiybanz
# support for relocation
# obqridjk ugelctsz
# problems with EU tool obqridjk ugelctsz
# problems with EU tool
# urgqkinl zpcokgbj
# ticket update query on ticket inc urgqkinl zpcokgbj
# ticket update query on ticket inc
# cyxieuwk rekwlqmu
# account expired for cyxieuwk rekwlqmu nd july
# account expired for  nd july
# nvawmlch ubyjolnc
# reset the password for nvawmlch ubyjolnc on erp production erp
# reset the password for  on erp production erp
# wvdxnkhf jirecvta
# wvdxnkhf jirecvta locked out himself from windows and needs a password reset
#  locked out himself from windows and needs a password reset
# stwpzxbf bjehirkx
# setup new ws stwpzxbf bjehirkx
# setup new ws
# xmlbfjpg yegzbvru
# problems with purchasing xmlbfjpg yegzbvru
# problems with purchasing
# ghaltiek lsuepvyx
# setup new ws ghaltiek lsuepvyx
# setup new ws
# hgrvubzo wgyhktic
# problems with database in EU tool hgrvubzo wgyhktic
# problems with database in EU tool
# cytohwau qfunricw
# mail address of cytohwau qfunricw at ticketing tool is missing
# mail address of  at ticketing tool is missing
# jcmxerol nbfyczqr
# reset passwords for jcmxerol nbfyczqr using password management tool password reset
# reset passwords for  using password management tool password reset
# cyxieuwk rekwlqmu
# termination for cyxieuwk rekwlqmu
# termination for
# recsynqt byoezmla
# unlock account email in cell phone the users cfgxpvzi dvpnfbrc recsynqt byoezmla and alexandre pinto
# unlock account email in cell phone the users cfgxpvzi dvpnfbrc  and alexandre pinto
# yimwfntl rkdwohas
# reset the password for yimwfntl rkdwohas on erp production erp
# reset the password for  on erp production erp
# zpfitlyu cemvwyso
# unlock account email in cell phone the user luciano amadeu and zpfitlyu cemvwyso
# unlock account email in cell phone the user luciano amadeu and
# svuxjkpg tpurnjvi
# setup new ws svuxjkpg tpurnjvi
# setup new ws
# xovczlad fkicawph
# setup new ws xovczlad fkicawph
# setup new ws
# bzekndcu ivhnpdbu
# setup new ws bzekndcu ivhnpdbu
# setup new ws
# qidgvtwa qvbutayx
# setup laptop for sandblasting machine and roboworker qidgvtwa qvbutayx
# setup laptop for sandblasting machine and roboworker
# chkzbeav ykeilmog
# setup new ws chkzbeav ykeilmog
# setup new ws
# tmqfjard qzhgdoua
# problems with erpgui tmqfjard qzhgdoua
# problems with erpgui
# ylhptzmd owslfzqi
# setup new ws ylhptzmd owslfzqi
# setup new ws
# wphqnxly htvrbxmd
# setup new ws wphqnxly htvrbxmd
# setup new ws
# pifyudbo tagsfbny
# barcode scanner defective pifyudbo tagsfbny
# barcode scanner defective
# tfrbwoua aegpkruc
# tfrbwoua aegpkruc unable to print from pdf
#  unable to print from pdf
# thnsguzj utwijzag
# setup new ws thnsguzj utwijzag
# setup new ws
# yucgfmiq jamgpnqe
# setup new ws yucgfmiq jamgpnqe
# setup new ws
# njdrcagt shourxyp
# install  bit version of ms office for pc  in the office blanks production njdrcagt shourxyp
# install  bit version of ms office for pc  in the office blanks production
# pdujfybc bvfdnale
# microsoft outlook is not working for pdujfybc bvfdnale
# microsoft outlook is not working for
# nkademwy ihsepkwz
# i am trying to help nkademwy ihsepkwz log into oneteam to update his direct deposit information
# i am trying to help  log into oneteam to update his direct deposit information
# sdxjiwlq ynowzqfh
# please move client from office  to  per sdxjiwlq ynowzqfh
# please move client from office  to  per
# xaqzisrk ahbgjrqz
# setup new ws xaqzisrk ahbgjrqz
# setup new ws
# wptbgchj jutpdcqf
# reset passwords for wptbgchj jutpdcqf using password management tool password reset
# reset passwords for  using password management tool password reset
# rxpjomyf hvolsgqn
# setup new ws rxpjomyf hvolsgqn
# setup new ws
# pnwbkitv phbnwmkl
# setup new ws pnwbkitv phbnwmkl
# setup new ws
# wyighrjl xcwavhyu
# setup new ws wyighrjl xcwavhyu
# setup new ws
# beosjgxt mdevcqjk
# setup new ws beosjgxt mdevcqjk
# setup new ws
# eqtofwbm mojfbwds
# mobile device activation request for user eqtofwbm mojfbwds
# mobile device activation request for user
# pmqansex nvihmbwc
# ticket update for pmqansex nvihmbwc
# ticket update for
# bqdlegnp lnphmsco
# bqdlegnp lnphmscos password has expired please call him at
# s password has expired please call him at
# kebogxzp difnjlkp
# install pdf mailer kebogxzp difnjlkp
# install pdf mailer
# couskjgd uzojtkmh
# reset the password for couskjgd uzojtkmh on windows login
# reset the password for  on windows login
# couskjgd uzojtkmh
# reset passwords for couskjgd uzojtkmh using password management tool password reset
# reset passwords for  using password management tool password reset
# xosdfhbu gtbfkisl
# problems with computer ewew defective fp sectors xosdfhbu gtbfkisl
# problems with computer ewew defective fp sectors
# mnakehrf mvunqihf
# investment antrag mnakehrf mvunqihf new laptop request mnakehrf mvunqihf
# investment antrag  new laptop request
# ahlqgjwx wbsfavhg
# data backup and restore ahlqgjwx wbsfavhg
# data backup and restore
# aqstdryv flbnyqzc
# setup new ws aqstdryv flbnyqzc
# setup new ws
# jrigdbox bgyluoqn
# reset passwords for jrigdbox bgyluoqn using password management tool password reset
# reset passwords for  using password management tool password reset
# urgapyzt tnxiuram
# unlock account email in cell phone the user urgapyzt tnxiuramdnty id vaghyliort
# unlock account email in cell phone the user dnty id vaghyliort
# xwlcqfsr lbcqfnie
# xwlcqfsr lbcqfnie not able to open purchasing
#  not able to open purchasing
# nvawmlch ubyjolnc
# reset the password for nvawmlch ubyjolnc on erp production erp
# reset the password for  on erp production erp
# niptbwdq csenjruz
# slow computer checking niptbwdq csenjruz
# slow computer checking
# kebogxzp difnjlkp
# setup new ws kebogxzp difnjlkp
# setup new ws
# jionmpsf wnkpzcmv
# problems with screen saver we jionmpsf wnkpzcmv
# problems with screen saver we
# zlxcsqdg ckpojwir
# zlxcsqdg ckpojwir cannot see all his customer accounts in msd crm
#  cannot see all his customer accounts in msd crm
# obvyknzx gzvjtish
# reset the password for obvyknzx gzvjtish on erp production erp
# reset the password for  on erp production erp
# hugcadrn ixhlwdgt
# please remove user hugcadrn ixhlwdgt ralfteimp from palo alto quarantine
# please remove user  ralfteimp from palo alto quarantine
# hbmwlprq ilfvyodx
# ticket update on inc to user hbmwlprq ilfvyodx
# ticket update on inc to user

# %%
# df.to_excel("nonsense_sd.xlsx",index=True)

# %%
df.iloc[2709]['Description']
# Out:
# 'support for alicona jionmpsf wnkpzcmv'

# %%
df['Description'] = df['Description'].apply(replaceNonsenseWords)
# Out:
# ecwtrjnq jpecxuty
# call for ecwtrjnq jpecxuty
# call for
# dkmcfreg anwmfvlg
# received from hi the printer printer is not working and needs a part replaced can you reroute the jobs in queue to printer printer wihuyjdo qpogfwkb has indicated that prqos needs a new part and it may not deliver for a few days so the inwarehouse tools will need to print on printer for now this needs to be taken care of today since the inwarehouse tools are printed and are picked up by an outside vendor at   pm in usa on a daily basis please contact dkmcfreg anwmfvlgenkataramdntyana if you have questions about the jobs in queue for today
# received from hi the printer printer is not working and needs a part replaced can you reroute the jobs in queue to printer printer wihuyjdo qpogfwkb has indicated that prqos needs a new part and it may not deliver for a few days so the inwarehouse tools will need to print on printer for now this needs to be taken care of today since the inwarehouse tools are printed and are picked up by an outside vendor at   pm in usa on a daily basis please contact enkataramdntyana if you have questions about the jobs in queue for today
# ecwtrjnq jpecxuty
# call for ecwtrjnq jpecxuty
# call for
# cdbaoqts wqbsodni
# received from hello please reset my scm software password cdbaoqts wqbsodni global product manager markhtyeting initiatives
# received from hello please reset my scm software password  global product manager markhtyeting initiatives
# yhmwxsqj ugnthxky
# user yhmwxsqj ugnthxky having issues logging to outlook rgtry will be available tomorrow around   am he works out of company campus request you to reach out to him fix the issue
# user  having issues logging to outlook rgtry will be available tomorrow around   am he works out of company campus request you to reach out to him fix the issue
# noscwdpm akiowsmp
# received from hello he is an kiosk user please reset the password and confirm noscwdpm akiowsmp from ihkolepb ozhnjyef sent  october    to subject ess portal access issue hi below mentioned employee krlszbqo spimolgz with user id sv is not able to login to ess portal to access his pay slips and related contents he is a attendance tool user please reset his user id and password and revert back
# received from hello he is an kiosk user please reset the password and confirm  from ihkolepb ozhnjyef sent  october    to subject ess portal access issue hi below mentioned employee krlszbqo spimolgz with user id sv is not able to login to ess portal to access his pay slips and related contents he is a attendance tool user please reset his user id and password and revert back
# ihkolepb ozhnjyef
# received from hello he is an kiosk user please reset the password and confirm  from ihkolepb ozhnjyef sent  october    to subject ess portal access issue hi below mentioned employee krlszbqo spimolgz with user id sv is not able to login to ess portal to access his pay slips and related contents he is a attendance tool user please reset his user id and password and revert back
# received from hello he is an kiosk user please reset the password and confirm  from  sent  october    to subject ess portal access issue hi below mentioned employee krlszbqo spimolgz with user id sv is not able to login to ess portal to access his pay slips and related contents he is a attendance tool user please reset his user id and password and revert back
# tvcdfqgp nrbcqwgj
# from tvcdfqgp nrbcqwgj sent friday october     pm to nwfodmhc exurcwkm subject Your mobile device has been temporarily blocked from syncing via exchange activesync until your administrator authorizes access hi i received this message and our local it expert has told me to open a ticket
# from  sent friday october     pm to nwfodmhc exurcwkm subject Your mobile device has been temporarily blocked from syncing via exchange activesync until your administrator authorizes access hi i received this message and our local it expert has told me to open a ticket
# qifzkoej etbmgjvo
# qifzkoej etbmgjvo is unable to start his dell   in  tablet device
#  is unable to start his dell   in  tablet device
# wvngzrca sfmrzdth
# name wvngzrca sfmrzdth language browser microsoft internet explorer customer number summary good morning i am having trouble getting into my vpn can you assist
# name  language browser microsoft internet explorer customer number summary good morning i am having trouble getting into my vpn can you assist
# bwfhtumx japznrvb
# received from bwfhtumx japznrvb regional controller
# received from  regional controller
# yfqoaepn xnezhsit
# received from hello till last week i was accessing bex reports using mms portal and there were no issues starting this week the system is incredibly slow when i log in and finally does not allow me to access any reports can it be the issue with any maintenance or my access rights or rather i should try to access bex using different way below the print screen from what i see after log in i am also able to get to finance reports see below however when i click profitability analysis as i was always doing separate window is open however apart rom that the screen is blank i appreciate your support have a great day robhyertyj yfqoaepn xnezhsit managing director finance manager cee tel    mob     company polska sp z o o ul krzywoustego    pozna company polska sp z o o z siedzib w polandiu   pozna ul krzywoustego  sp ka zarejestrowana w s dzie rejonowym pozna nowe miasto i wilda w polandiu wydzia viii gospodarczy krs pod numerem  kapita zak adowy   pln nip
# received from hello till last week i was accessing bex reports using mms portal and there were no issues starting this week the system is incredibly slow when i log in and finally does not allow me to access any reports can it be the issue with any maintenance or my access rights or rather i should try to access bex using different way below the print screen from what i see after log in i am also able to get to finance reports see below however when i click profitability analysis as i was always doing separate window is open however apart rom that the screen is blank i appreciate your support have a great day robhyertyj  managing director finance manager cee tel    mob     company polska sp z o o ul krzywoustego    pozna company polska sp z o o z siedzib w polandiu   pozna ul krzywoustego  sp ka zarejestrowana w s dzie rejonowym pozna nowe miasto i wilda w polandiu wydzia viii gospodarczy krs pod numerem  kapita zak adowy   pln nip
# xdvwitpm zscxqdho
# from xdvwitpm zscxqdhoalaramdntyan sent friday october     am to cc xyculgav cuqptoah subject fw crm license for dfgry hello crm is not installed in my laptop please support me on this
# from alaramdntyan sent friday october     am to cc xyculgav cuqptoah subject fw crm license for dfgry hello crm is not installed in my laptop please support me on this
# xyculgav cuqptoah
# from alaramdntyan sent friday october     am to cc xyculgav cuqptoah subject fw crm license for dfgry hello crm is not installed in my laptop please support me on this
# from alaramdntyan sent friday october     am to cc  subject fw crm license for dfgry hello crm is not installed in my laptop please support me on this
# qmglkaru qiwhfkdv
# assign crm and e license to nyrjkctu tbhkenlo use profile like qmglkaru qiwhfkdv
# assign crm and e license to nyrjkctu tbhkenlo use profile like
# nyrjkctu tbhkenlo
# assign crm and e license to nyrjkctu tbhkenlo use profile like
# assign crm and e license to  use profile like
# xjzcbgnp vfkwscao
# received from from hdytrkfiu sent thursday october     pm to cc xjzcbgnp vfkwscao subject export shipment of grinding mahcine to khdgd apac advance information we are pushixepyfbga wtqdyoin for dispatching an grinding machine to khdgd apac tomorrow this is just for your advance information once everything is in place we will seek your support in your areas to help us in clearing this consignment tomorrow
# received from from hdytrkfiu sent thursday october     pm to cc  subject export shipment of grinding mahcine to khdgd apac advance information we are pushixepyfbga wtqdyoin for dispatching an grinding machine to khdgd apac tomorrow this is just for your advance information once everything is in place we will seek your support in your areas to help us in clearing this consignment tomorrow
# arexjftu ohxdwngl
# support for fa konnica arexjftu ohxdwngl
# support for fa konnica
# ecwtrjnq jpecxuty
# call for ecwtrjnq jpecxuty
# call for
# gtxuamif pamxszek
# production order  is locked by user gtxuamif pamxszek no one has been able to unlock can this order be unlocked inspection lot  is being processed by gtxuamif pamxszek
# production order  is locked by user  no one has been able to unlock can this order be unlocked inspection lot  is being processed by
# bwfhtumx japznrvb
# received from i could always get into the finance section and now i cant i need access please bwfhtumx japznrvb regional controller
# received from i could always get into the finance section and now i cant i need access please  regional controller
# iygsxftl hysrbgad
# iygsxftl hysrbgad set up a spare company owned iphone cause the old one was broken agreement and supervisors appoval is attached now his account is quarantined could you please activate his new device
#  set up a spare company owned iphone cause the old one was broken agreement and supervisors appoval is attached now his account is quarantined could you please activate his new device
# ayrhcfxi zartupsw
# ic welcome our next available agent will be with you shortly ic interaction alerting agent ic website visitor has joined the conversation ayrhcfxi zartupsw hi ayrhcfxi zartupsw
# ic welcome our next available agent will be with you shortly ic interaction alerting agent ic website visitor has joined the conversation  hi
# ayrhcfxi zartupsw
# ic welcome our next available agent will be with you shortly ic interaction alerting agent ic website visitor has joined the conversation ayrhcfxi zartupsw hello gstdy yrada hi ayrhcfxi zartupsw hello
# ic welcome our next available agent will be with you shortly ic interaction alerting agent ic website visitor has joined the conversation  hello gstdy yrada hi  hello
# ayrhcfxi zartupsw
# ic welcome our next available agent will be with you shortly ic interaction alerting agent ic website visitor has joined the conversation ayrhcfxi zartupsw hello
# ic welcome our next available agent will be with you shortly ic interaction alerting agent ic website visitor has joined the conversation  hello
# ayrhcfxi zartupsw
# ic welcome our next available agent will be with you shortly ic interaction alerting agent ic website visitor has joined the conversation tyss ashdtyf greetings ayrhcfxi zartupsw hi ayrhcfxi zartupsw
# ic welcome our next available agent will be with you shortly ic interaction alerting agent ic website visitor has joined the conversation tyss ashdtyf greetings  hi
# obanjrhg rnafleys
# name obanjrhg rnafleys language browser microsoft internet explorer customer number summary hello problem signing in to skype
# name  language browser microsoft internet explorer customer number summary hello problem signing in to skype
# fygrwuna gomcekzi
# please reset password for fygrwuna gomcekzi e mail please new password to manager
# please reset password for  e mail please new password to manager
# laeusvjo fvaihgpx
# problems with drive z laeusvjo fvaihgpx
# problems with drive z
# vkjdgtxb pkinmjqs
# from gstdy tehdy sent thursday october     am to vkjdgtxb pkinmjqs subject re fw access to e time dear
# from gstdy tehdy sent thursday october     am to  subject re fw access to e time dear
# fmzdkyqv dbrslnhe
# received from fmzdkyqv dbrslnhe director finance business company
# received from  director finance business company
# jionmpsf wnkpzcmv
# EU tool is very slow adgtym ywqgrbnx jwnsyzbv jionmpsf wnkpzcmv
# EU tool is very slow adgtym ywqgrbnx jwnsyzbv
# wrcktgbd wzrgyunp
# pick up old eq wrcktgbd wzrgyunp
# pick up old eq
# wrcktgbd wzrgyunp
# probleme lan an tgeyd we wu wrcktgbd wzrgyunp
# probleme lan an tgeyd we wu
# zlqfptjx xnklbfua
# support for we zlqfptjx xnklbfua
# support for we
# inhekdol anvqzdif
# received from hello username gdthryd mgvpoyqd tnlshpwb is locked out of his computer i am sending this message on his behalf please help inhekdol anvqzdif quality technologist
# received from hello username gdthryd mgvpoyqd tnlshpwb is locked out of his computer i am sending this message on his behalf please help  quality technologist
# mgvpoyqd tnlshpwb
# received from hello username gdthryd mgvpoyqd tnlshpwb is locked out of his computer i am sending this message on his behalf please help  quality technologist
# received from hello username gdthryd  is locked out of his computer i am sending this message on his behalf please help  quality technologist
# laeusvjo fvaihgpx
# install EU tool laeusvjo fvaihgpx
# install EU tool
# koahsriq wdugqatr
# received from hello the account nikulatrhdy is currently locked out the user cannot log on the system please help koahsriq wdugqatr administrative assistant
# received from hello the account nikulatrhdy is currently locked out the user cannot log on the system please help  administrative assistant
# ufgkybsh ijswtdve
# from ufgkybsh ijswtdve sent tuesday october     pm to nwfodmhc exurcwkm subject tgryds fw engineering tool upload issue dear sir mam please find below the screenshot of engineering tool issue faced during upload please help me to resolve the same
# from  sent tuesday october     pm to nwfodmhc exurcwkm subject tgryds fw engineering tool upload issue dear sir mam please find below the screenshot of engineering tool issue faced during upload please help me to resolve the same
# yscgjexz hxlbvjgf
# password reset for yscgjexz hxlbvjgf
# password reset for
# mqjdyizg amhywoqg
# Myhrt sthry retired as plant manager in usa i have replaced him i request access to his collaboration platform to copy relevant documents before it is being deleted as per e mail below from mqjdyizg amhywoqg sent saturday october     am to subject fw Myhrt sthrys collaboration platform for business contents will be preserved for  days danie you should follow up on this to see if there are any files you may need utejhdyd vice president and general manager from sent saturday october     am to mqjdyizg amhywoqg subject Myhrt sthrys collaboration platform for business contents will be preserved for  days Myhrt sthrys account has been deleted from the active directory their collaboration platform for business will be preserved for  days youre the temporary owner of all documents saved to their collaboration platform for business if you would like to save content beyond the  day retention period you can copy important documents to another location you can also contact your administrator to reassign ownership to another collaboration platform for business owner after  days Myhrt sthrys collaboration platform for business will be permanently deleted go to Myhrt sthrys collaboration platform for business at
# Myhrt sthry retired as plant manager in usa i have replaced him i request access to his collaboration platform to copy relevant documents before it is being deleted as per e mail below from  sent saturday october     am to subject fw Myhrt sthrys collaboration platform for business contents will be preserved for  days danie you should follow up on this to see if there are any files you may need utejhdyd vice president and general manager from sent saturday october     am to  subject Myhrt sthrys collaboration platform for business contents will be preserved for  days Myhrt sthrys account has been deleted from the active directory their collaboration platform for business will be preserved for  days youre the temporary owner of all documents saved to their collaboration platform for business if you would like to save content beyond the  day retention period you can copy important documents to another location you can also contact your administrator to reassign ownership to another collaboration platform for business owner after  days Myhrt sthrys collaboration platform for business will be permanently deleted go to Myhrt sthrys collaboration platform for business at
# bkzcfmse naslrwdb
# cannot open excel files from HostName  departments hrm pricing current pricing fy and bkzcfmse naslrwdb can files are slow to open or will freeze
# cannot open excel files from HostName  departments hrm pricing current pricing fy and  can files are slow to open or will freeze
# oncidblt ucewizyd
# received from trhsys hrydjs would like to recall the message incident ticket no has been assigned to oncidblt ucewizyd
# received from trhsys hrydjs would like to recall the message incident ticket no has been assigned to
# knlrgsiv cqvuexjz
# knlrgsiv cqvuexjz has e license
#  has e license
# gzhapcld fdigznbk
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access qasouhlc xkhsirtd gzhapcld fdigznbk ugyothfz ugrmkdhx raosetuv hmgwrkzb mfyivqes cpihaxbs thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar akisjtzm uvbmysgcbenezer qfrntose ivnhumzjalakrisyuhnyrtn thtudb ghtysui
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access qasouhlc xkhsirtd  ugyothfz ugrmkdhx raosetuv hmgwrkzb mfyivqes cpihaxbs thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar akisjtzm uvbmysgcbenezer qfrntose ivnhumzjalakrisyuhnyrtn thtudb ghtysui
# ugyothfz ugrmkdhx
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access qasouhlc xkhsirtd  ugyothfz ugrmkdhx raosetuv hmgwrkzb mfyivqes cpihaxbs thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar akisjtzm uvbmysgcbenezer qfrntose ivnhumzjalakrisyuhnyrtn thtudb ghtysui
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access qasouhlc xkhsirtd   raosetuv hmgwrkzb mfyivqes cpihaxbs thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar akisjtzm uvbmysgcbenezer qfrntose ivnhumzjalakrisyuhnyrtn thtudb ghtysui
# akisjtzm uvbmysgc
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access qasouhlc xkhsirtd   raosetuv hmgwrkzb mfyivqes cpihaxbs thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar akisjtzm uvbmysgcbenezer qfrntose ivnhumzjalakrisyuhnyrtn thtudb ghtysui
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access qasouhlc xkhsirtd   raosetuv hmgwrkzb mfyivqes cpihaxbs thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar benezer qfrntose ivnhumzjalakrisyuhnyrtn thtudb ghtysui
# raosetuv hmgwrkzb
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access qasouhlc xkhsirtd   raosetuv hmgwrkzb mfyivqes cpihaxbs thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar benezer qfrntose ivnhumzjalakrisyuhnyrtn thtudb ghtysui
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access qasouhlc xkhsirtd    mfyivqes cpihaxbs thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar benezer qfrntose ivnhumzjalakrisyuhnyrtn thtudb ghtysui
# qasouhlc xkhsirtd
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access qasouhlc xkhsirtd    mfyivqes cpihaxbs thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar benezer qfrntose ivnhumzjalakrisyuhnyrtn thtudb ghtysui
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access     mfyivqes cpihaxbs thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar benezer qfrntose ivnhumzjalakrisyuhnyrtn thtudb ghtysui
# qfrntose ivnhumzj
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access     mfyivqes cpihaxbs thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar benezer qfrntose ivnhumzjalakrisyuhnyrtn thtudb ghtysui
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access     mfyivqes cpihaxbs thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar benezer alakrisyuhnyrtn thtudb ghtysui
# mfyivqes cpihaxbs
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access     mfyivqes cpihaxbs thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar benezer alakrisyuhnyrtn thtudb ghtysui
# hello can you add the users below to as team members to the cybersecurity website i should have ownership users below can have edit access      thrdyd dhdtwdd thrdyakdj yhtdush jqeczxtn gfjcronyudhakar benezer alakrisyuhnyrtn thtudb ghtysui
# knlrgsiv cqvuexjz
# problems with portal knlrgsiv cqvuexjz
# problems with portal
# puxsvfwr cwkjruni
# setup rechner ewel f r hr thrydad third consulting puxsvfwr cwkjruni
# setup rechner ewel f r hr thrydad third consulting
# ughzilfm cfibdamq
# please reactivate account ewel laptop for a hr auditor account for trhfyd sugajadd is active please call back fyi by mfyivqes cpihaxbs Broadcast Tuesday October     PM to ughzilfm cfibdamq subject re please reactivate account ewel laptop for a hr auditor account for rhfyd sugajadd is active please call back Hello please open a ticker to help they can do that greetings
# please reactivate account ewel laptop for a hr auditor account for trhfyd sugajadd is active please call back fyi by mfyivqes cpihaxbs Broadcast Tuesday October     PM to  subject re please reactivate account ewel laptop for a hr auditor account for rhfyd sugajadd is active please call back Hello please open a ticker to help they can do that greetings
# mfyivqes cpihaxbs
# please reactivate account ewel laptop for a hr auditor account for trhfyd sugajadd is active please call back fyi by mfyivqes cpihaxbs Broadcast Tuesday October     PM to  subject re please reactivate account ewel laptop for a hr auditor account for rhfyd sugajadd is active please call back Hello please open a ticker to help they can do that greetings
# please reactivate account ewel laptop for a hr auditor account for trhfyd sugajadd is active please call back fyi by  Broadcast Tuesday October     PM to  subject re please reactivate account ewel laptop for a hr auditor account for rhfyd sugajadd is active please call back Hello please open a ticker to help they can do that greetings
# bmudkpie qolrvbip
# the following sales managers cannot see the sales manager views in business objects explorer tcflirwg ojflyruq bmudkpie qolrvbip thryd athrdyau vksfrhdx njhaqket please check their security and settings with respect to bobj
# the following sales managers cannot see the sales manager views in business objects explorer tcflirwg ojflyruq  thryd athrdyau vksfrhdx njhaqket please check their security and settings with respect to bobj
# qnxfegjw rljdhmwb
# reset passwords for qnxfegjw rljdhmwb using password management tool password reset
# reset passwords for  using password management tool password reset
# tmqfjard qzhgdoua
# problems with erpgui tmqfjard qzhgdoua
# problems with erpgui
# laeusvjo fvaihgpx
# support for fa thrydsss funke laeusvjo fvaihgpx
# support for fa thrydsss funke
# vepxdgot poezmwny
# replace illustrated tape printer we vepxdgot poezmwny
# replace illustrated tape printer we
# bmudkpie qolrvbip
# received from team my sales managers are not seeing their team view in bobj anymore global access they need it to pull data analysis can you please reinstall global access for tcflirwg ojflyruq bmudkpie qolrvbip thryd adwjfpbreu vksfrhdx njhaqket
# received from team my sales managers are not seeing their team view in bobj anymore global access they need it to pull data analysis can you please reinstall global access for tcflirwg ojflyruq  thryd adwjfpbreu vksfrhdx njhaqket
# dbwkxalj cnhgysju
# name dbwkxalj cnhgysju language browser microsoft internet explorer customer number summary the users account is blocked now
# name  language browser microsoft internet explorer customer number summary the users account is blocked now
# mitgckqf ewourgcx
# name mitgckqf ewourgcx language browser microsoft internet explorer customer number summary i can not reach to password management tool password manager to change my password
# name  language browser microsoft internet explorer customer number summary i can not reach to password management tool password manager to change my password
# melhduty gqchtedl
# please provide details of the issue      melhduty gqchtedl hi My computer mailbox cant be opened Can you help me Thank you      melhduty gqchtedl Show system error Cannot create a new stack guard page      obuwfnkm ufpwmybi Share your desktop with me      melhduty gqchtedl id
# please provide details of the issue       hi My computer mailbox cant be opened Can you help me Thank you       Show system error Cannot create a new stack guard page      obuwfnkm ufpwmybi Share your desktop with me       id
# obuwfnkm ufpwmybi
# please provide details of the issue       hi My computer mailbox cant be opened Can you help me Thank you       Show system error Cannot create a new stack guard page      obuwfnkm ufpwmybi Share your desktop with me       id
# please provide details of the issue       hi My computer mailbox cant be opened Can you help me Thank you       Show system error Cannot create a new stack guard page       Share your desktop with me       id
# qpixeudn rjlziysd
# please create an purchasingupstreamsso and ad for qpixeudn rjlziysd bachsdadgtadw the samaccountname in ad is to be all lowercase
# please create an purchasingupstreamsso and ad for  bachsdadgtadw the samaccountname in ad is to be all lowercase
# tbvpkjoh wnxzhqoa
# received from i need access to the following path please see pmgzjikq potmrkxy for approval tbvpkjoh wnxzhqoa company usa plant controller
# received from i need access to the following path please see pmgzjikq potmrkxy for approval  company usa plant controller
# zuyimtsf qjtimdsp
# hi team could you please unlock account the user aeftjxos lhnyofad id vvsardkajdjtf case this account was expired please extend the access for the account the manager this user is zuyimtsf qjtimdsp please contact majsdtnrio or if you have more doubts please return me
# hi team could you please unlock account the user aeftjxos lhnyofad id vvsardkajdjtf case this account was expired please extend the access for the account the manager this user is  please contact majsdtnrio or if you have more doubts please return me
# rjsulvat uanigkqc
# from rjsulvat uanigkqc sent monday october     pm to nwfodmhc exurcwkm subject thadasgg fwd problem with outlook it is again sent from iphone start of forwarded message from rjsulvat uanigkqc to nwfodmhc exurcwkm topic problem with outlook hello i cannot start outlook sent from iphone
# from  sent monday october     pm to nwfodmhc exurcwkm subject thadasgg fwd problem with outlook it is again sent from iphone start of forwarded message from  to nwfodmhc exurcwkm topic problem with outlook hello i cannot start outlook sent from iphone
# oinqckds qieswrfu
# hello the username ccghksdm will be used to login to company via citrix i assume that we need to delete this user profile on the citrix servers so please send a ticket to the citrix team because his account in active directory is not locked oinqckds qieswrfu manager gesendet dienstag  oktober    an oinqckds qieswrfu betreff password hi can you please reset my account so i can login again my user is ccghksdm my last password was prbsddqd it doesnt work so i cant login at the moment
# hello the username ccghksdm will be used to login to company via citrix i assume that we need to delete this user profile on the citrix servers so please send a ticket to the citrix team because his account in active directory is not locked  manager gesendet dienstag  oktober    an  betreff password hi can you please reset my account so i can login again my user is ccghksdm my last password was prbsddqd it doesnt work so i cant login at the moment
# hybegvwo dbgrtqhs
# hello colleagues would you please be so kind and activate the new iphone of hybegvwo dbgrtqhs company kstdaddaad details please see mail below many
# hello colleagues would you please be so kind and activate the new iphone of  company kstdaddaad details please see mail below many
# eluvxqhw gpbfkqeu
# hello a k ndigung for eluvxqhw gpbfkqeu  effective    has been approved
# hello a k ndigung for   effective    has been approved
# uzpycdho hdswinlo
# from nwfodmhc exurcwkm sent monday october     pm to uzpycdho hdswinlo ustvaifg hmzfewks subject uzpycdho hdswinlo your windows password is expiring soon hi unfortunately it is an automatic process we cannot extend the time period once you come back from vacation please give us a call back we will reset the password for you
# from nwfodmhc exurcwkm sent monday october     pm to  ustvaifg hmzfewks subject  your windows password is expiring soon hi unfortunately it is an automatic process we cannot extend the time period once you come back from vacation please give us a call back we will reset the password for you
# ustvaifg hmzfewks
# from nwfodmhc exurcwkm sent monday october     pm to  ustvaifg hmzfewks subject  your windows password is expiring soon hi unfortunately it is an automatic process we cannot extend the time period once you come back from vacation please give us a call back we will reset the password for you
# from nwfodmhc exurcwkm sent monday october     pm to   subject  your windows password is expiring soon hi unfortunately it is an automatic process we cannot extend the time period once you come back from vacation please give us a call back we will reset the password for you
# xabkyoug wdkyiqfx
# received from hi team below is the hub posting to be published for us time change aerp revert if you have any questions planned service disruption what is the event daylight savings time ends in u s when does it begin   pm edt saturday th november  when does it end following time change   am est sunday  november  who and what will be affected all erp users all erp systems including erp plm bw crm supply chain hcm what is the reason all erp systems must be stopped during time change to prevent data inconsistency questions corporate datacenter xabkyoug wdkyiqfx nvyjtmca xjhpznds network operations best
# received from hi team below is the hub posting to be published for us time change aerp revert if you have any questions planned service disruption what is the event daylight savings time ends in u s when does it begin   pm edt saturday th november  when does it end following time change   am est sunday  november  who and what will be affected all erp users all erp systems including erp plm bw crm supply chain hcm what is the reason all erp systems must be stopped during time change to prevent data inconsistency questions corporate datacenter  nvyjtmca xjhpznds network operations best
# dctvfjrn oypnxftq
# name dctvfjrn oypnxftq language browser microsoft internet explorer customer number telephone summary reset the password for aolhgbps pbxqtcek uacyltoe hxgayczemii
# name  language browser microsoft internet explorer customer number telephone summary reset the password for aolhgbps pbxqtcek uacyltoe hxgayczemii
# lwizucan zvnxlobq
# received from hallo my outlook collapsed two times i tried to restart my laptop but it doesnt startup anymore restarting is on my screen for already half an hour image jpg met vriendelijke groet lwizucan zvnxlobq directeur company
# received from hallo my outlook collapsed two times i tried to restart my laptop but it doesnt startup anymore restarting is on my screen for already half an hour image jpg met vriendelijke groet  directeur company
# mgvpoyqd tnlshpwb
# reset passwords for mgvpoyqd tnlshpwb using password management tool password reset
# reset passwords for  using password management tool password reset
# gqhfieys pkwcdbrv
# name gqhfieys pkwcdbrv language browser microsoft internet explorer customer number telephone summary ts printer still not working after system restart
# name  language browser microsoft internet explorer customer number telephone summary ts printer still not working after system restart
# qvncizuf ueiybanz
# problems with fuser unit we qvncizuf ueiybanz
# problems with fuser unit we
# efrjkspc sfhbunrp
# from efrjkspc sfhbunrp sent monday october     am to nwfodmhc exurcwkm subject aw efrjkspc sfhbunrp your windows password is expiring soon importance high hello i have changed my password a few day days ago why get i this reminder please inform me if i have change again
# from  sent monday october     am to nwfodmhc exurcwkm subject aw  your windows password is expiring soon importance high hello i have changed my password a few day days ago why get i this reminder please inform me if i have change again
# tqnbkjgu xyedbsnm
# name tqnbkjgu xyedbsnm language browser microsoft internet explorer customer number telephone summary uacyltoe hxgaycze
# name  language browser microsoft internet explorer customer number telephone summary uacyltoe hxgaycze
# tqnbkjgu xyedbsnm
# tqnbkjgu xyedbsnm reported that he and his colleagues are unable to reach gso using the chat when they fill out the form the next page comes up only with the company logo
#  reported that he and his colleagues are unable to reach gso using the chat when they fill out the form the next page comes up only with the company logo
# hybegvwo dbgrtqhs
# received from hello colleagues would you please be so kind and activate the new iphone of hybegvwo dbgrtqhs company sdjdskjdkyr details please see mail below many
# received from hello colleagues would you please be so kind and activate the new iphone of  company sdjdskjdkyr details please see mail below many
# bfnvjgxd trqmnpvu
# reset passwords for bfnvjgxd trqmnpvu using password management tool password reset
# reset passwords for  using password management tool password reset
# dtlmbcrx mwuateyx
# problems with lan for computer erosion machine dtlmbcrx mwuateyx
# problems with lan for computer erosion machine
# lewbzysd gqdaikbv
# the following area codes below are being routed from our line to tyuhfljp zyjfpgtk when someone calls the help desk line they should be routed to lewbzysd gqdaikbv can you please check the routing area codes    group  dnis
# the following area codes below are being routed from our line to tyuhfljp zyjfpgtk when someone calls the help desk line they should be routed to  can you please check the routing area codes    group  dnis
# tyuhfljp zyjfpgtk
# the following area codes below are being routed from our line to tyuhfljp zyjfpgtk when someone calls the help desk line they should be routed to  can you please check the routing area codes    group  dnis
# the following area codes below are being routed from our line to  when someone calls the help desk line they should be routed to  can you please check the routing area codes    group  dnis
# wauhocsk vxuikqaf
# from wauhocsk vxuikqaf sent sunday october     pm to nwfodmhc exurcwkm cc lxrponic lyszwcxg ranlpbmw djwkylif subject fw impact awards dear sirs please be so kind and help i have been asking hr but they told me that you are the right people to talk to there have been done change on the position of director sales theeadjjd and we when sales managers from theeadjjd direct side are plugging in impact award points the approver is still ranlpbmw djwkylif should be wauhocsk vxuikqaf and i guess same issue might be with we wester europe there was a change of sales director as well we original sd crohuani dtjvhyob we new sd ranlpbmw djwkylif eseer original sd ranlpbmw djwkylif eseer new sd wauhocsk vxuikqaf would you be so kind and help us please in case you need more info let me know
# from  sent sunday october     pm to nwfodmhc exurcwkm cc lxrponic lyszwcxg ranlpbmw djwkylif subject fw impact awards dear sirs please be so kind and help i have been asking hr but they told me that you are the right people to talk to there have been done change on the position of director sales theeadjjd and we when sales managers from theeadjjd direct side are plugging in impact award points the approver is still ranlpbmw djwkylif should be  and i guess same issue might be with we wester europe there was a change of sales director as well we original sd crohuani dtjvhyob we new sd ranlpbmw djwkylif eseer original sd ranlpbmw djwkylif eseer new sd  would you be so kind and help us please in case you need more info let me know
# fdbgoamk hygxzkla
# from fdbgoamk hygxzklauthuchidambaramdnty sent sunday october     pm to nwfodmhc exurcwkm subject fw your mobile device is temporarily blocked from synchronizing using exchange activesync until your administrator usas it access please provide access for mails in my mobile phone
# from uthuchidambaramdnty sent sunday october     pm to nwfodmhc exurcwkm subject fw your mobile device is temporarily blocked from synchronizing using exchange activesync until your administrator usas it access please provide access for mails in my mobile phone
# bwfhtumx japznrvb
# received from i cannot get the data model to work in my excel bwfhtumx japznrvb regional controller
# received from i cannot get the data model to work in my excel  regional controller
# tsicojkp kghaozew
# received from there is an employee that has been terminated    who still has access to company email on his personal device aylrbosw gaeycbwd tsicojkp kghaozew commodity manager
# received from there is an employee that has been terminated    who still has access to company email on his personal device aylrbosw gaeycbwd  commodity manager
# aylrbosw gaeycbwd
# received from there is an employee that has been terminated    who still has access to company email on his personal device aylrbosw gaeycbwd  commodity manager
# received from there is an employee that has been terminated    who still has access to company email on his personal device   commodity manager
# tskvmwag awkrdqzb
# received from hello crm plug in buttons are not staying checked when i close outlook i lose the crm function in my outlook when i close the programdnty please see attached screen shot tskvmwag awkrdqzb sr sales engineer nc north central region
# received from hello crm plug in buttons are not staying checked when i close outlook i lose the crm function in my outlook when i close the programdnty please see attached screen shot  sr sales engineer nc north central region
# inxsupmy zhwmifvx
# received from hello team can you please create a business partner id for bertsckaadyd in solution manager inxsupmy zhwmifvx team lead sourcing logistics global it
# received from hello team can you please create a business partner id for bertsckaadyd in solution manager  team lead sourcing logistics global it
# slrgconp onukdesq
# name slrgconp onukdesq language browser microsoft internet explorer customer number telephone summary i opened a ticket this morning who is it assigned to
# name  language browser microsoft internet explorer customer number telephone summary i opened a ticket this morning who is it assigned to
# dfetvmzq brxavtzp
# from dpuifqeo eglwsfkn sent friday october     pm to nwfodmhc exurcwkm shkdwd dlwdwd cc dfetvmzq brxavtzp subject re purchasing dfetvmzq brxavtzp the email address on this profile is incorrect please change to also need to add the company catalog to her profile
# from dpuifqeo eglwsfkn sent friday october     pm to nwfodmhc exurcwkm shkdwd dlwdwd cc  subject re purchasing  the email address on this profile is incorrect please change to also need to add the company catalog to her profile
# dpuifqeo eglwsfkn
# from dpuifqeo eglwsfkn sent friday october     pm to nwfodmhc exurcwkm shkdwd dlwdwd cc  subject re purchasing  the email address on this profile is incorrect please change to also need to add the company catalog to her profile
# from  sent friday october     pm to nwfodmhc exurcwkm shkdwd dlwdwd cc  subject re purchasing  the email address on this profile is incorrect please change to also need to add the company catalog to her profile
# dtlmbcrx mwuateyx
# printer in lion uacyltoe hxgayczeraum knicrhtyt paper dtlmbcrx mwuateyx
# printer in lion uacyltoe hxgayczeraum knicrhtyt paper
# lndypaqg dhqwtcsr
# reinstall hardcopy und EU tool lndypaqg dhqwtcsr
# reinstall hardcopy und EU tool
# vzqomdgt jwoqbuml
# we only outputs an error message register in the network register the network settings not all processes can be completed wait a moment vzqomdgt jwoqbuml
# we only outputs an error message register in the network register the network settings not all processes can be completed wait a moment
# xosdfhbu gtbfkisl
# calculator for length measuring machine uacyltoe hxgayczeen xosdfhbu gtbfkisl
# calculator for length measuring machine uacyltoe hxgayczeen
# koahsriq wdugqatr
# received from hello we need a new pc name service tag of the pc is fynkssc koahsriq wdugqatr administrative assistant company ooo vavilova  corp  russia  russia
# received from hello we need a new pc name service tag of the pc is fynkssc  administrative assistant company ooo vavilova  corp  russia  russia
# pfjwinbg ljtzbdqg
# backup for computer lasplant  pfjwinbg ljtzbdqg
# backup for computer lasplant
# wgpimkle kijhcwur
# from wgpimkle kijhcwur sent friday october     am to nwfodmhc exurcwkm subject rad bex error help desk i got below error message when i ran rrmx through SID  please fix the issue
# from  sent friday october     am to nwfodmhc exurcwkm subject rad bex error help desk i got below error message when i ran rrmx through SID  please fix the issue
# lpoebzsc grknswyo
# please usa sasqkjqh lwddkqddq access to printer cl ps per lpoebzsc grknswyo
# please usa sasqkjqh lwddkqddq access to printer cl ps per
# ifblxjmc dyrgfwbm
# received from good afternoon can you please add a new library heading talent review to the library area can you also remove kristina cope as the owner of this portion of this page please use myself mtdyuhki fdnrxaci and ifblxjmc dyrgfwbm to this page
# received from good afternoon can you please add a new library heading talent review to the library area can you also remove kristina cope as the owner of this portion of this page please use myself mtdyuhki fdnrxaci and  to this page
# axcbfuqo yiagubvh
# axcbfuqo yiagubvh no longer has access to http bddjwwwdw he needs access please see the attached email from gilles good morning there is a very long time that i did not contacted the team and you i am in india for  weeks and work with the team using the new equipment i need your help because i am not anymore able to be connected to application where i was able to make a consultation i received this following message can you help to have this connection working again i have also the competitive databse but this is still working well
#  no longer has access to http bddjwwwdw he needs access please see the attached email from gilles good morning there is a very long time that i did not contacted the team and you i am in india for  weeks and work with the team using the new equipment i need your help because i am not anymore able to be connected to application where i was able to make a consultation i received this following message can you help to have this connection working again i have also the competitive databse but this is still working well
# gsotqxfi lidunfjg
# hi team i need your help with two error the customization the engineering tool the two errors attachment in ticket erro computer lpawty diwhdd jwddkwor and lpawty gsotqxfi lidunfjg if you have more doubts please contatc me
# hi team i need your help with two error the customization the engineering tool the two errors attachment in ticket erro computer lpawty diwhdd jwddkwor and lpawty  if you have more doubts please contatc me
# dxwuovgs lmuxizht
# received from hello is outlook down i cant seem to connect on laptop remotely please advise sent from my iphone dxwuovgs lmuxizht sr sales engineer
# received from hello is outlook down i cant seem to connect on laptop remotely please advise sent from my iphone  sr sales engineer
# ecwtrjnq jpecxuty
# called in to get in touch with ecwtrjnq jpecxuty
# called in to get in touch with
# xwirzvda okhyipgr
# support for roboworker sandblasting xwirzvda okhyipgr
# support for roboworker sandblasting
# lndypaqg dhqwtcsr
# setup new ws lndypaqg dhqwtcsr
# setup new ws
# xvwchsdg pladjmxt
# production order printer mp is being replaced remove rerouting from mp to mp on erp systems printer replacement you will need to have power network connectivity and the printer installed ready before a ticketing tool ticket can be opened do you have all  requirements above satisfied yes no yes replacing erp printer name e g hq id wy mp name stays the same ip address s if known     ip stays the same make model of the replacement erp printer hp laserjet  mf what erp printer do you currently use e g hq id wy list the erp system the printer needs to be defined erp SID  SID  SID  SID  SID  SID  hrp plm etc hrp SID  plm same as old mp what is currently printed on these printers from erp e g inwarehouse tools delivery notes etc same as old mp location of install country city building floor cubicle same as old mp local it site contact name xvwchsdg pladjmxt optional printer serial number printer mac address serial cnctft
# production order printer mp is being replaced remove rerouting from mp to mp on erp systems printer replacement you will need to have power network connectivity and the printer installed ready before a ticketing tool ticket can be opened do you have all  requirements above satisfied yes no yes replacing erp printer name e g hq id wy mp name stays the same ip address s if known     ip stays the same make model of the replacement erp printer hp laserjet  mf what erp printer do you currently use e g hq id wy list the erp system the printer needs to be defined erp SID  SID  SID  SID  SID  SID  hrp plm etc hrp SID  plm same as old mp what is currently printed on these printers from erp e g inwarehouse tools delivery notes etc same as old mp location of install country city building floor cubicle same as old mp local it site contact name  optional printer serial number printer mac address serial cnctft
# usalikfj lfmpxbcn
# setup new ws in br usalikfj lfmpxbcn
# setup new ws in br
# trgqbeax hfyzudql
# received from please restore the complete file HostName  hr fd employees trainees including all files under apprentices thank you best regards trgqbeax hfyzudql
# received from please restore the complete file HostName  hr fd employees trainees including all files under apprentices thank you best regards
# rxoynvgi ntgdsehl
# from kwddwdw hudfefwe sent thursday october     am to nwfodmhc exurcwkm cc rxoynvgi ntgdsehl gzawrocy shbgwxeparamdnty subject fw mm  iak urgent it help please help check its urgent din in future please raise such issue to our it as well ap logistics manager e from rxoynvgi ntgdsehl sent thursday october     am to gzawrocy shbgwxeparamdnty johthryugftyson hu cc kmvwxdti uaoyhcep subject re mm  iak hi morning this issue still not solve yet i still encounter same issue the net weight higher than gross weight net weight   kgs and physical gross weight   kgs but in erp SID  vln shown it is correct attached for your reference hi morning need your advice on this issue this is issue happen since last thursday still not solve yet attached email flow for your reference ksjfye fekfeealleh operation supervisor email from sent wednesday october     pm to gzawrocy shbgwxeparamdnty cc kmvwxdti uaoyhcep rxoynvgi ntgdsehl subject aw mm  iak hello it s done have a nice day mit freundlichen gr en best
# ...
# jdlxkygf wlzqaivr
# from qekdgaim wagshrzl sent saturday august     am to nwfodmhc exurcwkm subject amar help with mss worklist since manager left company hi i am writing on behalf of jdlxkygf wlzqaivr and mikhghytr ramdntysey  jdlxkygf wlzqaivr davidthds former manager and expense report approver gergrythg bigleman is no longer with the company davidthd has an expense report in gergrythgs queue  how does mikhghytr ramdntysey get access to that to approve and or forward to the correct manager  how can we ensure there are no other requests in gergrythgs universal worklist note our office will be closed monday september   for the labor day holiday best
# from qekdgaim wagshrzl sent saturday august     am to nwfodmhc exurcwkm subject amar help with mss worklist since manager left company hi i am writing on behalf of  and mikhghytr ramdntysey   davidthds former manager and expense report approver gergrythg bigleman is no longer with the company davidthd has an expense report in gergrythgs queue  how does mikhghytr ramdntysey get access to that to approve and or forward to the correct manager  how can we ensure there are no other requests in gergrythgs universal worklist note our office will be closed monday september   for the labor day holiday best
# qekdgaim wagshrzl
# from qekdgaim wagshrzl sent saturday august     am to nwfodmhc exurcwkm subject amar help with mss worklist since manager left company hi i am writing on behalf of  and mikhghytr ramdntysey   davidthds former manager and expense report approver gergrythg bigleman is no longer with the company davidthd has an expense report in gergrythgs queue  how does mikhghytr ramdntysey get access to that to approve and or forward to the correct manager  how can we ensure there are no other requests in gergrythgs universal worklist note our office will be closed monday september   for the labor day holiday best
# from  sent saturday august     am to nwfodmhc exurcwkm subject amar help with mss worklist since manager left company hi i am writing on behalf of  and mikhghytr ramdntysey   davidthds former manager and expense report approver gergrythg bigleman is no longer with the company davidthd has an expense report in gergrythgs queue  how does mikhghytr ramdntysey get access to that to approve and or forward to the correct manager  how can we ensure there are no other requests in gergrythgs universal worklist note our office will be closed monday september   for the labor day holiday best
# urgapyzt tnxiuram
# hello team could you please unlock account email in cell phone the user urgapyzt tnxiuramdnty id vaghyliort
# hello team could you please unlock account email in cell phone the user dnty id vaghyliort
# tgewaniq yepifgbl
# wesley tomlin wilsfgtjl verboncouer markhty a verboma current manager tgewaniq yepifgbl does this need a change in mapping chefgtnp mason bengtjamin masonb current manager tgewaniq yepifgbl does this need a change in mapping chefgtnp
# wesley tomlin wilsfgtjl verboncouer markhty a verboma current manager  does this need a change in mapping chefgtnp mason bengtjamin masonb current manager  does this need a change in mapping chefgtnp
# itslpwra vybdkuoa
# mys ptmjvysi vkrepcybwa please confirm to change to itslpwra vybdkuoa wilsfgtjl mikhghytr rushethryli wilsfgtjl talryhtir michghytuael tayloml current manager andrdgrtew c mohnrysu does this need a change in mapping mondhrbaz
# mys ptmjvysi vkrepcybwa please confirm to change to  wilsfgtjl mikhghytr rushethryli wilsfgtjl talryhtir michghytuael tayloml current manager andrdgrtew c mohnrysu does this need a change in mapping mondhrbaz
# itslpwra vybdkuoa
# wiksufty jimdghty l manager so i believe this user id does not need changes zazrtulds carmer craigfgh cardfrmeca please confirm to change to itslpwra vybdkuoa wilsfgtjl povich trtgoy mgr povictcfgt current manager andrdgrtew c mohnrysu does this need a change in mapping mondhrbaz mohnrysu andrdgrtew current manager johthryu c marftgytin does this need a change in mapping magtyrtijc
# wiksufty jimdghty l manager so i believe this user id does not need changes zazrtulds carmer craigfgh cardfrmeca please confirm to change to  wilsfgtjl povich trtgoy mgr povictcfgt current manager andrdgrtew c mohnrysu does this need a change in mapping mondhrbaz mohnrysu andrdgrtew current manager johthryu c marftgytin does this need a change in mapping magtyrtijc
# xwlcqfsr lbcqfnie
# xwlcqfsr lbcqfnie phone  having a problem with purchasing access email attached addressing the issue please contract keith to resolve
#  phone  having a problem with purchasing access email attached addressing the issue please contract keith to resolve
# ugyothfz ugrmkdhx
# from ugyothfz ugrmkdhx sent friday august     pm to ed pasgryowski rxuobtjg grcmqaxd tiyhum kuyiomar hqbxstoy mdjftxli dfupksnr drnqjzph epilwzux qjhitbcr zarlgjes nxjvzcta kzishqfu bmdawzoi cc kathght shfhyw sadmin hnynhsth jsuyhwssad qfrntose ivnhumzjalakrisyuhnyrtn subject spoof email issue hello all
# from  sent friday august     pm to ed pasgryowski rxuobtjg grcmqaxd tiyhum kuyiomar hqbxstoy mdjftxli dfupksnr drnqjzph epilwzux qjhitbcr zarlgjes nxjvzcta kzishqfu bmdawzoi cc kathght shfhyw sadmin hnynhsth jsuyhwssad qfrntose ivnhumzjalakrisyuhnyrtn subject spoof email issue hello all
# zarlgjes nxjvzcta
# from  sent friday august     pm to ed pasgryowski rxuobtjg grcmqaxd tiyhum kuyiomar hqbxstoy mdjftxli dfupksnr drnqjzph epilwzux qjhitbcr zarlgjes nxjvzcta kzishqfu bmdawzoi cc kathght shfhyw sadmin hnynhsth jsuyhwssad qfrntose ivnhumzjalakrisyuhnyrtn subject spoof email issue hello all
# from  sent friday august     pm to ed pasgryowski rxuobtjg grcmqaxd tiyhum kuyiomar hqbxstoy mdjftxli dfupksnr drnqjzph epilwzux qjhitbcr  kzishqfu bmdawzoi cc kathght shfhyw sadmin hnynhsth jsuyhwssad qfrntose ivnhumzjalakrisyuhnyrtn subject spoof email issue hello all
# rxuobtjg grcmqaxd
# from  sent friday august     pm to ed pasgryowski rxuobtjg grcmqaxd tiyhum kuyiomar hqbxstoy mdjftxli dfupksnr drnqjzph epilwzux qjhitbcr  kzishqfu bmdawzoi cc kathght shfhyw sadmin hnynhsth jsuyhwssad qfrntose ivnhumzjalakrisyuhnyrtn subject spoof email issue hello all
# from  sent friday august     pm to ed pasgryowski  tiyhum kuyiomar hqbxstoy mdjftxli dfupksnr drnqjzph epilwzux qjhitbcr  kzishqfu bmdawzoi cc kathght shfhyw sadmin hnynhsth jsuyhwssad qfrntose ivnhumzjalakrisyuhnyrtn subject spoof email issue hello all
# qfrntose ivnhumzj
# from  sent friday august     pm to ed pasgryowski  tiyhum kuyiomar hqbxstoy mdjftxli dfupksnr drnqjzph epilwzux qjhitbcr  kzishqfu bmdawzoi cc kathght shfhyw sadmin hnynhsth jsuyhwssad qfrntose ivnhumzjalakrisyuhnyrtn subject spoof email issue hello all
# from  sent friday august     pm to ed pasgryowski  tiyhum kuyiomar hqbxstoy mdjftxli dfupksnr drnqjzph epilwzux qjhitbcr  kzishqfu bmdawzoi cc kathght shfhyw sadmin hnynhsth jsuyhwssad alakrisyuhnyrtn subject spoof email issue hello all
# hqbxstoy mdjftxli
# from  sent friday august     pm to ed pasgryowski  tiyhum kuyiomar hqbxstoy mdjftxli dfupksnr drnqjzph epilwzux qjhitbcr  kzishqfu bmdawzoi cc kathght shfhyw sadmin hnynhsth jsuyhwssad alakrisyuhnyrtn subject spoof email issue hello all
# from  sent friday august     pm to ed pasgryowski  tiyhum kuyiomar  dfupksnr drnqjzph epilwzux qjhitbcr  kzishqfu bmdawzoi cc kathght shfhyw sadmin hnynhsth jsuyhwssad alakrisyuhnyrtn subject spoof email issue hello all
# niptbwdq csenjruz
# slow computer checking niptbwdq csenjruz
# slow computer checking
# kebogxzp difnjlkp
# setup new ws kebogxzp difnjlkp
# setup new ws
# jionmpsf wnkpzcmv
# problems with screen saver we jionmpsf wnkpzcmv
# problems with screen saver we
# qkmgtnla buraxcij
# summary i need acces to run bex reports showing margins it should be the same access as qkmgtnla buraxcij pqkthilr uitfqsen also i also had erp business objects loaded onto my machine however it does not work i get the following message the launcher is exited with error see log file for more details the analysis add in is not registered correctly
# summary i need acces to run bex reports showing margins it should be the same access as  pqkthilr uitfqsen also i also had erp business objects loaded onto my machine however it does not work i get the following message the launcher is exited with error see log file for more details the analysis add in is not registered correctly
# pqkthilr uitfqsen
# summary i need acces to run bex reports showing margins it should be the same access as  pqkthilr uitfqsen also i also had erp business objects loaded onto my machine however it does not work i get the following message the launcher is exited with error see log file for more details the analysis add in is not registered correctly
# summary i need acces to run bex reports showing margins it should be the same access as   also i also had erp business objects loaded onto my machine however it does not work i get the following message the launcher is exited with error see log file for more details the analysis add in is not registered correctly
# zjcsqtdn jikyworg
# telephony software automated status update user zjcsqtdn jikyworg activated the screen saver by pressing windows l gabryltkla maier germany warehouse were calling her the phone was ringing and christgrytas status was changed to acd agent not answering automatically by loging on again the status was remaining at acd agent not answering call id  as we facing that gap occationally would you please let us know if we could have the status changing back again to available automatically
# telephony software automated status update user  activated the screen saver by pressing windows l gabryltkla maier germany warehouse were calling her the phone was ringing and christgrytas status was changed to acd agent not answering automatically by loging on again the status was remaining at acd agent not answering call id  as we facing that gap occationally would you please let us know if we could have the status changing back again to available automatically
# wckrxovs aunsgzmd
# the printer is at wckrxovs aunsgzmds place
# the printer is at s place
# djpwfxzt cfkwxlmq
# turn off telephony software for turkey between     local time due to meeting approved by djpwfxzt cfkwxlmq
# turn off telephony software for turkey between     local time due to meeting approved by
# uxndyfrs vahxnfgl
# from uxndyfrs vahxnfgl sent friday august     am to nwfodmhc exurcwkm subject rad fw calculation of the claim amount will make a mistake hi calculation of the claim amount will make a mistake please fix this the total amount of money usd  best
# from  sent friday august     am to nwfodmhc exurcwkm subject rad fw calculation of the claim amount will make a mistake hi calculation of the claim amount will make a mistake please fix this the total amount of money usd  best
# ntydihzo aeptfbgs
# from ntydihzo aeptfbgs sent friday august     am to nwfodmhc exurcwkm subject wg the synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator importance high hi it help team please unblock my new company device
# from  sent friday august     am to nwfodmhc exurcwkm subject wg the synchronization with exchange activesync is temporarily blocked on your device until access is granted by the administrator importance high hi it help team please unblock my new company device
# kzbuhixt zjdmoahr
# from mikhghytr wafglhdrhjop sent thursday august     pm to nwfodmhc exurcwkm subject rak fw ethics collaboration platform site please review your recent ticketing tool tickets and let me know who modified the ethics collaboration platform site a few weeks ago i had requested a change that placed a third column of selections not sure who or why this was undone mikhghytr wafglhdrhjop sr manager global ethics and compliance programdntys from kzbuhixt zjdmoahr sent thursday august     am to mikhghytr wafglhdrhjop subject re ethics collaboration platform site oh sethdyr hdtyr assistant general counsel compliance and real estate global director of ethics compliance ccep
# from mikhghytr wafglhdrhjop sent thursday august     pm to nwfodmhc exurcwkm subject rak fw ethics collaboration platform site please review your recent ticketing tool tickets and let me know who modified the ethics collaboration platform site a few weeks ago i had requested a change that placed a third column of selections not sure who or why this was undone mikhghytr wafglhdrhjop sr manager global ethics and compliance programdntys from  sent thursday august     am to mikhghytr wafglhdrhjop subject re ethics collaboration platform site oh sethdyr hdtyr assistant general counsel compliance and real estate global director of ethics compliance ccep
# ugyothfz ugrmkdhx
# from rakthyesh ramdntythanjesh sent friday august     am to ugyothfz ugrmkdhx cc mikhghytr rhoades subject ticket no no acces to paystub and etime good morning safrgyynjit user called to service desk and requested to expedite the case requesting you to own the issue on priority and assist user on same kind
# from rakthyesh ramdntythanjesh sent friday august     am to  cc mikhghytr rhoades subject ticket no no acces to paystub and etime good morning safrgyynjit user called to service desk and requested to expedite the case requesting you to own the issue on priority and assist user on same kind
# eagvusbr nguqityl
# received from hi team i was going into the ess file and checking some things for the ytd and this is the screen that shows up this is on my report tab when i am logged into vpn please assist in getting this to english eagvusbr nguqityl sales engineer
# received from hi team i was going into the ess file and checking some things for the ytd and this is the screen that shows up this is on my report tab when i am logged into vpn please assist in getting this to english  sales engineer
# pacvbetl yptglhoe
# from pacvbetl yptglhoe sent thursday august     pm to nwfodmhc exurcwkm subject amar fw case id ref case  ref others please see the forwarded email below this looks suspicious to me and may be some sort of phishing or spamming email please review it and let me know if it looks legitimate and is from legitimate individuals at company i did not open or view any of the attachments i have no idea why accounts payable would be sending me an email best
# from  sent thursday august     pm to nwfodmhc exurcwkm subject amar fw case id ref case  ref others please see the forwarded email below this looks suspicious to me and may be some sort of phishing or spamming email please review it and let me know if it looks legitimate and is from legitimate individuals at company i did not open or view any of the attachments i have no idea why accounts payable would be sending me an email best
# hugcadrn ixhlwdgt
# please remove user hugcadrn ixhlwdgt ralfteimp from palo alto quarantine users pc has been replaced
# please remove user  ralfteimp from palo alto quarantine users pc has been replaced
# hbmwlprq ilfvyodx
# ticket update on inc to user hbmwlprq ilfvyodx
# ticket update on inc to user
# mfeyouli ndobtzpw
# name mfeyouli ndobtzpw language browser microsoft internet explorer customer number telephone summary unlock erp account for gadbpfrz unvdyask user name boivin
# name  language browser microsoft internet explorer customer number telephone summary unlock erp account for gadbpfrz unvdyask user name boivin
# gadbpfrz unvdyask
# name  language browser microsoft internet explorer customer number telephone summary unlock erp account for gadbpfrz unvdyask user name boivin
# name  language browser microsoft internet explorer customer number telephone summary unlock erp account for  user name boivin

# %%
df.to_excel('nonsense.xlsx',index=True)

# %%
def removeStopwords(txt):
  text = nlp(txt)
  row =[]
  for tk in text:
    text_details = nlp.vocab[tk.text]
    if tk.text and tk.text.strip():
      flag=False
    else:
      flag = True
    if text_details.is_stop == False and flag == False:
      row.append(tk.text)
  #print(row)
  return ' '.join(row)

# %%
df['Short description'] = df['Short description'].apply(removeStopwords)
df['Description'] = df['Description'].apply(removeStopwords)

# %%
df.to_excel("stopwords.xlsx",index=True)

# %% [markdown]
# **Checking all the misspelled words in the data**
#
# **Below code related to pyenchant will not work in colab**

# %%
# !pip install pyenchant
import enchant
from enchant.checker import SpellChecker
import numpy as np
from collections import defaultdict

# %%
df = pd.read_excel("stopwords.xlsx",index_col=0)

# %%
def createComboColumn(d):
    d['Description'] = np.where(d['Description'].isna(),d['Short description'],d['Description'])
    d['Short description'] = np.where(d['Short description'].isna(),'',d['Short description'])
    d['Combo'] = np.where((d['Short description'] != d['Description']),d['Short description'] + ' ' + d['Description'],d['Description'])
    return d

# %% [markdown]
# No difference between US and UK and words like analyse and analyze are both shortlisted

# %%
chkr_us = SpellChecker("en_US")
chkr_uk = SpellChecker("en_GB")

# %%
error_dictionary = defaultdict()
def createMisspelledDictionary(series,chkr):
    idx=0
    for item in series:
        chkr.set_text(item)
        for err in chkr:
            if err.word in error_dictionary.keys():
                error_dictionary[err.word]+=1
            else:
                error_dictionary[err.word]=1
    return error_dictionary

# %%
crazy_words_dictionary_us = createMisspelledDictionary(df['Combo'],chkr_us)
#crazy_words_dictionary_uk = createMisspelledDictionary(df['Combo'],chkr_uk)

# %% [markdown]
# # The above words can be removed from the data with the exception of the Jargon words below

# %% [markdown]
# **Manually Extracted Words from misspelled list that are sensible and not incorrect**
# # Problem 3 :  Could not find a way to do this in automated way

# %%
import pickle

# %%
jargon = pd.read_pickle("jargon.pkl")
